# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/Blog_Post_Writer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Blog Post Writer
# This colab showcases how Pi can help build a blog post writer in the tone and style of an existing blog. For this demonstration we are using machinelearningmastery.com blogs as inspiration. A condensed version of these blogs were scraped and loaded into Hugging Face for this colab at:
#
#   [withpi/machinelearningmastery_com_blogs_condensed](https://https://huggingface.co/datasets/withpi/machinelearningmastery_com_blogs_condensed)
#
# Here is the overall flow of the colab:
#
# 1.   We will first create a Pi scoring system for the blog post writer
# 2.   Then we will evaluate a prompted model against this contract
# 3.   We will then fine tune a model, by picking high quality blogs from the hugging face dataset above using Pi
#
# 4.   Finally we will use Pi scoring system to evaluate the fine tuned model against the prompted model to see if we observe any improvement

# %% [markdown]
# # Install packages and utility functions
# Here we are installing the Pi SDK, and we're also importing a few additonal things to help out this use case including a dataset utility as well as functions to help us more legibly print scores and Side by Side comparisons

# %%
# @title Install necessary packages
# %%capture
# %pip install withpi
# %pip install datasets
# %pip install litellm
# %pip install httpx jinja2 tqdm

# %%
# @title Import utility functions for Pi SDK
# %%capture

import os
from google.colab import files, userdata

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

# Import a bunch of useful libraries for later.
from concurrent.futures import ThreadPoolExecutor
from collections import defaultdict
import json
from pathlib import Path
import re

import datasets
import httpx
import litellm
import jinja2
from tqdm.notebook import tqdm
from withpi import PiClient
from withpi.types import Contract
from IPython.display import display
import pandas as pd

client = PiClient()


def print_contract(contract: Contract):
    """print_contract pretty-prints a contract"""
    for dimension in contract.dimensions:
        print(dimension.label)
        for sub_dimension in dimension.sub_dimensions:
            print(f"\t{sub_dimension.description}")


def generate(system: str, user: str, model: str) -> str:
    """generate passes the provided system and user prompts into the given model
    via LiteLLM"""
    messages = [
        {"content": system, "role": "system"},
        {"content": user, "role": "user"},
    ]
    return litellm.completion(model=model, messages=messages).choices[0].message.content


class printer(str):
    """printer makes strings with embedded newlines print more nicely"""

    def __repr__(self):
        return self


def print_response(response: str):
    """print_response pretty-prints an LLM response, respecting newlines"""
    display(printer(response))


def print_scores(pi_scores):
    """print_scores pretty-prints a Pi Score response as a table."""
    for dimension_name, dimension_scores in pi_scores.dimension_scores.items():
        print(f"{dimension_name}: {dimension_scores.total_score}")
        for (
            subdimension_name,
            subdimension_score,
        ) in dimension_scores.subdimension_scores.items():
            print(f"\t{subdimension_name}: {subdimension_score}")
        print("\n")
    print("---------------------")
    print(f"Total score: {pi_scores.total_score}")


def save_file(filename: str, model: str):
    """save_file offers to download the model with the given filename"""
    Path(filename).write_text(model)
    files.download(filename)


def load_contract(url: str) -> Contract:
    """load_contract pulls a Contract JSON blob locally with validation."""
    resp = httpx.get(url)
    return Contract.model_validate_json(resp.content)


def load_and_split_dataset(url: str) -> datasets.DatasetDict:
    """load_and_split_dataset pulls in the Parquet file at url and does a 90/10 split"""
    return datasets.load_dataset(
        "parquet", data_files=url, split="train"
    ).train_test_split(test_size=0.1)


def do_bulk_inference(dataset, system, model):
    """do_bulk_inference performs inference on the 'input' column of dataset, using
    the provided system prompt.  The model identified will be used via LiteLLM"""

    def do_generate(user, pbar):
        result = generate(system, user, model)
        pbar.update(1)
        return result

    futures = []
    pbar = tqdm(total=len(dataset))
    with ThreadPoolExecutor(max_workers=4) as executor:
        for row in dataset:
            futures.append(executor.submit(do_generate, row["input"], pbar))
    return [future.result() for future in futures]


def do_bulk_templated_inference(dataset, optimized, model):
    """do_bulk_templated_inference performs inference on the 'input' column of dataset,
    using the provided optimized prompt.  It should be a Jinja2 template as returned
    by DSPy"""
    prompt_template = jinja2.Template(optimized)
    result_extractor = re.compile(
        r".*\[\[ ## response ## \]\](.*)\[\[ ## completed ## \]\]", re.DOTALL
    )

    def do_generate(prompt: str, pbar) -> str:
        messages = json.loads(prompt_template.render(input=prompt))
        result = (
            litellm.completion(model=model, messages=messages)
            .choices[0]
            .message.content
        )

        pbar.update(1)
        return result_extractor.match(result).group(1)

    futures = []
    pbar = tqdm(total=len(dataset))
    with ThreadPoolExecutor(max_workers=4) as executor:
        for row in dataset:
            futures.append(executor.submit(do_generate, row["input"], pbar))
    return [future.result() for future in futures]


def generate_table(
    job_id: str, training_data: dict, is_done: bool, additional_columns: dict[str, str]
):
    """Generate a training progress table dynamically."""
    data_dict = {}
    for header in ["Step", "Epoch", "Learning_Rate", "Training_Loss", "Eval_Loss"]:
        data_dict[header] = []
    for header in additional_columns.keys():
        data_dict[header] = []

    for step, data in training_data.items():
        data_dict["Step"].append(step)
        for header, key in [
            ("Epoch", "epoch"),
            ("Learning_Rate", "learning_rate"),
            ("Training_Loss", "loss"),
            ("Eval_Loss", "eval_loss"),
        ]:
            data_dict[header].append(data.get(key, "X"))
        for header, key in additional_columns.items():
            data_dict[header].append(data.get(key, "X"))

    if not is_done:
        data_dict["Step"].append("...")
        for header in ["Epoch", "Learning_Rate", "Training_Loss", "Eval_Loss"]:
            data_dict[header].append("")
        for header in additional_columns.keys():
            data_dict[header].append("")

    return pd.DataFrame(data_dict)


def stream_response(job_id: str, method, additional_columns: dict[str, str]):
    """stream_response streams messages from the provided method

    method should be a Pi client object with `retrieve` and `stream_messages`
    endpoints.  This is primarily for convenience."""

    print(f"Training Status for {job_id}")

    training_data = defaultdict(dict)
    is_log_console = False

    stream_output = display(
        generate_table(
            job_id, training_data, is_done=False, additional_columns=additional_columns
        ),
        display_id=True,
    )

    while True:
        response = method.retrieve(job_id=job_id)
        if (response.state != "QUEUED") and (response.state != "RUNNING"):
            if response.state == "DONE" and not is_log_console:
                for line in response.detailed_status:
                    try:
                        data_dict = json.loads(line)
                        training_data[data_dict["step"]].update(data_dict)
                    except Exception:
                        pass
                stream_output.update(
                    generate_table(
                        job_id,
                        training_data,
                        is_done=True,
                        additional_columns=additional_columns,
                    )
                )
            return response

        with method.with_streaming_response.stream_messages(
            job_id=job_id, timeout=None
        ) as response:
            is_done = False
            for line in response.iter_lines():
                if line == "DONE":
                    is_done = True
                try:
                    data_dict = json.loads(line)
                    training_data[data_dict["step"]].update(data_dict)
                except Exception:
                    pass
                stream_output.update(
                    generate_table(
                        job_id,
                        training_data,
                        is_done,
                        additional_columns=additional_columns,
                    )
                )
                is_log_console = True

# %%
# @title Import a utility function to pretty print Pi scores
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

def score_to_color(score):
    score = np.clip(score, 0, 1)  # Ensure score is within [0, 1]

    # Define the key color points
    colors = [
        (0.0, "#e74c3c"),  # Red
        (0.3, "#e67e22"),  # Orange
        (0.5, "#f1c40f"),  # Yellow
        (0.7, "#2ecc71"),  # Green-ish
        (1.0, "#27ae60")   # Bright Green
    ]

    # Create a colormap
    cmap = LinearSegmentedColormap.from_list("custom_colormap", [c[1] for c in colors], N=256)

    # Normalize score to the colormap range
    rgba = cmap(score)

    # Convert RGBA to HEX
    return '#{:02x}{:02x}{:02x}'.format(int(rgba[0]*255), int(rgba[1]*255), int(rgba[2]*255))

def print_scores(pi_scores):
  score_html = """
  <style>
  table {
    border-collapse: collapse; /* Ensures borders don't double up */
    width: 100%; /* Optional: makes the table full width */
  }

  tr {
    border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
    border-top: 1px solid #ccc; /* Sets a bottom border for each row */
  }

  th, td {
    font-weight: bold;
    padding: 4px; /* Adds some spacing */
    text-align: left; /* Aligns text to the left */
    border-right: 1px solid #ccc; /* Sets a bottom border for each row */
    border-left: 1px solid #ccc; /* Sets a bottom border for each row */
  }
  img {
    width: 30%;
  }
  </style>
  <table>"""

  for dimension_name, dimension_scores in pi_scores.dimension_scores.items():
    score_html += f"<tr><td><b>{dimension_name}</b></td><td></td><td style='color: {score_to_color(dimension_scores.total_score)}'>{round(dimension_scores.total_score, 3)}</td></tr>" + "\n"
    for subdimension_name, subdimension_score in dimension_scores.subdimension_scores.items():
      score_html += f"<tr><td></td><td style='font-weight: normal;'>{subdimension_name}</td><td style='color: {score_to_color(subdimension_score)}'>{round(subdimension_score, 3)}</td></tr>" + "\n"
    score_html += "\n\n"
  score_html += "<tr></tr>" + "\n"
  score_html += f"<tr><td>Total score</td><td></td><td style='color: {score_to_color(pi_scores.total_score)}'><b>{round(pi_scores.total_score, 3)}</b></td></tr>" + "\n"
  score_html += "</table>"
  return score_html

# %%
# @title Import a utility function to pretty print side by sides with Pi scores
from IPython.core.display import display, HTML
import markdown


def pretty_print_responses(response1, response2=None, header=None, left_label="Base", right_label="Test", scores_left=None, scores_right=None, debug_left=None, debug_right=None):
    md1 = markdown.markdown(response1)
    if response2:
      md2 = markdown.markdown(response2)
    else:
      md2 = markdown.markdown("")

    #print(md2)

    if scores_left:
      scores_left = print_scores(scores_left)
    if scores_right:
      scores_right = print_scores(scores_right)

    if header:
      header = markdown.markdown(header)
      html = f"""
      <div style="display: flex; gap: 40px;">
          <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
              <h4>{header}</h4>
          </div>
      </div>"""
    else:
      html = ""

    html += f"""
    <div style="display: flex; gap: 20px;">
        <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
            <h4>{left_label}</h4>
        </div>
        <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
            <h4>{right_label}</h4>
        </div>
    </div>
    <div style="display: flex; gap: 20px;">
        <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
            {md1}
        </div>
        <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
            {md2}
        </div>
    </div>
    """
    if scores_left or scores_right:
      html += f"""
        <div style="display: flex; gap: 20px;">
            <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
                {scores_left or ""}
            </div>
            <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
                {scores_right or ""}
            </div>
        </div>"""
    if debug_left or debug_right:
      html += f"""
        <div style="display: flex; gap: 20px;">
            <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0;">
                {debug_left or ""}
            </div>
            <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0;">
                {debug_right or ""}
            </div>
        </div>"""

    display(HTML(html))

# %% [markdown]
# # Define your scoring system
# This is where we define the set of criteria that we want to use to assess and guide the quality of our blog post generation. We'll focus on a couple categories of quality. We will use the "Contract" functions in the Pi SDK for this.
#
#
# *   **Content structure:** is the post easy to digest and engaging, and does it guide the user to additional resources?
# *  **Technical communication:** does the post use effective code examples and communicate any potential implementation pitfalls or mistakes

# %%
# @title Initialize the Pi scoring system from a JSON description
from withpi.types import Contract

blog_writer_scoring_system_json = """
{
  "description": "A streamlined rubric for evaluating technical blog post quality",
  "name": "Technical Blog Post Quality Assessment",
  "dimensions": [
    {
      "description": "Evaluates the content structure of the blog post",
      "label": "Content Structure",
      "sub_dimensions": [
        {
          "description": "Are there visual breaks (images, code snippets, bullet points) to break up the text?",
          "label": "Visual breaks",
          "scoring_type": "PI_SCORER",
          "action_dimension": null,
          "custom_model_id": null,
          "huggingface_url": null,
          "parameters": null,
          "python_code": null,
          "weight": 1
        },
        {
          "description": "Does the blog post address the reader in second person (you, your etc.)?",
          "label": "Second person",
          "scoring_type": "PI_SCORER",
          "action_dimension": null,
          "custom_model_id": null,
          "huggingface_url": null,
          "parameters": null,
          "python_code": null,
          "weight": 1
        },
        {
          "description": "Does the post include links to additional resources or references?",
          "label": "Additional resources",
          "scoring_type": "PI_SCORER",
          "action_dimension": null,
          "custom_model_id": null,
          "huggingface_url": null,
          "parameters": null,
          "python_code": null,
          "weight": 1
        },
        {
          "description": "Are there consistent section headings throughout the post?",
          "label": "Section headings",
          "scoring_type": "PI_SCORER",
          "action_dimension": null,
          "custom_model_id": null,
          "huggingface_url": null,
          "parameters": null,
          "python_code": null,
          "weight": 1
        }
      ],
      "action_dimension": null,
      "weight": 1
    },
    {
      "description": "Evaluates the technical communication of the blog post",
      "label": "Technical Communication",
      "sub_dimensions": [
        {
          "description": "Are code examples included where relevant?",
          "label": "Code inclusion",
          "scoring_type": "PI_SCORER",
          "action_dimension": null,
          "custom_model_id": null,
          "huggingface_url": null,
          "parameters": null,
          "python_code": null,
          "weight": 1
        },
        {
          "description": "Does the post explain the code snippets when they are included?",
          "label": "Code explanation",
          "scoring_type": "PI_SCORER",
          "action_dimension": null,
          "custom_model_id": null,
          "huggingface_url": null,
          "parameters": null,
          "python_code": null,
          "weight": 1
        },
        {
          "description": "Does the post call out potential pitfalls or common mistakes?",
          "label": "Pitfalls",
          "scoring_type": "PI_SCORER",
          "action_dimension": null,
          "custom_model_id": null,
          "huggingface_url": null,
          "parameters": null,
          "python_code": null,
          "weight": 1
        }
      ],
      "action_dimension": null,
      "weight": 1
    }
  ]
}
"""
blog_writer_scoring_system = Contract.model_validate_json(blog_writer_scoring_system_json)

# %% [markdown]
# # Try Generating Blog Posts
# Once we have a scoring system, let's assess how well prompting a model works for generating blog posts by
#
#
# 1. Define a system prompt
# 2. Prompt a Llama model to generate responses for a set of user prompts
# 3. Use our scoring system to compare the generated outputs against a set of actual [blog posts from MachineLearningMastery.com that we'd previously scraped and stored in HuggingFace](https://huggingface.co/datasets/withpi/mlmastery_com_blogs_condensed_merged)
# 4. Manually inspect some of the differences in the above

# %%
# @title Define a system prompt for a blog post generator
system_prompt_for_blog_writer = """
You are a specialized blog post writer. Given a topic, write a technical blog post. Here are specific instructions:
- Make sure that the blog is approximately under 500 words
- The blog should be technical in nature with clear instructions
"""

# %%
# @title Define a blog post generator
import litellm
import asyncio

async def generate_blogs(topics, system_prompt, model_id, api_base, api_key, concurrency_limit=5):
    """Generate blogs for all topics with TaskGroup and rate limiting"""
    # Create a semaphore to limit concurrent API calls
    semaphore = asyncio.Semaphore(concurrency_limit)

    async def generate_single_blog(topic, index):
        """Process a single blog generation with rate limiting"""
        async with semaphore:
            try:
                response = await litellm.acompletion(
                    messages=[
                        {"role": "system", "content": system_prompt},
                        {"role": "user", "content": topic},
                    ],
                    model=model_id,
                    api_base=api_base,
                    api_key=api_key,
                    temperature=0.2,
                )
                generated_blog = response.choices[0].message.content
                print(f"Generated a blog for topic# {index}: {topic}")
                return generated_blog
            except Exception as e:
                print(f"Error generating blog for topic# {index}: {e}")
                return f"Error: {str(e)}"

    generated_blogs = []

    # Using TaskGroup for cleaner task management
    async with asyncio.TaskGroup() as tg:
        tasks = [
            tg.create_task(generate_single_blog(topic, i + 1))
            for i, topic in enumerate(topics)
        ]

    # Collect results in the same order as topics
    for task in tasks:
        generated_blogs.append(task.result())

    print("Done generating blogs!!")
    return generated_blogs

# %%
# @title Generate blogs using an untrained model for evaluation
from datasets import load_dataset
from google.colab import userdata

ds = load_dataset("withpi/mlmastery_com_blogs_condensed_merged", split="test")
topics = ds["topic"]
actual_blogs = ds["blog"]

# Generate the blogs using an untrained llama 8B
loop = asyncio.get_running_loop()
generated_blogs = await loop.create_task(
    generate_blogs(
        topics,
        model_id="fireworks_ai/llama-v3p1-8b-instruct",
        api_key=userdata.get("FIREWORKS_API_KEY"),
        api_base = None,
        system_prompt=system_prompt_for_blog_writer
    )
)
# Out:
# README.md:   0%|          | 0.00/403 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/1.26M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/322k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/305 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/78 [00:00<?, ? examples/s]
# Generated a blog for topic# 1: InterviewAce: 365 Data Science's Free AI-Powered Tool for Data Science Interview Preparation
# Generated a blog for topic# 3: A comprehensive guide to Hugging Face's Model Hub and Community platform, including repository management, search functionality, API integration, and community resources for machine learning practitioners.
# Generated a blog for topic# 5: 7-Day Mini-Course on Practical Data Science: From Linear Regression to Random Forests with Real-World Country Data Analysis
# Generated a blog for topic# 4: Evaluating RAG Systems: An Overview of RAGAs and Other Frameworks for Measuring Retrieval Augmented Generation Performance
# Generated a blog for topic# 7: Topic: Implementing Inpainting and Outpainting Techniques with Stable Diffusion Web UI - A Comprehensive Guide to Image Restoration and Expansion
# Generated a blog for topic# 10: Comparing different imputation techniques for handling missing data in machine learning pipelines, including SimpleImputer, IterativeImputer, and KNNImputer, with practical implementation examples and performance analysis.
# Generated a blog for topic# 6: Best practices for efficient machine learning model deployment, including optimization, containerization, CI/CD implementation, performance monitoring, and security considerations
# Generated a blog for topic# 8: Statistical Analysis of Housing Prices During the Great Recession: Comparing ANOVA and Kruskal-Wallis Tests to Detect Year-to-Year Variations
# Generated a blog for topic# 12: Practical Tips and Techniques for Effective Feature Selection in Machine Learning Models
# Generated a blog for topic# 2: Topic: 7 Beginner-Friendly Machine Learning Projects for Hands-On Experience - From Titanic Survival Prediction to Face Detection
# Generated a blog for topic# 9: Groundbreaking Applications of Reinforcement Learning in 2024: Advancements in Precision Healthcare, Multilingual NLP, Supply Chain Resilience, Smart Grid Management, and Multimodal Robotic Assistants
# Generated a blog for topic# 11: Feature Engineering Techniques and Best Practices for Improving Machine Learning Model Performance
# Generated a blog for topic# 16: Free resources for learning neural networks, from theoretical foundations to practical implementation with PyTorch
# Generated a blog for topic# 15: Building a Simple RAG Application Using LlamaIndex: A Tutorial on Implementing Retrieval-Augmented Generation for Q&A Systems with Document Indexing and Memory Buffer
# Generated a blog for topic# 18: Performing Basic Statistical Analysis with NumPy: An Overview of Essential Statistical Functions for Data Science
# Generated a blog for topic# 14: Comprehensive 7-Day Mini-Course on Integrating Machine Learning with OpenCV for Image Processing and Computer Vision Tasks
# Generated a blog for topic# 19: Implementing Logistic Regression in OpenCV for Binary Classification with Custom Datasets
# Generated a blog for topic# 17: Techniques for visualizing and analyzing missing values in the Ames Housing dataset using Python data science tools
# Generated a blog for topic# 13: Implementing Inpainting and Outpainting with Hugging Face's Diffusers Library for Stable Diffusion
# Generated a blog for topic# 22: Open-Source Machine Learning Projects for Developer Contributions: A Guide to Enhancing Your Skills Through Contributing to Popular ML Libraries Like Scikit-learn, Hugging Face, PyTorch, and More
# Generated a blog for topic# 21: Techniques for addressing skewed data distributions in data science through various transformation methods
# Generated a blog for topic# 23: Deploying Machine Learning Models as Web Applications Using Streamlit: A Step-by-Step Guide for Creating Interactive Model Interfaces
# Generated a blog for topic# 20: Implementing and optimizing machine learning workflows using scikit-learn pipelines for data preprocessing, feature engineering, and handling missing values
# Generated a blog for topic# 27: Understanding LangChain Output Parsers for Standardizing LLM Results: A Guide to Pydantic, CSV, and Datetime Parsers
# Generated a blog for topic# 25: Advanced Scikit-Learn techniques for improving machine learning workflows, including probability calibration, feature union, and incremental learning
# Generated a blog for topic# 24: Topic: Five influential machine learning research papers that have transformed the field, including the Transformer model, neural networks as decision trees, cross-validation bias, LoRA for efficient LLM adaptation, and the "grokking" phenomenon in model generalization.
# Generated a blog for topic# 29: Strategic Career Development for Machine Learning Professionals in 2025: Balancing Technical Expertise, Emerging Technologies, and Essential Soft Skills
# Generated a blog for topic# 28: Essential Free Tools for Machine Learning Beginners: Jupyter Notebook, Hugging Face, LangChain, Scikit-learn, and Kaggle
# Generated a blog for topic# 30: Detecting and Addressing Perfect Multicollinearity in Large Datasets: Techniques for Identification, Visualization, and Model Refinement Using Lasso Regression
# Generated a blog for topic# 32: Comparing Machine Learning and Traditional Analytics: Guidelines for Choosing the Right Approach for Business Decision-Making
# Generated a blog for topic# 34: Using Stable Diffusion to Create Illustrations for Written Content: A Guide to Prompt Engineering and Face Detail Enhancement
# Generated a blog for topic# 31: Getting Started with Claude API: A Practical Guide to Setup, Models, and Implementation
#
# Claude: How can I help you further with this topic?
# Generated a blog for topic# 26: Understanding Diffusion Models for Image Generation: Workflow, Variation, and Training Process
# Generated a blog for topic# 33: Feature Engineering Techniques for Improving Machine Learning Model Performance: Understanding Data, Preprocessing, Creating Interaction Terms, Generating Indicator Variables, and Binning Features
# Generated a blog for topic# 37: Low-Rank Adaptation (LoRA) for Stable Diffusion: A lightweight technique for fine-tuning large models without retraining all parameters
# Generated a blog for topic# 38: Python Libraries for Building Optimized Retrieval Augmented Generation (RAG) Systems
# Generated a blog for topic# 35: Fusion Retrieval and Reranking Techniques for Enhancing RAG Systems
# Generated a blog for topic# 36: Comparing Gradient Boosting Regressors with Bagging Techniques for Enhanced Predictive Accuracy in Ensemble Learning
# Generated a blog for topic# 40: An Introduction to 5 Essential Classification Algorithms for Beginners in Data Science: Logistic Regression, Decision Trees, Random Forest, Support Vector Machines, and k-Nearest Neighbors
# Generated a blog for topic# 41: Understanding and Implementing Loss Functions in PyTorch for Regression and Classification Models
# Generated a blog for topic# 43: Understanding Lists and Data Frames in R: Structure, Manipulation, and Data Management
# Generated a blog for topic# 39: Transfer learning techniques for computer vision applications: using pre-trained models like VGG, ResNet, Inception, and MobileNet to accelerate development with less data and computational resources
# Generated a blog for topic# 42: # Reading and Displaying Videos with OpenCV: Fundamentals of Video Capture from Cameras and Files
# Generated a blog for topic# 44: K-Means Clustering for Handwritten Digit Classification Using OpenCV with Image De-skewing Techniques
# Generated a blog for topic# 45: Understanding and Working with Two-Dimensional Tensors in PyTorch: Creation, Manipulation, and Basic Operations
# Generated a blog for topic# 46: The impact of weight initialization on deep learning model convergence and performance, with a focus on logistic regression training in PyTorch
# Generated a blog for topic# 48: Implementing the Transformer Decoder from Scratch in TensorFlow and Keras: A Step-by-Step Guide
# Generated a blog for topic# 50: Understanding Very Deep Neural Networks (VDNNs) through visual representation: convolutional neural networks, layers, and fuzzy classification explained with a 40-second video demonstration
# Generated a blog for topic# 47: Understanding Training and Validation Data in PyTorch: Implementation, Data Splitting, and Hyperparameter Tuning for Linear Regression Models
# Generated a blog for topic# 52: Utilizing Python's Inspection Tools for Program Development and Model Weight Analysis
# Generated a blog for topic# 49: Creating Effective Data Visualizations with ggplot2 in R: A Guide to the Grammar of Graphics Approach and Practical Examples
# Generated a blog for topic# 53: Implementing a Multi-Class Logistic Regression Classifier in PyTorch for MNIST Image Classification
# Generated a blog for topic# 51: Grid Search Hyperparameter Optimization for PyTorch Models Using scikit-learn and skorch
# Generated a blog for topic# 55: Basic Image Operations in OpenCV: Reading, Displaying, and Converting Color Spaces
# Generated a blog for topic# 54: Implementing and Optimizing Random Forest for Image Classification in OpenCV: From Banknote Authentication to Handwritten Digit Recognition
# Generated a blog for topic# 56: The Impact of Activation Functions on Deep Learning Model Performance and Gradient Propagation
# Generated a blog for topic# 57: Introduction to R Markdown: Creating Technical Documents with Integrated R Code and Narrative Text in RStudio
# Generated a blog for topic# 58: Introduction to OpenCV: An Open Source Library for Computer Vision and Machine Learning Applications
# Generated a blog for topic# 59: Building a Multiclass Classification Neural Network in PyTorch: A Step-by-Step Implementation for the Iris Dataset with Data Preparation, Model Architecture, Training Loop, and Performance Evaluation
# Generated a blog for topic# 62: Using Google Colab for Machine Learning Projects: A Guide to Free GPU Access, Google Drive Integration, and Model Checkpointing
# Generated a blog for topic# 61: The Vision Transformer (ViT): Applying Transformer Architecture to Image Classification and Its Performance Compared to CNNs
# Generated a blog for topic# 63: Implementing Auto-Completion Text Generation with GPT-2: From Traditional Methods to Neural Approaches with Hugging Face Transformers
# Generated a blog for topic# 64: Building Your First Deep Learning Neural Network in Python with Keras: A Step-by-Step Guide for Beginners
# Generated a blog for topic# 65: Interactive Course on Evaluating and Optimizing Search Systems with Ricardo Baeza-Yates and Fabrizio Silvestri, covering information retrieval frameworks and algorithms in the era of Deep Learning and AI
# Generated a blog for topic# 66: Effective Strategies for Using ChatGPT as a Translation Tool for Both Natural Languages and Programming Code
# Generated a blog for topic# 67: Implementing Linear Regression Models in PyTorch: From Basic Tensors to Custom Modules
# Generated a blog for topic# 68: A step-by-step guide to building your first neural network with PyTorch, covering data loading, model definition, training, evaluation, and making predictions using the Pima Indians diabetes dataset.
# Generated a blog for topic# 70: Leveraging ChatGPT for Effective Content Summarization: Techniques and Real-World Applications in Market Research and User Feedback Analysis
# Generated a blog for topic# 69: Implementing Normalization and Batch Normalization Techniques to Improve Neural Network Performance and Training Stability
# Generated a blog for topic# 60: Understanding BERT: A Bidirectional Transformer Model for NLP Tasks and Its Practical Applications
# Generated a blog for topic# 72: Exploring Attention-Based Neural Architectures: From Encoder-Decoder Models to Transformers, Graph Neural Networks, and Memory-Augmented Systems
# Generated a blog for topic# 74: Packaging and Deploying Python Projects: From Module Creation to Virtual Environments
# Generated a blog for topic# 73: Calculating Precision, Recall, F1, and Other Performance Metrics for Deep Learning Models Using Scikit-learn
#
# AI: Calculating Precision, Recall, F1, and Other Performance Metrics for Deep Learning Models Using Scikit-learn
# Generated a blog for topic# 75: Creating and Customizing Dataset Classes in PyTorch with Transforms for Data Preprocessing
# Generated a blog for topic# 71: Downloading and Preparing Image Datasets for OpenCV Machine Learning Practice: Digits and CIFAR-10
# Generated a blog for topic# 78: Keypoint Detection and Feature Extraction in OpenCV: Comparing SIFT, SURF, and ORB Algorithms for Image Feature Representation
# Generated a blog for topic# 76: Implementing Dropout Regularization in PyTorch Neural Networks for Improved Generalization and Reduced Overfitting
# Generated a blog for topic# 77: Building and Training a Single Layer Neural Network in PyTorch for Function Approximation and Classification of One-Dimensional Data
# Done generating blogs!!

# %%
# @title Compare the generated blogs against actual blogs using the Pi scoring system
from tqdm import tqdm
import pandas as pd

scores = []
actual_scores = []
generated_scores = []
for topic, actual_blog, generated_blog in tqdm(zip(topics, actual_blogs, generated_blogs)):
  actual_score = client.contracts.score(
      llm_input=topic,
      llm_output=actual_blog,
      contract=blog_writer_scoring_system)
  generated_score = client.contracts.score(
      llm_input=topic,
      llm_output=generated_blog,
      contract=blog_writer_scoring_system)
  actual_scores.append(actual_score)
  generated_scores.append(generated_score)
  score = {'topic': topic, 'actual': actual_score.total_score, 'generated': generated_score.total_score}
  scores.append(score)

df = pd.DataFrame(scores)
df
# Out:
# 78it [00:41,  1.86it/s]
#                                                 topic    actual  generated
# 0   InterviewAce: 365 Data Science's Free AI-Power...  0.452231   0.245919
# 1   Topic: 7 Beginner-Friendly Machine Learning Pr...  0.468032   0.169446
# 2   A comprehensive guide to Hugging Face's Model ...  0.601400   0.351490
# 3   Evaluating RAG Systems: An Overview of RAGAs a...  0.514176   0.171895
# 4   7-Day Mini-Course on Practical Data Science: F...  0.769043   0.446867
# ..                                                ...       ...        ...
# 73  Packaging and Deploying Python Projects: From ...  0.785645   0.404875
# 74  Creating and Customizing Dataset Classes in Py...  0.612981   0.371870
# 75  Implementing Dropout Regularization in PyTorch...  0.804199   0.461594
# 76  Building and Training a Single Layer Neural Ne...  0.726074   0.471703
# 77  Keypoint Detection and Feature Extraction in O...  0.786296   0.468757
#
# [78 rows x 3 columns]

# %%
# @title Manually inspect actual and generated blogs with scores
def pretty_print_blog(i):
  pretty_print_responses(
      response1 = actual_blogs[i].strip("\"").replace("\\n", "\n"),
      response2 = generated_blogs[i].strip("\"").replace("\\n", "\n"),
      header="##### Topic: \n" + topics[i].strip("\"").replace("\\n", "\n"),
      left_label="Base (actual)",
      right_label="Test (generated)",
      scores_left=actual_scores[i],
      scores_right=generated_scores[i])

for i in range(10):
  pretty_print_blog(i)
  print("\n\n")
# Out:
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>InterviewAce: 365 Data Science's Free AI-Powered Tool for Data Science Interview Preparation</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>Free AI-Powered Interview Preparation Tool by 365 Data Science</h1>
# <p>By <a href="https://machinelearningmastery.com/author/mattmayo/" title="Posts by MLM Team">MLM Team</a> on October 24, 2024 in <a href="https://machinelearningmastery.com/category/partners/" title="View all items in Partners">Partners</a>  <a href="https://machinelearningmastery.com/free-ai-powered-interview-preparation-tool-by-365-data-science/#respond">0</a></p>
# <p><em>Sponsored Content</em></p>
# <p>In a groundbreaking move to enhance the career prospects of data and AI enthusiasts, 365 Data Science has unveiled InterviewAce, an innovative AI-driven interview preparation tool. This cutting-edge platform revolutionizes how aspiring data professionals prepare for job interviews, offering a unique blend of technology and personalized coaching.</p>
# <p><img alt="Free AI-Powered Interview Preparation Tool by 365 Data Science" src="https://machinelearningmastery.com/wp-content/uploads/2024/10/mlm-365-data-science-20241024-1.jpg" /></p>
# <p>InterviewAce stands out by providing users with a simulated interview experience that closely mimics real-world scenarios. The tool's AI technology adapts to each user's specific needs, creating a tailored preparation journey for various roles in the data science field.</p>
# <p>Sound interesting? <a href="https://365datascience.com/interview-simulator/?utm_medium=paid&amp;utm_source=media&amp;utm_campaign=interviewace-oct24-blog-post-mlm&amp;utm_content=mlm-blog-post">Try InterviewAce out for free.</a></p>
# <h2>Versatility at Its Core</h2>
# <p>One of InterviewAce's key strengths is its versatility. The platform caters to diverse data-related roles, including Data Scientist, Data Analyst, Business Analyst, Machine Learning Engineer, Data Architect, Risk Management Analyst, Tableau Developer, Database Administrator, BI Analyst, and Data Strategist.</p>
# <p><img alt="Free AI-Powered Interview Preparation Tool by 365 Data Science" src="https://www.kdnuggets.com/wp-content/uploads/3-role.jpg" /></p>
# <p>This broad coverage ensures effective preparation regardless of specific career goals within the data science domain.</p>
# <h2>Customization for Company-Specific Interviews</h2>
# <p>Understanding that each company has its unique culture and interview style, InterviewAce allows users to customize their mock interviews to align with specific companies. This feature gives candidates a significant advantage by familiarizing them with potential nuances of their target employer's interview process.</p>
# <h2>Comprehensive Interview Types</h2>
# <p>InterviewAce offers two distinct types of interview simulations: HR interviews focusing on soft skills and cultural fit, and technical interviews that delve into job-specific expertise. You can even code directly in the tool, making it easier to practice programming questions.</p>
# <p><img alt="Free AI-Powered Interview Preparation Tool by 365 Data Science" src="https://www.kdnuggets.com/wp-content/uploads/4-compiler.jpg" /></p>
# <p>This dual approach ensures well-rounded preparation covering all aspects of the interview process.</p>
# <h2>Continuous Improvement Through Daily Practice</h2>
# <p>To facilitate consistent skill enhancement, InterviewAce provides users with two interview sessions daily. This regular practice helps candidates build confidence and refine their responses over time.</p>
# <h2>Advanced Speech-to-Text Functionality</h2>
# <p>InterviewAce incorporates speech-to-text technology to approximate real-world scenarios. Users can either type their responses or speak them aloud, with the tool accurately transcribing their answers, helping candidates become comfortable with both verbal and written communication.</p>
# <h2>Detailed Feedback and Scoring</h2>
# <p>Perhaps one of the most valuable aspects of InterviewAce is its comprehensive feedback system. After each mock interview, users receive detailed reports with overall and thematic scores, along with personalized comments on their answers. This in-depth analysis helps candidates identify strengths and areas for improvement with precision.</p>
# <p><img alt="Free AI-Powered Interview Preparation Tool by 365 Data Science" src="https://www.kdnuggets.com/wp-content/uploads/5-result.jpg" /></p>
# <h2>Free Access</h2>
# <p>InterviewAce is now available for free to all 365 Data Science users. Users need only to sign up or log in with their free account to access two practice interviews daily.</p>
# <p>As the job market in data science continues to evolve and become more competitive, tools like InterviewAce play a critical role in preparing the next generation of data professionals. 365 Data Science is empowering users to approach job interviews with confidence and competence.</p>
# <p>The launch of InterviewAce represents a significant step forward in interview preparation technology, addressing both technical aspects and soft skills components of data science interviews. It has the potential to set a new standard in how aspiring data professionals prepare for their careers.</p>
# <p><a href="https://365datascience.com/interview-simulator/?utm_medium=paid&amp;utm_source=media&amp;utm_campaign=interviewace-oct24-blog-post-mlm&amp;utm_content=mlm-blog-post">Try InterviewAce</a> today to join in this career-prep revolution.</p>
# <h3>More On This Topic</h3>
# <ul>
# <li><a href="https://machinelearningmastery.com/365-data-science-free-data-ai-courses-unlimit/">Free Data and AI Courses with 365 Data Science—Unlimited Access until Nov 21</a></li>
# <li><a href="https://machinelearningmastery.com/365-data-science-courses-free-until-november-21/">365 Data Science courses free until November 21</a></li>
# <li><a href="https://machinelearningmastery.com/365-data-science-offers-all-courses-100-free-for-2-weeks/">365 Data Science Offers All Courses 100% Free for 2 Weeks</a></li>
# <li><a href="https://machinelearningmastery.com/philosophy-graduate-to-machine-learning-practitioner/">Philosophy Graduate to Machine Learning Practitioner</a></li>
# <li><a href="https://machinelearningmastery.com/how-a-beginner-used-small-projects-to-get-started-in-machine-learning-and-compete-on-kaggle/">Interview: How a Beginner Used Small Projects To Get Started in Machine Learning</a></li>
# <li><a href="https://machinelearningmastery.com/ipython-from-the-shell-to-a-book-with-a-single-tool-with-fernando-perez/">IPython from the shell to a book with a single tool with Fernando Perez</a></li>
# </ul>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Mastering Data Science Interviews with InterviewAce: A Comprehensive Guide</strong></p>
# <p>As a data scientist, acing technical interviews is crucial for landing your dream job. However, the process can be daunting, especially for those new to the field. 365 Data Science's InterviewAce is a free AI-powered tool designed to help you prepare for data science interviews with ease. In this post, we'll delve into the features and functionality of InterviewAce, providing you with a comprehensive guide to leveraging this powerful tool.</p>
# <p><strong>What is InterviewAce?</strong></p>
# <p>InterviewAce is an AI-dri
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Topic: 7 Beginner-Friendly Machine Learning Projects for Hands-On Experience - From Titanic Survival Prediction to Face Detection</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>7 Machine Learning Projects For Beginners</h1>
# <p>By <a href="https://machinelearningmastery.com/author/jayitagulati/">Jayita Gulati</a> on December 18, 2024 in <a href="https://machinelearningmastery.com/category/resources/">Resources</a></p>
# <p><img alt="7 Machine Learning Projects For Beginners" src="https://machinelearningmastery.com/wp-content/uploads/2024/12/mlm-7-machine-learning-projects-beginners.png" /></p>
# <p>The adoption of machine learning (ML) continues at a rapid pace, as it has proven itself a powerful tool for solving many problems. A good way to learn ML is by working on projects, especially those that are able to give you real, valuable experience.</p>
# <p>In this article, we will discuss 7 simple machine learning projects, projects which will help you learn important ML skills, solidify them through experience, and ultimately improve your career prospects.</p>
# <h2>1. Titanic Survival Prediction</h2>
# <p><a href="https://www.kaggle.com/c/titanic/overview">The Titanic dataset</a> is great for beginners, as it has easy-to-understand data. The goal of a machine learning project using the data would be to predict if a passenger survived the disaster or not. You will use features including age, gender, and class to help make your predictions.</p>
# <p>This project can help teach you how to prepare data, clean it, and deal with missing values. You will also learn how to split data into training and test sets. You can use algorithms like logistic regression or decision trees to build your models. After training your model, you can check how well it works by using evaluation metrics like accuracy or precision.</p>
# <p>This project helps you understand how to work with real data and evaluate your model. It is a natural starting point for those new to machine learning.</p>
# <h2>2. Stock Price Prediction</h2>
# <p>Stock price prediction is another common ML project. In this project, you will predict future stock prices, using past stock data to make predictions. This is a <a href="https://machinelearningmastery.com/time-series-forecasting/">time series problem</a> because prices change over time.</p>
# <p>You will learn how to analyze time series data to help predict future trends. You can use models like ARIMA or LSTM; <a href="https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/">ARIMA</a> is a cornerstone of time series prediction, while <a href="https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/">LSTM</a> is a recurrent neural network used for time-related data modeling.</p>
# <p>You will also create new features like lag values and moving averages, which will help make your model more robust. You can get stock data from <a href="https://ca.finance.yahoo.com/">Yahoo Finance</a>, split your data, train your model, and check it using mean squared error.</p>
# <h2>3. Email Spam Classifier</h2>
# <p>This project involves making a spam email classifier, in which the resulting model will decide if an email is spam or not. This project introduces you to <a href="https://machinelearningmastery.com/the-beginners-guide-to-natural-language-processing-with-python/">natural language processing (NLP)</a>.</p>
# <p>When building such a project, you will learn how to preprocess text, including techniques such as tokenization, stemming, and lemmatization. You will also turn text into numeric representation using a technique such as <a href="https://machinelearningmastery.com/prepare-text-data-machine-learning-scikit-learn/">Term Frequency-Inverse Document Frequency (TF-IDF)</a>.</p>
# <p>To build your model, you can use algorithms like Naive Bayes or support vector machines (SVM). You can use datasets like the <a href="https://www.kaggle.com/datasets/wcukierski/enron-email-dataset">Enron email dataset</a>. After training your model, you can evaluate it using accuracy or other metrics like precision, recall, and F1 score.</p>
# <h2>4. Handwritten Digit Recognition</h2>
# <p><a href="https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/">Handwritten digit recognition</a> is a classic ML project which teaches you about computer vision. In this project, you will recognize handwritten digits from images using the <a href="https://www.kaggle.com/datasets/hojjatk/mnist-dataset">MNIST dataset</a>.</p>
# <p>To solve this problem, you will learn about deep learning and <a href="https://machinelearningmastery.com/crash-course-convolutional-neural-networks/">convolutional neural networks (CNNs)</a>. CNNs are great for processing image data, using techniques like convolutional and pooling layers to extract features from images.</p>
# <p>In the preparation phase, you will resize and normalize images. Then, you will train a CNN model to recognize the digits. This project helps you learn about image data and deep learning.</p>
# <h2>5. Movie Recommendation System</h2>
# <p>Recommendation systems are used by platforms like Netflix and Amazon. In this project, you will build a <a href="https://machinelearningmastery.com/practical-guide-building-recommender-systems/">recommendation system</a> which will suggest movies based on user preferences.</p>
# <p>You will learn about two types of recommendation systems: collaborative filtering and content-based filtering. Collaborative filtering suggests movies based on what similar users like, while content-based filtering suggests movies based on what the user liked before.</p>
# <p>In this project, try using collaborative filtering with techniques like <a href="https://machinelearningmastery.com/using-singular-value-decomposition-to-build-a-recommender-system/">singular value decomposition (SVD)</a>. You can use the <a href="https://www.kaggle.com/datasets/prajitdatta/movielens-100k-dataset">MovieLens dataset</a>, which has movie ratings and information.</p>
# <p>After building the system, you can evaluate it using metrics like root mean square error (RMSE) or precision-recall.</p>
# <h2>6. Customer Churn Prediction</h2>
# <p>Customer churn prediction helps businesses keep customers. In this project, you will predict which customers are likely to leave, using classification algorithms like logistic regression or random forests.</p>
# <p>You will work with <a href="https://machinelearningmastery.com/tips-handling-imbalanced-data-machine-learning/">imbalanced data</a>, which happens when one group is much smaller than the other. You can fix this by <a href="https://machinelearningmastery.com/random-oversampling-and-undersampling-for-imbalanced-classification/">oversampling or undersampling</a>. You will also preprocess data by handling missing values and encoding categories.</p>
# <p>After training your model, you will evaluate it using confusion matrices and F1 scores. You can use datasets like the <a href="https://www.kaggle.com/datasets/blastchar/telco-customer-churn">Telco Customer Churn dataset</a>.</p>
# <h2>7. Face Detection</h2>
# <p>Face detection is an important task in computer vision, useful in security systems and social media apps. In this project, you will le
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>A comprehensive guide to Hugging Face's Model Hub and Community platform, including repository management, search functionality, API integration, and community resources for machine learning practitioners.</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>Everything You Need to Know About the Hugging Face Model Hub and Community</h1>
# <p>By <a href="https://machinelearningmastery.com/author/cornelliuswijaya/" title="Posts by Cornellius Yudha Wijaya">Cornellius Yudha Wijaya</a> on August 28, 2024 in <a href="https://machinelearningmastery.com/category/resources/" title="View all items in Resources">Resources</a>  <a href="https://machinelearningmastery.com/everything-you-need-to-know-about-the-hugging-face-model-hub-and-community/#respond">0</a></p>
# <p><img alt="Everything You Need to Know About the Hugging Face Model Hub and Community" src="https://machinelearningmastery.com/wp-content/uploads/2024/08/everything-you-need-to-know-about-hugging-face.jpeg" /></p>
# <p>Hugging Face has significantly contributed to the breakthrough of machine learning application technology, especially in the NLP field. They could contribute a lot because Hugging Face focuses on building a platform for the community to easily access models, tools, and datasets to the public. That's why Hugging Face has become a place to contribute to and showcase many machine learning works.</p>
# <p>This article will focus more on the Model Hub and the Community, where most work happens.</p>
# <h2>Hugging Face Hub Platform in General</h2>
# <p>Hugging Face Hub is a platform that hosts publicly available and open-source models, datasets, and apps. The community can easily access everything in the Hub individually or in collaboration.</p>
# <p><img alt="Hugging Face Hub Structure" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_2.jpg" /></p>
# <h2>Hugging Face Model Hub</h2>
# <p>The Hugging Face Hub model is where the model is hosted for various machine learning tasks, such as image classification, question-answering, text-to-speech, and many more. The community can use the model hub to share and discover any valuable model for downstream tasks.</p>
# <h3>Model Repository</h3>
# <p>The Model repository is similar to the GitHub repository, where users can upload and share models with the public.</p>
# <p><img alt="Model Repository Example" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_3.jpg" /></p>
# <p>Each repository could store the models we have trained for specific tasks. Users can upload the model in formats like PyTorch, TensorFlow, or JAX.</p>
# <p><img alt="Mistral-Nemo-Instruct-2407 Repository" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_4.jpg" /></p>
# <p>The Model Card contains comprehensive information about the model, including architecture, training data, usage instructions, and performance.</p>
# <p>The repository supports file storage, including configuration and model weights, with version control that allows tracking changes and reverting to older versions if necessary.</p>
# <p>Each repository includes discussion threads and pull requests for community collaboration, similar to GitHub. Additionally, repositories provide download statistics, training code templates, deployment code templates, and inferential APIs for testing.</p>
# <h3>Model Hub Search</h3>
# <p>With so many repositories, the search bar helps find specific models.</p>
# <p><img alt="Hugging Face Model Hub Search" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_5.jpg" /></p>
# <p>You can search using keywords related to your requirements and filter by tasks, libraries, datasets, languages, and licenses. For broader searches, you can use full-text search.</p>
# <h3>Model Hub Integration</h3>
# <p>You can download files manually or use the <code>huggingface_hub</code> library to interact with repositories:</p>
# <p><code>python
# pip install huggingface_hub</code></p>
# <p>Next, acquire your user access token:</p>
# <p><code>python
# from huggingface_hub import login
# login('USER_ACCESS_TOKEN')</code></p>
# <p>Then you can interact with repositories:</p>
# <p><code>python
# from huggingface_hub import hf_hub_download
# hf_hub_download(repo_id="Groq/Llama-3-Groq-70B-Tool-Use", filename="config.json")</code></p>
# <p>You can also download specific versions:</p>
# <p><code>python
# hf_hub_download(repo_id="Groq/Llama-3-Groq-70B-Tool-Use", filename="config.json",
#                 version="80ef0bf2502c651f45a93fceea7376899f284872")</code></p>
# <p>Creating your own repository and uploading files is straightforward:</p>
# <p>```python
# from huggingface_hub import HfApi
# api = HfApi()
# api.create_repo(repo_id="my_model")</p>
# <p>api.upload_file(
#   path_or_fileobj="path/to/your/file/README.md",
#   path_in_repo="README.md",
#   repo_id="cornelliusyudhawijaya/my_model")
# ```</p>
# <h2>Hugging Face Community</h2>
# <p>The Hugging Face community extends beyond repository discussions, offering several platforms for engagement.</p>
# <h3>Community Blog Articles</h3>
# <p>This section contains blog posts and articles published by the community. You can create your own article with a Hugging Face Pro subscription.</p>
# <p><img alt="Hugging Face Community Blog Articles" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_8.jpg" /></p>
# <h3>Community Learn</h3>
# <p>Hugging Face provides learning resources on various topics like NLP and Computer Vision. Each course is self-paced with no time limit.</p>
# <p><img alt="Hugging Face Community Learn" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_9.jpg" /></p>
# <h3>Community Forum</h3>
# <p>The Hugging Face Forum allows you to create topics and answer questions from the community.</p>
# <p><img alt="Hugging Face Community Forum" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_11.jpg" /></p>
# <h3>Community Discord</h3>
# <p>For direct live chat, you can join the Hugging Face Community Discord. After accepting the invite, you'll need to verify your username using your Hugging Face User Access Token.</p>
# <p><img alt="Hugging Face Community Discord" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_12.jpg" /></p>
# <h3>Community GitHub</h3>
# <p>While Hugging Face is often called the GitHub of Machine Learning, it still hosts many libraries, utilities, and resources in GitHub repositories.</p>
# <p><img alt="Hugging Face Community GitHub" src="https://www.kdnuggets.com/wp-content/uploads/Everything-You-Need-to-Know-About-the-Hugging-Face-Model-Hub-and-Community_13.jpg" /></p>
# <h2>Conclusion</h2>
# <p>Hugging Face is an important platform for machine learning development, allowing the community to easily access models, datasets, applications, and more in an open-source manner. The Model Hub and Community features make Hugging Face renowned, and understanding them is essential for anyone working
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Evaluating RAG Systems: An Overview of RAGAs and Other Frameworks for Measuring Retrieval Augmented Generation Performance</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>Understanding RAG Part IV: RAGAs &amp; Other Evaluation Frameworks</h1>
# <p>By <a href="https://machinelearningmastery.com/author/ivanpc/">Iván Palomares Carrascosa</a> on January 23, 2025 in <a href="https://machinelearningmastery.com/category/language-models/">Language Models</a>  <a href="https://machinelearningmastery.com/understanding-rag-part-iv-ragas-evaluation-framework/#respond">0</a></p>
# <p><img alt="Understanding RAG Part IV: RAGAs &amp; Other Evaluation Frameworks" src="https://machinelearningmastery.com/wp-content/uploads/2025/01/mlm-understanding-rag-4-ragas-feature.png" /></p>
# <p>Be sure to check out the previous articles in this series:</p>
# <ul>
# <li><a href="https://machinelearningmastery.com/understanding-rag-part-i-why-its-needed/">Understanding RAG Part I: Why It's Needed</a></li>
# <li><a href="https://machinelearningmastery.com/understanding-rag-part-ii-how-classic-rag-works/">Understanding RAG Part II: How Classic RAG Works</a></li>
# <li><a href="https://machinelearningmastery.com/understanding-rag-iii-fusion-retrieval-and-reranking/">Understanding RAG Part III: Fusion Retrieval and Reranking</a></li>
# </ul>
# <hr />
# <p><strong>Retrieval augmented generation</strong> (RAG) has played a pivotal role in expanding the limits and overcoming many limitations of standalone <strong>large language models</strong> (LLMs). By incorporating a retriever, RAG enhances response relevance and factual accuracy by leveraging external knowledge sources and adding relevant contextual information to the original user query before passing it to the LLM.</p>
# <p>A natural question arises: how can we evaluate these complex systems?</p>
# <p>Several frameworks exist for this purpose, including:</p>
# <ul>
# <li><strong>DeepEval</strong>: Offers 14+ evaluation metrics to assess criteria like hallucination and faithfulness</li>
# <li><strong>MLflow LLM Evaluate</strong>: Known for modularity and simplicity, enabling evaluations within custom pipelines</li>
# <li><strong>RAGAs</strong>: Focuses on defining RAG pipelines with metrics such as faithfulness and contextual relevancy to compute a comprehensive quality score</li>
# </ul>
# <p><img alt="RAG evaluation frameworks" src="https://www.kdnuggets.com/wp-content/uploads/ragas.png" /></p>
# <h2>Understanding RAGAs</h2>
# <p><a href="https://github.com/explodinggradients/ragas">RAGAs</a> (retrieval augmented generation assessment) is considered one of the best toolkits for evaluating LLM applications. It evaluates the performance of a RAG system's components—the retriever and generator—both individually and as a unified pipeline.</p>
# <p>A core element of RAGAs is its <strong>metric-driven development</strong> (MDD) approach, which relies on data to make informed system decisions. MDD involves continuously monitoring essential metrics over time, providing clear insights into an application's performance while supporting reproducibility.</p>
# <h2>RAGAs Components</h2>
# <ul>
# <li><strong>Prompt object</strong>: Defines the structure and content of prompts used to elicit responses from the language model</li>
# <li><strong>Evaluation Sample</strong>: An individual data instance containing a user query, generated response, and reference response/ground truth</li>
# <li><strong>Evaluation dataset</strong>: A collection of evaluation samples used to systematically assess the RAG system's performance</li>
# </ul>
# <h2>RAGAs Metrics</h2>
# <p>RAGAs allows configuring your RAG system metrics by defining specific metrics for both retriever and generator, then blending them into an overall RAGAs score:</p>
# <p><img alt="RAGAs score" src="https://www.kdnuggets.com/wp-content/uploads/component-wise-metrics.webp" /></p>
# <h3>Retrieval Performance Metrics:</h3>
# <ul>
# <li><strong>Contextual recall</strong>: Measures the fraction of relevant documents retrieved from the knowledge base across the ground-truth top-k results</li>
# <li><strong>Contextual precision</strong>: Evaluates how many of the retrieved documents are relevant to the prompt rather than noise</li>
# </ul>
# <h3>Generation Performance Metrics:</h3>
# <ul>
# <li><strong>Faithfulness</strong>: Evaluates whether the generated response aligns with the retrieved evidence by comparing the response and retrieved documents</li>
# <li><strong>Contextual Relevancy</strong>: Determines how relevant the generated response is to the query, typically computed via human judgment or automated semantic similarity scoring</li>
# </ul>
# <h3>Bridging Metric:</h3>
# <ul>
# <li><strong>Context utilization</strong>: Evaluates how effectively an RAG system utilizes the retrieved context to generate its response</li>
# </ul>
# <p>In the RAGAs framework, these individual metrics are combined to calculate an <strong>overall RAGAs score</strong> that comprehensively quantifies the system's performance. The process involves selecting relevant metrics, normalizing them to a common range (typically 0-1), and computing a weighted average based on use case priorities.</p>
# <p>More about RAGAs metrics and their calculation through Python examples can be found <a href="https://docs.ragas.io/en/v0.1.21/concepts/metrics/">here</a>.</p>
# <h2>Wrapping Up</h2>
# <p>This article introduces RAGAs: a popular evaluation framework to systematically measure several aspects of RAG systems performance, both from information retrieval and text generation perspectives. Understanding the key elements of this framework is the first step toward mastering its practical use to develop high-performing RAG applications.</p>
# <hr />
# <p><img alt="Iván Palomares Carrascosa" src="https://machinelearningmastery.com/wp-content/uploads/2024/09/ivan-pc-author-150x150.png" /></p>
# <h4>About Iván Palomares Carrascosa</h4>
# <p><a href="https://www.linkedin.com/in/ivanpc/"><strong>Iván Palomares Carrascosa</strong></a> is a leader, writer, speaker, and adviser in AI, machine learning, deep learning &amp; LLMs. He trains and guides others in harnessing AI in the real world.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Evaluating RAG Systems: An Overview of RAGAs and Other Frameworks for Measuring Retrieval Augmented Generation Performance</strong></p>
# <p>The field of natural language processing (NLP) has witnessed a significant shift in recent years with the emergence of Retrieval Augmented Generation (RAG) systems. These systems combine the strengths of retrieval-based and generation-based approaches to produce high-quality text. However, evaluating the performance of RAG systems poses a unique challenge. In this blog post, we will provide an overview of RAGAs and other frameworks for measuring RAG performance.</p>
# <p><strong>What are RAG Systems?</strong></p>
# <p>RAG systems are designed to leverage the strengths of both retrieval-based and generation-based approaches. The retrieval component retrieves relevant documents or passages from a large corpus, while the generation component uses these retrieved passages to generate high-quality text. This hybrid approach enables RAG systems to produce more accurate and informative text than either retrieval-based or gene
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>7-Day Mini-Course on Practical Data Science: From Linear Regression to Random Forests with Real-World Country Data Analysis</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>Next-Level Data Science (7-Day Mini-Course)</h1>
# <p>By <a href="https://machinelearningmastery.com/author/adriantam/">Adrian Tam</a> on February 21, 2025 in <a href="https://machinelearningmastery.com/category/data-science/">Data Science</a></p>
# <p>Data science was originally known as statistical analysis before it got its name, as that was the primary method for extracting information from data. With recent advances in technology, machine learning models have been introduced, expanding our ability to analyze and understand data. The most important thing is to understand how these tools can help you.</p>
# <p>In this 7-part crash course, you will learn through examples how to carry out a data science project using the most common machine learning models. This mini-course focuses on the core aspects of data science, assuming you have already gathered and prepared the data. It's designed for practitioners comfortable with Python programming and eager to learn about common data science tools like pandas and scikit-learn.</p>
# <p><img alt="" src="https://machinelearningmastery.com/wp-content/uploads/2025/02/geraldo-stanislas-JfPIfLTaJY4-unsplash-scaled.jpg" /></p>
# <p>Net Level Data Science (7-day Mini-Course)<br />
# Photo by <a href="https://unsplash.com/photos/low-angle-photography-of-white-building-interior-with-clear-glass-roof-during-daytime-JfPIfLTaJY4">geraldo stanislas</a>. Some rights reserved.</p>
# <h2>Who Is This Mini-Course For?</h2>
# <p>This course is designed for:</p>
# <ul>
# <li><strong>Developers with some coding experience</strong> who are comfortable writing Python code and setting up development environments</li>
# <li><strong>Developers with basic machine learning knowledge</strong> who understand machine learning models and their strengths/weaknesses</li>
# <li><strong>Developers familiar with data science tools</strong> like Jupyter notebooks and pandas</li>
# </ul>
# <p>This mini-course serves as a project-based guide that takes you step by step through completing a data science project.</p>
# <h2>Mini-Course Overview</h2>
# <p>This mini-course is divided into 7 parts, each designed to take about 30 minutes:</p>
# <ul>
# <li><strong>Lesson 1</strong>: Getting the Data</li>
# <li><strong>Lesson 2</strong>: Find the Numeric Columns for Linear Regression</li>
# <li><strong>Lesson 3</strong>: Performing Linear Regression</li>
# <li><strong>Lesson 4</strong>: Interpreting Factors</li>
# <li><strong>Lesson 5</strong>: Feature Selection</li>
# <li><strong>Lesson 6</strong>: Decision Tree</li>
# <li><strong>Lesson 7</strong>: Random Forest and Probability</li>
# </ul>
# <h2>Lesson 01: Getting the Data</h2>
# <p>The dataset we'll use is the "All Countries Dataset" from Kaggle:
# * <a href="https://www.kaggle.com/datasets/adityakishor1/all-countries-details">https://www.kaggle.com/datasets/adityakishor1/all-countries-details</a></p>
# <p>This dataset describes countries' demographic, economic, geographic, health, and political data. Let's check this dataset with pandas:</p>
# <p><code>python
# import pandas as pd
# df = pd.read_csv("All Countries.csv")
# df.info()</code></p>
# <p>This will print a table showing the dataset has 194 entries (rows) and 64 columns. Some columns are numeric (float64), and some are strings (object). There are also some missing values in certain columns.</p>
# <h3>Your Task</h3>
# <p>Using <code>df.sample(5)</code> would be more helpful as it randomly samples 5 rows. To show all columns from the sample, you can use:
# <code>python
# pd.set_option('display.max_columns', None)
# print(df.sample(5).to_string())</code></p>
# <h2>Lesson 02: Find the Numeric Columns for Linear Regression</h2>
# <p>Before using linear regression, we need to ensure no bad data is involved. Missing values (<code>NaN</code>) must be addressed.</p>
# <p>You can replace missing values with zero:
# <code>python
# df_filled = df.fillna(0)</code></p>
# <p>To identify columns with missing values:
# <code>python
# print(df.isnull().sum().sort_values(ascending=False).to_string())</code></p>
# <p>To list columns with no missing values:
# <code>python
# df_null_count = df.isnull().sum().sort_values(ascending=False)
# print(df_null_count[df_null_count == 0].index)</code></p>
# <p>For linear regression, we need numeric columns:
# <code>python
# print(df.describe().columns)</code></p>
# <p>To find columns that are both numerical and have no missing values:
# <code>python
# print(list(set(df.describe().columns) &amp; set(df_null_count[df_null_count == 0].index)))</code></p>
# <h3>Your Task</h3>
# <p>GDP is missing from the list because one country lacks GDP data. To identify which country:
# <code>python
# print(df[df['gdp'].isnull()])</code></p>
# <p>To find columns with three or fewer missing values and remove countries with missing values:
# <code>python
# good_cols = list(set(df_null_count[df_null_count &lt;= 3].index) &amp; set(df.describe().columns))
# df_cleaned = df.dropna(subset=good_cols)</code></p>
# <h2>Lesson 03: Performing Linear Regression</h2>
# <p>Let's identify numeric columns with few missing values and build a linear regression model:</p>
# <p>```python
# df_null_count = df.isnull().sum().sort_values(ascending=False)
# good_cols = list(set(df_null_count[df_null_count &lt;= 3].index) &amp; set(df.describe().columns))
# df_cleaned = df.dropna(axis="index", how="any", subset=good_cols).copy()</p>
# <p>from sklearn.linear_model import LinearRegression
# model = LinearRegression(fit_intercept=True)
# X = df_cleaned[["population"]]
# Y = df_cleaned["gdp"]
# model.fit(X, Y)
# print(model.coef_)
# print(model.intercept_)
# print(model.score(X, Y))
# ```</p>
# <p>The R² score of 0.34 indicates population alone isn't a strong predictor of GDP. Adding more predictors:</p>
# <p><code>python
# model = LinearRegression(fit_intercept=True)
# X = df_cleaned[["population", "rural_population", "median_age", "life_expectancy"]]
# Y = df_cleaned["gdp"]
# model.fit(X, Y)
# print(model.score(X, Y))</code></p>
# <p>The R² score increases to 0.66, showing significant improvement.</p>
# <h3>Your Task</h3>
# <p>Using all numerical columns for regression would look like:
# <code>python
# X = df_cleaned[[x for x in good_cols if x != "gdp"]]
# Y = df_cleaned["gdp"]
# model.fit(X, Y)
# print(model.score(X, Y))</code></p>
# <p>To determine which factors positively correlate with GDP, examine the coefficients:
# <code>python
# for col, coef in zip(X.columns, model.coef_):
#     print(f"{col}: {coef}")</code></p>
# <h2>Lesson 04: Interpreting Factors</h2>
# <p>Let's predict life expectancy using all relevant factors:</p>
# <p>```python
# df_null_count = df.isnull().sum().sort_values(ascending=False)
# good_cols = list(set(df_null_count[df_null_count &lt;= 3].index) &amp; set(df.describe().columns))</p>
# <p>X = df_cleaned[[x for x in good_cols if x != "life_expectancy"]]
# Y = df_cleaned["life_expectancy"]
# model.fit(X, Y)
# print(model.score(X, Y))</p>
# <p>for col, coef in zip(X.columns, model.coef_):
#     print("%s: %.3e" % (col, coef))
# ```</p>
# <p>Some factors have negative coefficients, meaning they negatively impact life expectancy. For example, a higher death rate decreases life expectancy, which makes sense.</p>
# <h3>Your Task</h3>
# <p>To automatically find the best features, you could write a loop that
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Best practices for efficient machine learning model deployment, including optimization, containerization, CI/CD implementation, performance monitoring, and security considerations</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>Tips for Deploying Machine Learning Models Efficiently</h1>
# <p>By <a href="https://machinelearningmastery.com/author/matt/">Matthew Mayo</a> on May 30, 2024 in <a href="https://machinelearningmastery.com/category/resources/">Resources</a>  <a href="https://machinelearningmastery.com/tips-deploying-machine-learning-models-efficiently/#respond">0</a></p>
# <p><img alt="Tips for Deploying Machine Learning Models Efficiently" src="https://machinelearningmastery.com/wp-content/uploads/2024/05/colorful_cargo_containers.png" /></p>
# <p>Image created by Author using Midjourney</p>
# <h2>Introduction</h2>
# <p>Deploying machine learning models is a critical step in bringing AI technologies to the real world. However, this process can be challenging as models must continue to perform well in changing environments. The following tips aim to guide practitioners in best practices for model deployment, covering optimization, containerization, deployment processes, monitoring, and security.</p>
# <h2>1. Optimize Your Models for Production</h2>
# <p>In production, machine learning models require optimization to meet latency demands and resource constraints. Several techniques can help:</p>
# <ul>
# <li><strong>Quantization</strong>: Reduces bits used to represent weights, creating smaller models with faster inference</li>
# <li><strong>Pruning</strong>: Eliminates unnecessary weights for a streamlined model</li>
# <li><strong>Knowledge distillation</strong>: Transfers knowledge from larger to smaller models</li>
# </ul>
# <p>Tools like TensorFlow Lite and ONNX can optimize models during conversion, making them ready for inference in various settings, including embedded and mobile environments.</p>
# <h2>2. Containerize Your Application</h2>
# <p>Containerization packages your model and its dependencies into a single deployable artifact that can run in virtually any environment. This approach provides:</p>
# <ul>
# <li>Portability across different systems</li>
# <li>Independence from host system configurations</li>
# <li>Consistent runtime environments</li>
# </ul>
# <p>Docker is a popular containerization tool that creates encapsulated, portable software packages. Kubernetes can effectively manage container lifecycles. Mastering containerization is essential for machine learning engineers looking to widen their audience and manage projects in production.</p>
# <h2>3. Implement Continuous Integration and Continuous Deployment</h2>
# <p>CI/CD improves the reliability of model deployment by automating testing, deployment, and updates. This approach makes exception handling in system testing and updates seamless.</p>
# <p>Tools like Jenkins and GitHub Actions can carry out CI/CD processes:
# - <strong>Jenkins</strong>: An open-source automation server for building, testing, and deploying code
# - <strong>GitHub Actions</strong>: Provides flexible CI/CD workflows integrated with GitHub repositories</p>
# <p>Both tools help automate the entire machine learning model deployment lifecycle through configuration files.</p>
# <h2>4. Monitor Model Performance in Production</h2>
# <p>Once deployed, models need careful observation to ensure continued value. Effective monitoring includes:</p>
# <ul>
# <li>Tracking model accuracy, response time, and resource usage</li>
# <li>Implementing solid logging strategies</li>
# <li>Setting up automated alerting systems for performance deviations</li>
# <li>Creating centralized dashboards for holistic views of all deployed models</li>
# </ul>
# <p>Proactive monitoring allows for immediate investigation of issues like model drift, minimizing potential disruptions.</p>
# <h2>5. Ensure Model Security and Compliance</h2>
# <p>Security is crucial but often overlooked in model deployment. Simple steps with significant impact include:</p>
# <ul>
# <li>Safeguarding models at rest and during transit</li>
# <li>Limiting access to models and their inputs</li>
# <li>Understanding your model's internal structure for better defense</li>
# <li>Ensuring regulatory compliance</li>
# </ul>
# <p>These measures help protect against breaches and maintain responsible AI practices.</p>
# <h2>Summary</h2>
# <p>Deploying machine learning models effectively involves optimization for better performance, containerization for portability, CI/CD for reliable updates, monitoring for continued accuracy, and security measures for protection and compliance.</p>
# <p><img alt="Tips for Deploying Machine Learning Models Efficiently" src="https://machinelearningmastery.com/wp-content/uploads/2024/05/mermaid-diagram-2024-05-29-102850-e1716993028149.png" /></p>
# <p>Development to Production: A timeline with example tasks and tools<br />
# Visualization created by Author</p>
# <p>By implementing these practices before deployment, your machine learning models will have the best chance to achieve successful results in production.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Efficient Machine Learning Model Deployment: Best Practices</strong></p>
# <p>Machine learning (ML) model deployment is a critical step in the ML lifecycle, where the trained model is integrated into a production environment. However, deploying ML models can be a complex and time-consuming process. In this blog post, we will discuss the best practices for efficient ML model deployment, including optimization, containerization, CI/CD implementation, performance monitoring, and security considerations.</p>
# <p><strong>Optimization</strong></p>
# <p>Before deploying an ML model, it's essential to optimize it for production. This includes:</p>
# <ol>
# <li><strong>Model pruning</strong>: Remove unnecessary weights and connections to reduce model size and improve inference speed.</li>
# <li><strong>Quantization</strong>: Convert model weights and activations to lower precision data types (e.g., from float32 to int8) to reduce memory usage and improve inference speed.</li>
# <li><strong>Knowledge distillation</strong>: Transfer knowledge from a larger, more complex model to a smaller, simpler model to improve inference speed and reduce model size.</li>
# </ol>
# <p><strong>Containerization</strong></p>
# <p>Containerization is a popular approach for deploying ML models in production. It provides a lightweight and portable way to package the model, dependencies, and runtime environment. Popular containerization tools include:</p>
# <ol>
# <li><strong>Docker</strong>: Create a Docker image with the ML model, dependencies, and runtime environment.</li>
# <li><strong>Kubernetes</strong>: Deploy the Docker image to a Kubernetes cluster for scalable and high-availability deployment.</li>
# </ol>
# <p><strong>CI/CD Implementation</strong></p>
# <p>Continuous Integration/Continuous Deployment (CI/CD) is a software development practice that automates the build, test, and deployment of ML models. This ensures that the model is thoroughly tested and validated before deployment. Popular CI/CD tools include:</p>
# <ol>
# <li><strong>Jenkins</strong>: Automate the build, test, and deployment of ML models using Jenkins pipelines.</li>
# <li><strong>CircleCI</strong>: Automate the
# ...
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Groundbreaking Applications of Reinforcement Learning in 2024: Advancements in Precision Healthcare, Multilingual NLP, Supply Chain Resilience, Smart Grid Management, and Multimodal Robotic Assistants</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>5 Groundbreaking Applications of Reinforcement Learning in 2024</h1>
# <p>By <a href="https://machinelearningmastery.com/author/vbpm1401/">Vinod Chugani</a> on August 29, 2024 in <a href="https://machinelearningmastery.com/category/resources/">Resources</a>  <a href="https://machinelearningmastery.com/5-groundbreaking-applications-of-reinforcement-learning-in-2024/#respond">0</a></p>
# <p><img alt="5 Groundbreaking Applications of Reinforcement Learning in 2024" src="https://machinelearningmastery.com/wp-content/uploads/2024/08/machine-learning-model-being-used-to-optimize-supply-chains.jpeg" /></p>
# <p>Reinforcement Learning (RL) has emerged as a powerful paradigm in artificial intelligence, enabling machines to learn optimal behavior through interaction with their environment. In RL, an agent learns to make decisions by performing actions and receiving rewards or penalties, ultimately aiming to maximize cumulative rewards over time. This approach has led to remarkable advancements across various domains, from gaming to robotics.</p>
# <p>As we explore the developments in 2024, it's important to understand that the distinction between "new" and "established" applications in RL is often unclear. The field's rapid evolution means that many seemingly novel applications are, in fact, sophisticated advancements or specialized implementations of concepts that have been in development for years.</p>
# <h2>Established Applications of Reinforcement Learning</h2>
# <p>Before we explore the cutting-edge applications of 2024, let's briefly acknowledge some well-established areas where RL has already made significant impacts:</p>
# <ol>
# <li><strong>Autonomous Vehicles</strong>: RL has been instrumental in developing decision-making algorithms for self-driving cars, enabling them to navigate complex environments.</li>
# <li><strong>Robotics</strong>: Industrial robots and robotic systems have long benefited from RL, learning to perform tasks through trial and error.</li>
# <li><strong>Financial Trading</strong>: Algorithmic trading strategies powered by RL have been optimizing investment decisions for years.</li>
# <li><strong>Game Playing</strong>: RL's application in mastering complex games like Go and chess has been a landmark achievement in AI.</li>
# </ol>
# <p>These applications continue to evolve, with ongoing research pushing the boundaries of what's possible. However, 2024 has seen some truly groundbreaking applications that deserve special attention.</p>
# <h2>1. Precision Healthcare Optimization</h2>
# <p>While RL in healthcare isn't entirely new, 2024 has seen unprecedented advancements in personalized treatment optimization. RL algorithms are now capable of fine-tuning chemotherapy and radiotherapy dosing schedules with remarkable precision. These systems analyze vast amounts of patient data, including genetic information, treatment history, and real-time physiological responses, to dynamically adjust treatment plans.</p>
# <p>What sets 2024's applications apart is their ability to adapt in real-time to patient responses, minimizing side effects while maximizing treatment efficacy. This level of personalization was previously unattainable and represents a significant leap forward in patient care.</p>
# <h2>2. Advanced Natural Language Processing for Diverse Languages</h2>
# <p>RL has made substantial strides in NLP, particularly in developing more sophisticated dialogue systems and chatbots. The breakthrough in 2024 lies in the ability of these systems to learn and adapt to a wide range of languages and dialects, including those with limited digital resources.</p>
# <p>These new RL-powered language models can now understand and generate contextually appropriate responses in real-time, adapting to individual user's speech patterns, idioms, and even code-switching between multiple languages. This advancement has significant implications for global communication, education, and accessibility.</p>
# <h2>3. Resilient Supply Chain Optimization</h2>
# <p>While supply chain optimization using RL isn't new, the events of recent years have highlighted the need for more resilient and adaptive systems. In 2024, RL algorithms are being deployed to create supply chain networks that can quickly adapt to global disruptions, from pandemics to geopolitical tensions.</p>
# <p>These advanced systems not only optimize for efficiency but also for resilience, learning from simulated crisis scenarios to develop robust strategies. They can predict potential disruptions, suggest alternative suppliers or routes, and even recommend strategic inventory placement, all in real-time.</p>
# <h2>4. Eco-Friendly Smart Grid Management</h2>
# <p>Energy management systems have utilized RL for years, but 2024 has seen a significant leap in their capabilities, particularly in managing renewable energy sources. The latest RL algorithms can balance supply and demand across complex grid systems with unprecedented efficiency.</p>
# <p>What's groundbreaking is their ability to integrate a diverse range of energy sources, including residential solar panels, wind farms, and electric vehicle batteries, creating a truly decentralized and resilient energy network. These systems can predict energy consumption patterns, optimize storage, and even incentivize consumer behavior to balance grid load, all while minimizing carbon footprint.</p>
# <h2>5. Multimodal Learning for Robotic Assistants</h2>
# <p>The field of robotics has seen remarkable advancements through RL, but 2024 brings us closer to the realization of truly versatile robotic assistants. The latest breakthrough lies in multimodal learning, where robots use RL to integrate information from various sensory inputs – vision, touch, sound, and even natural language instructions.</p>
# <p>These advanced robotic systems can now learn complex tasks by observing human demonstrations, understanding verbal instructions, and adapting to new environments with minimal reprogramming. This represents a significant step towards robots that can assist in diverse scenarios, from healthcare and elderly care to disaster response and household tasks.</p>
# <h2>Looking Ahead</h2>
# <p>As we witness these groundbreaking applications of reinforcement learning in 2024, it's clear that we're only scratching the surface of RL's potential. The field continues to evolve rapidly, with researchers and practitioners pushing the boundaries of what's possible.</p>
# <p>The convergence of RL with other AI technologies, such as deep learning and quantum computing, promises even more exciting developments in the near future. As these systems become more sophisticated and are deployed in increasingly critical roles, it's essential to consider the ethical implications and ensure responsible development and deployment.</p>
# <p>These developments are not only technologically significant but also bring substantial social and economic benefits. The advancements in healthcare optimization are improving patient outcomes and potentially saving lives. Eco-friendly smart grid management is enabling more susta
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Comparing different imputation techniques for handling missing data in machine learning pipelines, including SimpleImputer, IterativeImputer, and KNNImputer, with practical implementation examples and performance analysis.</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (actual)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <h1>Filling the Gaps: A Comparative Guide to Imputation Techniques in Machine Learning</h1>
# <p>By <a href="https://machinelearningmastery.com/author/vbpm1401/">Vinod Chugani</a> on November 5, 2024 in <a href="https://machinelearningmastery.com/category/intermediate-data-science/">Intermediate Data Science</a>  <a href="https://machinelearningmastery.com/filling-the-gaps-a-comparative-guide-to-imputation-techniques-in-machine-learning/#respond">0</a></p>
# <p>In our previous exploration of penalized regression models such as Lasso, Ridge, and ElasticNet, we demonstrated how effectively these models manage multicollinearity, allowing us to utilize a broader array of features to enhance model performance. Building on this foundation, we now address another crucial aspect of data preprocessing—handling missing values. Missing data can significantly compromise the accuracy and reliability of models if not appropriately managed. This post explores various imputation strategies to address missing data and embed them into our pipeline. This approach allows us to further refine our predictive accuracy by incorporating previously excluded features, thus making the most of our rich dataset.</p>
# <p><strong>Kick-start your project</strong> with my book <a href="https://machinelearningmastery.com/next-level-data-science/">Next-Level Data Science</a>. It provides <strong>self-study tutorials</strong> with <strong>working code</strong>.</p>
# <p>Let's get started.</p>
# <p><img alt="" src="https://machinelearningmastery.com/wp-content/uploads/2024/05/lan-deng-eAWFUVw9OX0-unsplash.jpg" /></p>
# <p>Filling the Gaps: A Comparative Guide to Imputation Techniques in Machine Learning<br />
# Photo by <a href="https://unsplash.com/photos/person-in-white-shirt-and-blue-jeans-walking-inside-gap-store-eAWFUVw9OX0">lan deng</a>. Some rights reserved.</p>
# <h2>Overview</h2>
# <p>This post is divided into three parts; they are:</p>
# <ul>
# <li>Reconstructing Manual Imputation with SimpleImputer</li>
# <li>Advancing Imputation Techniques with IterativeImputer</li>
# <li>Leveraging Neighborhood Insights with KNN Imputation</li>
# </ul>
# <h2>Reconstructing Manual Imputation with SimpleImputer</h2>
# <p>In part one of this post, we revisit and reconstruct our earlier manual imputation techniques using <code>SimpleImputer</code>. Our previous exploration of the Ames Housing dataset provided foundational insights into <a href="https://machinelearningmastery.com/classifying_variables/">using the data dictionary</a> to tackle missing data. We demonstrated manual imputation strategies tailored to different data types, considering domain knowledge and data dictionary details. For example, categorical variables missing in the dataset often indicate an absence of the feature (e.g., a missing 'PoolQC' might mean no pool exists), guiding our imputation to fill these with "None" to preserve the dataset's integrity. Meanwhile, numerical features were handled differently, employing techniques like mean imputation.</p>
# <p>Now, by automating these processes with scikit-learn's <code>SimpleImputer</code>, we enhance reproducibility and efficiency. Our pipeline approach not only incorporates imputation but also scales and encodes features, preparing them for regression analysis with models such as Lasso, Ridge, and ElasticNet:</p>
# <p>```python</p>
# <h1>Import the necessary libraries</h1>
# <p>import pandas as pd
# from sklearn.pipeline import Pipeline
# from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
# from sklearn.linear_model import Lasso, Ridge, ElasticNet
# from sklearn.model_selection import cross_val_score</p>
# <h1>Load the dataset</h1>
# <p>Ames = pd.read_csv('Ames.csv')</p>
# <h1>Exclude 'PID' and 'SalePrice' from features and specifically handle the 'Electrical' column</h1>
# <p>numeric_features = Ames.select_dtypes(include=['int64', 'float64']).drop(columns=['PID', 'SalePrice']).columns
# categorical_features = Ames.select_dtypes(include=['object']).columns.difference(['Electrical'])
# electrical_feature = ['Electrical'] # Specifically handle the 'Electrical' column</p>
# <h1>Helper function to fill 'None' for missing categorical data</h1>
# <p>def fill_none(X):
#     return X.fillna("None")</p>
# <h1>Pipeline for numeric features: Impute missing values then scale</h1>
# <p>numeric_transformer = Pipeline(steps=[
#     ('impute_mean', SimpleImputer(strategy='mean')),
#     ('scaler', StandardScaler())
# ])</p>
# <h1>Pipeline for general categorical features: Fill missing values with 'None' then apply one-hot encoding</h1>
# <p>categorical_transformer = Pipeline(steps=[
#     ('fill_none', FunctionTransformer(fill_none, validate=False)),
#     ('onehot', OneHotEncoder(handle_unknown='ignore'))
# ])</p>
# <h1>Specific transformer for 'Electrical' using the mode for imputation</h1>
# <p>electrical_transformer = Pipeline(steps=[
#     ('impute_electrical', SimpleImputer(strategy='most_frequent')),
#     ('onehot_electrical', OneHotEncoder(handle_unknown='ignore'))
# ])</p>
# <h1>Combined preprocessor for numeric, general categorical, and electrical data</h1>
# <p>preprocessor = ColumnTransformer(
#     transformers=[
#         ('num', numeric_transformer, numeric_features),
#         ('cat', categorical_transformer, categorical_features),
#         ('electrical', electrical_transformer, electrical_feature)
#     ])</p>
# <h1>Target variable</h1>
# <p>y = Ames['SalePrice']</p>
# <h1>All features</h1>
# <p>X = Ames[numeric_features.tolist() + categorical_features.tolist() + electrical_feature]</p>
# <h1>Define the model pipelines with preprocessor and regressor</h1>
# <p>models = {
#     'Lasso': Lasso(max_iter=20000),
#     'Ridge': Ridge(),
#     'ElasticNet': ElasticNet()
# }</p>
# <p>results = {}
# for name, model in models.items():
#     pipeline = Pipeline(steps=[
#         ('preprocessor', preprocessor),
#         ('regressor', model)
#     ])
#     # Perform cross-validation
#     scores = cross_val_score(pipeline, X, y)
#     results[name] = round(scores.mean(), 4)</p>
# <h1>Output the cross-validation scores</h1>
# <p>print("Cross-validation scores with Simple Imputer:", results)
# ```</p>
# <p>The results from this implementation are displayed, showing how simple imputation affects model accuracy and establishes a benchmark for more sophisticated methods discussed later:</p>
# <p><code>Cross-validation scores with Simple Imputer: {'Lasso': 0.9138, 'Ridge': 0.9134, 'ElasticNet': 0.8752}</code></p>
# <p>Transitioning from manual steps to a pipeline approach using scikit-learn enhances several aspects of data processing:</p>
# <ol>
# <li><strong>Efficiency and Error Reduction:</strong> Manually imputing values is time-consuming and prone to errors, especially as data complexity increases. The pipeline automates these steps, ensuring consistent transformations and reducing mistakes.</li>
# <li><strong>Reusability and Integration:</strong> Manual methods are less reusable. In contrast, pipelines encapsulate the entire preprocessing and modeling steps, making the

# %% [markdown]
# # Fine Tune a Better Blog Post Generator
# Now that we've seen that the MachineLearningMastery posts are still significantly better than our prompt generated posts, let's see if we can capture some of that goodness by fine tuning our own model with examples from the original blog. To do so we will:
#
# 1. Download a [dataset of previously scraped posts from HuggingFace](https://huggingface.co/datasets/withpi/mlmastery_com_blogs_condensed_mergedhttps://)
#
# 2. Filter the dataset to **just the posts that perform really well per our scoring system** (this is the special sauce)
#
# 3. Plug that data into our fine tuning SDK endpoint, which will show us a running log as Fine Tuning improves the model's performance on our scoring system

# %%
# @title Prepare training data for Fine-tuning by filtering low scoring blogs (<0.7)
from datasets import load_dataset
import pandas

def score(topic:str, blog:str):
  return client.contracts.score(
      llm_input=topic,
      llm_output=blog,
      contract=blog_writer_scoring_system).total_score

ds = load_dataset("withpi/mlmastery_com_blogs_condensed_merged", split = "train")
ds = ds.map(lambda x: {"score": score(x["topic"], x["blog"])})
ds = ds.filter(lambda x: x["score"] > 0.7)
df = ds.to_pandas()
df
# Out:
# WARNING:datasets.fingerprint:Parameter 'function'=<function <lambda> at 0x7eb187d5d6c0> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/305 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/305 [00:00<?, ? examples/s]
#                                                  topic  \
# 0    The topic of this blog post is: "Understanding...
# 1    Cross-validation techniques for comprehensive ...
# 2    Automated Feature Engineering in PyCaret: Stre...
# 3    Strategies and techniques for handling imbalan...
# 4    Finding the optimal feature subset for linear ...
# ..                                                 ...
# 132  Visualizing PyTorch Model Architectures Using ...
# 133  Understanding and Working with One-Dimensional...
# 134  Making Predictions with Keras: A Guide to Clas...
# 135  Visualizing and Interpreting Model Training Me...
# 136  Understanding and Using Static Analysis Tools ...
#
#                                                   blog     score
# 0    # The Da Vinci Code of Data: Mastering The Dat...  0.736165
# 1    # From Train-Test to Cross-Validation: Advanci...  0.960286
# 2    # Automated Feature Engineering in PyCaret\n\n...  0.806478
# 3    # Tips for Handling Imbalanced Data in Machine...  0.836202
# 4    # The Search for the Sweet Spot in a Linear Re...  0.910970
# ..                                                 ...       ...
# 132  # Visualizing a PyTorch Model\n\nBy [Adrian Ta...  0.849609
# 133  # One-Dimensional Tensors in Pytorch\n\nBy [Mu...  0.723145
# 134  # How to Make Predictions with Keras\n\nBy [Ja...  0.814941
# 135  # Understand Model Behavior During Training by...  0.926432
# 136  # Static Analyzers in Python\n\nBy [Adrian Tam...  0.840332
#
# [137 rows x 3 columns]

# %%
# @title [SLOW - will run for 80+ minutes] Fine tune the model based on the above training data
status = client.model.sft.start_job(
    contract=blog_writer_scoring_system,
    examples=[
        {"llm_input": row["topic"], "llm_output": row["blog"]}
        for row in ds
    ],
    base_sft_model="LLAMA_3.1_8B",
    lora_config={"lora_rank": "R_16"},
    system_prompt=system_prompt_for_blog_writer,
    num_train_epochs=10,
)
print(status)
# Out:
# SftStatus(detailed_status=['LAUNCHING'], job_id='sft_jobs:babf2fa45c086088a9e43d648f8ef22e58d7584ce21f17fda4509f2421d84c4c:382edcaa-f921-4ea0-bef6-490308c1a865', state='QUEUED', trained_models=[])

# %%
# @title Monitor the fine-tuning job for completion (watch the Eval_Pi_Score increase!)
response = stream_response(
    status.job_id,
    client.model.sft,
    additional_columns={"Eval_Pi_Score": "contract_score"},
)
if response.state == "ERROR":
  print("The job failed due to:\n{}".format('\n'.join(response.detailed_status[-5:])))
else:
  print("SFT model = {}".format(response.trained_models[0].model_dump_json(indent=2)))
# Out:
# Training Status for sft_jobs:babf2fa45c086088a9e43d648f8ef22e58d7584ce21f17fda4509f2421d84c4c:382edcaa-f921-4ea0-bef6-490308c1a865
#    Step     Epoch Learning_Rate Training_Loss Eval_Loss Eval_Pi_Score
# 0     0         0             X             X  1.190794      0.421585
# 1     3  0.387097       0.00012        1.1977         X             X
# 2     6  0.774194      0.000197        1.1557  1.113977      0.459801
# 3     9  1.258065      0.000188        1.4782         X             X
# 4    12  1.645161      0.000178        1.0975  1.051968      0.506237
# 5    15  2.129032      0.000169        1.4086         X             X
# 6    18  2.516129       0.00016        0.9544   1.02279      0.596232
# 7    21  2.903226      0.000151        1.0153         X             X
# 8    24  3.387097      0.000142        1.3013  1.005253      0.416762
# 9    27  3.774194      0.000132        0.9336         X             X
# 10   30  4.258065      0.000123        1.2607  0.996309      0.601538
# 11   33  4.645161      0.000114        0.9074         X             X
# 12   36  5.129032      0.000105        1.1782  0.991751       0.61098
# 13   39  5.516129      0.000095        0.8984         X             X
# 14   42  5.903226      0.000086        0.8851  0.991827      0.568324
# 15   45  6.387097      0.000077        1.1792         X             X
# 16   48  6.774194      0.000068          0.82  0.999628      0.603948
# 17   51  7.258065      0.000058        1.0437         X             X
# 18   54  7.645161      0.000049        0.8338  1.006401      0.649252
# 19   57  8.129032       0.00004        1.1096         X             X
# 20   60  8.516129      0.000031        0.7269  1.011821      0.655333
# 21   63  8.903226      0.000022        0.8182         X             X
# 22   66  9.387097      0.000012        1.0758  1.016026      0.656549
# 23   69  9.774194      0.000003        0.7559         X             X
# 24   70  9.903226             X             X         X             X
# 25  ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-f168a402db73> in <cell line: 0>()
#       1 # @title Monitor the fine-tuning job for completion
# ----> 2 response = stream_response(
#       3     status.job_id,
#       4     client.model.sft,
#       5     additional_columns={"Eval_Pi_Score": "contract_score"},
#
# <ipython-input-20-bb952f1b0c5d> in stream_response(job_id, method, additional_columns)
#     207         ) as response:
#     208             is_done = False
# --> 209             for line in response.iter_lines():
#     210                 if line == "DONE":
#     211                     is_done = True
#
# /usr/local/lib/python3.11/dist-packages/withpi/_response.py in iter_lines(self)
#     366     def iter_lines(self) -> Iterator[str]:
#     367         """Like `iter_text()` but will only yield chunks for each line"""
# --> 368         for chunk in self.http_response.iter_lines():
#     369             yield chunk
#     370
#
# /usr/local/lib/python3.11/dist-packages/httpx/_models.py in iter_lines(self)
#     927         decoder = LineDecoder()
#     928         with request_context(request=self._request):
# --> 929             for text in self.iter_text():
#     930                 for line in decoder.decode(text):
#     931                     yield line
#
# /usr/local/lib/python3.11/dist-packages/httpx/_models.py in iter_text(self, chunk_size)
#     914         chunker = TextChunker(chunk_size=chunk_size)
#     915         with request_context(request=self._request):
# --> 916             for byte_content in self.iter_bytes():
#     917                 text_content = decoder.decode(byte_content)
#     918                 for chunk in chunker.decode(text_content):
#
# /usr/local/lib/python3.11/dist-packages/httpx/_models.py in iter_bytes(self, chunk_size)
#     895             chunker = ByteChunker(chunk_size=chunk_size)
#     896             with request_context(request=self._request):
# --> 897                 for raw_bytes in self.iter_raw():
#     898                     decoded = decoder.decode(raw_bytes)
#     899                     for chunk in chunker.decode(decoded):
#
# /usr/local/lib/python3.11/dist-packages/httpx/_models.py in iter_raw(self, chunk_size)
#     949
#     950         with request_context(request=self._request):
# --> 951             for raw_stream_bytes in self.stream:
#     952                 self._num_bytes_downloaded += len(raw_stream_bytes)
#     953                 for chunk in chunker.decode(raw_stream_bytes):
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in __iter__(self)
#     151
#     152     def __iter__(self) -> typing.Iterator[bytes]:
# --> 153         for chunk in self._stream:
#     154             yield chunk
#     155
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in __iter__(self)
#     125     def __iter__(self) -> typing.Iterator[bytes]:
#     126         with map_httpcore_exceptions():
# --> 127             for part in self._httpcore_stream:
#     128                 yield part
#     129
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in __iter__(self)
#     405         except BaseException as exc:
#     406             self.close()
# --> 407             raise exc from None
#     408
#     409     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in __iter__(self)
#     401     def __iter__(self) -> typing.Iterator[bytes]:
#     402         try:
# --> 403             for part in self._stream:
#     404                 yield part
#     405         except BaseException as exc:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in __iter__(self)
#     340             with ShieldCancellation():
#     341                 self.close()
# --> 342             raise exc
#     343
#     344     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in __iter__(self)
#     332         try:
#     333             with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334                 for chunk in self._connection._receive_response_body(**kwargs):
#     335                     yield chunk
#     336         except BaseException as exc:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_response_body(self, request)
#     201
#     202         while True:
# --> 203             event = self._receive_event(timeout=timeout)
#     204             if isinstance(event, h11.Data):
#     205                 yield bytes(event.data)
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.11/ssl.py in recv(self, buflen, flags)
#    1293                     "non-zero flags not allowed in calls to recv() on %s" %
#    1294                     self.__class__)
# -> 1295             return self.read(buflen)
#    1296         else:
#    1297             return super().recv(buflen, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1166                 return self._sslobj.read(len, buffer)
#    1167             else:
# -> 1168                 return self._sslobj.read(len)
#    1169         except SSLError as x:
#    1170             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# # Test Out & Evaluate Your Fine Tuned Generator
#
# Now our new model is ready to be tested out!
#
# 1. First, we'll generate blog posts for the same topics we were looking at before
#
# 2. Then we'll score all of these blog posts so we can compare them to the generations by our prompted model
#
# 3. Then we'll look at some of the individual examples and their scores Side by Side so we can see how much fine tuning improved our blog posts

# %%
# @title Generate blogs using the fine tuned model for evaluation
SFT_JOB_ID = "sft_jobs:babf2fa45c086088a9e43d648f8ef22e58d7584ce21f17fda4509f2421d84c4c:382edcaa-f921-4ea0-bef6-490308c1a865"
from datasets import load_dataset
from google.colab import userdata

ds = load_dataset("withpi/mlmastery_com_blogs_condensed_merged", split = "test")
topics = ds["topic"]

# Generate the blogs using fine tuned llama 8B
client.model.sft.load(SFT_JOB_ID)
loop = asyncio.get_running_loop()
new_generated_blogs = await loop.create_task(
    generate_blogs(
        topics,
        model_id="fireworks_ai/0",
        api_base=f"https://api.withpi.ai/v1/model/sft/{SFT_JOB_ID}",
        api_key=os.environ["WITHPI_API_KEY"],
        system_prompt=system_prompt_for_blog_writer
    )
)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# <ipython-input-11-0133836e5ef9> in <cell line: 0>()
#       8
#       9 # Generate the blogs using fine tuned llama 8B
# ---> 10 client.model.sft.load(SFT_JOB_ID)
#      11 loop = asyncio.get_running_loop()
#      12 new_generated_blogs = await loop.create_task(
#
# /usr/local/lib/python3.11/dist-packages/withpi/resources/model/sft.py in load(self, job_id, extra_headers, extra_query, extra_body, timeout)
#     219         if not job_id:
#     220             raise ValueError(f"Expected a non-empty value for `job_id` but received {job_id!r}")
# --> 221         return self._post(
#     222             f"/model/sft/{job_id}/load",
#     223             options=make_request_options(
#
# /usr/local/lib/python3.11/dist-packages/withpi/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1223             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224         )
# -> 1225         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1226
#    1227     def patch(
#
# /usr/local/lib/python3.11/dist-packages/withpi/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     915             retries_taken = 0
#     916
# --> 917         return self._request(
#     918             cast_to=cast_to,
#     919             options=options,
#
# /usr/local/lib/python3.11/dist-packages/withpi/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1003             if remaining_retries > 0 and self._should_retry(err.response):
#    1004                 err.response.close()
# -> 1005                 return self._retry_request(
#    1006                     input_options,
#    1007                     cast_to,
#
# /usr/local/lib/python3.11/dist-packages/withpi/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1052         time.sleep(timeout)
#    1053
# -> 1054         return self._request(
#    1055             options=options,
#    1056             cast_to=cast_to,
#
# /usr/local/lib/python3.11/dist-packages/withpi/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1003             if remaining_retries > 0 and self._should_retry(err.response):
#    1004                 err.response.close()
# -> 1005                 return self._retry_request(
#    1006                     input_options,
#    1007                     cast_to,
#
# /usr/local/lib/python3.11/dist-packages/withpi/_base_client.py in _retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1052         time.sleep(timeout)
#    1053
# -> 1054         return self._request(
#    1055             options=options,
#    1056             cast_to=cast_to,
#
# /usr/local/lib/python3.11/dist-packages/withpi/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1018
#    1019             log.debug("Re-raising status error")
# -> 1020             raise self._make_status_error_from_response(err.response) from None
#    1021
#    1022         return self._process_response(
#
# InternalServerError: Error code: 500 - {'exception': ['ValueError: Command failed with exit code 1\n']}

# %%
# @title Compare the newly generated blogs against previous ones using the Pi scoring system
from tqdm import tqdm
import pandas as pd

scores = []
generated_scores = []
new_generated_scores = []
for topic, generated_blog, new_generated_blog in tqdm(zip(topics, generated_blogs, new_generated_blogs)):
  generated_score = client.contracts.score(
      llm_input=topic,
      llm_output=generated_blog,
      contract=blog_writer_scoring_system)
  new_generated_score = client.contracts.score(
      llm_input=topic,
      llm_output=new_generated_blog,
      contract=blog_writer_scoring_system)
  generated_scores.append(generated_score)
  new_generated_scores.append(new_generated_score)
  score = {'topic': topic, 'generated': generated_score.total_score, 'new generated': new_generated_score.total_score}
  scores.append(score)

df = pd.DataFrame(scores)
df
# Out:
# 78it [00:16,  4.59it/s]
#                                                 topic  generated  \
# 0   InterviewAce: 365 Data Science's Free AI-Power...   0.125428
# 1   Topic: 7 Beginner-Friendly Machine Learning Pr...   0.188105
# 2   A comprehensive guide to Hugging Face's Model ...   0.296890
# 3   Evaluating RAG Systems: An Overview of RAGAs a...   0.125052
# 4   7-Day Mini-Course on Practical Data Science: F...   0.414086
# ..                                                ...        ...
# 73  Packaging and Deploying Python Projects: From ...   0.304791
# 74  Creating and Customizing Dataset Classes in Py...   0.321662
# 75  Implementing Dropout Regularization in PyTorch...   0.389350
# 76  Building and Training a Single Layer Neural Ne...   0.440276
# 77  Keypoint Detection and Feature Extraction in O...   0.408884
#
#     new generated
# 0        0.000020
# 1        0.000781
# 2        0.006804
# 3        0.001931
# 4        0.000090
# ..            ...
# 73       0.048944
# 74       0.045525
# 75       0.035131
# 76       0.037730
# 77       0.038663
#
# [78 rows x 3 columns]

# %%
# @title Manually inspect new generated blogs against previous ones with scores
def pretty_print_blog(i):
  pretty_print_responses(
      response1 = generated_blogs[i].strip("\"").replace("\\n", "\n"),
      response2 = new_generated_blogs[i].strip("\"").replace("\\n", "\n"),
      header="##### Topic: \n" + topics[i].strip("\"").replace("\\n", "\n"),
      left_label="Base (generated)",
      right_label="Test (new generated)",
      scores_left=generated_scores[i],
      scores_right=new_generated_scores[i])

for i in range(10):
  pretty_print_blog(i)
  print("\n\n")
# Out:
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>InterviewAce: 365 Data Science's Free AI-Powered Tool for Data Science Interview Preparation</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Mastering Data Science Interviews with InterviewAce: A Comprehensive Guide</strong></p>
# <p>As the demand for data science professionals continues to rise, so does the complexity of data science interview processes. To help candidates prepare for these challenging interviews, 365 Data Science has developed InterviewAce, a free AI-powered tool designed to simulate real-world data science interview experiences. In this blog post, we will delve into the features and functionality of InterviewAce, providing a comprehensive guide on how to utilize this tool to ace your next data science interview.</p>
# <p><strong>What is InterviewAce?</strong></p>
# <p>InterviewAce is an AI-driven platform that offers a comprehensive set of tools and resources to help data science candidates prepare for their interviews. The platform provides a simulated interview experience, complete with real-world problems, coding challenges, and behavioral questions. By leveraging machine learning algorithms and natural language processing, InterviewAce assesses a candidate's technical skills, problem-solving abilities, and communication skills, providing personalized feedback and recommendations for improvement.</p>
# <p><strong>Key Features of InterviewAce</strong></p>
# <ol>
# <li><strong>Simulated Interviews</strong>: InterviewAce offers a range of simulated interview scenarios, each designed to mimic real-world data science interview experiences. Candidates can choose from a variety of topics, including machine learning, statistics, and data visualization.</li>
# <li><strong>Coding Challenges</strong>: The platform provides a set of coding challenges, ranging from simple to complex, to test a candidate's programming skills. Candidates can choose from a variety of programming languages, including Python, R, and SQL.</li>
# <li><strong>Behavioral Questions</strong>: InterviewAce includes a comprehensive set of behavioral questions, designed to assess a candidate's communication skills, teamwork experience, and problem-solving abilities.</li>
# <li><strong>Personalized Feedback</strong>: After completing a simulated interview, candidates receive personalized feedback on their performance, highlighting areas of strength and weakness.</li>
# <li><strong>Practice Mode</strong>: InterviewAce offers a practice mode, allowing candidates to simulate interviews in a low-stakes environment, helping them build confidence and improve their performance.</li>
# </ol>
# <p><strong>How to Use InterviewAce</strong></p>
# <ol>
# <li><strong>Create an Account</strong>: To access InterviewAce, candidates need to create an account on the 365 Data Science website.</li>
# <li><strong>Choose a Topic</strong>: Select a topic or scenario from the available options, such as machine learning or data visualization.</li>
# <li><strong>Complete the Interview</strong>: Answer questions, complete coding challenges, and respond to behavioral questions, just as you would in a real interview.</li>
# <li><strong>Review Feedback</strong>: After completing the interview, review personalized feedback and recommendations for improvement.</li>
# <li><strong>Practice and Refine</strong>: Use the practice mode to refine your skills and build confidence before the actual interview.</li>
# </ol>
# <p><strong>Conclusion</strong></p>
# <p>InterviewAce is a powerful tool for data science candidates looking to improve their interview preparation. By leveraging AI-powered technology and real-world scenarios, InterviewAce provides a comprehensive and personalized experience, helping candidates build confidence and improve their performance. With its free access and user-friendly interface, InterviewAce is an essential resource for anyone looking to ace their next data science interview.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e67e21'>0.251</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.003</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Technical Communication</b></td><td></td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code inclusion</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code explanation</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Pitfalls</td><td style='color: #e74c3c'>0.0</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #e6652e'><b>0.125</b></td></tr>
# </table>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</t
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Topic: 7 Beginner-Friendly Machine Learning Projects for Hands-On Experience - From Titanic Survival Prediction to Face Detection</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>7 Beginner-Friendly Machine Learning Projects for Hands-On Experience</strong></p>
# <p>Machine learning is a rapidly growing field that has numerous applications in various industries, including healthcare, finance, and technology. As a beginner, it can be challenging to get started with machine learning, but with the right projects, you can gain hands-on experience and build a strong foundation in the field. In this article, we will explore 7 beginner-friendly machine learning projects that will help you get started with machine learning.</p>
# <p><strong>1. Titanic Survival Prediction</strong></p>
# <p>The Titanic dataset is a classic machine learning dataset that contains information about the passengers who boarded the Titanic. The goal of this project is to predict whether a passenger survived or not based on various features such as age, sex, and class. This project is a great starting point for beginners as it involves simple data preprocessing and model selection.</p>
# <p><strong>Step-by-Step Instructions:</strong></p>
# <ul>
# <li>Import necessary libraries (pandas, numpy, scikit-learn)</li>
# <li>Load the Titanic dataset</li>
# <li>Preprocess the data by handling missing values and encoding categorical variables</li>
# <li>Split the data into training and testing sets</li>
# <li>Train a logistic regression model on the training data</li>
# <li>Evaluate the model on the testing data</li>
# </ul>
# <p><strong>2. Image Classification with CIFAR-10</strong></p>
# <p>The CIFAR-10 dataset is a collection of 60,000 32x32 color images in 10 classes. This project involves training a convolutional neural network (CNN) to classify images into their respective classes. This project is a great way to learn about image processing and deep learning.</p>
# <p><strong>Step-by-Step Instructions:</strong></p>
# <ul>
# <li>Import necessary libraries (tensorflow, keras)</li>
# <li>Load the CIFAR-10 dataset</li>
# <li>Preprocess the data by normalizing pixel values</li>
# <li>Split the data into training and testing sets</li>
# <li>Train a CNN model on the training data</li>
# <li>Evaluate the model on the testing data</li>
# </ul>
# <p><strong>3. Sentiment Analysis with IMDB Dataset</strong></p>
# <p>The IMDB dataset is a collection of 50,000 movie reviews with corresponding sentiment labels (positive or negative). This project involves training a text classification model to predict the sentiment of a movie review based on its text. This project is a great way to learn about natural language processing (NLP).</p>
# <p><strong>Step-by-Step Instructions:</strong></p>
# <ul>
# <li>Import necessary libraries (pandas, numpy, scikit-learn)</li>
# <li>Load the IMDB dataset</li>
# <li>Preprocess the data by tokenizing text and removing stop words</li>
# <li>Split the data into training and testing sets</li>
# <li>Train a logistic regression model on the training data</li>
# <li>Evaluate the model on the testing data</li>
# </ul>
# <p><strong>4. Face Detection with OpenCV</strong></p>
# <p>Face detection is a fundamental task in computer vision that involves detecting faces in images or videos. This project involves using OpenCV to detect faces in images and videos. This project is a great way to learn about computer vision and image processing.</p>
# <p><strong>Step-by-Step Instructions:</strong></p>
# <ul>
# <li>Import necessary libraries (OpenCV)</li>
# <li>Load an image or video</li>
# <li>Convert the image or video to grayscale</li>
# <li>Detect faces using the Haar cascade classifier</li>
# <li>Draw rectangles around detected faces</li>
# </ul>
# <p><strong>5. Time Series Forecasting with Stock Prices</strong></p>
# <p>Time series forecasting involves predicting future values of a time series based on past values. This project involves using a simple ARIMA model to forecast stock prices. This project is a great way to learn about time series analysis.</p>
# <p><strong>Step-by-Step Instructions:</strong></p>
# <ul>
# <li>Import necessary libraries (pandas, numpy, statsmodels)</li>
# <li>Load stock price data</li>
# <li>Preprocess the data by handling missing values and normalizing values</li>
# <li>Split the data into training and testing sets</li>
# <li>Train an ARIMA model on the training data</li>
# <li>Evaluate the model on the testing data</li>
# </ul>
# <p><strong>6. Recommendation System with MovieLens Dataset</strong></p>
# <p>The MovieLens dataset is a collection of movie ratings from users. This project involves building a recommendation system that suggests movies to users based on their ratings. This project is a great way to learn about collaborative filtering.</p>
# <p><strong>Step-by-Step Instructions:</strong></p>
# <ul>
# <li>Import necessary libraries (pandas, numpy, scikit-learn)</li>
# <li>Load the MovieLens dataset</li>
# <li>Preprocess the data by handling missing values and normalizing values</li>
# <li>Split the data into training and testing sets</li>
# <li>Train a matrix factorization model on the training data</li>
# <li>Evaluate the model on the testing data</li>
# </ul>
# <p><strong>7. Chatbot with Natural Language Processing</strong></p>
# <p>Building a chatbot involves using NLP to understand user input and respond accordingly. This project involves using a simple chatbot framework to build a chatbot that responds to user queries. This project is a great way to learn about NLP and chatbots.</p>
# <p><strong>Step-by-Step Instructions:</strong></p>
# <ul>
# <li>Import necessary libraries (NLTK, spaCy)</li>
# <li>Load a chatbot framework (e.g. Rasa)</li>
# <li>Train a chatbot model on a dataset of user queries and responses</li>
# <li>Evaluate the model on a testing dataset</li>
# </ul>
# <p>In conclusion, these 7 beginner-friendly machine learning projects are a great way to get started with machine learning. Each project involves a different aspect of machine learning, from data preprocessing to model selection, and from image processing to NLP. By working on these projects, you will gain hands-on experience and build a strong foundation in machine learning.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>A comprehensive guide to Hugging Face's Model Hub and Community platform, including repository management, search functionality, API integration, and community resources for machine learning practitioners.</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Unlocking the Power of Hugging Face's Model Hub and Community Platform</strong></p>
# <p>As machine learning practitioners, we're constantly on the lookout for efficient and effective ways to develop, deploy, and share our models. Hugging Face's Model Hub and Community platform has revolutionized the way we approach model development, providing a comprehensive ecosystem for model management, collaboration, and innovation. In this guide, we'll delve into the key features and functionalities of the platform, empowering you to unlock its full potential.</p>
# <p><strong>Repository Management</strong></p>
# <p>The Model Hub is a centralized repository for hosting and sharing pre-trained models, datasets, and tasks. To manage your repositories effectively:</p>
# <ol>
# <li><strong>Create a new repository</strong>: Click on the "New Repository" button and fill in the required information, including the repository name, description, and tags.</li>
# <li><strong>Upload models and datasets</strong>: Use the "Upload" button to add your models, datasets, and tasks to the repository. You can also import models from popular frameworks like TensorFlow and PyTorch.</li>
# <li><strong>Organize and categorize</strong>: Use tags and categories to organize your repositories and make them easily discoverable.</li>
# </ol>
# <p><strong>Search Functionality</strong></p>
# <p>The Model Hub's search functionality allows you to quickly find and access relevant models, datasets, and tasks. To search effectively:</p>
# <ol>
# <li><strong>Use keywords</strong>: Enter relevant keywords in the search bar to find models, datasets, and tasks that match your criteria.</li>
# <li><strong>Filter results</strong>: Use the filters on the left-hand side to narrow down your search results based on factors like model type, task, and dataset.</li>
# <li><strong>Explore popular models</strong>: Browse the "Popular" section to discover trending models and datasets.</li>
# </ol>
# <p><strong>API Integration</strong></p>
# <p>The Model Hub provides a robust API for integrating models into your applications. To integrate the API:</p>
# <ol>
# <li><strong>Get your API token</strong>: Generate an API token by clicking on your profile picture and selecting "API Tokens."</li>
# <li><strong>Use the API</strong>: Use the API to download models, datasets, and tasks, or to upload new models and datasets.</li>
# <li><strong>Integrate with popular frameworks</strong>: Use the API to integrate models with popular frameworks like TensorFlow, PyTorch, and scikit-learn.</li>
# </ol>
# <p><strong>Community Resources</strong></p>
# <p>The Hugging Face Community platform is a vibrant hub for machine learning practitioners to share knowledge, collaborate, and learn from each other. To tap into community resources:</p>
# <ol>
# <li><strong>Join discussions</strong>: Participate in discussions on the forum to ask questions, share knowledge, and get feedback on your projects.</li>
# <li><strong>Attend webinars and meetups</strong>: Stay up-to-date with the latest developments and best practices by attending webinars and meetups.</li>
# <li><strong>Contribute to open-source projects</strong>: Contribute to open-source projects on the platform to give back to the community and enhance your skills.</li>
# </ol>
# <p><strong>Conclusion</strong></p>
# <p>Hugging Face's Model Hub and Community platform has revolutionized the way we approach model development, deployment, and sharing. By mastering repository management, search functionality, API integration, and community resources, you'll be able to unlock the full potential of the platform and take your machine learning projects to the next level. Join the Hugging Face community today and start exploring the vast array of models, datasets, and tasks available on the platform.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #efc40f'>0.5</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Technical Communication</b></td><td></td><td style='color: #e65e32'>0.094</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code inclusion</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code explanation</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Pitfalls</td><td style='color: #e7871f'>0.281</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #e88b1e'><b>0.297</b></td></tr>
# </table>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weigh
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Evaluating RAG Systems: An Overview of RAGAs and Other Frameworks for Measuring Retrieval Augmented Generation Performance</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Evaluating RAG Systems: An Overview of RAGAs and Other Frameworks for Measuring Retrieval Augmented Generation Performance</strong></p>
# <p>The field of natural language processing (NLP) has witnessed a significant shift in recent years with the emergence of Retrieval Augmented Generation (RAG) systems. These systems combine the strengths of retrieval-based and generation-based approaches to produce high-quality text. However, evaluating the performance of RAG systems poses a unique challenge. In this blog post, we will provide an overview of RAGAs and other frameworks for measuring retrieval augmented generation performance.</p>
# <p><strong>What are RAG Systems?</strong></p>
# <p>RAG systems are a type of NLP model that combines the strengths of retrieval-based and generation-based approaches. The retrieval component retrieves relevant documents or passages from a large corpus, while the generation component uses these retrieved passages to generate high-quality text. This approach has been shown to outperform traditional generation-based models in various NLP tasks, such as question answering and text summarization.</p>
# <p><strong>RAGAs: A Framework for Evaluating RAG Systems</strong></p>
# <p>RAGAs (Retrieval Augmented Generation Assessment) is a framework specifically designed for evaluating RAG systems. RAGAs assesses the performance of RAG systems by evaluating the quality of the generated text, the relevance of the retrieved passages, and the overall effectiveness of the system. The framework consists of three main components:</p>
# <ol>
# <li><strong>Retrieval Quality</strong>: This component evaluates the relevance of the retrieved passages to the input query or prompt.</li>
# <li><strong>Generation Quality</strong>: This component assesses the quality of the generated text, including its coherence, fluency, and accuracy.</li>
# <li><strong>System Effectiveness</strong>: This component evaluates the overall effectiveness of the RAG system, including its ability to answer questions, summarize text, or perform other NLP tasks.</li>
# </ol>
# <p><strong>Other Frameworks for Evaluating RAG Systems</strong></p>
# <p>While RAGAs is a comprehensive framework for evaluating RAG systems, other frameworks and metrics can also be used to assess their performance. Some of these frameworks include:</p>
# <ol>
# <li><strong>BLEU</strong>: This metric evaluates the similarity between the generated text and a reference text.</li>
# <li><strong>ROUGE</strong>: This metric assesses the similarity between the generated text and a reference text, with a focus on n-gram overlap.</li>
# <li><strong>METEOR</strong>: This metric evaluates the similarity between the generated text and a reference text, with a focus on word-level similarity.</li>
# <li><strong>TER</strong>: This metric assesses the similarity between the generated text and a reference text, with a focus on word-level similarity and grammatical correctness.</li>
# </ol>
# <p><strong>Conclusion</strong></p>
# <p>Evaluating the performance of RAG systems is a complex task that requires a comprehensive framework. RAGAs is a framework specifically designed for evaluating RAG systems, while other frameworks and metrics, such as BLEU, ROUGE, METEOR, and TER, can also be used to assess their performance. By using these frameworks and metrics, developers can evaluate the effectiveness of their RAG systems and identify areas for improvement.</p>
# <p><strong>Recommendations</strong></p>
# <ol>
# <li><strong>Use RAGAs</strong>: RAGAs is a comprehensive framework for evaluating RAG systems. It assesses the quality of the generated text, the relevance of the retrieved passages, and the overall effectiveness of the system.</li>
# <li><strong>Use multiple metrics</strong>: Using multiple metrics, such as BLEU, ROUGE, METEOR, and TER, can provide a more comprehensive evaluation of the RAG system's performance.</li>
# <li><strong>Tune hyperparameters</strong>: Tuning hyperparameters, such as the retrieval threshold and the generation temperature, can significantly impact the performance of the RAG system.</li>
# <li><strong>Use a large corpus</strong>: Using a large corpus can improve the performance of the RAG system by providing more relevant and diverse passages for retrieval.</li>
# </ol>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e67e21'>0.25</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Technical Communication</b></td><td></td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code inclusion</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code explanation</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Pitfalls</td><td style='color: #e74c3c'>0.0</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #e6652e'><b>0.125</b></td></tr>
# </table>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom bord
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>7-Day Mini-Course on Practical Data Science: From Linear Regression to Random Forests with Real-World Country Data Analysis</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Day 1: Introduction to Data Science and Linear Regression</strong></p>
# <p>Welcome to our 7-day mini-course on practical data science! In this course, we will take you on a journey from the basics of data science to advanced machine learning techniques using real-world country data analysis. In this first day, we will introduce the fundamentals of data science and linear regression.</p>
# <p><strong>What is Data Science?</strong></p>
# <p>Data science is a multidisciplinary field that combines statistics, computer science, and domain-specific knowledge to extract insights from data. It involves collecting, processing, and analyzing large datasets to answer complex questions and make informed decisions.</p>
# <p><strong>Linear Regression</strong></p>
# <p>Linear regression is a fundamental technique in data science used for predicting continuous outcomes based on one or more predictor variables. The goal of linear regression is to find the best-fitting line that minimizes the difference between observed and predicted values.</p>
# <p><strong>Real-World Example: Country GDP Analysis</strong></p>
# <p>Let's use a real-world example to illustrate the concept of linear regression. We will analyze the relationship between a country's GDP (Gross Domestic Product) and its population size. We will use the World Bank's dataset, which contains GDP and population data for over 200 countries.</p>
# <p><strong>Step-by-Step Instructions</strong></p>
# <ol>
# <li>Import necessary libraries: <code>import pandas as pd</code> and <code>import numpy as np</code>.</li>
# <li>Load the World Bank dataset: <code>gdp_data = pd.read_csv('gdp_data.csv')</code>.</li>
# <li>Explore the dataset: <code>print(gdp_data.head())</code> and <code>print(gdp_data.info())</code>.</li>
# <li>Prepare the data: <code>gdp_data['gdp'] = gdp_data['gdp'] / 1e9</code> (convert GDP to billions of USD).</li>
# <li>Split the data into training and testing sets: <code>from sklearn.model_selection import train_test_split; X_train, X_test, y_train, y_test = train_test_split(gdp_data['population'], gdp_data['gdp'], test_size=0.2, random_state=42)</code>.</li>
# <li>Train a linear regression model: <code>from sklearn.linear_model import LinearRegression; model = LinearRegression(); model.fit(X_train.values.reshape(-1, 1), y_train.values)</code>.</li>
# <li>Evaluate the model: <code>y_pred = model.predict(X_test.values.reshape(-1, 1)); print('R-squared:', model.score(X_test.values.reshape(-1, 1), y_test.values))</code>.</li>
# </ol>
# <p><strong>Day 2: Introduction to Decision Trees and Random Forests</strong></p>
# <p>In this second day, we will introduce decision trees and random forests, two popular machine learning algorithms used for classification and regression tasks.</p>
# <p><strong>Decision Trees</strong></p>
# <p>Decision trees are a type of supervised learning algorithm that splits data into subsets based on feature values. Each internal node represents a feature, and each leaf node represents a class label or predicted value.</p>
# <p><strong>Random Forests</strong></p>
# <p>Random forests are an ensemble learning method that combines multiple decision trees to improve the accuracy and robustness of predictions. Each decision tree is trained on a random subset of the data, and the final prediction is made by aggregating the predictions of all trees.</p>
# <p><strong>Real-World Example: Country Life Expectancy Analysis</strong></p>
# <p>Let's use a real-world example to illustrate the concept of random forests. We will analyze the relationship between a country's life expectancy and its GDP per capita. We will use the World Bank's dataset, which contains life expectancy and GDP per capita data for over 200 countries.</p>
# <p><strong>Step-by-Step Instructions</strong></p>
# <ol>
# <li>Import necessary libraries: <code>import pandas as pd</code> and <code>import numpy as np</code>.</li>
# <li>Load the World Bank dataset: <code>life_expectancy_data = pd.read_csv('life_expectancy_data.csv')</code>.</li>
# <li>Explore the dataset: <code>print(life_expectancy_data.head())</code> and <code>print(life_expectancy_data.info())</code>.</li>
# <li>Prepare the data: <code>life_expectancy_data['gdp_per_capita'] = life_expectancy_data['gdp_per_capita'] / 1e3</code> (convert GDP per capita to thousands of USD).</li>
# <li>Split the data into training and testing sets: <code>from sklearn.model_selection import train_test_split; X_train, X_test, y_train, y_test = train_test_split(life_expectancy_data['gdp_per_capita'], life_expectancy_data['life_expectancy'], test_size=0.2, random_state=42)</code>.</li>
# <li>Train a random forest model: <code>from sklearn.ensemble import RandomForestRegressor; model = RandomForestRegressor(n_estimators=100, random_state=42); model.fit(X_train.values.reshape(-1, 1), y_train.values)</code>.</li>
# <li>Evaluate the model: <code>y_pred = model.predict(X_test.values.reshape(-1, 1)); print('R-squared:', model.score(X_test.values.reshape(-1, 1), y_test.values))</code>.</li>
# </ol>
# <p><strong>Stay tuned for Day 3, where we will introduce polynomial regression and feature engineering!</strong></p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #eca816'>0.399</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #a3c736'>0.598</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Technical Communication</b></td><td></td><td style='color: #edaf14'>0.429</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code inclusion</td><td style='color: #31cb6f'>0.742</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code explanation</td><td style='color: #cdc520'>0.543</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Pitfalls</td><td style
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Best practices for efficient machine learning model deployment, including optimization, containerization, CI/CD implementation, performance monitoring, and security considerations</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Efficient Machine Learning Model Deployment: Best Practices</strong></p>
# <p>Deploying machine learning (ML) models in production environments can be a complex task, requiring careful consideration of various factors to ensure efficient, scalable, and secure deployment. In this post, we'll outline best practices for optimizing, containerizing, implementing CI/CD pipelines, monitoring performance, and addressing security concerns.</p>
# <p><strong>Optimization</strong></p>
# <ol>
# <li><strong>Model Pruning</strong>: Remove unnecessary parameters and layers to reduce model size and computational requirements.</li>
# <li><strong>Quantization</strong>: Convert model weights and activations to lower precision formats (e.g., 8-bit integers) to reduce memory usage and improve inference speed.</li>
# <li><strong>Knowledge Distillation</strong>: Train a smaller model to mimic the behavior of a larger, more complex model, reducing computational requirements.</li>
# <li><strong>Model Compression</strong>: Use techniques like Huffman coding or arithmetic coding to compress model weights and reduce storage requirements.</li>
# </ol>
# <p><strong>Containerization</strong></p>
# <ol>
# <li><strong>Docker</strong>: Use Docker to create lightweight, portable containers that encapsulate the ML model, dependencies, and runtime environment.</li>
# <li><strong>Container Orchestration</strong>: Utilize tools like Kubernetes or Docker Swarm to manage containerized deployments, ensuring scalability and high availability.</li>
# <li><strong>Image Optimization</strong>: Use techniques like multi-stage builds or image caching to reduce container image size and improve deployment efficiency.</li>
# </ol>
# <p><strong>CI/CD Implementation</strong></p>
# <ol>
# <li><strong>Continuous Integration</strong>: Use tools like Jenkins, Travis CI, or CircleCI to automate testing, building, and validation of ML models.</li>
# <li><strong>Continuous Deployment</strong>: Implement automated deployment pipelines using tools like Docker, Kubernetes, or GitLab CI/CD.</li>
# <li><strong>Model Versioning</strong>: Use version control systems like Git to track model changes and ensure reproducibility.</li>
# </ol>
# <p><strong>Performance Monitoring</strong></p>
# <ol>
# <li><strong>Model Inference Time</strong>: Measure the time taken for model inference to identify performance bottlenecks.</li>
# <li><strong>Resource Utilization</strong>: Monitor CPU, memory, and storage usage to ensure efficient resource allocation.</li>
# <li><strong>Model Accuracy</strong>: Track model accuracy and precision to detect degradation over time.</li>
# </ol>
# <p><strong>Security Considerations</strong></p>
# <ol>
# <li><strong>Data Encryption</strong>: Use encryption techniques like SSL/TLS to protect sensitive data during transmission.</li>
# <li><strong>Model Obfuscation</strong>: Use techniques like model watermarking or obfuscation to prevent model theft or unauthorized use.</li>
# <li><strong>Access Control</strong>: Implement role-based access control to restrict access to sensitive model data and deployment environments.</li>
# </ol>
# <p>By following these best practices, you can ensure efficient, scalable, and secure deployment of machine learning models in production environments. Remember to continuously monitor and optimize your deployments to maintain high performance and accuracy.</p>
# <p><strong>Example Use Case</strong></p>
# <p>Suppose you're deploying a computer vision model for image classification. You can use the following steps to optimize, containerize, and deploy the model:</p>
# <ol>
# <li><strong>Optimize</strong>: Prune the model to reduce computational requirements and use knowledge distillation to train a smaller model.</li>
# <li><strong>Containerize</strong>: Create a Docker image with the optimized model, dependencies, and runtime environment.</li>
# <li><strong>Implement CI/CD</strong>: Use Jenkins to automate testing, building, and validation of the model, and deploy it to a Kubernetes cluster using a CI/CD pipeline.</li>
# <li><strong>Monitor Performance</strong>: Use Prometheus and Grafana to monitor model inference time, resource utilization, and accuracy.</li>
# <li><strong>Secure Deployment</strong>: Use SSL/TLS encryption to protect sensitive data during transmission and implement role-based access control to restrict access to sensitive model data and deployment environments.</li>
# </ol>
# <p>By following these steps, you can ensure efficient, scalable, and secure deployment of your machine learning model.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e67e21'>0.25</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Technical Communication</b></td><td></td><td style='color: #e67028'>0.184</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code inclusion</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code explanation</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Pitfalls</td><td style='color: #c7c523'>0.551</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #e67725'><b>0.217</b></td></tr>
# </table>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* S
# ...
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Groundbreaking Applications of Reinforcement Learning in 2024: Advancements in Precision Healthcare, Multilingual NLP, Supply Chain Resilience, Smart Grid Management, and Multimodal Robotic Assistants</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Unlocking the Potential of Reinforcement Learning: 5 Groundbreaking Applications in 2024</strong></p>
# <p>Reinforcement learning (RL), a subfield of machine learning, has been gaining significant attention in recent years due to its ability to learn from trial and error, making it an ideal approach for complex decision-making tasks. As we step into 2024, we can expect to see significant advancements in various industries, driven by the power of RL. In this blog post, we will explore five groundbreaking applications of RL that are poised to revolutionize precision healthcare, multilingual NLP, supply chain resilience, smart grid management, and multimodal robotic assistants.</p>
# <p><strong>1. Precision Healthcare: Personalized Medicine with RL</strong></p>
# <p>RL can be used to develop personalized treatment plans for patients with complex diseases. By analyzing electronic health records (EHRs) and medical imaging data, RL algorithms can identify the most effective treatment strategies for individual patients. For instance, researchers at Stanford University have developed an RL-based system that can predict the optimal treatment plan for patients with breast cancer, resulting in improved treatment outcomes and reduced side effects.</p>
# <p><strong>Implementation Steps:</strong></p>
# <ul>
# <li>Collect and preprocess EHRs and medical imaging data</li>
# <li>Train an RL model to predict treatment outcomes based on patient characteristics and medical history</li>
# <li>Integrate the RL model with electronic health records systems for real-time decision support</li>
# </ul>
# <p><strong>2. Multilingual NLP: Breaking Language Barriers with RL</strong></p>
# <p>RL can be used to develop multilingual language models that can understand and generate text in multiple languages. This can be achieved by training RL models on large datasets of multilingual text, allowing them to learn the patterns and relationships between languages. For example, researchers at Google have developed a multilingual language model that can translate text from English to Spanish, French, and German with high accuracy.</p>
# <p><strong>Implementation Steps:</strong></p>
# <ul>
# <li>Collect and preprocess multilingual text datasets</li>
# <li>Train an RL model to learn language patterns and relationships</li>
# <li>Integrate the RL model with translation APIs for real-time language translation</li>
# </ul>
# <p><strong>3. Supply Chain Resilience: Optimizing Logistics with RL</strong></p>
# <p>RL can be used to optimize supply chain logistics, reducing costs and improving delivery times. By analyzing real-time data on demand, inventory, and transportation, RL algorithms can identify the most efficient routes and schedules for goods movement. For instance, researchers at MIT have developed an RL-based system that can optimize the delivery of perishable goods, such as food and pharmaceuticals, reducing waste and improving customer satisfaction.</p>
# <p><strong>Implementation Steps:</strong></p>
# <ul>
# <li>Collect and preprocess real-time data on demand, inventory, and transportation</li>
# <li>Train an RL model to optimize logistics and reduce costs</li>
# <li>Integrate the RL model with supply chain management systems for real-time decision support</li>
# </ul>
# <p><strong>4. Smart Grid Management: Predicting Energy Demand with RL</strong></p>
# <p>RL can be used to predict energy demand and optimize energy distribution in smart grids. By analyzing real-time data on weather, temperature, and energy usage, RL algorithms can identify patterns and relationships that can be used to predict energy demand. For example, researchers at the University of California, Berkeley have developed an RL-based system that can predict energy demand and optimize energy distribution in smart grids, reducing energy waste and improving grid resilience.</p>
# <p><strong>Implementation Steps:</strong></p>
# <ul>
# <li>Collect and preprocess real-time data on weather, temperature, and energy usage</li>
# <li>Train an RL model to predict energy demand and optimize energy distribution</li>
# <li>Integrate the RL model with smart grid management systems for real-time decision support</li>
# </ul>
# <p><strong>5. Multimodal Robotic Assistants: Enhancing Human-Robot Collaboration with RL</strong></p>
# <p>RL can be used to develop multimodal robotic assistants that can understand and respond to human gestures, speech, and other forms of communication. By analyzing real-time data on human behavior and robot performance, RL algorithms can identify the most effective ways to interact with humans and improve collaboration. For instance, researchers at Carnegie Mellon University have developed an RL-based system that can enable robots to understand and respond to human gestures, improving human-robot collaboration in manufacturing and healthcare settings.</p>
# <p><strong>Implementation Steps:</strong></p>
# <ul>
# <li>Collect and preprocess real-time data on human behavior and robot performance</li>
# <li>Train an RL model to understand and respond to human gestures and speech</li>
# <li>Integrate the RL model with robotic systems for real-time decision support</li>
# </ul>
# <p>In conclusion, the applications of reinforcement learning in 2024 are vast and exciting, with the potential to revolutionize precision healthcare, multilingual NLP, supply chain resilience, smart grid management, and multimodal robotic assistants. By following the implementation steps outlined above, organizations can unlock the full potential of RL and drive innovation in these critical areas.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e67e21'>0.251</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.003</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='
#       <div style="display: flex; gap: 40px;">
#           <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#               <h4><h5>Topic:</h5>
# <p>Comparing different imputation techniques for handling missing data in machine learning pipelines, including SimpleImputer, IterativeImputer, and KNNImputer, with practical implementation examples and performance analysis.</p></h4>
#           </div>
#       </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Base (generated)</h4>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#             <h4>Test (new generated)</h4>
#         </div>
#     </div>
#     <div style="display: flex; gap: 20px;">
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p><strong>Handling Missing Data in Machine Learning Pipelines: A Comparison of Imputation Techniques</strong></p>
# <p>Missing data is a common problem in machine learning pipelines, and imputation techniques are used to fill in the missing values. In this blog post, we will compare three popular imputation techniques: SimpleImputer, IterativeImputer, and KNNImputer. We will provide practical implementation examples and analyze their performance.</p>
# <p><strong>SimpleImputer</strong></p>
# <p>SimpleImputer is a basic imputation technique that replaces missing values with a constant value. It is the simplest and fastest imputation technique, but it can lead to biased results if the constant value is not representative of the data.</p>
# <p>```python
# from sklearn.impute import SimpleImputer</p>
# <h1>Create a SimpleImputer object</h1>
# <p>imputer = SimpleImputer(strategy='mean')</p>
# <h1>Fit and transform the data</h1>
# <p>data_imputed = imputer.fit_transform(data)
# ```</p>
# <p><strong>IterativeImputer</strong></p>
# <p>IterativeImputer is a more advanced imputation technique that uses a iterative process to impute missing values. It uses a regression model to predict the missing values based on the existing data.</p>
# <p>```python
# from sklearn.impute import IterativeImputer</p>
# <h1>Create an IterativeImputer object</h1>
# <p>imputer = IterativeImputer(max_iter=10, init=None, random_state=0)</p>
# <h1>Fit and transform the data</h1>
# <p>data_imputed = imputer.fit_transform(data)
# ```</p>
# <p><strong>KNNImputer</strong></p>
# <p>KNNImputer is a popular imputation technique that uses the k-nearest neighbors algorithm to impute missing values. It finds the k most similar rows to the row with missing values and uses their values to impute the missing values.</p>
# <p>```python
# from sklearn.impute import KNNImputer</p>
# <h1>Create a KNNImputer object</h1>
# <p>imputer = KNNImputer(n_neighbors=5)</p>
# <h1>Fit and transform the data</h1>
# <p>data_imputed = imputer.fit_transform(data)
# ```</p>
# <p><strong>Performance Analysis</strong></p>
# <p>To evaluate the performance of these imputation techniques, we will use the Mean Absolute Error (MAE) metric. We will compare the MAE of each imputation technique on a synthetic dataset with missing values.</p>
# <p>```python
# from sklearn.metrics import mean_absolute_error</p>
# <h1>Create a synthetic dataset with missing values</h1>
# <p>data = pd.DataFrame(np.random.rand(100, 10))
# data.iloc[:, 5] = np.nan</p>
# <h1>Impute the missing values using each technique</h1>
# <p>data_simple_imputed = SimpleImputer(strategy='mean').fit_transform(data)
# data_iterative_imputed = IterativeImputer(max_iter=10, init=None, random_state=0).fit_transform(data)
# data_knn_imputed = KNNImputer(n_neighbors=5).fit_transform(data)</p>
# <h1>Calculate the MAE for each imputation technique</h1>
# <p>mae_simple = mean_absolute_error(data, data_simple_imputed)
# mae_iterative = mean_absolute_error(data, data_iterative_imputed)
# mae_knn = mean_absolute_error(data, data_knn_imputed)</p>
# <p>print("MAE SimpleImputer:", mae_simple)
# print("MAE IterativeImputer:", mae_iterative)
# print("MAE KNNImputer:", mae_knn)
# ```</p>
# <p><strong>Conclusion</strong></p>
# <p>In this blog post, we compared three popular imputation techniques: SimpleImputer, IterativeImputer, and KNNImputer. We provided practical implementation examples and analyzed their performance using the Mean Absolute Error (MAE) metric. The results show that KNNImputer outperforms the other two techniques in terms of MAE. However, the choice of imputation technique depends on the specific problem and dataset.</p>
#         </div>
#         <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <p>Error: litellm.NotFoundError: NotFoundError: Fireworks_aiException - Error code: 404 - {'detail': '{"error":"Model not found, inaccessible, and/or not deployed"}'}</p>
#         </div>
#     </div>
#
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e67e21'>0.25</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Technical Communication</b></td><td></td><td style='color: #84c845'>0.637</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code inclusion</td><td style='color: #28b664'>0.93</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Code explanation</td><td style='color: #b2c62e'>0.578</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Pitfalls</td><td style='color: #eca916'>0.402</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #eeb413'><b>0.443</b></td></tr>
# </table>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;  background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Content Structure</b></td><td></td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Visual breaks</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Second person</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Additional resources</td><td style='color: #e74c3c'>0.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Section headings</td><td style='color: #e74c3c'>0.0</td>
