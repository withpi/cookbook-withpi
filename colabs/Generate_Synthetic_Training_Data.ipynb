# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/colabs/Generate_Synthetic_Training_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://withpi.ai"><img src="https://play.withpi.ai/logo/logoFullBlack.svg" width="240"></a>
#
# <a href="https://code.withpi.ai"><font size="4">Documentation</font></a>
#
# <a href="https://build.withpi.ai"><font size="4">Copilot</font></a>

# %% [markdown]
# # Generate Synthetic Training Data
#
# Many techniques require input and LLM response to drives evaluation and training, but getting high-quality data can be painful and expensive.
#
# Generating this data with AI support can give you a higher quality set with much lower effort.  This notebook walks you through getting full Examples (input and output pairs).

# %% [markdown]
# ## Install and initialize SDK
#
# You'll need a `WITHPI_API_KEY` from https://build.withpi.ai/account/keys.  Add it to your notebook secrets (the key symbol) on the left.
#
# Run the cell below to install packages and load the SDK

# %%
# %%capture

# %pip install withpi withpi-utils datasets tqdm

import os
from google.colab import userdata
from withpi import PiClient

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

pi = PiClient()

# %% [markdown]
# ## Setup scoring system
#
# Let's say we're building an AI to generate stories in the style of Aesop's Fables.  In good test-driven development, we need to decide what we're looking for out of our system.  Initialize a Scoring System and score function:

# %%
scoring_spec = [{'question': q} for q in [
    "Does the response contain a clear beginning, middle, and end?",
    "Does the story follow a logical progression of events?",
    "Does the story resolve the conflict in a satisfying manner?",
    "Is the life lesson clearly conveyed in the story?",
    "Is the life lesson relevant to the input provided by the user?"
]]

def score(input, output):
  return pi.scoring_system.score(
    scoring_spec=scoring_spec,
    llm_input=input,
    llm_output=output,
)

# %% [markdown]
# ## Generate an Example Set
#
# To start with, we'll need some training examples containing plausible moral lessons and reasonable stories.

# %%
from withpi_utils import stream
from datasets import Dataset

synthetic_data_generation_status = pi.data.generate_input_response_pairs.start_job(
    system_prompt="""
Write a children's story in the style of Aesop's Fables teaching a life lesson
specified by the user. Provide just the story with no extra content.
""",
    num_pairs_to_generate=9,
    seeds=[],
    batch_size=3,
    num_shots=3,
)

examples = []

for data in stream(pi.data.generate_input_response_pairs, synthetic_data_generation_status):
    examples.append(data)
    print(f"[OUTPUT] - {data}")

examples = Dataset.from_list(examples)
# Out:
# LAUNCHING
# Still waiting...
# [INFO] Generating 9 seeds as they are not provided.
# [INFO] Yielding generated 9 seeds
# [INFO] Synthetic Data Generation Complete => Good Pairs: 9. Bad Pairs: 0. Similar Pairs: 0
# DONE
# [OUTPUT] - {'llm_input': "Write a children's story teaching the importance of sharing with others.", 'llm_output': 'Once upon a time in a lush green forest, there lived a clever little squirrel named Sammy. Sammy was known far and wide for his incredible acorn stash. Every fall, while other animals toiled to collect their food, Sammy would gather the most acorns anyone had ever seen, storing them in his cozy tree hollow.\n\nOne crisp autumn day, as Sammy admired his mountain of acorns, he heard a soft rustling nearby. Curiosity piqued, he peeked out and saw Lily the rabbit, her nose twitching with hunger. She looked thin and weary, having struggled to find enough food for the coming winter.\n\n"Hello, Sammy," Lily called, trying to sound cheerful. "Your acorns are so beautiful! Do you think you could spare just a few?"\n\nSammy, with a hearty
He gathered the animals once more and said, “Dear friends, I misled you. My bell is lost, and I cannot grant wishes. I only wanted to feel important and clever.”\n\nThe animals listened intently, and slowly, they forgave him. They appreciated his honesty. Inspired, they decided to help Finn search for his golden bell together. With teamwork and genuine efforts, they finally retrieved the bell from the river.\n\nFrom that day on, Finn learned the value of honesty. He realized that it was far better to be truthful and genuine with others, rather than trying to impress them with tricks and lies. In doing so, he not only regained his golden bell but also the trust and friendship of the entire forest.\n\nAnd so, the clever fox turned wise, and the forest thrived on the honesty that had brought them all together.\n\nThe moral of the story: Honesty is the best policy; it builds trust and friendship.'}
# [OUTPUT] - {'llm_input': 'Tell a fable about why teamwork leads to greater success.', 'llm_output': 'Once upon a time in a lush green forest, there lived a group of animals: Benny the Bear, Lucy the Lizard, and Freddy the Fox. Each was strong and clever in their own right, but they often preferred to work alone. One hot summer day, a rumor spread through the forest about a huge pile of juicy berries hidden deep in the woods. Each animal dreamed of feasting on the sweet treat.\n\nBenny pounded through the thick bushes, thinking his strength would help him reach the berries faster than anyone else. Lucy scurried along narrow paths, convinced that her speed and agility would lead her right to the prize. Freddy, with his sharp wits, chose to sneak through the shadows, believing that his stealth would guarantee success.\n\nAs they ventured deeper into the forest, Benny found himself stuck in a marshy area, his large paws sinking into the mud. Lucy, too, faced trouble; she was darting around wildly when she accidentally led herself into a web of prickly thorns. Freddy, while being sneaky, found that the deeper he went, the more tangled up he became in the underbrush, unable to move.\n\nAfter a while, the three animals met at the old oak tree, each covered in mud, thorns, and brambles. They realized they had all failed on their own.\n\n"Perhaps we should work together," suggested Lucy, who had finally wiped some thorns from her tiny legs. "Each of us has something to contribute!"\n\nBenny nodded, "That makes sense. I can clear away the heavy branches with my strength."\n\nFreddy grinned, "And I can scout ahead to find the best path to the berries!"\n\nSo, they teamed up. Benny used his strength to push aside fallen logs, Lucy zipped around to find the safest routes, and Freddy guided them, ensuring they avoided traps and obstacles. With their combined skills, they quickly navigated the forest, speaking and strategizing together.\n\nFinally, after a short while, they stumbled upon the colossal patch of berries, ripe and glistening in the sunlight. They all cheered in delight, filled with excitement as they chomped down on the delicious fruit.\n\nFrom that day forward, the trio learned the value of teamwork. They shared not just the berries but also their adventures, knowing that together they could accomplish what was impossible alone.\n\nAnd so, the wise animals of the forest added a new lesson to their stories: "When we work together, we can achieve greater feats than we ever could alone." \n\nThe End.'}
# [OUTPUT] - {'llm_input': 'Write a story that shows how being kind to others can lead to unexpected rewards.', 'llm_output': 'Once in a bright and blooming forest lived a kind little rabbit named Ruby. Ruby had a soft, fluffy coat and gentle eyes that sparkled with kindness. Every day, she hopped along the winding paths, greeting her friends and helping those in need.\n\nOne sunny afternoon, Ruby came across a tired old tortoise named Toby, who was struggling to climb a steep hill. His legs moved slowly, and he sighed with every effort. Seeing Toby in distress, Ruby rushed over. "Let me help you, Toby!" she said, her heart full of compassion.\n\nWith the strength of her small body, Ruby offered to nudge Toby gently with her head so he could regain his footing. Slowly but surely, with Ruby\'s encouragement, Toby made it to the top of the hill. “Thank you, dear Ruby! You have such a kind heart,” said Toby, resting for a moment as he took in the view.\n\nA few days later, a grand race was announced in the forest, inviting all the animals to compete. Ruby, full of excitement and a bit of nervousness, decided to join. As she practiced, she overheard some animals gossiping about a dreadful storm approaching. It made her anxious, but she continued to train.\n\nOn the day of the race, dark clouds filled the sky, and soon, pouring rain began to fall. The animals, frightened and muddy, looked for shelter. Just then, Ruby spotted Toby, struggling again to find a safe place. Remembering her kindness, Ruby immediately went to help him.\n\n“Hop on my back, Toby! I’ll take you somewhere dry,” she urged. Together, Ruby dashed through the rain, finding a large tree that provided shelter for all the animals gathered there. They waited for the storm to pass, feeling grateful for Ruby\'s warmth and bravery.\n\nAs the rain ceased, the animals cheered Ruby’s name. “You saved us, Ruby! And today was the day of the race! We owe our safety to you!” shouted a little squirrel.\n\nWhen Ruby heard this, her heart swelled with joy. The animals decided then and there to hold a new race, not for speed but to celebrate friendship and kindness. Ruby and Toby took their places at the front, and all the animals raced together, laughing and cheering each other on.\n\nFrom that day forward, Ruby learned that kindness not only helped others in need but also led to unexpected rewards, like friendship and joy. And so, in that vibrant forest, the tales of Ruby\'s kindness spread from animal to animal, reminding all to help one another, for you never know what beautiful gifts might follow.\n\nAnd thus, as the sun set behind the hills, Ruby smiled knowing that kindness is truly a treasure that keeps on giving. \n\nMoral: When you are kind to others, you may find joy and friendship in return.'}
# [OUTPUT] - {'llm_input': 'Create a tale teaching children why perseverance is important in achieving their goals.', 'llm_output': 'Once upon a time in a lush green forest, there lived a young tortoise named Tilly. Unlike the other animals, Tilly was slow and often felt disheartened by her speed. While the rabbits raced around, showcasing their agility, Tilly would watch from the sidelines, dreaming of the day she could join them in their adventures.\n\nOne sunny morning, the wise owl, Mr. Hoot, announced a Great Race throughout the forest. All the animals were excited, especially the swift rabbits who boasted about their sure victory. Tilly watched, her heart pounding with a mix of excitement and fear. “I want to join,” she declared shyly. The other animals snickered, "You’re too slow, Tilly. You could never keep up!"\n\nBut Tilly remembered her grandmother’s words: “Perseverance is the path to success.” With newfound determination, she signed up for the race. The day of the race arrived, and Mr. Hoot blew his whistle. Off bounced the rabbits, swift as the wind, while Tilly plodded along at her own pace.\n\nAs the rabbits zoomed ahead, they grew overconfident. “Let’s take a break!” said Rabbity. They found a sunny patch and began to nap, thinking they had plenty of time to finish. Meanwhile, Tilly continued, slowly but surely, her little legs working hard with every step.\n\nWhen the rabbits woke up, they were startled to see the sun setting. “We must hurry!” they exclaimed and raced off. But it was too late. Just as they rounded a bend, they saw Tilly crossing the finish line, her head held high. The animals gasped in disbelief. “How did this happen?” cried the rabbits.\n\nMr. Hoot, with a twinkle in his eye, addressed the crowd. “This race teaches us a valuable lesson. Speed is not everything. Tilly’s perseverance and determination have proven that with hard work and tenacity, even the slowest among us can achieve great things.”\n\nFrom that day forward, Tilly became an inspiration to all the forest creatures. They learned that no matter how slow or small you may be, never give up on your dreams, for perseverance can lead you to victory. And so, Tilly the tortoise continued to race, not with the speed of the rabbits, but with the strength of her unwavering spirit. \n\nAnd the forest thrived in joy, knowing that sometimes, the slow and steady can indeed win the race.'}
’s misleading clues.\n\nBut as the sun started to set, Felix realized that his prank had gone too far. Benny was still chasing the treasure, and he hadn’t returned despite the growing darkness. Felix felt a pang of guilt as he thought of his friend, alone and searching in the dark. Instead of accepting his mistake and bringing Benny back, Felix covered his ears and continued to laugh with the other animals.\n\nAs the night grew darker, Felix's laughter faded and was replaced by worry. In that moment, he heard Benny's soft whimpers from somewhere in the bushes. Felix’s heart sank. He knew he had to take responsibility for his actions. Gathering his courage, he dashed into the woods and called out, “Benny! I’m sorry! I made a mistake! Follow my voice!”\n\nFinally, after searching and calling, Felix found Benny shivering beneath a bush. The little bunny looked up, eyes wide with fear. “I can’t find my way home!” he cried.\n\nFelix sighed deeply, regret filling his heart. “I led you on a wild chase. I’m so sorry, Benny. Let me help you.” \n\nWith newfound determination, Felix guided Benny back along the true path to safety. They walked together in silence, the moon shining brightly above them. When they finally reached Benny’s cozy burrow, the warmth of home made them both feel better.\n\n“Thank you for helping me, Felix,” said Benny, his fear replaced with relief. “I knew you were clever, but now I see you are also brave. You took responsibility for your mistake, and that’s what matters most.”\n\nFelix smiled, understanding the value of honesty and responsibility. As he nestled down for the night, he felt a little wiser and a little better for accepting his mistake. From that day forward, Felix decided he would use his cleverness to lift up his friends rather than to trick them.\n\nAnd so, in the forest, Felix the fox became known not only for his wit but also for his honesty, reminding everyone that true growth comes from accepting responsibility for one’s mistakes.\n\nMoral: Accepting responsibility for our mistakes can lead to personal growth and stronger friendships."}

# %% [markdown]
# # Score the data
#
# Let's score the data to see how the generator did.  This lets us focus on the "good" responses for use later.

# %%
from withpi_utils.colab import pretty_print_responses
from tqdm.notebook import tqdm

for example in tqdm(examples):
    pretty_print_responses(
        header="#### Input:\n" + example['llm_input'],
        response1="#### Output:\n" + example['llm_output'],
        left_label="Pi Synthetic Data",
        scores_left=score(example['llm_input'],example['llm_output']),
    )
    print("\n\n")
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a children's story teaching the importance of sharing with others.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time in a lush green forest, there lived a clever little squirrel named Sammy. Sammy was known far and wide for his incredible acorn stash. Every fall, while other animals toiled to collect their food, Sammy would gather the most acorns anyone had ever seen, storing them in his cozy tree hollow.</p>
# <p>One crisp autumn day, as Sammy admired his mountain of acorns, he heard a soft rustling nearby. Curiosity piqued, he peeked out and saw Lily the rabbit, her nose twitching with hunger. She looked thin and weary, having struggled to find enough food for the coming winter.</p>
# <p>"Hello, Sammy," Lily called, trying to sound cheerful. "Your acorns are so beautiful! Do you think you could spare just a few?"</p>
# <p>Sammy, with a hearty laugh, replied, "Oh, Lily, there are too many for me to eat! I'll never miss a few!" But deep down, he felt protective of his treasures and shook his head. "You should have gathered more when you had the chance!"</p>
# <p>Lily's ears drooped sadly, and she hopped away, searching for scraps elsewhere. As days passed, Sammy watched the leaves turn golden and the forest prepare for winter. Each time he went to his stash, he couldn’t help but think of poor Lily.</p>
# <p>One frosty morning, Sammy woke up to see a thick blanket of snow covering the ground. He ventured outside, ready to enjoy his acorns, but to his dismay, he found that many of them had frozen solid! As he tried to crack one open, he realized that he couldn’t eat them, and soon, he would go hungry.</p>
# <p>Feeling frightened and very cold, Sammy ran to find Lily, hoping she had had better luck. He discovered her snug in her burrow with a warm fire and lots of food. Seeing her cozy home, Sammy felt a pang of regret.</p>
# <p>"Please, Lily," he asked shivering, "I was unkind, and I need help. I didn’t think I would have trouble eating. Can you share some of your food with me?"</p>
# <p>Lily looked at Sammy for a moment, then smiled. "Of course, Sammy! I would love to share. But remember, sometimes it is good to share before you need something in return."</p>
# <p>As Sammy shared in Lily’s kindness, he learned a valuable lesson that day: Sharing creates bonds of friendship and ensures no one goes hungry in times of need. From that winter on, Sammy not only gathered acorns but also made sure to share with others in the forest. And those who came together through sharing found warmth not just from food, but in their hearts.</p>
# <p>And so, the clever little squirrel and the kind rabbit thrived together, all thanks to the power of sharing. </p>
# <p>The moral of the story: Sharing with others brings happiness and builds friendships that can warm the coldest of days.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #2dcb70'>0.754</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #28b363'><b>0.951</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Create a story that illustrates the value of honesty in everyday situations.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once in a peaceful forest, there lived a clever little fox named Finn. Finn was known for his sharp mind and quick tricks, often outsmarting other animals when searching for food. However, there was one thing he loved more than his cleverness—his shiny, golden bell.</p>
# <p>One sunny morning, while playing by the river, Finn accidentally dropped his golden bell into the water. He stared in despair as it sank below the surface. Just then, Benny, the wise old turtle, appeared beside him.</p>
# <p>“Why do you look so sad, Finn?” asked Benny.</p>
# <p>“My lovely bell is lost!” Finn cried. “I’ll do anything to get it back!”</p>
# <p>Benny pondered for a moment, then suggested, “Perhaps you could ask the water sprites for help. They love shiny things and might have seen it.”</p>
# <p>Finn, being clever, decided to wave the bell’s loss around to gather a crowd. He called all the animals of the forest, claiming he had a treasure beyond compare—a magical golden bell that could grant wishes.</p>
# <p>The animals were intrigued and gathered around, eager to hear how it worked. Finn, full of excitement, spun tales of its wonders, leaving out the part about it being lost.</p>
# <p>“Gather and form a line,” he announced, “and you shall get your wish!”</p>
# <p>Just then, Benny the turtle stepped forward and raised a paw. “Finn, is this truly honest? You are misrepresenting the truth.”</p>
# <p>Finn scoffed, “What does honesty matter? I’ll get their help, and then I’ll find my bell!”</p>
# <p>Despite Benny’s caution, Finn continued his scheme. The animals, entranced by his stories, lined up eagerly. Yet, as they each approached him, Finn fumbled for answers, realizing he couldn’t deliver the wishes he promised.</p>
# <p>Frustration grew among the animals when Finn could not fulfill the magic he had claimed. One by one, they left disappointed, feeling tricked and angry.</p>
# <p>Seeing this, Benny sighed and said, “Finn, you should have been honest from the start. Instead of trying to impress others, you should have simply told them the truth.”</p>
# <p>Finn’s heart sank as he realized that his cleverness had caused disappointment, not only for others but also for himself. He had lost the trust of his friends, and his shiny bell was still lost in the depths of the river.</p>
# <p>Feeling ashamed, Finn decided to come clean. He gathered the animals once more and said, “Dear friends, I misled you. My bell is lost, and I cannot grant wishes. I only wanted to feel important and clever.”</p>
# <p>The animals listened intently, and slowly, they forgave him. They appreciated his honesty. Inspired, they decided to help Finn search for his golden bell together. With teamwork and genuine efforts, they finally retrieved the bell from the river.</p>
# <p>From that day on, Finn learned the value of honesty. He realized that it was far better to be truthful and genuine with others, rather than trying to impress them with tricks and lies. In doing so, he not only regained his golden bell but also the trust and friendship of the entire forest.</p>
# <p>And so, the clever fox turned wise, and the forest thrived on the honesty that had brought them all together.</p>
# <p>The moral of the story: Honesty is the best policy; it builds trust and friendship.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27ae60'><b>1.0</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Tell a fable about why teamwork leads to greater success.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time in a lush green forest, there lived a group of animals: Benny the Bear, Lucy the Lizard, and Freddy the Fox. Each was strong and clever in their own right, but they often preferred to work alone. One hot summer day, a rumor spread through the forest about a huge pile of juicy berries hidden deep in the woods. Each animal dreamed of feasting on the sweet treat.</p>
# <p>Benny pounded through the thick bushes, thinking his strength would help him reach the berries faster than anyone else. Lucy scurried along narrow paths, convinced that her speed and agility would lead her right to the prize. Freddy, with his sharp wits, chose to sneak through the shadows, believing that his stealth would guarantee success.</p>
# <p>As they ventured deeper into the forest, Benny found himself stuck in a marshy area, his large paws sinking into the mud. Lucy, too, faced trouble; she was darting around wildly when she accidentally led herself into a web of prickly thorns. Freddy, while being sneaky, found that the deeper he went, the more tangled up he became in the underbrush, unable to move.</p>
# <p>After a while, the three animals met at the old oak tree, each covered in mud, thorns, and brambles. They realized they had all failed on their own.</p>
# <p>"Perhaps we should work together," suggested Lucy, who had finally wiped some thorns from her tiny legs. "Each of us has something to contribute!"</p>
# <p>Benny nodded, "That makes sense. I can clear away the heavy branches with my strength."</p>
# <p>Freddy grinned, "And I can scout ahead to find the best path to the berries!"</p>
# <p>So, they teamed up. Benny used his strength to push aside fallen logs, Lucy zipped around to find the safest routes, and Freddy guided them, ensuring they avoided traps and obstacles. With their combined skills, they quickly navigated the forest, speaking and strategizing together.</p>
# <p>Finally, after a short while, they stumbled upon the colossal patch of berries, ripe and glistening in the sunlight. They all cheered in delight, filled with excitement as they chomped down on the delicious fruit.</p>
# <p>From that day forward, the trio learned the value of teamwork. They shared not just the berries but also their adventures, knowing that together they could accomplish what was impossible alone.</p>
# <p>And so, the wise animals of the forest added a new lesson to their stories: "When we work together, we can achieve greater feats than we ever could alone." </p>
# <p>The End.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>0.996</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #2cc46c'>0.809</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #28b463'>0.941</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #28b363'><b>0.949</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a story that shows how being kind to others can lead to unexpected rewards.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once in a bright and blooming forest lived a kind little rabbit named Ruby. Ruby had a soft, fluffy coat and gentle eyes that sparkled with kindness. Every day, she hopped along the winding paths, greeting her friends and helping those in need.</p>
# <p>One sunny afternoon, Ruby came across a tired old tortoise named Toby, who was struggling to climb a steep hill. His legs moved slowly, and he sighed with every effort. Seeing Toby in distress, Ruby rushed over. "Let me help you, Toby!" she said, her heart full of compassion.</p>
# <p>With the strength of her small body, Ruby offered to nudge Toby gently with her head so he could regain his footing. Slowly but surely, with Ruby's encouragement, Toby made it to the top of the hill. “Thank you, dear Ruby! You have such a kind heart,” said Toby, resting for a moment as he took in the view.</p>
# <p>A few days later, a grand race was announced in the forest, inviting all the animals to compete. Ruby, full of excitement and a bit of nervousness, decided to join. As she practiced, she overheard some animals gossiping about a dreadful storm approaching. It made her anxious, but she continued to train.</p>
# <p>On the day of the race, dark clouds filled the sky, and soon, pouring rain began to fall. The animals, frightened and muddy, looked for shelter. Just then, Ruby spotted Toby, struggling again to find a safe place. Remembering her kindness, Ruby immediately went to help him.</p>
# <p>“Hop on my back, Toby! I’ll take you somewhere dry,” she urged. Together, Ruby dashed through the rain, finding a large tree that provided shelter for all the animals gathered there. They waited for the storm to pass, feeling grateful for Ruby's warmth and bravery.</p>
# <p>As the rain ceased, the animals cheered Ruby’s name. “You saved us, Ruby! And today was the day of the race! We owe our safety to you!” shouted a little squirrel.</p>
# <p>When Ruby heard this, her heart swelled with joy. The animals decided then and there to hold a new race, not for speed but to celebrate friendship and kindness. Ruby and Toby took their places at the front, and all the animals raced together, laughing and cheering each other on.</p>
# <p>From that day forward, Ruby learned that kindness not only helped others in need but also led to unexpected rewards, like friendship and joy. And so, in that vibrant forest, the tales of Ruby's kindness spread from animal to animal, reminding all to help one another, for you never know what beautiful gifts might follow.</p>
# <p>And thus, as the sun set behind the hills, Ruby smiled knowing that kindness is truly a treasure that keeps on giving. </p>
# <p>Moral: When you are kind to others, you may find joy and friendship in return.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #2dcb70'>0.754</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #28b363'><b>0.951</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Create a tale teaching children why perseverance is important in achieving their goals.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time in a lush green forest, there lived a young tortoise named Tilly. Unlike the other animals, Tilly was slow and often felt disheartened by her speed. While the rabbits raced around, showcasing their agility, Tilly would watch from the sidelines, dreaming of the day she could join them in their adventures.</p>
# <p>One sunny morning, the wise owl, Mr. Hoot, announced a Great Race throughout the forest. All the animals were excited, especially the swift rabbits who boasted about their sure victory. Tilly watched, her heart pounding with a mix of excitement and fear. “I want to join,” she declared shyly. The other animals snickered, "You’re too slow, Tilly. You could never keep up!"</p>
# <p>But Tilly remembered her grandmother’s words: “Perseverance is the path to success.” With newfound determination, she signed up for the race. The day of the race arrived, and Mr. Hoot blew his whistle. Off bounced the rabbits, swift as the wind, while Tilly plodded along at her own pace.</p>
# <p>As the rabbits zoomed ahead, they grew overconfident. “Let’s take a break!” said Rabbity. They found a sunny patch and began to nap, thinking they had plenty of time to finish. Meanwhile, Tilly continued, slowly but surely, her little legs working hard with every step.</p>
# <p>When the rabbits woke up, they were startled to see the sun setting. “We must hurry!” they exclaimed and raced off. But it was too late. Just as they rounded a bend, they saw Tilly crossing the finish line, her head held high. The animals gasped in disbelief. “How did this happen?” cried the rabbits.</p>
# <p>Mr. Hoot, with a twinkle in his eye, addressed the crowd. “This race teaches us a valuable lesson. Speed is not everything. Tilly’s perseverance and determination have proven that with hard work and tenacity, even the slowest among us can achieve great things.”</p>
# <p>From that day forward, Tilly became an inspiration to all the forest creatures. They learned that no matter how slow or small you may be, never give up on your dreams, for perseverance can lead you to victory. And so, Tilly the tortoise continued to race, not with the speed of the rabbits, but with the strength of her unwavering spirit. </p>
# <p>And the forest thrived in joy, knowing that sometimes, the slow and steady can indeed win the race.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #2bc26b'>0.824</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27b162'><b>0.965</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a story showing the negative consequences of greed.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a lush green valley, there lived a clever fox named Felix. He was known far and wide for his cunning tricks and his insatiable desire for treasure. One sunny afternoon, while wandering through the forest, Felix stumbled upon a hidden cave. Curiosity sparked in his eyes as he peeked inside and to his amazement, he found heaps of sparkling jewels and glistening gold coins.</p>
# <p>Excited by his discovery, Felix began to gather the treasures, filling his pockets until they were about to burst. Yet, the more he collected, the greedier he became. “I can’t just take a little,” he thought to himself. “I deserve all of this!”</p>
# <p>So, Felix devised a plan. He would return to the cave every day, taking as much treasure as he could carry. But the more he took, the more he wanted. Day after day, he packed himself with jewels, failing to realize that they were far too heavy for him to carry.</p>
# <p>One fateful day, as he entered the cave with a great big sack, he decided he wanted even more. Ignoring the warning signs in his heart, he stuffed the sack full until it was bursting at the seams. Just as he was about to leave, he saw one last shining emerald nestled at the back of the cave. Felix’s eyes sparkled with greed, and he lunged for it.</p>
# <p>But, with the sack so full and heavy, he lost his balance. The polished stones glimmered in the dim light before they came crashing down upon him. The floor of the cave trembled, and suddenly, rocks began to fall. In his avarice, Felix could not escape, and he was trapped beneath the weight of his own greed.</p>
# <p>Days passed before the other animals of the forest noticed that Felix had not returned. Worried, they ventured into the cave and found him buried under shining stones. The wise old owl, who had been searching for Felix, shook his head sadly. "Dear Felix,” the owl said, “your greed has led you to this fate. You wanted more than you needed, and now you have lost everything.”</p>
# <p>Realizing his folly, Felix learned that in his quest for treasure, he had risked it all. He had too much and had let his greed cloud his judgment. With help from the other animals, they managed to free him, but the treasures he had once adored were lost forever.</p>
# <p>From that day on, Felix understood that true wealth lies not in treasures, but in the friendships and kindness we share. He vowed to never let greed guide his heart again.</p>
# <p>And so, the tale of Felix the fox whispers through the valley, reminding everyone that greed can lead to one’s downfall, while appreciation for what we have brings true happiness. </p>
# <p>Moral: Greed can lead to loss, but valuing what we have brings true happiness.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #47ca64'>0.715</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #28b463'><b>0.943</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Tell a children's story explaining why listening to advice can be helpful.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time in a sunny meadow lived a young rabbit named Benny. Benny was energetic and full of curiosity, always hopping around to explore new places. He loved to discover things on his own, and often ignored the guidance of the wise old tortoise, Mr. Tumble.</p>
# <p>One bright morning, as the sun rose high in the sky, Benny overheard a few birds chirping about a delicious patch of clover in a nearby field. Their beaks glittered as they spoke about the sweet, tender clovers that awaited them. Benny, excited by the thought of a meal, decided to hop over there right away without thinking twice.</p>
# <p>As he rushed forward, he passed by Mr. Tumble, who was slowly munching on some delicious grass. "Benny, my dear," said Mr. Tumble, "be cautious as you race off! There could be hidden dangers in that field." </p>
# <p>Benny, feeling clever and adventurous, waved his paw dismissively. "Oh, Mr. Tumble! You worry too much! I can take care of myself!" And off he hopped, ignoring the wise tortoise's advice.</p>
# <p>Arriving at the patch of clover, Benny was thrilled to see vast green leaves shining in the sun. He eagerly began munching on the clover, but as he dove deeper into the field, he suddenly noticed something strange—the ground began to tremble beneath him!</p>
# <p>Benny looked down and saw a trap laid for unsuspecting animals, hidden cleverly among the clovers. In a panic, he realized that he was caught! The more he struggled, the more trapped he felt. All the joy of the food faded as he was ensnared in the weeds.</p>
# <p>Just then, Mr. Tumble appeared, moving slowly but surely toward Benny. "I told you to be cautious, my friend," he said with compassion. Using his sturdy shell, Mr. Tumble carefully nudged away some of the clovers to give Benny enough room to escape. With a few big hops, Benny was free at last!</p>
# <p>Breathless and grateful, Benny turned to Mr. Tumble. "I should have listened to you. Your advice was wise, and I could have avoided this trouble if I had only heeded your words."</p>
# <p>Mr. Tumble nodded gently. "Sometimes, dear Benny, those who have more experience can see dangers we cannot. It is wise to listen and learn from others."</p>
# <p>From that day on, Benny always remembered the lesson he learned. He still loved to explore, but he made sure to listen to the advice of wise friends first. And so, Benny the rabbit became known not just for his curiosity, but also for his willingness to listen, making him one of the wisest animals in the meadow.</p>
# <p>And the moral of the story is: Listening to the advice of those with experience can save us from trouble.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #27af61'>0.98</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27ae60'><b>0.996</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Create a fable teaching children that patience often leads to better outcomes.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time in a lush, green forest, there lived a young hare named Harry. Harry was known for his speed and enthusiasm, always bounding around the meadow, nipping at flowers and frolicking with his friends. One sunny day, as he raced past the old sage owl, he noticed a slow but steady tortoise named Tina, who was sipping dew from the leaves.</p>
# <p>“Why do you move so slowly, Tina?” Harry laughed, his ears bouncing in rhythm to his giggles. “You’ll never get anywhere at that pace!”</p>
# <p>Tina looked up and smiled gently. “I prefer to take my time, Harry. There's more to life than rushing. You might be surprised by the outcomes.”</p>
# <p>But Harry, too full of energy, scoffed at her words. “I’ll show you how fast I can get things done!” he shouted, zooming away.</p>
# <p>Later, a rumor spread across the forest of a wonderful prize hidden deep in the woods. The prize was a delicious golden carrot that would bring happiness to whoever found it. News traveled fast, and all the animals were eager to find it. Harry, excited by the prospect, took off at top speed, darting through bushes and leaping over rocks. He dashed through the forest, convinced that his speed would earn him the carrot first.</p>
# <p>Meanwhile, Tina, with her steady and deliberate pace, began her journey too. She looked around, enjoying the colorful flowers and the chirping of the birds, taking the time to appreciate all the sights and sounds of the forest.</p>
# <p>As Harry zipped through the woods, he raced right past the golden carrot, hidden under a leafy bush. He didn’t notice it, too busy chasing after the thought of being first. He continued his sprint, convinced there was more prize ahead.</p>
# <p>Eventually, panting and exhausted, Harry paused to catch his breath. He turned around and searched frantically. It was then he saw Tina, slowly and steadily making her way to the bush where the golden carrot lay.</p>
# <p>“Slow and steady wins the race, Harry,” Tina said with a twinkle in her eye as she gently lifted the carrot from its hiding place. “Sometimes, patience brings the sweetest reward.”</p>
# <p>Harry, humbled, realized the truth in Tina’s words. It wasn’t just about speed; it was about being aware and taking your time. He squeaked out a smile and joined Tina as she shared the delicious golden carrot, learning that sometimes by slowing down, you can truly savor the journey and find the treasures missed in haste.</p>
# <p>And from that day on, whether it was racing friends or finding a treasure, Harry learned to balance his energetic spirit with the art of patience. </p>
# <p>The moral of the story: Patience often leads to better outcomes than rushing ahead.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #2cc56d'>0.801</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #28b262'><b>0.96</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a story that demonstrates how accepting responsibility for mistakes can lead to personal growth.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Pi Synthetic Data</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once in a lush green forest, there lived a clever little fox named Felix. Felix was known throughout the forest for his quick wit and playful tricks. He loved to show off his cleverness by playing pranks on his friends. </p>
# <p>One sunny morning, Felix devised a grand plan to trick his friend, Benny the bunny. He set up a fake treasure map that led Benny on a wild chase through the forest, promising him delightful carrots at the end. Everyone gathered to watch the spectacle, chuckling as Benny hopped eagerly along the false trail, following the map’s misleading clues.</p>
# <p>But as the sun started to set, Felix realized that his prank had gone too far. Benny was still chasing the treasure, and he hadn’t returned despite the growing darkness. Felix felt a pang of guilt as he thought of his friend, alone and searching in the dark. Instead of accepting his mistake and bringing Benny back, Felix covered his ears and continued to laugh with the other animals.</p>
# <p>As the night grew darker, Felix's laughter faded and was replaced by worry. In that moment, he heard Benny's soft whimpers from somewhere in the bushes. Felix’s heart sank. He knew he had to take responsibility for his actions. Gathering his courage, he dashed into the woods and called out, “Benny! I’m sorry! I made a mistake! Follow my voice!”</p>
# <p>Finally, after searching and calling, Felix found Benny shivering beneath a bush. The little bunny looked up, eyes wide with fear. “I can’t find my way home!” he cried.</p>
# <p>Felix sighed deeply, regret filling his heart. “I led you on a wild chase. I’m so sorry, Benny. Let me help you.” </p>
# <p>With newfound determination, Felix guided Benny back along the true path to safety. They walked together in silence, the moon shining brightly above them. When they finally reached Benny’s cozy burrow, the warmth of home made them both feel better.</p>
# <p>“Thank you for helping me, Felix,” said Benny, his fear replaced with relief. “I knew you were clever, but now I see you are also brave. You took responsibility for your mistake, and that’s what matters most.”</p>
# <p>Felix smiled, understanding the value of honesty and responsibility. As he nestled down for the night, he felt a little wiser and a little better for accepting his mistake. From that day forward, Felix decided he would use his cleverness to lift up his friends rather than to trick them.</p>
# <p>And so, in the forest, Felix the fox became known not only for his wit but also for his honesty, reminding everyone that true growth comes from accepting responsibility for one’s mistakes.</p>
# <p>Moral: Accepting responsibility for our mistakes can lead to personal growth and stronger friendships.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27ae60'><b>1.0</b></td></tr>
# </table>
#                 </div>
#             </div>

# %% [markdown]
# ## Next Steps
#
# This set can drive training or evaluation workflows.  You can adjust the above methods to add seeds and steer the AI in different ways.
