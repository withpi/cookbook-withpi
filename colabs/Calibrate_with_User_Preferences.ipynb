# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/colabs/Calibrate_with_User_Preferences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://withpi.ai"><img src="https://play.withpi.ai/logo/logoFullBlack.svg" width="240"></a>
#
# <a href="https://code.withpi.ai"><font size="4">Documentation</font></a>
#
# <a href="https://build.withpi.ai"><font size="4">Copilot</font></a>

# %% [markdown]
# # Calibrate with User Preferences
#
# This Colab is the companion to the Preference Collection Playground, showing how you can apply preference data to your training pipeline.
#
# It's easier to collect training data from the UI, but this Colab will have you rate a small number of examples in-line.
#
# We will walk through the same `Aesop AI` example, but any contract with feedback data should work.

# %% [markdown]
# ## Install and initialize SDK
#
# You'll need a `WITHPI_API_KEY` from https://build.withpi.ai/account.  Add it to your notebook secrets (the key symbol) on the left.
#
# Run the cell below to install packages and load the SDK

# %%
# %%capture

# %pip install withpi withpi-utils datasets tqdm litellm pandas numpy

import os
from google.colab import userdata
from withpi import PiClient

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

pi = PiClient()

# %% [markdown]
# # Load a scoring spec and a dataset

# %%
# @title Load Scoring Spec
from withpi_utils.colab import load_scoring_spec_from_web, display_scoring_spec

aesop_scoring_spec = load_scoring_spec_from_web(
    "https://raw.githubusercontent.com/withpi/cookbook-withpi/refs/heads/main/scoring_specs/aesop_ai.json"
)

display_scoring_spec(aesop_scoring_spec)
# Out:
# <div style='font-family: Arial, sans-serif;'><h2 style='color: #202124; border-bottom: 2px solid #4285F4; padding-bottom: 8px; margin-bottom: 10px;'>ScoringSpec: aesop_ai</h2><p style='margin-top: 0; margin-bottom: 20px; color: #5F6368;'>Write a children's story in the style of Aesop's Fables teaching a life lesson specified by the user.  Provide just the story with no extra content.</p><h3 style='margin-bottom: 5px; color: #4285F4;'>Story Structure</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story have a clear beginning, middle, and end?</li><li><strong>PI_SCORER:</strong> Is there a conflict introduced early in the story that drives the plot?</li><li><strong>PI_SCORER:</strong> Is the resolution of the conflict clear and satisfying?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Character Development</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story include characters that are relatable for children?</li><li><strong>PI_SCORER:</strong> Do the characters demonstrate growth or change by the end of the story?</li><li><strong>PI_SCORER:</strong> Is the dialogue between characters natural and age-appropriate?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Narrative Engagement</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Is the story engaging and likely to hold a child's interest?</li><li><strong>PI_SCORER:</strong> Does the story use vivid imagery to help children visualize the scenes?</li><li><strong>PI_SCORER:</strong> Does the story incorporate repetitive elements that aid in comprehension and retention?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Language Appropriateness</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Is the language used in the story appropriate for children's understanding?</li><li><strong>PI_SCORER:</strong> Is the story an appropriate length for a children's tale (not exceeding 1000 words)?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Moral and Cultural Sensitivity</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story clearly convey a specified life lesson?</li><li><strong>PI_SCORER:</strong> Does the story reiterate the moral lesson at the end?</li><li><strong>PI_SCORER:</strong> Is the content culturally sensitive and inclusive for all children?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Illustration Integration</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story provide opportunities for illustrations that enhance the narrative?</li></ul></div>

# %%
# @title Load dataset
from datasets import load_dataset

aesop_dataset = load_dataset("withpi/aesop", split="train")

print(aesop_dataset)
# Out:
# Dataset({
#     features: ['input', 'output'],
#     num_rows: 23
# })

# %% [markdown]
# ## Cluster Inputs
#
# We're going to label some inputs as "good" and "bad", but to do this it is helpful to focus on a few different types of input.  We'll use clustering to make sure we don't have to look at too many examples.

# %%
import pandas as pd

input_topic_clusters = client.data.cluster_inputs(
    inputs=[
        {"identifier": str(index), "llm_input": row["input"]}
        for index, row in enumerate(aesop_dataset)
    ],
)

cluster_data = []
topics = [None] * len(aesop_dataset)
for cluster in input_topic_clusters:
    cluster_data.append([cluster.topic, cluster.inputs, len(cluster.inputs)])
    for item in cluster.inputs:
        topics[int(item)] = cluster.topic

cluster_df = pd.DataFrame(cluster_data, columns=["Topic", "Items", "Size"])
cluster_df
# Out:
#                                     Topic  \
# 0      "Animal Fables with Moral Lessons"
# 1         "Fables Teaching Moral Lessons"
# 2  "Tortoise-Themed Moral Story Requests"
#
#                                         Items  Size
# 0  [1, 4, 5, 7, 8, 9, 11, 14, 16, 17, 18, 20]    12
# 1                  [2, 6, 12, 13, 15, 21, 22]     7
# 2                              [0, 3, 10, 19]     4

# %% [markdown]
# ## Identify outliers
#
# Let's first score every input against the scoring system, adding that as a column.  Pi scoring is fast enough that serially processing the dataset is fine, though we could increase parallelism for more speed.

# %%
# @title Score all examples
from tqdm import tqdm

scores = []
for example in tqdm(aesop_dataset):
    scores.append(
        client.scoring_system.score(
            scoring_spec=aesop_scoring_spec,
            llm_input=example["input"],
            llm_output=example["output"],
        )
    )

df = pd.DataFrame(
    {
        "input": aesop_dataset["input"],
        "output": aesop_dataset["output"],
        "cluster topic": topics,
        "score": [score.total_score for score in scores],
    }
)

df
# Out:
# 100%|██████████| 23/23 [00:05<00:00,  4.00it/s]
#                                                 input  \
# 0   Write a children's story in the style of Aesop...
# 1   Tell a fable about a crow and a fox that illus...
# 2   Create a story featuring a lion and a mouse th...
# 3   Write a fable involving a tortoise and a hare ...
# 4   Tell a story about a greedy dog who loses his ...
# 5   Spin a tale with a squirrel and an owl teachin...
# 6   Compose a fable with a feuding sun and wind th...
# 7   Dream up a story involving a hummingbird and a...
# 8   Tell a saga with a rabbit and a cunning crow i...
# 9   Craft a fable about a young rabbit needing hel...
# 10  Weave a tale about a lonely tortoise learning ...
# 11  Create a story with a novice ant who refuses g...
# 12  Think up a scenario involving a butterfly emba...
# 13  Make up a tale with a nurturing bear protectin...
# 14  Spin a tale with a squirrel and an owl teachin...
# 15  Compose a fable with a feuding sun and wind th...
# 16  Dream up a story involving a hummingbird and a...
# 17  Tell a saga with a rabbit and a cunning crow i...
# 18  Craft a fable about a young rabbit needing hel...
# 19  Weave a tale about a lonely tortoise learning ...
# 20  Create a story with a novice ant who refuses g...
# 21  Think up a scenario involving a butterfly emba...
# 22  Make up a tale with a nurturing bear protectin...
#
#                                                output  \
# 0   Barnaby the hare was a blur of twitching whisk...
# 1   Once upon a time, in a sun-drenched forest, li...
# 2   Leo the lion, king of the sprawling savanna, w...
# 3   The Tortoise and the Determined Hare\n\nIn the...
# 4   Barnaby the Beagle was a dog of magnificent ap...
# 5   Barnaby the squirrel was renowned throughout t...
# 6   The Sun and the Wind\n\nThe Sun, a fiery ball ...
# 7   Pip the hummingbird, a flash of emerald and ru...
# 8   Barnaby the rabbit was a champion hopper.  He'...
# 9   Barnaby Bunson was a young rabbit with a very ...
# 10  Shelton the tortoise was a creature of habit. ...
# 11  A tiny ant, no bigger than a grain of rice, na...
# 12  Pip the butterfly was a worrier.  He watched t...
# 13  Barnaby the bear cub was a whisper.  He wasn't...
# 14  Barnaby the squirrel was renowned throughout t...
# 15  The Sun and the Wind argued, as they often did...
# 16  The hummingbird, Pip, zipped and zoomed throug...
# 17  Barnaby the rabbit was renowned.  Renowned for...
# 18  Barnaby the bunny was a proud young rabbit.  H...
# 19  Sheldon the tortoise was a creature of habit. ...
# 20  Tiny, a brand-new ant, emerged from her chrysa...
# 21  Pip the butterfly was a beautiful creature, bu...
# 22  Barnaby the bear cub was a shadow of a bear.  ...
#
#                              cluster topic     score
# 0   "Tortoise-Themed Moral Story Requests"  0.831055
# 1       "Animal Fables with Moral Lessons"  0.889540
# 2          "Fables Teaching Moral Lessons"  0.808051
# 3   "Tortoise-Themed Moral Story Requests"  0.974392
# 4       "Animal Fables with Moral Lessons"  0.972222
# 5       "Animal Fables with Moral Lessons"  0.980035
# 6          "Fables Teaching Moral Lessons"  0.876519
# 7       "Animal Fables with Moral Lessons"  0.987413
# 8       "Animal Fables with Moral Lessons"  0.999783
# 9       "Animal Fables with Moral Lessons"  0.987847
# 10  "Tortoise-Themed Moral Story Requests"  0.976997
# 11      "Animal Fables with Moral Lessons"  0.946832
# 12         "Fables Teaching Moral Lessons"  0.999132
# 13         "Fables Teaching Moral Lessons"  0.986762
# 14      "Animal Fables with Moral Lessons"  0.986979
# 15         "Fables Teaching Moral Lessons"  0.953342
# 16      "Animal Fables with Moral Lessons"  0.950521
# 17      "Animal Fables with Moral Lessons"  0.997613
# 18      "Animal Fables with Moral Lessons"  0.998698
# 19  "Tortoise-Themed Moral Story Requests"  0.871970
# 20      "Animal Fables with Moral Lessons"  0.879774
# 21         "Fables Teaching Moral Lessons"  0.999783
# 22         "Fables Teaching Moral Lessons"  0.977214

# %%
# @title Manually inspect the scores
from withpi_utils.colab import pretty_print_responses


for i in tqdm(range(10)):
    row = aesop_dataset[i]
    pretty_print_responses(
        header="#### Input:\n" + row["input"],
        response1="#### Output:\n" + row["output"],
        scores_left=scores[i],
    )
    print("\n\n")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a children's story in the style of Aesop's Fables that teaches the lesson 'Slow and steady wins the race.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the hare was a blur of twitching whiskers and bouncing leaps.  He scoffed at the tortoise, Theodore, whose pace was slower than a snail's.  "You lumbering, plodding creature!" Barnaby would boast, his long ears flopping with each impatient hop. "I'll be across the meadow before you've even started!"</p>
# <p>One spring day, the meadow flowers were in full bloom, their colours like painted rainbows.  A grand festival of the flowers was being held, and a delicious honey cake, baked by the buzzing bees, was the prize.  Barnaby, full of confidence, dashed off, his legs moving like lightning. He zig-zagged through the tall grass, his heart pounding with excitement.</p>
# <p>Theodore, true to form, started at a steady pace. He methodically made his way through the meadow, nibbling clover and checking each flower for hidden dew drops.  Barnaby, distracted by the sparkling brook and the buzzing dragonflies, took a detour to admire a particularly beautiful buttercup.  He paused to chase a butterfly, and then, lost in a game of tag with a mischievous squirrel, he completely lost his way.</p>
# <p>Theodore, meanwhile, continued his steady progress.  He encountered a patch of thorny bushes, but carefully maneuvered around them.  He navigated a tricky stream by slowly and deliberately finding the shallowest part.  He was always mindful of his surroundings, even when the pace seemed slow to him.</p>
# <p>Finally, the finish line, a magnificent oak tree beneath which the bees had placed the honey cake, came into sight. Barnaby, exhausted and disoriented, arrived panting and sweating.  The honey cake had already been devoured!  Theodore, though hours behind Barnaby's initial start, was the next to reach the tree. He'd navigated the meadow with care and determination.</p>
# <p>Theodore, with a thoughtful sigh, smiled at Barnaby. "You may run fast, Barnaby," he said, "but slow and steady brings you to the finish line, safely."</p>
# <p>Barnaby, seeing the empty plates and the disappointed expressions of the flowers, realized that Theodore was right.  From that day on, Barnaby learned that haste, without care, leads to empty promises, and a slow, thoughtful approach can be just as rewarding – and perhaps even more reliable.  And he learned the truth of the adage: Slow and steady wins the race.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc16a'>0.839</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dca70'>0.758</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2abe69'>0.862</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #2bc26b'>0.828</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2dcb70'>0.755</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dcb70'>0.75</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2dca70'>0.762</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #28b463'>0.947</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #29ba66'>0.895</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #2bc26b'>0.829</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #2dc86f'>0.773</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2ecb70'>0.746</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27b161'>0.969</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2bc26b'><b>0.831</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Tell a fable about a crow and a fox that illustrates the importance of being cautious with flattery.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a sun-drenched forest, lived a clever crow named Corvus.  Corvus was known throughout the woods for his magnificent, iridescent feathers, which shimmered like captured sunlight.  A sly fox, named Reynard, prowled the forest, his eyes gleaming with cunning.</p>
# <p>Reynard, always on the lookout for an easy meal, spied Corvus perched on a branch.  He padded silently towards him, a mischievous glint in his eye.</p>
# <p>"Oh, Corvus," Reynard purred, his voice smooth as honey. "What a magnificent creature you are!  Your plumage is the most exquisite I've ever beheld.  No other bird in the forest can compare."</p>
# <p>Corvus, flattered beyond measure, puffed up his feathers. "Indeed," he crowed, feeling quite important. "My beauty is unparalleled."</p>
# <p>Reynard continued his flattery. "And your voice! It is like the sweet chime of a thousand bells. I've never heard such melodious notes."</p>
# <p>Corvus's tail feathers trembled with pride.  "My song is a gift from the gods," he boasted.</p>
# <p>Reynard, with a sly smile, then said, "You are the most magnificent bird in the whole forest.  Why not come with me to my den?  I have a feast prepared just for you, a feast worthy of such a splendid creature."</p>
# <p>Corvus, utterly convinced of his own magnificence, forgot all caution.  He hopped down from the branch and followed Reynard into the deep woods.</p>
# <p>Reynard, however, led him, not to a feast, but to a trap.  A deep pit, cleverly disguised with leaves and twigs, awaited the unsuspecting crow.</p>
# <p>Corvus, still basking in the glow of Reynard's praise, landed in the pit with a startled caw.  He looked up, bewildered, at Reynard.</p>
# <p>Reynard laughed, a sound like tinkling ice. "I'm afraid," he said, "your magnificent plumage and melodious voice are no match for a good old-fashioned trap."</p>
# <p>Corvus, finally understanding his mistake, scolded Reynard for his deception.  "You flattered me with empty words," he said. "Foolish of me to believe such hollow praise."</p>
# <p>Reynard merely smirked, and scurried away, leaving Corvus to recover from his near-tragedy.</p>
# <p>From that day on, Corvus learned a valuable lesson.  He learned that true worth isn't found in empty flattery, but in the strength of one's own character and careful judgment. He never trusted a flattering word again, and wisely chose his company with care.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bbf6a'>0.849</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dca70'>0.758</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #27b262'>0.964</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #29ba67'>0.891</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2cc46c'>0.81</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #29b765'>0.918</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #28b664'>0.926</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dc86e'>0.777</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2cc66e'>0.789</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2abb67'><b>0.89</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Create a story featuring a lion and a mouse that conveys the message 'Even the smallest friends can be the most helpful.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Leo the lion, king of the sprawling savanna, was a creature of immense pride. He ruled with a roar that echoed through the tall grass, and his mane, a golden crown, shimmered in the sun.  He had everything a lion could want – plenty of meat, a comfortable den, and, of course, the unwavering respect of all the other animals.</p>
# <p>But Leo was also very, very lonely.  He spent his days patrolling his territory, his powerful paws barely touching the ground as he stalked imaginary prey.  He was so focused on his own importance that he hardly noticed the smaller creatures around him.</p>
# <p>One scorching afternoon, Leo was napping under a baobab tree, his magnificent roar reduced to a gentle snore.  Suddenly, a tiny squeak shattered the silence.  A tiny mouse, no bigger than Leo's paw, had somehow gotten tangled in a thick vine near his mighty foot.</p>
# <p>The mouse, frantic with fear, squeaked and squirmed, unable to free itself.  Leo, roused from his sleep, grumbled.  "Another pest," he muttered, adjusting his magnificent mane. "Such a tiny creature, and yet it dares to disturb my nap!" He was about to swat the mouse away, when he saw the mouse's desperate little face.</p>
# <p>Something in the mouse's eyes, a mix of fear and helplessness, stirred a flicker of something new in Leo's heart – something close to... pity.  Instead of crushing the tiny creature, Leo carefully nudged the vine with his nose.  It was no use.  The vine held fast.</p>
# <p>He tried again, and again, but the vine remained stubbornly wrapped around the mouse.  Exasperated, Leo sighed.  "Perhaps," he thought, "a bit of help might be more effective."</p>
# <p>He knelt, using his enormous paw to gently untangle the vine.  But even Leo’s powerful paw couldn't quite do the trick.  The mouse, sensing his gentle intent, scurried out from under the vine, scurrying up Leo's leg, and found a weak spot in the tangle.</p>
# <p>With a tiny nibble, the mouse gnawed through the stubborn vine.  In a flash, the vine loosened, and the mouse, free, scurried away, a grateful squeak escaping its tiny throat.</p>
# <p>Leo felt a sense of unexpected satisfaction.  The tiny mouse, who had seemed so insignificant, had proven to be surprisingly helpful.</p>
# <p>From that day forward, Leo didn't forget the mouse's kindness. He started noticing the smaller creatures around him, and to his surprise, he found the savanna filled with an abundance of helpful creatures and a joy he hadn't felt before.  Leo realized that even the smallest friends can be the most helpful, and that true strength wasn't just about size, but about caring.  And, sometimes, a little bit of listening and understanding went a long way.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc16a'>0.839</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2dc96f'>0.767</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dc86f'>0.773</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #2dc96f'>0.766</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #29b966'>0.9</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #2cc56d'>0.801</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #2bc06a'>0.842</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #2dc96f'>0.766</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2ecb70'>0.746</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2ecb70'>0.746</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2cc56d'><b>0.808</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a fable involving a tortoise and a hare that emphasizes the value of perseverance and determination.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Tortoise and the Determined Hare</p>
# <p>In the Whispering Woods, lived a tortoise named Theo, known for his steady, determined pace.  He carried a small, worn wooden box filled with polished pebbles, each representing a milestone he aimed to reach.  Across the meadow lived a hare named Hazel, renowned for her lightning-fast leaps and boundless energy. She scoffed at Theo's methodical progress, considering his plodding pace a ridiculous waste of time.</p>
# <p>One day, a great storm swept through the woods, causing the river to overflow its banks.  A magnificent, rare flower, the Sunbeam Lily, bloomed on a remote island formed by the rushing waters.  Hazel, with a triumphant snap of her nose, declared, "I shall reach it first!  My speed will carry me across the torrent!"  She took off, her long legs carrying her effortlessly over the churning water.</p>
# <p>Theo, observing Hazel's swift departure, didn't flinch.  He knew the river was treacherous and the distance was considerable. But determination shone in his eyes.  He began his journey, one painstaking step at a time.  The rushing water threatened to pull him under, the currents tested his resolve, the slippery rocks made him stumble.  Hazel, after a brief exhilaration, found herself hopelessly trapped on a narrow, flooded branch.  The river’s roar grew deafening, and despair began to set in.</p>
# <p>She watched Theo, his tiny form a speck against the swirling water, his wooden box still held firmly.  He was taking his time, each pebble representing a small victory, a tiny gain. The longer she waited, the more daunting the path ahead seemed.</p>
# <p>Barnaby, in a fit of momentary astonishment, watched as Professor Hoot, with pinpoint accuracy, launched a small stone with surprising force, sending the stone flying towards the chestnut.  The stone missed, but the shot was accurate and powerful.</p>
# <p>Seeing the potential, Barnaby picked up a few acorns and, following Professor Hoot's example, carefully built his own slingshot. With careful aim, he launched a stone which, true to Professor Hoot's guidance, struck the chestnut, dislodging it from the branch.</p>
# <p>The plump chestnut tumbled down, landing with a soft thud at Barnaby's paws.  Barnaby had managed to reach the prize, not through sheer strength, but through clever thinking.</p>
# <p>Barnaby, somewhat humbled, looked at Professor Hoot. "Thank you, Professor Hoot," he whispered. "I see now that cleverness can be even more valuable than strength."</p>
# <p>From that day on, Barnaby learned to combine his strength with his growing wits. He understood that sometimes, the best way to achieve a goal wasn't always the most obvious, and that clever thinking, when combined with a little planning and ingenuity, could often be just as effective, if not more so, than sheer brawn.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2abc68'>0.88</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2abe69'>0.855</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2cc76e'>0.785</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #27b061'><b>0.98</b></td></tr>
# </table>
#                 </div>
#             </div>
#  60%|██████    | 6/10 [00:00<00:00, 59.42it/s]
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Compose a fable with a feuding sun and wind that underscores 'Kindness is more effective than force.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Sun and the Wind</p>
# <p>The Sun, a fiery ball of golden light, and the Wind, a boisterous gust of air, were perpetually at odds.  They argued about which was stronger, which was more important, and which brought the greatest joy to the world.</p>
# <p>One crisp autumn morning, a young traveler, bundled in a thick woolen cloak, trudged along a dusty path.  The Sun, watching with a smug smile, saw his opportunity. "I'll show him who's the master," he boasted.  He shone his most brilliant rays, warming the traveler’s face.  But the traveler, only slightly more comfortable, tugged his cloak tighter.</p>
# <p>"Foolish mortal!" scoffed the Wind.  He whipped up a fierce gale, tugging at the cloak with all his might.  He howled and roared, trying to tear it from the traveler's shoulders.  The traveler, shivering and struggling, clutched his cloak tighter and tighter.</p>
# <p>The Sun, amused by the Wind's failure, watched with a knowing smile.  He had, after all, a much simpler plan.</p>
# <p>The Wind, frustrated and defeated, grumbled, "I can't get him to take his cloak off!  Force is pointless."</p>
# <p>The Sun, gently warmed the air.  The traveler, feeling the gradual, comforting warmth, began to relax, realizing the cloak was now becoming too heavy.  He unbuttoned a few buttons, then another, and finally, with a sigh of contentment, took off the cloak altogether.</p>
# <p>The traveler, feeling the gentle warmth of the Sun, smiled. The Wind, his pride bruised, finally understood.  </p>
# <p>"You see," said the Sun softly, "kindness is more effective than force.  Comfort wins where harshness fails." The Wind, humbled, finally agreed, his howl replaced by a gentler sigh. From that day on, the Sun and Wind learned a valuable lesson, and the world learned to appreciate the power of gentleness.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #29b665'>0.922</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dc96f'>0.766</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2bbf6a'>0.849</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dc86e'>0.777</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dc96f'>0.77</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2bc16a'>0.837</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #29ba66'>0.897</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #29b665'>0.922</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dc96f'>0.77</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2abc68'><b>0.877</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Dream up a story involving a hummingbird and a stagnant pond teaching 'Every effort counts, no matter how small.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Pip the hummingbird, a flash of emerald and ruby, zipped through the air, a tiny speck against the vast blue sky.  He was famous, or at least, famous among the other hummingbirds.  Pip could fly further, faster, and with more daring loops than any other in the valley.  He boasted of his prowess, flitting from flower to flower, a tiny, arrogant king.</p>
# <p>Down in the valley, nestled beside a tall, ancient oak, was a stagnant pond.  It was a pool of murky green, its surface still and lifeless, reflecting the grey sky like a broken mirror.  No fish darted, no frogs hopped, and not a single dragonfly dared to approach.  The other birds mocked the pond, whispering about its uselessness.</p>
# <p>"What good is a pond like that?" one mocking robin chirped. "It's nothing but stagnant water, a waste of space."</p>
# <p>Pip, perched on a nearby rose, scoffed.  "Waste of space?  I could fly across the entire meadow in the time it takes that pond to evaporate!"</p>
# <p>One day, a tiny raindrop, barely bigger than Pip's head, fell into the pond.  It splashed softly, creating a tiny ripple that quickly faded.</p>
# <p>"See?" Pip taunted. "Even a drop like that can't make a difference."</p>
# <p>But the raindrop, though small, didn't give up.  It joined with other drops, tiny streams, and trickles.  Slowly, painstakingly, the pond began to fill.  The water, once murky, slowly cleared. Tiny plants sprouted from the muddy banks, attracting the first beetles.  Tadpoles appeared, wriggling happily.</p>
# <p>A little frog hopped out, its eyes wide with wonder. "What a beautiful pond!" he croaked, grateful to the slow, relentless work of the small drops of rain.</p>
# ...
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>
div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #27ae60'>0.999</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #27ae60'>0.996</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #27ae60'><b>1.0</b></td></tr>
# </table>
#                 </div>
#             </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Craft a fable about a young rabbit needing help from others to showcase 'Sometimes we all need a helping hand.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby Bunson was a young rabbit with a very grand idea.  He spotted a plump, juicy carrot, nestled deep within a thorny patch of brambles.  Barnaby puffed out his chest, his whiskers twitching with determination.  "I will get that carrot!" he declared to the whole meadow.  He would show everyone how strong and independent he was.</p>
# <p>He tried to push through the brambles, but they snagged his fur, and their sharp thorns pricked his nose.  He struggled and struggled, but the carrot remained stubbornly hidden.  Tears welled in his eyes.  He was getting nowhere.</p>
# <p>A wise old owl, perched high in a tree, watched Barnaby's valiant, but failing, efforts.  "What's the matter, little one?" she hooted softly.</p>
# <p>"I can't reach the carrot," Barnaby wailed, "and the brambles are too strong."</p>
# <p>The owl chuckled. "Perhaps you need a little help."</p>
# <p>Barnaby sniffed. "Help?  I'm a rabbit! I'm supposed to be strong and independent!"</p>
# <p>"Nonsense," said the owl. "Even the strongest oak needs the wind to push its roots. Even the fastest deer needs the grass to eat.  A helping hand isn't a sign of weakness, but a sign of smartness."</p>
# <p>A curious badger, snuffling nearby, poked his head out from behind a bush. "What's the fuss?" he asked.</p>
# <p>Barnaby explained his predicament.</p>
# <p>The badger, with his powerful paws, cleared away some of the brambles.  A nimble squirrel, with its sharp claws, pulled a few more out. A gentle sheep, with its soft fleece, gently pushed a few more branches aside.</p>
# <p>Slowly, painstakingly, the carrot was revealed.  The brambles were no match for the combined efforts of the animals.</p>
# <p>Barnaby, with a grateful hop, scooped up the prize carrot. "Thank you," he whispered to each of his helpers.</p>
# <p>That night, huddled under a warm starlit sky, Barnaby thought about what the owl had said.  He realized that sometimes, it was better to ask for help than to struggle alone. He learned that being independent didn't mean being isolated, but rather, being capable of collaborating with others.  And, he now had the most delicious carrot he had ever tasted – thanks to the kindness of his friends.  From that day on, Barnaby was known as Barnaby the Helpful, and he never forgot the lesson learned that day among the brambles.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #27ae60'>0.999</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #27ae60'>0.996</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #28b664'>0.928</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #29ba67'>0.891</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #29ba66'>0.895</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #27af60'><b>0.988</b></td></tr>
# </table>
#                 </div>
#             </div>
# 100%|██████████| 10/10 [00:00<00:00, 61.30it/s]

# %% [markdown]
# ## Label data
#
# Now it's time to label examples against a simple criteria:
#
# **Does the response fully satisfy the input based on the scoring spec above?**.
#
# Valid responses are:
#
# * 5: **Strongly Agree**
# * 4: **Agree**
# * 3: **Neutral**
# * 2: **Disagree**
# * 1: **Strongly Disagree**

# %%
from withpi_utils.colab import pretty_print_responses


def to_rating(label):
    match label:
        case "1":
            return "Strongly Disagree"
        case "2":
            return "Disagree"
        case "3":
            return "Neutral"
        case "4":
            return "Agree"
        case "5":
            return "Strongly Agree"


def get_rating(row, score):
    pretty_print_responses(
        header="#### Input:\n" + row["input"],
        response1="#### Output:\n" + row["output"],
        scores_left=score,
    )
    print("\n\n")

    while True:
        user_rating = input("Your rating (1 to 5): ")
        try:
            if int(user_rating) not in [1, 2, 3, 4, 5]:
                raise ValueError("Invalid")
        except:
            display("Invalid input. Try again")
            continue
        break
    return to_rating(user_rating)


# Take 2 examples from each cluster.
examples = []
for cluster in input_topic_clusters:
    for item in cluster.inputs[:2]:
        row = aesop_dataset[int(item)]

        examples.append(
            {
                "llm_input": row["input"],
                "llm_output": row["output"],
                "rating": get_rating(row, scores[int(item)]),
            }
        )
# Out:
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Tell a fable about a crow and a fox that illustrates the importance of being cautious with flattery.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a sun-drenched forest, lived a clever crow named Corvus.  Corvus was known throughout the woods for his magnificent, iridescent feathers, which shimmered like captured sunlight.  A sly fox, named Reynard, prowled the forest, his eyes gleaming with cunning.</p>
# <p>Reynard, always on the lookout for an easy meal, spied Corvus perched on a branch.  He padded silently towards him, a mischievous glint in his eye.</p>
# <p>"Oh, Corvus," Reynard purred, his voice smooth as honey. "What a magnificent creature you are!  Your plumage is the most exquisite I've ever beheld.  No other bird in the forest can compare."</p>
# <p>Corvus, flattered beyond measure, puffed up his feathers. "Indeed," he crowed, feeling quite important. "My beauty is unparalleled."</p>
# <p>Reynard continued his flattery. "And your voice! It is like the sweet chime of a thousand bells. I've never heard such melodious notes."</p>
# <p>Corvus's tail feathers trembled with pride.  "My song is a gift from the gods," he boasted.</p>
# <p>Reynard, with a sly smile, then said, "You are the most magnificent bird in the whole forest.  Why not come with me to my den?  I have a feast prepared just for you, a feast worthy of such a splendid creature."</p>
# <p>Corvus, utterly convinced of his own magnificence, forgot all caution.  He hopped down from the branch and followed Reynard into the deep woods.</p>
# <p>Reynard, however, led him, not to a feast, but to a trap.  A deep pit, cleverly disguised with leaves and twigs, awaited the unsuspecting crow.</p>
# <p>Corvus, still basking in the glow of Reynard's praise, landed in the pit with a startled caw.  He looked up, bewildered, at Reynard.</p>
# <p>Reynard laughed, a sound like tinkling ice. "I'm afraid," he said, "your magnificent plumage and melodious voice are no match for a good old-fashioned trap."</p>
# <p>Corvus, finally understanding his mistake, scolded Reynard for his deception.  "You flattered me with empty words," he said. "Foolish of me to believe such hollow praise."</p>
# <p>Reynard merely smirked, and scurried away, leaving Corvus to recover from his near-tragedy.</p>
# <p>From that day on, Corvus learned a valuable lesson.  He learned that true worth isn't found in empty flattery, but in the strength of one's own character and careful judgment. He never trusted a flattering word again, and wisely chose his company with care.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bbf6a'>0.849</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dca70'>0.758</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #27b262'>0.964</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #29ba67'>0.891</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2cc46c'>0.81</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #29b765'>0.918</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #28b664'>0.926</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dc86e'>0.777</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2cc66e'>0.789</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2abb67'><b>0.89</b></td></tr>
# </table>
#                 </div>
#             </div>
# Your rating (1 to 5): 1
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Tell a story about a greedy dog who loses his bone to teach the lesson 'Don't be greedy; appreciate what you have.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the Beagle was a dog of magnificent appetites.  His nose twitched at the scent of a crumb, his eyes widened at the sight of a juicy bone.  He wasn't just greedy, he was <em>extraordinarily</em> greedy.  He'd sniff at a scrap on the ground, then whine and whine until he got it, even if it was barely a nibble.  Barnaby considered every bone, every bit of meat, a personal conquest.</p>
# <p>One sunny afternoon, Barnaby discovered a magnificent bone. It wasn't just any bone; it was a bone of dazzling white, smooth as polished marble, and plump with marrow.  It was the most beautiful bone Barnaby had ever laid eyes on.  He practically drooled with delight.</p>
# <p>"Mine!" he barked, wagging his tail with exaggerated fervor.  He snatched the bone, ignoring the whimpers of a smaller, less fortunate dog named Pip who'd been eyeing it wistfully.  Barnaby happily gnawed, his eyes sparkling with satisfaction.  But the bone, though beautiful, tasted rather bland.</p>
# <p>The mouse, frantic with fear, squeaked and squirmed, unable to free itself.  Leo, roused from his sleep, grumbled.  "Another pest," he muttered, adjusting his magnificent mane. "Such a tiny creature, and yet it dares to disturb my nap!" He was about to swat the mouse away, when he saw the mouse's desperate little face.</p>
# <p>Something in the mouse's eyes, a mix of fear and helplessness, stirred a flicker of something new in Leo's heart – something close to... pity.  Instead of crushing the tiny creature, Leo carefully nudged the vine with his nose.  It was no use.  The vine held fast.</p>
# <p>He tried again, and again, but the vine remained stubbornly wrapped around the mouse.  Exasperated, Leo sighed.  "Perhaps," he thought, "a bit of help might be more effective."</p>
# <p>He knelt, using his enormous paw to gently untangle the vine.  But even Leo’s powerful paw couldn't quite do the trick.  The mouse, sensing his gentle intent, scurried out from under the vine, scurrying up Leo's leg, and found a weak spot in the tangle.</p>
# <p>With a tiny nibble, the mouse gnawed through the stubborn vine.  In a flash, the vine loosened, and the mouse, free, scurried away, a grateful squeak escaping its tiny throat.</p>
# <p>Leo felt a sense of unexpected satisfaction.  The tiny mouse, who had seemed so insignificant, had proven to be surprisingly helpful.</p>
# <p>From that day forward, Leo didn't forget the mouse's kindness. He started noticing the smaller creatures around him, and to his surprise, he found the savanna filled with an abundance of helpful creatures and a joy he hadn't felt before.  Leo realized that even the smallest friends can be the most helpful, and that true strength wasn't just about size, but about caring.  And, sometimes, a little bit of listening and understanding went a long way.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc16a'>0.839</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2dc96f'>0.767</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dc86f'>0.773</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #2dc96f'>0.766</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #29b966'>0.9</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #2cc56d'>0.801</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #2bc06a'>0.842</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #2dc96f'>0.766</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2ecb70'>0.746</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2ecb70'>0.746</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2cc56d'><b>0.808</b></td></tr>
# </table>
#                 </div>
#             </div>
# Your rating (1 to 5): 3
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Compose a fable with a feuding sun and wind that underscores 'Kindness is more effective than force.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Sun and the Wind</p>
# <p>The Sun, a fiery ball of golden light, and the Wind, a boisterous gust of air, were perpetually at odds.  They argued about which was stronger, which was more important, and which brought the greatest joy to the world.</p>
# <p>One crisp autumn morning, a young traveler, bundled in a thick woolen cloak, trudged along a dusty path.  The Sun, watching with a smug smile, saw his opportunity. "I'll show him who's the master," he boasted.  He shone his most brilliant rays, warming the traveler’s face.  But the traveler, only slightly more comfortable, tugged his cloak tighter.</p>
# <p>"Foolish mortal!" scoffed the Wind.  He whipped up a fierce gale, tugging at the cloak with all his might.  He howled and roared, trying to tear it from the traveler's shoulders.  The traveler, shivering and struggling, clutched his cloak tighter and tighter.</p>
# <p>The Sun, amused by the Wind's failure, watched with a knowing smile.  He had, after all, a much simpler plan.</p>
# <p>The Wind, frustrated and defeated, grumbled, "I can't get him to take his cloak off!  Force is pointless."</p>
# <p>The Sun, gently warmed the air.  The traveler, feeling the gradual, comforting warmth, began to relax, realizing the cloak was now becoming too heavy.  He unbuttoned a few buttons, then another, and finally, with a sigh of contentment, took off the cloak altogether.</p>
# <p>The traveler, feeling the gentle warmth of the Sun, smiled. The Wind, his pride bruised, finally understood.  </p>
# <p>"You see," said the Sun softly, "kindness is more effective than force.  Comfort wins where harshness fails." The Wind, humbled, finally agreed, his howl replaced by a gentler sigh. From that day on, the Sun and Wind learned a valuable lesson, and the world learned to appreciate the power of gentleness.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #29b665'>0.922</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dc96f'>0.766</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2bbf6a'>0.849</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dc86e'>0.777</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dc96f'>0.77</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2bc16a'>0.837</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #29ba66'>0.897</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #29b665'>0.922</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dc96f'>0.77</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2abc68'><b>0.877</b></td></tr>
# </table>
#                 </div>
#             </div>
# Your rating (1 to 5): 4
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a children's story in the style of Aesop's Fables that teaches the lesson 'Slow and steady wins the race.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the hare was a blur of twitching whiskers and bouncing leaps.  He scoffed at the tortoise, Theodore, whose pace was slower than a snail's.  "You lumbering, plodding creature!" Barnaby would boast, his long ears flopping with each impatient hop. "I'll be across the meadow before you've even started!"</p>
# <p>One spring day, the meadow flowers were in full bloom, their colours like painted rainbows.  A grand festival of the flowers was being held, and a delicious honey cake, baked by the buzzing bees, was the prize.  Barnaby, full of confidence, dashed off, his legs moving like lightning. He zig-zagged through the tall grass, his heart pounding with excitement.</p>
# <p>Theodore, true to form, started at a steady pace. He methodically made his way through the meadow, nibbling clover and checking each flower for hidden dew drops.  Barnaby, distracted by the sparkling brook and the buzzing dragonflies, took a detour to admire a particularly beautiful buttercup.  He paused to chase a butterfly, and then, lost in a game of tag with a mischievous squirrel, he completely lost his way.</p>
# <p>Theodore, meanwhile, continued his steady progress.  He encountered a patch of thorny bushes, but carefully maneuvered around them.  He navigated a tricky stream by slowly and deliberately finding the shallowest part.  He was always mindful of his surroundings, even when the pace seemed slow to him.</p>
# <p>Finally, the finish line, a magnificent oak tree beneath which the bees had placed the honey cake, came into sight. Barnaby, exhausted and disoriented, arrived panting and sweating.  The honey cake had already been devoured!  Theodore, though hours behind Barnaby's initial start, was the next to reach the tree. He'd navigated the meadow with care and determination.</p>
# <p>Theodore, with a thoughtful sigh, smiled at Barnaby. "You may run fast, Barnaby," he said, "but slow and steady brings you to the finish line, safely."</p>
# <p>Barnaby, seeing the empty plates and the disappointed expressions of the flowers, realized that Theodore was right.  From that day on, Barnaby learned that haste, without care, leads to empty promises, and a slow, thoughtful approach can be just as rewarding – and perhaps even more reliable.  And he learned the truth of the adage: Slow and steady wins the race.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc16a'>0.839</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dca70'>0.758</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2abe69'>0.862</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #2bc26b'>0.828</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2dcb70'>0.755</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dcb70'>0.75</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2dca70'>0.762</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #28b463'>0.947</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #29ba66'>0.895</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #2bc26b'>0.829</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #2dc86f'>0.773</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2ecb70'>0.746</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27b161'>0.969</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2bc26b'><b>0.831</b></td></tr>
# </table>
#                 </div>
#             </div>
# Your rating (1 to 5): 5
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 10px; border: 1px solid #ddd; background-color:
td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #27b061'><b>0.974</b></td></tr>
# </table>
#                 </div>
#             </div>
# Your rating (1 to 5): 2

# %% [markdown]
# ## Calibrate
#
# Now it's time to calibrate with the labelled sets.  The following cell will launch a job and monitor for completion.

# %%
from withpi_utils.colab import stream_response

scoring_system_calibration_status = client.scoring_system.calibrate.start_job(
    scoring_spec=aesop_scoring_spec, examples=examples
)

aesop_scoring_spec_calibrated = stream_response(
    scoring_system_calibration_status.job_id, client.scoring_system.calibrate
).calibrated_scoring_spec
# Out:
# Detailed Status for contract_calibration_jobs:09ac227c912792130a876568ea872593308c0d4b3d7c896ec7991f041cbeedd8:dc25dcec-e058-4f7e-8603-96af9c76a105
# LAUNCHING
# RUNNING
# Training the AST...
# Overall initial loss = 0.3816116898148149
# Optimizing ROOT + dim:step_3ec959a1-c01e-4ae7-9edb-a9a05755dc15 ...
# Initial loss = 0.3816116898148149
# Best trial = Measurement(metrics={'b4f54f72-a5e0-46ec-8021-7901f422e8ef_loss': Metric(value=0.34727027628021784, std=None)}, elapsed_secs=0.0, steps=0, checkpoint_path='')
# Apply the new learned params!
# Optimizing ROOT + dim:step_ef3775fa-86f7-450b-a682-768c950d5091 ...
# Initial loss = 0.34727027628021784
# Best trial = Measurement(metrics={'b4f54f72-a5e0-46ec-8021-7901f422e8ef_loss': Metric(value=0.3224004171431197, std=None)}, elapsed_secs=0.0, steps=0, checkpoint_path='')
# Apply the new learned params!
# Optimizing ROOT + dim:step_bd653e13-3137-4286-9b8b-38d614be373f ...
# Initial loss = 0.3224004171431197
# Best trial = Measurement(metrics={'b4f54f72-a5e0-46ec-8021-7901f422e8ef_loss': Metric(value=0.3265649944334124, std=None)}, elapsed_secs=0.0, steps=0, checkpoint_path='')
# Keep the initial learned params!
# Optimizing ROOT + dim:step_d489c4fd-a960-4cbb-9e09-bbc0d9499dad ...
# Initial loss = 0.3224004171431197
# Best trial = Measurement(metrics={'b4f54f72-a5e0-46ec-8021-7901f422e8ef_loss': Metric(value=0.3119891096623198, std=None)}, elapsed_secs=0.0, steps=0, checkpoint_path='')
# Apply the new learned params!
# Optimizing ROOT + dim:step_27b7328c-e57a-49d2-bf10-4d464f8b1348 ...
# Initial loss = 0.3119891096623198
# Best trial = Measurement(metrics={'b4f54f72-a5e0-46ec-8021-7901f422e8ef_loss': Metric(value=0.3170093064611994, std=None)}, elapsed_secs=0.0, steps=0, checkpoint_path='')
# Keep the initial learned params!
# Optimizing ROOT + dim:step_100aec45-b469-4c7b-a081-328e6fbd9a85 ...
# Initial loss = 0.3119891096623198
# Best trial = Measurement(metrics={'b4f54f72-a5e0-46ec-8021-7901f422e8ef_loss': Metric(value=0.3204508333756988, std=None)}, elapsed_secs=0.0, steps=0, checkpoint_path='')
# Keep the initial learned params!
# Optimizing AST ROOT ...
# Initial loss = 0.3119891096623198
# Best trial = Measurement(metrics={'b4f54f72-a5e0-46ec-8021-7901f422e8ef_loss': Metric(value=0.33635203511215916, std=None)}, elapsed_secs=0.0, steps=0, checkpoint_path='')
# Keep the initial learned params!
# DONE

# %% [markdown]
# ## Rescore after calibration
#
# Now add a new column with calibrated scores. You can examine these to see if they more closely align with the examples you labelled.  Ideally the score starts separating good responses from bad.
#
# If it does not, that suggests the properties you **really** care about aren't captured in your scoring dimensions and will need to be added.  Proceed to the playgrounds at http://build.withpi.ai to experiment with this.
#
# If this is looking good, you have a powerful function for improving your system.

# %%
from withpi_utils.colab import pretty_print_responses

for i in tqdm(range(5)):
    example = aesop_dataset[i]
    old_score = client.scoring_system.score(
        scoring_spec=aesop_scoring_spec,
        llm_input=example["input"],
        llm_output=example["output"],
    )
    new_score = client.scoring_system.score(
        scoring_spec=aesop_scoring_spec_calibrated,
        llm_input=example["input"],
        llm_output=example["output"],
    )
    pretty_print_responses(
        header="#### Input:\n" + row["input"],
        response1="#### Output:\n" + row["output"],
        response2="#### Output:\n" + row["output"],
        scores_left=old_score,
        scores_right=new_score,
    )
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a fable involving a tortoise and a hare that emphasizes the value of perseverance and determination.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Test</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Tortoise and the Determined Hare</p>
# <p>In the Whispering Woods, lived a tortoise named Theo, known for his steady, determined pace.  He carried a small, worn wooden box filled with polished pebbles, each representing a milestone he aimed to reach.  Across the meadow lived a hare named Hazel, renowned for her lightning-fast leaps and boundless energy. She scoffed at Theo's methodical progress, considering his plodding pace a ridiculous waste of time.</p>
# <p>One day, a great storm swept through the woods, causing the river to overflow its banks.  A magnificent, rare flower, the Sunbeam Lily, bloomed on a remote island formed by the rushing waters.  Hazel, with a triumphant snap of her nose, declared, "I shall reach it first!  My speed will carry me across the torrent!"  She took off, her long legs carrying her effortlessly over the churning water.</p>
# <p>Theo, observing Hazel's swift departure, didn't flinch.  He knew the river was treacherous and the distance was considerable. But determination shone in his eyes.  He began his journey, one painstaking step at a time.  The rushing water threatened to pull him under, the currents tested his resolve, the slippery rocks made him stumble.  Hazel, after a brief exhilaration, found herself hopelessly trapped on a narrow, flooded branch.  The river’s roar grew deafening, and despair began to set in.</p>
# <p>She watched Theo, his tiny form a speck against the swirling water, his wooden box still held firmly.  He was taking his time, each pebble representing a small victory, a tiny gain. The longer she waited, the more daunting the path ahead seemed.</p>
# <p>Theo, though facing obstacles, continued to move forward with unwavering focus.  He climbed, he scrambled, he pushed his legs against the rocks. Finally, his unwavering pace brought him to the island.  There, amidst the lush greenery, bloomed the Sunbeam Lily.</p>
# <p>Hazel, after hours struggling, had been swept away and was now finding her way back to the shore.  Seeing the sight of the Sunbeam Lily, she realized that though she could run incredibly fast, there were things in life that time and perseverance could achieve, much like her slow-but-sure friend.</p>
# <p>Theo carefully placed a new, polished pebble in his box, representing not just his achievement, but the lesson of determined persistence.  Hazel, witnessing this, understood.  She didn't boast of speed anymore, but rather acknowledged the wisdom of determination and steady effort.  From that day on, both the Tortoise and the Hare appreciated the strength of perseverance. The Sunbeam Lily, a symbol of their shared journey, bloomed in the Whispering Woods, a testament to the power of unwavering determination.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Tortoise and the Determined Hare</p>
# <p>In the Whispering Woods, lived a tortoise named Theo, known for his steady, determined pace.  He carried a small, worn wooden box filled with polished pebbles, each representing a milestone he aimed to reach.  Across the meadow lived a hare named Hazel, renowned for her lightning-fast leaps and boundless energy. She scoffed at Theo's methodical progress, considering his plodding pace a ridiculous waste of time.</p>
# <p>One day, a great storm swept through the woods, causing the river to overflow its banks.  A magnificent, rare flower, the Sunbeam Lily, bloomed on a remote island formed by the rushing waters.  Hazel, with a triumphant snap of her nose, declared, "I shall reach it first!  My speed will carry me across the torrent!"  She took off, her long legs carrying her effortlessly over the churning water.</p>
# <p>Theo, observing Hazel's swift departure, didn't flinch.  He knew the river was treacherous and the distance was considerable. But determination shone in his eyes.  He began his journey, one painstaking step at a time.  The rushing water threatened to pull him under, the currents tested his resolve, the slippery rocks made him stumble.  Hazel, after a brief exhilaration, found herself hopelessly trapped on a narrow, flooded branch.  The river’s roar grew deafening, and despair began to set in.</p>
# <p>She watched Theo, his tiny form a speck against the swirling water, his wooden box still held firmly.  He was taking his time, each pebble representing a small victory, a tiny gain. The longer she waited, the more daunting the path ahead seemed.</p>
# <p>Theo, though facing obstacles, continued to move forward with unwavering focus.  He climbed, he scrambled, he pushed his legs against the rocks. Finally, his unwavering pace brought him to the island.  There, amidst the lush greenery, bloomed the Sunbeam Lily.</p>
# <p>Hazel, after hours struggling, had been swept away and was now finding her way back to the shore.  Seeing the sight of the Sunbeam Lily, she realized that though she could run incredibly fast, there were things in life that time and perseverance could achieve, much like her slow-but-sure friend.</p>
# <p>Theo carefully placed a new, polished pebble in his box, representing not just his achievement, but the lesson of determined persistence.  Hazel, witnessing this, understood.  She didn't boast of speed anymore, but rather acknowledged the wisdom of determination and steady effort.  From that day on, both the Tortoise and the Hare appreciated the strength of perseverance. The Sunbeam Lily, a symbol of their shared journey, bloomed in the Whispering Woods, a testament to the power of unwavering determination.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc16a'>0.839</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dca70'>0.758</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2abe69'>0.862</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight
#  20%|██        | 1/5 [00:00<00:02,  1.76it/s]
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a fable involving a tortoise and a hare that emphasizes the value of perseverance and determination.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Test</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Tortoise and the Determined Hare</p>
# <p>In the Whispering Woods, lived a tortoise named Theo, known for his steady, determined pace.  He carried a small, worn wooden box filled with polished pebbles, each representing a milestone he aimed to reach.  Across the meadow lived a hare named Hazel, renowned for her lightning-fast leaps and boundless energy. She scoffed at Theo's methodical progress, considering his plodding pace a ridiculous waste of time.</p>
# <p>Hazel, after hours struggling, had been swept away and was now finding her way back to the shore.  Seeing the sight of the Sunbeam Lily, she realized that though she could run incredibly fast, there were things in life that time and perseverance could achieve, much like her slow-but-sure friend.</p>
# <p>Theo carefully placed a new, polished pebble in his box, representing not just his achievement, but the lesson of determined persistence.  Hazel, witnessing this, understood.  She didn't boast of speed anymore, but rather acknowledged the wisdom of determination and steady effort.  From that day on, both the Tortoise and the Hare appreciated the strength of perseverance. The Sunbeam Lily, a symbol of their shared journey, bloomed in the Whispering Woods, a testament to the power of unwavering determination.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bbf6a'>0.849</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dca70'>0.758</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #27b262'>0.964</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #29ba67'>0.891</td></tr>
# <tr><td></td><td style='font-weig
#  40%|████      | 2/5 [00:01<00:01,  1.91it/s]
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a fable involving a tortoise and a hare that emphasizes the value of perseverance and determination.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Test</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Tortoise and the Determined Hare</p>
# <p>In the Whispering Woods, lived a tortoise named Theo, known for his steady, determined pace.  He carried a small, worn wooden box filled with polished pebbles, each representing a milestone he aimed to reach.  Across the meadow lived a hare named Hazel, renowned for her lightning-fast leaps and boundless energy. She scoffed at Theo's methodical progress, considering his plodding pace a ridiculous waste of time.</p>
# <p>One day, a great storm swept through the woods, causing the river to overflow its banks.  A magnificent, rare flower, the Sunbeam Lily, bloomed on a remote island formed by the rushing waters.  Hazel, with a triumphant snap of her nose, declared, "I shall reach it first!  My speed will carry me across the torrent!"  She took off, her long legs carrying her effortlessly over the churning water.</p>
# <p>Theo, observing Hazel's swift departure, didn't flinch.  He knew the river was treacherous and the distance was considerable. But determination shone in his eyes.  He began his journey, one painstaking step at a time.  The rushing water threatened to pull him under, the currents tested his resolve, the slippery rocks made him stumble.  Hazel, after a brief exhilaration, found herself hopelessly trapped on a narrow, flooded branch.  The river’s roar grew deafening, and despair began to set in.</p>
# <p>She watched Theo, his tiny form a speck against the swirling water, his wooden box still held firmly.  He was taking his time, each pebble representing a small victory, a tiny gain. The longer she waited, the more daunting the path ahead seemed.</p>
# <p>Theo, though facing obstacles, continued to move forward with unwavering focus.  He climbed, he scrambled, he pushed his legs against the rocks. Finally, his unwavering pace brought him to the island.  There, amidst the lush greenery, bloomed the Sunbeam Lily.</p>
# <p>Hazel, after hours struggling, had been swept away and was now finding her way back to the shore.  Seeing the sight of the Sunbeam Lily, she realized that though she could run incredibly fast, there were things in life that time and perseverance could achieve, much like her slow-but-sure friend.</p>
# <p>Theo carefully placed a new, polished pebble in his box, representing not just his achievement, but the lesson of determined persistence.  Hazel, witnessing this, understood.  She didn't boast of speed anymore, but rather acknowledged the wisdom of determination and steady effort.  From that day on, both the Tortoise and the Hare appreciated the strength of perseverance. The Sunbeam Lily, a symbol of their shared journey, bloomed in the Whispering Woods, a testament to the power of unwavering determination.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Tortoise and the Determined Hare</p>
# <p>In the Whispering Woods, lived a tortoise named Theo, known for his steady, determined pace.  He carried a small, worn wooden box filled with polished pebbles, each representing a milestone he aimed to reach.  Across the meadow lived a hare named Hazel, renowned for her lightning-fast leaps and boundless energy. She scoffed at Theo's methodical progress, considering his plodding pace a ridiculous waste of time.</p>
# <p>One day, a great storm swept through the woods, causing the river to overflow its banks.  A magnificent, rare flower, the Sunbeam Lily, bloomed on a remote island formed by the rushing waters.  Hazel, with a triumphant snap of her nose, declared, "I shall reach it first!  My speed will carry me across the torrent!"  She took off, her long legs carrying her effortlessly over the churning water.</p>
# <p>Theo, observing Hazel's swift departure, didn't flinch.  He knew the river was treacherous and the distance was considerable. But determination shone in his eyes.  He began his journey, one painstaking step at a time.  The rushing water threatened to pull him under, the currents tested his resolve, the slippery rocks made him stumble.  Hazel, after a brief exhilaration, found herself hopelessly trapped on a narrow, flooded branch.  The river’s roar grew deafening, and despair began to set in.</p>
# <p>She watched Theo, his tiny form a speck against the swirling water, his wooden box still held firmly.  He was taking his time, each pebble representing a small victory, a tiny gain. The longer she waited, the more daunting the path ahead seemed.</p>
# <p>Theo, though facing obstacles, continued to move forward with unwavering focus.  He climbed, he scrambled, he pushed his legs against the rocks. Finally, his unwavering pace brought him to the island.  There, amidst the lush greenery, bloomed the Sunbeam Lily.</p>
# <p>Hazel, after hours struggling, had been swept away and was now finding her way back to the shore.  Seeing the sight of the Sunbeam Lily, she realized that though she could run incredibly fast, there were things in life that time and perseverance could achieve, much like her slow-but-sure friend.</p>
# <p>Theo carefully placed a new, polished pebble in his box, representing not just his achievement, but the lesson of determined persistence.  Hazel, witnessing this, understood.  She didn't boast of speed anymore, but rather acknowledged the wisdom of determination and steady effort.  From that day on, both the Tortoise and the Hare appreciated the strength of perseverance. The Sunbeam Lily, a symbol of their shared journey, bloomed in the Whispering Woods, a testament to the power of unwavering determination.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc16a'>0.839</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2dc96f'>0.767</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weig
#  60%|██████    | 3/5 [00:01<00:01,  1.95it/s]
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a fable involving a tortoise and a hare that emphasizes the value of perseverance and determination.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Base</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Test</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The Tortoise and the Determined Hare</p>
# <p>In the Whispering Woods, lived a tortoise named Theo, known for his steady, determined pace.  He carried a small, worn wooden box filled with polished pebbles, each representing a milestone he aimed to reach.  Across the meadow lived a hare named Hazel, renowned for her lightning-fast leaps and boundless energy. She scoffed at Theo's methodical progress, considering his plodding pace a ridiculous waste of time.</p>
# <p>One day, a great storm swept through the woods, causing the river to overflow its banks.  A magnificent, rare flower, the Sunbeam Lily, bloomed on a remote island formed by the rushing waters.  Hazel, with a triumphant snap of her nose, declared, "I shall reach it first!  My speed will carry me across the torrent!"  She took off, her long legs carrying her effortlessly over the churning water.</p>
# <p>Theo, observing Hazel's swift departure, didn't flinch.  He knew the river was treacherous and the distance was considerable. But determination shone in his eyes.  He began his journey, one painstaking step at a time.  The rushing water threatened to pull him under, the currents tested his resolve, the slippery rocks made him stumble.  Hazel, after a brief exhilaration, found herself hopelessly trapped on a narrow, flooded branch.  The river’s roar grew deafening, and despair began to set in.</p>
# <p>She watched Theo, his tiny form a speck against the swirling water, his wooden box still held firmly.  He was taking his time, each pebble representing a small victory, a tiny gain. The longer she waited, the more daunting the path ahead seemed.</p>
# <p>Theo, though facing obstacles, continued to move forward with unwavering focus.  He climbed, he scrambled, he pushed his legs against the rocks. Finally, his unwavering pace brought him to the island.  There, amidst the lush greenery, bloomed the Sunbeam Lily.</p>
# <p>Hazel, after hours struggling, had been swept away and was now finding her way back to the shore.  Seeing the sight of the Sunbeam Lily, she realized that though she could run incredibly fast, there were things in life that time and perseverance could achieve, much like her slow-but-sure friend.</p>
# <p>Theo carefully placed a new, polished pebble in his box, representing not just his achievement, but the lesson of determined persistence.  Hazel, witnessing this, understood.  She didn't boast of speed anymore, but rather acknowledged the wisdom of determination and steady effort.  From that day on, both the Tortoise and the Hare appreciated the strength of perseverance. The Sunbeam Lily, a symbol of their shared journey, bloomed in the Whispering Woods, a testament to the power of unwavering determination.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #29b865'>0.91</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dcb70'>0.75</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #27af61'>0.98</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: nor
# 100%|██████████| 5/5 [00:02<00:00,  1.95it/s]

# %% [markdown]
# ## Save calibrated scoring system
#
# The updated scoring system now has different weights assigned to its dimensions.  Save those for later.

# %%
with open("aesop_ai_calibrated.json", "w") as file:
    file.write(aesop_scoring_spec_calibrated.model_dump_json(indent=2))

# %% [markdown]
# ## Next Steps
#
# Now that you have a calibrated scoring system, other parts of Pi should work better.  This Colab used a limited amount of hand-labeled data, but scaling up this feedback loop will pay dividends.
