# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/colabs/Query_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://withpi.ai"><img src="https://play.withpi.ai/logo/logoFullBlack.svg" width="240"></a>
#
# <a href="https://code.withpi.ai"><font size="4">Documentation</font></a>
#
# <a href="https://play.withpi.ai"><font size="4">Technique Catalog</font></a>

# %% [markdown]
# # Query Classification
#
# Query classification is a key primitive for AI systems, and allows for powerful RAG pipelines.
#
# A "query" could be:
#   * a search term in an e-commerce search (eg. "levis 501")
#   * a message from a customer to a support team
#   * a prompt to an AI assistant
#
# The "classification" part could involve:
#   * deciding whether retrieval is needed
#   * deciding what data sources to use
#   * deciding what pre- or post-processing to apply
#
# This Colab will take you through classifying queries for your use case, and improving query classification through minimal work. A small amount of teaching the model through **data labeling** will make it better at classifying queries for your use case, and enable you to use smaller and faster models for your use case.

# %% [markdown]
# ## Install and initialize SDK
#
# Connect to a regular CPU Python 3 runtime.  You won't need GPUs for this notebook.
#
# You'll need a WITHPI_API_KEY from https://play.withpi.ai.  Add it to your notebook secrets (the key symbol) on the left.
#
# Run the cell below to install packages and load the SDK

# %%
# %%capture

# %pip install withpi withpi-utils datasets tqdm litellm

import os
from google.colab import userdata
from withpi import PiClient

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

client = PiClient()

###  QUERY CLASSIFICATION  ###

import requests
from io import BytesIO
import tarfile
from pathlib import Path
import json


# Caching jobs allows us to avoid repeating job starts.
if 'job_id_by_hash' not in locals():
    job_id_by_hash = {}

def generate_inputs(
    queries: list[str],
    exploration_mode: str = "ADVENTUROUS",
    application_description: str = "",
    num_examples: int = 10,
) -> list[str]:
    job_hash = hash(json.dumps([
        num_examples,
        exploration_mode,
        queries,
        application_description
    ]))

    if job_hash not in job_id_by_hash:
        print(f"Generating {num_examples} new examples...")
        data_generation_status = client.data.generate.start_job(
            application_description=application_description,
            num_inputs_to_generate=num_examples,
            num_shots=10,
            exploration_mode=exploration_mode,
            seeds=queries,
        )
        job_id_by_hash[job_hash] = data_generation_status.job_id

    job_id = job_id_by_hash[job_hash]
    job_status = client.data.generate.retrieve(job_id)
    if job_status.state == "ERROR":
        raise RuntimeError(f"Generation job failed")
    if job_status.state == "DONE":
        return job_status.data

    with (
        client.data.with_streaming_response.generate.stream_messages(
            job_id
        ) as response
    ):
        for line in response.iter_lines():
            print(f"Generation progress: {line}")

    job_status = client.data.generate.retrieve(
        job_id
    )
    assert job_status.state == "DONE"
    return job_status.data


def download_classifier(job_id: str, path: str, serving_id: int | None = 0) -> Path:
    if not serving_id:
        # TODO: explicitly use the lowest eval loss here by default.
        #   this currently happens to be the zeroeth element, but we can
        #   avoid relying on it!
        #
        # job_status = client.search.query_classifier.distill.retrieve(job_id=job_id)
        serving_id = 0
    url = json.loads(client.search.query_classifier.distill.download(job_id=job_id, serving_id=serving_id))
    return download_and_extract(url, path)


def download_and_extract(url: str, output_dir: str) -> Path:
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    response = requests.get(url)
    response.raise_for_status()
    tar_bytes = BytesIO(response.content)
    with tarfile.open(fileobj=tar_bytes, mode="r:gz") as tar:
        tar.extractall(path=output_dir)
    return output_path

# %% [markdown]
# # Detecting spam in social media DMs
# For our task, let's imagine that we need to detect spam messages in DMs sent between people on a social media platform.
#
# We'll lay out:
# * **input description** - describing what the inputs are to help calibrate our data generator
# * **classes** - the classes we want to split it into, with descriptions to help calibrate the query classifier
# * **examples** - queries and classes that we know to be correct

# %%
# This is describing the kind of inputs we'll be dealing with.
input_description = "direct messages received by users on a social media network"

# These are the classes that we want to classify our queries into.
# In this example, the queries are direct messages that users receive,
# which we want to classify as spam or legitimate communication.
classes = [
    {"label": "Spam", "description": "Unsolicited messages promoting products, services, or containing suspicious links"},
    {"label": "Not Spam", "description": "Legitimate messages from real users with genuine communication intent"}
]

# Here are some examples that we can provide to the zero-shot
# query classification model, and later to our trained model.
examples = [
    {"label": "Spam", "text": "CONGRATULATIONS! You've been selected to receive a free luxury watch! Click here to claim: bit.ly/2x4fakelink"},
    {"label": "Spam", "text": "Hello dear, I noticed your profile and think you have great investment potential. I manage a portfolio worth $25M and can help you earn 300% returns monthly. Message me for details."},
    {"label": "Spam", "text": "Hi there! 👋 I'm selling handmade bracelets at 70% discount today only! Check my store: handmade-jewelry.fakesite.co/discount"},
    {"label": "Not Spam", "text": "Hey, are we still meeting for coffee tomorrow at 2? Let me know if you need to reschedule."},
    {"label": "Not Spam", "text": "Hi Sarah! Just wanted to thank you for your help with the project yesterday. Your input really made a difference. Hope we can collaborate again soon!"},
    {"label": "Not Spam", "text": "Dude, did you see that game last night? Incredible comeback in the final quarter! We should watch the next one together."},
    {"label": "Spam", "text": "URGENT: Your account will be suspended in 24 hours! Verify your identity now: security-verify.suspiciouslink.net"},
    {"label": "Spam", "text": "Hello friend! I am international business person with opportunity for you. I have $5,000,000 USD to transfer and need your assistance. Reply for 30% commission."},
    {"label": "Spam", "text": "Want to lose 20 pounds in just 1 week? Our new miracle supplement guarantees results or money back! Order now with code SLIM50 for 50% off!"},
    {"label": "Not Spam", "text": "The photos from our hiking trip are finally uploaded! Here's the link to the shared album I promised: photos.legitimatesite.com/album/hiking2023"},
    {"label": "Not Spam", "text": "Mom asked me to check if you're still coming for dinner on Sunday. She's planning the menu and wants to know if you're bringing anyone."},
    {"label": "Not Spam", "text": "Hi Professor, I'm emailing about the assignment due next week. Could I get a short extension? I've been dealing with some health issues and could use a couple extra days."},
    {"label": "Spam", "text": "⚠️ Your profile has received 38 secret admirers today! Upgrade your account to see who likes you: premium-vip-access.scamsite.co"},
    {"label": "Spam", "text": "Exclusive opportunity for selected members only! Join our private cryptocurrency group and learn how I made $50,000 in just one week trading! Limited spots available!"},
    {"label": "Spam", "text": "Your package delivery failed! Reschedule delivery by confirming your details: delivery-service.maliciouslink.com"},
    {"label": "Not Spam", "text": "Hey, can you send me that recipe you mentioned yesterday? I want to try making it this weekend."},
    {"label": "Not Spam", "text": "The concert tickets just went on sale! Should I grab two for us for the Friday show, or does Saturday work better for you?"},
    {"label": "Not Spam", "text": "Just landed! The flight was delayed but I'm finally here. Can you still pick me up from the airport or should I grab a taxi?"},
]

# Let's classify and see how our classifications turn out!
response = client.search.query_classifier.classify(
    queries=[
        "Hey! I noticed your photography skills and I'm impressed! I run a modeling agency and think you'd be perfect for our upcoming campaign. DM me for details!",
        "Hi Alex, are we still on for lunch tomorrow at the usual place? I might be running about 10 minutes late.",
        "CONGRATULATIONS! You've won a $1000 gift card! Claim now: www.totallylegitprizes.co/claim-now",
        "Can you send me the notes from yesterday's meeting? I had to leave early and missed the last part.",
        "FREE iPhone 13 Pro! You've been selected in our monthly giveaway! Click here to claim within 24 hours: bit.ly/claim-prize"
    ],
    classes=classes,
    mode="generative",
    examples=examples,
)

for classification in response.results:
    print(f"Query: {repr(classification.query)}")
    print(f"Classification: {repr(classification.prediction)}")
    print()
# Out:
# Query: "Hey! I noticed your photography skills and I'm impressed! I run a modeling agency and think you'd be perfect for our upcoming campaign. DM me for details!"
# Classification: 'Spam'
#
# Query: 'Hi Alex, are we still on for lunch tomorrow at the usual place? I might be running about 10 minutes late.'
# Classification: 'Not Spam'
#
# Query: "CONGRATULATIONS! You've won a $1000 gift card! Claim now: www.totallylegitprizes.co/claim-now"
# Classification: 'Spam'
#
# Query: "Can you send me the notes from yesterday's meeting? I had to leave early and missed the last part."
# Classification: 'Not Spam'
#
# Query: "FREE iPhone 13 Pro! You've been selected in our monthly giveaway! Click here to claim within 24 hours: bit.ly/claim-prize"
# Classification: 'Spam'

# %% [markdown]
# ## Distillation
#
# Distillation is the process of training a small model with the use of a big model. Distillation is a powerful tool to create fast classifiers, that can be used for decision-making in latency-sensitive scenarios such as RAG pipelines and AI agents.
#
# In distillation, we refer to the big model as the **teacher model** and the small model as the **student model**.  In order to use the teacher model, you also need a **pool of unlabeled data**.
#
# In this case:
#
# * The teacher model is the query classification model from the Pi SDK.
# * The student model is a ModernBERT model, a small and capable model for this task.
# * The unlabeled data are queries that we're going to generate using the Pi SDK's "generate from seeds" synthetic data generator. When we give it our `queries`, it will generate more similar queries.

# %% [markdown]
# ### Generating queries
#
# First, let's generate some queries. To illustrate the process quickly, we'll generate only 100 queries. In a realistic run, you will have the best results generating at least 500 queries.
#
# 💁 **Tip:** If you have a pool of real user queries, you will be able to distill a better model than using only generated inputs, since it will better help the model learn the kind of queries it will see.
#
# ⏰ **Note:** This cell can take ~10m to run.

# %%
import pandas as pd

# We'll generate 100 training samples in total, and split them
# equally across the different classes to yield a balanced
# training set.
examples_df = pd.DataFrame(examples)
groups = examples_df.groupby('label')
samples_per_group = 100 // len(groups)
classes_by_label = {c["label"]: c["description"] for c in classes}

generated_queries = []
for label, label_examples in groups:
    # We can use the Pi SDK to generate inputs given some examples of
    # input that we'd like more of. A description of the application
    # helps the input generator create inputs that are relevant to our use case.
    new_inputs = generate_inputs(
        queries=[example["text"] for example in label_examples.to_records()],
        application_description=f"""
            Queries should match the input description and belong to
            the following class:

            <class_name>{label}</class_name>
            <class_description>{classes_by_label[label]}</class_description>
            <input_description>{input_description}</input_description>
            """,
        num_examples=samples_per_group,
        exploration_mode='ADVENTUROUS'
    )

    print(f"Adding inputs for label {label}:")
    for input in new_inputs:
        print(f"- {input}")

    generated_queries.extend(new_inputs)
# Out:
# Generating 50 new examples...
# Generation progress: LAUNCHING
# Generation progress: RUNNING
# Generation progress: [INFO] Progress=> Good: 0/50 Bad: 0 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.37
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 1/50. Bad Inputs: 2. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 1/50 Bad: 2 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.22
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 2/50. Bad Inputs: 5. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 2/50 Bad: 5 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.18
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 6/50. Bad Inputs: 6. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 6/50 Bad: 6 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.06
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 8/50. Bad Inputs: 9. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 8/50 Bad: 9 Similar: 0
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Good news, the assignment extension request was approved! Do you want to meet up to finalize our sections?' too similar to:
# Generation progress:  'Hi Professor, I'm emailing about the assignment due next week. Could I get a short extension? I've been dealing with some health issues and could use a couple extra days.'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.1
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 12/50. Bad Inputs: 9. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 12/50 Bad: 9 Similar: 1
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.1
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 17/50. Bad Inputs: 9. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 17/50 Bad: 9 Similar: 1
# Generation progress: [INFO] With similarity score: 0.81, New input: 'Hi Laura, are you going to attend the community meeting this Friday? I think it is at 6 PM. Let me know if you'd like to coordinate!' too similar to:
# Generation progress:  'Hey, I’m organizing a little get-together for the weekend. You free to join us?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.14
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 21/50. Bad Inputs: 9. Similar Inputs: 2
# Generation progress: [INFO] Progress=> Good: 21/50 Bad: 9 Similar: 2
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Our networking session is scheduled for 3 PM next Friday. Let me know if you need details about the venue.' too similar to:
# Generation progress:  'Hey Sam, just wanted to confirm if the band practice is still scheduled for Tuesday evening?'
# Generation progress: [INFO] With similarity score: 0.82, New input: 'The tickets for the music festival are selling out fast! Shall I book for both of us?' too similar to:
# Generation progress:  'The concert tickets just went on sale! Should I grab two for us for the Friday show, or does Saturday work better for you?'
# Generation progress: [INFO] With similarity score: 0.83, New input: 'I found that book you recommended! It's available at the library. Feel like joining me to check it out this weekend?' too similar to:
# Generation progress:  'Had a fantastic book recommendation from a coworker: \"The Midnight Library\" by Matt Haig. Have you read it?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.26
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 23/50. Bad Inputs: 9. Similar Inputs: 5
# Generation progress: [INFO] Progress=> Good: 23/50 Bad: 9 Similar: 5
# Generation progress: [INFO] With similarity score: 0.79, New input: 'Could you get back to me later regarding the schedule for next week’s meeting? I need to finalize things today.' too similar to:
# Generation progress:  'Hey, are we still meeting for coffee tomorrow at 2? Let me know if you need to reschedule.'
# Generation progress: [INFO] With similarity score: 0.78, New input: 'The new practice session got rescheduled later this week. Let me know if there’s anything setup for assignments afterward.' too similar to:
# Generation progress:  'Hey Sam, just wanted to confirm if the band practice is still scheduled for Tuesday evening?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.3
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 25/50. Bad Inputs: 10. Similar Inputs: 7
# Generation progress: [INFO] Progress=> Good: 25/50 Bad: 10 Similar: 7
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.1
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 25/50. Bad Inputs: 12. Similar Inputs: 7
# Generation progress: [INFO] Progress=> Good: 25/50 Bad: 12 Similar: 7
# Generation progress: [INFO] With similarity score: 0.88, New input: 'Hey, we’re organizing a get-together next week at my place—would you be able to make it?' too similar to:
# Generation progress:  'Hey, I’m organizing a little get-together for the weekend. You free to join us?'
# Generation progress: [INFO] With similarity score: 0.80, New input: 'Hi Clare! I'll be visiting your area this Thursday afternoon. If you're free, could we catch up then?' too similar to:
# Generation progress:  'Hey, I’m organizing a little get-together for the weekend. You free to join us?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.18
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 28/50. Bad Inputs: 12. Similar Inputs: 9
# Generation progress: [INFO] Progress=> Good: 28/50 Bad: 12 Similar: 9
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Are you free on Thursday afternoon to go hiking? Weather seems perfect right now!' too similar to:
# Generation progress:  'Remember our hiking trip next weekend! Do we have the sleeping bags packed and ready?'
# Generation progress: [INFO] With similarity score: 0.83, New input: 'I'm organizing a game night at my place this weekend. Any interest in joining?' too similar to:
# Generation progress:  'Hey, I’m organizing a little get-together for the weekend. You free to join us?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.26
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 31/50. Bad Inputs: 12. Similar Inputs: 11
# Generation progress: [INFO] Progress=> Good: 31/50 Bad: 12 Similar: 11
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.26
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 36/50. Bad Inputs: 12. Similar Inputs: 11
# Generation progress: [INFO] Progress=> Good: 36/50 Bad: 12 Similar: 11
# Generation progress: [INFO] With similarity score: 0.79, New input: 'Hey, did those tickets for the concert arrive? Hoping to finalize our plans once you confirm.' too similar to:
# Generation progress:  'Hey Sam, just wanted to confirm if the band practice is still scheduled for Tuesday evening?'
# Generation progress: [INFO] With similarity score: 0.78, New input: 'That new hike you mentioned in your last message sounds perfect for this weekend—still up for it?' too similar to:
# Generation progress:  'Remember our hiking trip next weekend! Do we have the sleeping bags packed and ready?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.3
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 38/50. Bad Inputs: 13. Similar Inputs: 13
# Generation progress: [INFO] Progress=> Good: 38/50 Bad: 13 Similar: 13
# Generation progress: [INFO] With similarity score: 0.80, New input: 'Have you by chance tried out that sushi spot we discussed last week? I'm thinking of taking a friend there.' too similar to:
# Generation progress:  'I heard there's a new Thai restaurant that opened nearby. Do you want to try it out tomorrow evening?'
# Generation progress: [INFO] With similarity score: 0.78, New input: 'There's an art sale this Sunday downtown. It seems right up your alley, care to join?' too similar to:
# Generation progress:  'Hey, I’m organizing a little get-together for the weekend. You free to join us?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.38
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 41/50. Bad Inputs: 13. Similar Inputs: 15
# Generation progress: [INFO] Progress=> Good: 41/50 Bad: 13 Similar: 15
# Generation progress: [INFO] With similarity score: 0.81, New input: 'Hey Jennie, I found a brilliant photo capture yesterday, I think it aligns perfectly with us lovers of abstract photography! Interested in one of my albums?' too similar to:
# Generation progress:  'Guess what! I found a painting that reminded me of your studio's current vibe—want me to send a picture?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.31
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 41/50. Bad Inputs: 15. Similar Inputs: 16
# Generation progress: [INFO] Progress=> Good: 41/50 Bad: 15 Similar: 16
# Generation progress: [INFO] With similarity score: 0.79, New input: 'Are you still down for that virtual watch party Thursday night? My choice for the first movie drop is ready!' too similar to:
# Generation progress:  'The new movie we're excited about came out today. Want to watch it over the weekend?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.35
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 45/50. Bad Inputs: 15. Similar Inputs: 17
# Generation progress: [INFO] Progress=> Good: 45/50 Bad: 15 Similar: 17
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Is the Spartan meetup venue finalized? Do we head there at once?' too similar to:
# Generation progress:  'Hey Sam, just wanted to confirm if the band practice is still scheduled for Tuesday evening?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.39
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 49/50. Bad Inputs: 15. Similar Inputs: 18
# Generation progress: [INFO] Progress=> Good: 49/50 Bad: 15 Similar: 18
# Generation progress: [INFO] With similarity score: 0.81, New input: 'How’s your trip coming along? Send some photos if you’ve got a bit of downtime to share!' too similar to:
# Generation progress:  'The photos from our hiking trip are finally uploaded! Here's the link to the shared album I promised: photos.legitimatesite.com/album/hiking2023'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.29
# Generation progress: [INFO] Data Generation Complete => Good Inputs: 50. Bad Inputs: 19. Similar Inputs: 19
# Generation progress: DONE
# Adding inputs for label Not Spam:
# - Hey Alex, did you watch that summit livestream today? I'd love to hear your thoughts on the proposals presented.
# - Hey Mark! Don't forget the assignment is due tomorrow. It's group-chaved and it needs full proper citation, okay?
# - Had such a blast at the party yesterday, thanks for hosting! I think I left my scarf there, did you see it?
# - Going to make pasta for tonight’s dinner! Any tips or good recipes I should try?
# - Hey, we’re camping this weekend, any chance you could swing by to water the plants? Promise brownies in return!
# - Leaving for the trip tomorrow, even packed already! Any souvenirs you want me to bring back?
# - Remember our hiking trip next weekend! Do we have the sleeping bags packed and ready?
# - Any way we can revise our project draft before the feedback session? I'd love to polish it more.
# - Can you please double-check if we still have that reservation for next week's dinner? I can't seem to find the confirmation email.
# - The new movie we're excited about came out today. Want to watch it over the weekend?
# - I remember you were looking for that book. Found a signed edition at my local store—should I grab it for you?
# - Just got back from the farmer's market and picked up some fresh ingredients. Interested in coming over for a home-cooked meal later?
# - It’s Ellen’s birthday next week! What do you think we should get her as a gift?
# - Hey, I’m organizing a little get-together for the weekend. You free to join us?
# - I heard you know a lot about photography—could I get some tips from you on choosing a good beginner's camera?
# - I heard there's a new Thai restaurant that opened nearby. Do you want to try it out tomorrow evening?
# - Just finished setting up my work-from-home desk! What does your new setup look like?
# - Can you recommend me a pet sitter in our area? I need someone for the weekend and Monday.
# - Hey Sam, just wanted to confirm if the band practice is still scheduled for Tuesday evening?
# - The article you shared about urban gardening was great! Do you have more resources like that for beginners?
# - Had a fantastic book recommendation from a coworker: \"The Midnight Library\" by Matt Haig. Have you read it?
# - Hey Dan, did you get a chance to review the draft I sent yesterday? Let me know your thoughts when you can.
# - Got some time to brainstorm ideas for the fundraiser event we discussed? Looking forward to collaborating on this!
# - Any ideas about how to plan for addressing upcoming campus events and prep next month?
# - Hey Sam! Noticed the talk referencing recent field surveys―can pinpoint trending sites more applicable. Interested in re-linking those?
# - Could you send me the notes from yesterday’s group meeting? I wasn’t able to attend, and I want to stay caught up.
# - I’ve been meaning to ask, where did you get that charming vase in your living room?
# - Do you think we should go with option A or B for the team project? Let me know your preference.
# - Could you recommend a good book you've read recently? I'm looking for something engaging.
# - Thinking of repainting my room. How do you feel about earthy tones compared to vibrant reds?
# - My cat did the funniest thing today; remind me to send you the video. It's absolutely hilarious!
# - Margaret told me you’ve been exploring digital art recently—do you have any tips for someone just starting out?
# - Since you love hiking, I wanted to ask if you've ever tried Horseshoe Trail; It's around here!
# - Quick question: Do you prefer satin or linen for cushion covers? I’m ordering new ones and could use your interior design expertise!
# - Hey Grace, could you remind me where we're planning to stick those charity fundraiser flyers tomorrow?
# - Just wanted to share some good news—I got that internship I was applying for! Would love to celebrate with you soon!
# - What's the name of that cycling app you recommended? I want to download it to prepare for my ride-away.
# - Let me know when you’re online, I’ve got a few questions on the committee plan and need some clarification.
# - The event starts at 6 PM sharp; will you be able to make it in time or should I save a seat for you?
# - Guess what! I found a painting that reminded me of your studio's current vibe—want me to send a picture?
# - Do you mind proofreading this summary I prepared before I submit it, given your knack for concise writing?
# - I stumbled across this video about ancient civilizations and thought of our history project—want the link?
# - My laptop's started acting weird—could you lend a hand troubleshooting it tonight?
# - Found a box of someone's stuff labeled 'donations' down the hall. Did you leave it by accident?
# - Hey, Jane asked me to clarify if your team is presenting first at the seminar. Could you confirm?
# - I saw you dismissed your Uber a while ago. Are you already in the cafe?
# - Emily asked about our availability for rehearsal this Thursday. Should I count you in?
# - Did you catch Jing's latest podcast? I think it could be key for the AI seminar at work.
# - Don’t forget, we wanted to train for the marathon. Can you scad time this Thursday?
# - Don't forget the book club meeting! They're expecting some insights from that novel you liked.
# Generating 50 new examples...
# Generation progress: LAUNCHING
# Generation progress: RUNNING
# Generation progress: [INFO] Progress=> Good: 0/50 Bad: 0 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.3
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 0/50. Bad Inputs: 2. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 0/50 Bad: 2 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.22
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 3/50. Bad Inputs: 4. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 3/50 Bad: 4 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.22
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 8/50. Bad Inputs: 4. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 8/50 Bad: 4 Similar: 0
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Super payday deal! 📢 Exclusive membership discount offered, giving free food finds daily. Secure signup at Cosmosavings.feedapp.reg.offers!' too similar to:
# Generation progress:  'Special discount! Get free rides every day by signing up for monthly credits on our service’s bonus generator: freemonths.ridesupply.skyways/inviteus.'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.26
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 12/50. Bad Inputs: 4. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 12/50 Bad: 4 Similar: 1
# Generation progress: [INFO] With similarity score: 0.79, New input: '🚨 Dear user, a rare chance to earn thousands without lifting a finger! Join at instantmoneyboost.megacashing.foreveryone.' too similar to:
# Generation progress:  'Exclusive opportunity for selected members only! Join our private cryptocurrency group and learn how I made $50,000 in just one week trading! Limited spots available!'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.22
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 14/50. Bad Inputs: 6. Similar Inputs: 2
# Generation progress: [INFO] Progress=> Good: 14/50 Bad: 6 Similar: 2
# Generation progress: [INFO] With similarity score: 0.84, New input: 'Exclusive offer just for you! Invest only $50 in our magic trading app and earn $5,000 in one week guaranteed! Join top traders now.' too similar to:
# Generation progress:  'Exclusive opportunity for selected members only! Join our private cryptocurrency group and learn how I made $50,000 in just one week trading! Limited spots available!'
# Generation progress: [INFO] With similarity score: 0.79, New input: 'Our amazing fashion startup loves your style! Click this UNIQUE link to choose your free outfit while supplies last: freetrial.fakeonlinestore.promolinks.ds' too similar to:
# Generation progress:  'Anna selected exclusive outfits you'll ❤ - amazingly discounted for 24h only at the fashion-choice.shop/index23! Don’t miss out now!'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.3
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 17/50. Bad Inputs: 6. Similar Inputs: 4
# Generation progress: [INFO] Progress=> Good: 17/50 Bad: 6 Similar: 4
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.14
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 18/50. Bad Inputs: 10. Similar Inputs: 4
# Generation progress: [INFO] Progress=> Good: 18/50 Bad: 10 Similar: 4
# Generation progress: [INFO] With similarity score: 0.87, New input: 'Immediate action required! Your online banking account is under threat. Secure it now at bank92.com/security-fast-fix.' too similar to:
# Generation progress:  'Act Fast! Your bank account response is needed: Confirm your details here to avoid account restrictions now: bankconsole.securityverify.biz'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.18
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 22/50. Bad Inputs: 10. Similar Inputs: 5
# Generation progress: [INFO] Progress=> Good: 22/50 Bad: 10 Similar: 5
# Generation progress: [INFO] With similarity score: 0.78, New input: 'URGENT: Strange activity detected in your trading account! Secure it now by following the instructions at trader-check.securityfixpage.biz.' too similar to:
# Generation progress:  'Act Fast! Your bank account response is needed: Confirm your details here to avoid account restrictions now: bankconsole.securityverify.biz'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.22
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 26/50. Bad Inputs: 10. Similar Inputs: 6
# Generation progress: [INFO] Progress=> Good: 26/50 Bad: 10 Similar: 6
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.14
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 29/50. Bad Inputs: 12. Similar Inputs: 6
# Generation progress: [INFO] Progress=> Good: 29/50 Bad: 12 Similar: 6
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.06
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 32/50. Bad Inputs: 14. Similar Inputs: 6
# Generation progress: [INFO] Progress=> Good: 32/50 Bad: 14 Similar: 6
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.06
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 37/50. Bad Inputs: 14. Similar Inputs: 6
# Generation progress: [INFO] Progress=> Good: 37/50 Bad: 14 Similar: 6
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.06
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 42/50. Bad Inputs: 14. Similar Inputs: 6
# Generation progress: [INFO] Progress=> Good: 42/50 Bad: 14 Similar: 6
# Generation progress: [INFO] With similarity score: 0.81, New input: 'Win a free smartphone now! Visit amazingtechgifts.superdeal.claimtoday to enter our giveaway.' too similar to:
# Generation progress:  'OMG, you've won our lucky iPhone13 giveaway! 🌟 Click below to claim now: winner-iphone13.promolink.mist.pl'
# Generation progress: [INFO] With similarity score: 0.81, New input: 'Congratulations! You've won a $100 gift card. Claim it immediately at yourdealinstant.rewardverifynow.life.' too similar to:
# Generation progress:  'Claim your free gift card worth $500! Redeem now at amazingfreerewards.bigduosgiveaway.online.'
# Generation progress: [INFO] With similarity score: 0.87, New input: 'This is your last chance to protect your account from suspension. Verify your information now at verifiesecure.place-safeaccess.com.' too similar to:
# Generation progress:  'URGENT: Your account will be suspended in 24 hours! Verify your identity now: security-verify.suspiciouslink.net'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.18
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 44/50. Bad Inputs: 14. Similar Inputs: 9
# Generation progress: [INFO] Progress=> Good: 44/50 Bad: 14 Similar: 9
# Generation progress: [INFO] With similarity score: 0.83, New input: 'Congratulations! You're invited to an exclusive giveaway for $599 gift cards. Redeem here: fake-giveaway.giftblast-redeem.net.' too similar to:
# Generation progress:  'Special secret giveaway underway! 🎉 Gift set valued over $999 awaiting you. Enter to claim now at prizego.vipwinning.Activity755.'
# Generation progress: [INFO] With similarity score: 0.81, New input: 'Warning 🚨: Account alert detected! Verify a questionable activity taking place. Secure instantly at alert-readdress.confirmsafety.net.' too similar to:
# Generation progress:  'URGENT: Your account will be suspended in 24 hours! Verify your identity now: security-verify.suspiciouslink.net'
# Generation progress: [INFO] With similarity score: 0.81, New input: 'Outstanding news 🎊! You win a voucher of 100 free meals. Approve for redemption at giftify.specialaccess-app.now.' too similar to:
# Generation progress:  'Special secret giveaway underway! 🎉 Gift set valued over $999 awaiting you. Enter to claim now at prizego.vipwinning.Activity755.'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.26
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 45/50. Bad Inputs: 15. Similar Inputs: 12
# Generation progress: [INFO] Progress=> Good: 45/50 Bad: 15 Similar: 12
# Generation progress: [INFO] With similarity score: 0.79, New input: 'Congratulations on being selected in our exclusive lucky draw! You've won a premium holiday opportunity with megaprime.travelpremium.awardwizard.classX.co global tripguination.' too similar to:
# Generation progress:  'CONGRATULATIONS! You've been selected to receive a free luxury watch! Click here to claim: bit.ly/2x4fakelink'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.16
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 47/50. Bad Inputs: 20. Similar Inputs: 13
# Generation progress: [INFO] Progress=> Good: 47/50 Bad: 20 Similar: 13
# Generation progress: [INFO] With similarity score: 0.80, New input: '"Win a year of free streaming subscription and access exclusive content now! Just claim it on youraccount.premiumflix.stream.offer"' too similar to:
# Generation progress:  'Claim your exclusive limited-time access to streaming movies in HD for free now at watchmovies.freestreamtime.watch.'
# Generation progress: [INFO] With similarity score: 0.78, New input: '"Last-minute discount. Featured products from distributors! Secure great deals today at shoppremierglobaldotcom.dealsupgrade358,"' too similar to:
# Generation progress:  'Big discounts! Mega steals of personal gadgets highlighted weekly. Bestfinest.discountntmammon4ever.sale on FreshElectronDotComp.'
# Generation progress: [INFO] With similarity score: 0.78, New input: '"Get your energy peak back with specialized supplements to invigorate your lifestyle: healthnow.offertodayspecadeals.com!"' too similar to:
# Generation progress:  'Super-alert! Our highest-quality wellness supplements are now discounted only for you. Grab them today: ultimate-wellness.superdeals.activeboostshop.net.'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.28
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 49/50. Bad Inputs: 20. Similar Inputs: 16
# Generation progress: [INFO] Progress=> Good: 49/50 Bad: 20 Similar: 16
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Grand clearance! Electronics up to 85% off—shop these unbeatable prices before midnight at megasale.electrodeals.vip-nights.special.store.' too similar to:
# Generation progress:  '"Exclusive deal for tech enthusiasts! Hot new electronics priced below retail at electricsdiscount.qualitydeals.techshop.'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.2
# Generation progress: [INFO] Data Generation Complete => Good Inputs: 50. Bad Inputs: 23. Similar Inputs: 17
# Generation progress: DONE
# Adding inputs for label Spam:
# - Act fast! Order now to get your free coffee maker before stock runs out! Simply click bestfreecoffee.give-a-way/br299 to redeem.
# - OMG, you've won our lucky iPhone13 giveaway! 🌟 Click below to claim now: winner-iphone13.promolink.mist.pl
# - Anna selected exclusive outfits you'll ❤ - amazingly discounted for 24h only at the fashion-choice.shop/index23! Don’t miss out now!
# - Hi there! 🔥 I've found an amazing way to double your likes on every post! Check our secret tool at doublemylikes.socialboosts.plus!!
# - You’ve just won a contest 🏆! Click here to claim your brand-new gaming console now: contestwinner.get-your-rewards.megasite.com.
# - Hey friend! Wanna know how you can travel the world for almost FREE? Join our network of secret travel hackers today: travelmaster.paidconsult.codes.special.us.
# - Special discount! Get free rides every day by signing up for monthly credits on our service’s bonus generator: freemonths.ridesupply.skyways/inviteus.
# - ⚡ Attention! This amazing weekend deal offers 90% discount on full-flight first-class travel searches! Check cheapestflights.bestoffers.quicklink.helpfree.
# - Dear User! Don't miss this chance ⏰! Learn how to earn $1000 per day with the special guide at moneyprojects.socialcash.plus.
# - Huge opportunity for fashion lovers! 😍 Chic 5-star custom outfits are 60% off for today at dezzclothes.stylishchoice.shopexclusive.
# - Unlock hidden benefit codes to use on our VIP food delivery platform at leadsaler.rodeats.deliveryorder! 🥩 Enjoy premium service today.
# - Special secret giveaway underway! 🎉 Gift set valued over $999 awaiting you. Enter to claim now at prizego.vipwinning.Activity755.
# - 🔥 Don't wait! Get up to 90% off on premium designer bags this weekend! Visit handbag-desire.promos.crazydeals.com.
# - Happy User! 🎉 Click here premiumsubs.offers.specialaccess.true.com/rewards to unlock surprise rewards.Active limited hours.
# - Act Fast! Your bank account response is needed: Confirm your details here to avoid account restrictions now: bankconsole.securityverify.biz
# - BREAKING: National shortage on custom-fit bracelets – secure yours today at BigDiscountBraceletRange.logisticajax.net!
# - Good evening! Discover secret revenue-generating strategies for 120% profit increase monthly. Showcase others’ results at hiddenwealthplan.oportalgenerator.org insight!
# - Inbox party begins! GET BEST HERE thriftodadero.shinyshopitems.com.blangeb ! cashback rewards FAST.
# - Your subscription to premium services expires today! Renew now and get a 20% discount at renew.premiumsave-now-discount.net.
# - Reserve your spot in our luxury investment group and learn the best-kept tips on multiplying your wealth. Visit join.todaybiznes-opportunity-z.ir.
# - Congratulations user! Celebrate your chance to claim an Apple MacBook Pro. Redeem at: winpro.appleclaim-fastgadgetlink.net.
# - Ad alert 💰: Buy designer sunglasses online at 70% off! Visit true.imaginarysales-dotfast-global54.com today.
# - Attention book lovers! Don't miss out on amazing deals on popular bestsellers this weekend⁠—grab them now at exclusive-deals.bookstore-online.shop.
# - Claim your exclusive limited-time access to streaming movies in HD for free now at watchmovies.freestreamtime.watch.
# - Congratulation music enthusiast, you've won access to premier concerts in your city! Claim yours instantly at goldenentertainment-tickets.bestwins.store.
# - Get prime gaming features with stunning discounts available for gamers at spategamedownloads.evolution-mode.store. Hurry before it expires!
# - Super-alert! Our highest-quality wellness supplements are now discounted only for you. Grab them today: ultimate-wellness.superdeals.activeboostshop.net.
# - 💼 Career opportunity knocks! Secure your dream role learning directly from top industry insiders through opsmaster.learncareer.show.demo.
# - Access FREE top-tier entertainment subscriptions and view only Premier seasons worldwide without the usual high price here: advertisement.showlocale.promoliquidcefant.comregional.
# - "Exclusive deal for tech enthusiasts! Hot new electronics priced below retail at electricsdiscount.qualitydeals.techshop.
# - "Lowest flight rates in decades! Secure your next adventure abroad through flightpromo.cheaptickets.vacation-joy."
# - "Urgent! Download our app for free top-rated fitness plans, only available for a short while: freefitness.download-time.lrfast."
# - Win big this weekend! Claim your free slot spin at lowrates-online.vip.casinospinklubb.com and start winning effortlessly!
# - Never before seen sale! Huge discounts on our skincare products. Visit glowyskincare.discount.marketbro.shop now!
# - Attention tech lovers! Grab the latest gadgets at unbeatable prices only here: techdiscounts.club.offersunibox.space.
# - Here’s your chance to take part in a unique investment opportunity! Furious.rates.tradefastsecurex.com. Act fast!
# - 🌟 Hurry! This is your last chance to enjoy amazing savings on luxury items here at promo-deals.citymarketwow.shop.
# - Claim your free gift card worth $500! Redeem now at amazingfreerewards.bigduosgiveaway.online.
# - Experience faster and smoother browsing! Upgrade to VIP status now at mypremiuminternet.success.browserfastchoice.tel.
# - Get a lifetime supply of vitamins for free! Just pay a tiny shipping fee, click healthyliving.lifefastsupply.club for more.
# - Be part of the hottest club this season! Exclusive access awaits you, join now at vandychicexclusive.members.passbestOferta.win.
# - Upgrade your gaming level now with free cool skins! Visit gamingbonanza.event.perkogamesupply.link.
# - Your account has been selected for a premium upgrade! Confirm your details now at vip.upgrade-now-security.net.
# - Check out our exclusive one-time offer on luxury watches. Get up to 80% off at luxurytime.sales.jupiterpromo.com.
# - Exclusive buy-one-get-one-free deal on smartphones! Offer valid today only. Shop now at techpanic.smartphoneblowout.global.
# - 🍹 Summer cocktail specials exclusively at MixTegration recipes. Plus free guide at summersexclusivecocktailsfest.boost.mox.info.club.
# - Big discounts! Mega steals of personal gadgets highlighted weekly. Bestfinest.discountntmammon4ever.sale on FreshElectronDotComp.
# - "Exclusive fashion drops! Grab the pieces before it's too late at: luxury-sales.transaction.glamfittedhuge.store"
# - "⚔ Weapon skins reduced as limited-time promotional offer expires soon!View offerings at skincrafstandoutshift.campaign.bpx.me/armsweapon"
# - Love coffee? You've been selected to try our new unbiased coffee rating platform! Get your first premium userid: free yourcoffeebizating.abusive.promo.startto.try

# %% [markdown]
# ### Labeling queries
# Now we'll use the teacher model to generate good labels for these queries, going from a **pool of inputs** to **labeled examples** that we can use for training.

# %%
from traceback import print_exception
import pandas as pd

# This table allows us to monitor labeling progress.
table = display(pd.DataFrame(), display_id=True)

# We're going to take 5 examples at a time, and use the query
# classifier to label them. The examples that we give to the
# classifier will help it make good labeling decisions.
batch_size = 5
training_examples = []
for i in range(0, len(generated_queries), batch_size):
    batch = generated_queries[i:i+batch_size]
    response = client.search.query_classifier.classify(
        queries=batch,
        classes=classes,
        examples=examples,
        mode="generative",
    )

    for classification in response.results:
        training_examples.append({
            "llm_input": classification.query,
            "llm_output": classification.prediction,
        })
        table.update(pd.DataFrame(training_examples))
# Out:
#                                             llm_input llm_output
# 0   Hey Alex, did you watch that summit livestream...   Not Spam
# 1   Hey Mark! Don't forget the assignment is due t...   Not Spam
# 2   Had such a blast at the party yesterday, thank...   Not Spam
# 3   Going to make pasta for tonight’s dinner! Any ...   Not Spam
# 4   Hey, we’re camping this weekend, any chance yo...   Not Spam
# ..                                                ...        ...
# 95  🍹 Summer cocktail specials exclusively at MixT...       Spam
# 96  Big discounts! Mega steals of personal gadgets...       Spam
# 97  "Exclusive fashion drops! Grab the pieces befo...       Spam
# 98  "⚔ Weapon skins reduced as limited-time promot...       Spam
# 99  Love coffee? You've been selected to try our n...       Spam
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Training a tiny classifier
#
# Lastly, let's train a classifier using the training examples that we've gathered through generated inputs and zero-shot classification.
#
# ⏰ **Note:** This cell can take 5-15 minutes to run.

# %%
# Kick off the training job.
job_status = client.search.query_classifier.distill.start_job(
    examples=training_examples,
    base_model="MODERNBERT_BASE",
    learning_rate=5e-5,
    num_train_epochs=3,
)
job_id = job_status.job_id

# %%
from withpi_utils.colab import stream_training_response

# Monitor the training.
response = stream_training_response(
    job_status.job_id,
    client.search.query_classifier.distill,
    additional_columns={"F1": "eval_f1"},
)

if response.state != "DONE":
  print(f"Jobs state = {response.state}")
  print("The error message:\n{}".format('\n'.join(response.detailed_status[-5:])))
else:
  print("Classifier model = {}".format(response.trained_models[0].model_dump_json(indent=2)))

# NOTE: After training finishes, it may take a minute or two for the model to
#       become available.
# Out:
# Training Status for classification_jobs:09ac227c912792130a876568ea872593308c0d4b3d7c896ec7991f041cbeedd8:2de5b51c-e163-4559-a107-500dc60fec0a
#    Step     Epoch  Learning_Rate  Training_Loss  Eval_Loss        F1
# 0     2  0.333333       0.000033         0.9042   0.832422  0.320124
# 1     4  0.666667       0.000047         0.9073   0.725977  0.475524
# 2     6  1.000000       0.000040         0.6278   0.588867  0.685315
# 3     8  1.333333       0.000033         0.4576   0.491797  0.800000
# 4    10  1.666667       0.000027         0.4490   0.434668  0.902875
# 5    12  2.000000       0.000020         0.3795   0.396777  1.000000
# 6    14  2.333333       0.000013         0.3546   0.375195  1.000000
# 7    16  2.666667       0.000007         0.2936   0.369629  1.000000
# 8    18  3.000000       0.000000         0.3242   0.366211  1.000000
# Classifier model = {
#   "contract_score": 0.0,
#   "epoch": 3.0,
#   "eval_loss": 0.3662109375,
#   "serving_id": 0,
#   "serving_state": "UNLOADED",
#   "step": 18
# }

# %% [markdown]
# ### Evaluating the model
#
# We already have a handful of **ground-truth examples**, the `examples` that we used in the beginning to create our query set and label our queries.
#
# As an approximation for accuracy, let's see how well the distilled model performs on those examples.

# %%
from transformers import pipeline

def evaluate(dataset, classifier):
    df = pd.DataFrame(dataset)  # columns: ['text', 'label']
    df["prediction"] = [prediction["label"] for prediction in classifier(df["text"].tolist())]
    df["correct"] = df["label"] == df["prediction"]
    return df

path = download_classifier(job_id, "./model-checkpoint")
classifier = pipeline("text-classification", model="./model-checkpoint")
df = evaluate(examples, classifier)
print(f"Accuracy: {100*df['correct'].mean():.1f}%")

df[['text', 'label', 'prediction', 'correct']]
# Out:
# Device set to use cpu
# Compiling the model with `torch.compile` and using a `torch.cpu` device is not supported. Falling back to non-compiled mode.
# Accuracy: 83.3%
#                                                  text     label prediction  \
# 0   CONGRATULATIONS! You've been selected to recei...      Spam       Spam
# 1   Hello dear, I noticed your profile and think y...      Spam       Spam
# 2   Hi there! 👋 I'm selling handmade bracelets at ...      Spam       Spam
# 3   Hey, are we still meeting for coffee tomorrow ...  Not Spam   Not Spam
# 4   Hi Sarah! Just wanted to thank you for your he...  Not Spam   Not Spam
# 5   Dude, did you see that game last night? Incred...  Not Spam   Not Spam
# 6   URGENT: Your account will be suspended in 24 h...      Spam       Spam
# 7   Hello friend! I am international business pers...      Spam   Not Spam
# 8   Want to lose 20 pounds in just 1 week? Our new...      Spam   Not Spam
# 9   The photos from our hiking trip are finally up...  Not Spam       Spam
# 10  Mom asked me to check if you're still coming f...  Not Spam   Not Spam
# 11  Hi Professor, I'm emailing about the assignmen...  Not Spam   Not Spam
# 12  ⚠️ Your profile has received 38 secret admirer...      Spam       Spam
# 13  Exclusive opportunity for selected members onl...      Spam       Spam
# 14  Your package delivery failed! Reschedule deliv...      Spam       Spam
# 15  Hey, can you send me that recipe you mentioned...  Not Spam   Not Spam
# 16  The concert tickets just went on sale! Should ...  Not Spam   Not Spam
# 17  Just landed! The flight was delayed but I'm fi...  Not Spam   Not Spam
#
#     correct
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True

# %% [markdown]
# ## Next steps
#
# You now have a tiny model that approximates the performance of the zero-shot model. Here are some steps you can take to improve the performance of this model.
#
#  1. **Providing more inputs for input generation.** If you have 20-100 inputs, sharing more inputs as seed for data generation can be helpful.
#  2. **Using real input data for training.** If you have 100+ inputs, you can use those inputs as the inputs to teacher model, rather than using generated input. These models will better reflect the **input distribution**, or the data that the model will see during inference.
#  3. **Using real examples for training.** If you have 300+ (the more the better) high-quality labeled examples, you can train a classifier directly. This will yield the best performance for your use case, but may take time to obtain. Therefore, steps (1) and (2) are a great way to quickly deploy a first iteration of a system that can be used to collect high-quality inputs, which can then be labeled to build a high quality training set.
