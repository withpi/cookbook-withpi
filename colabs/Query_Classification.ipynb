# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/colabs/Query_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://withpi.ai"><img src="https://play.withpi.ai/logo/logoFullBlack.svg" width="240"></a>
#
# <a href="https://code.withpi.ai"><font size="4">Documentation</font></a>
#
# <a href="https://play.withpi.ai"><font size="4">Technique Catalog</font></a>

# %% [markdown]
# # Query Classification
#
# Query classification is a key primitive for AI systems, and allows for powerful RAG pipelines.
#
# A "query" could be:
#   * a search term in an e-commerce search (eg. "levis 501")
#   * a message from a customer to a support team
#   * a prompt to an AI assistant
#
# The "classification" part could involve:
#   * deciding whether retrieval is needed
#   * deciding what data sources to use
#   * deciding what pre- or post-processing to apply
#
# This Colab will take you through classifying queries for your use case, and improving query classification through minimal work. A small amount of teaching the model through **data labeling** will make it better at classifying queries for your use case, and enable you to use smaller and faster models for your use case.

# %% [markdown]
# ## Install and initialize SDK
#
# Connect to a regular CPU Python 3 runtime.  You won't need GPUs for this notebook.
#
# You'll need a WITHPI_API_KEY from https://play.withpi.ai.  Add it to your notebook secrets (the key symbol) on the left.
#
# Run the cell below to install packages and load the SDK

# %%
# %%capture

import os
from google.colab import files, userdata

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

# %pip install withpi litellm httpx datasets jinja2 tqdm requests

# Import a bunch of useful libraries for later.
from concurrent.futures import ThreadPoolExecutor
from collections import defaultdict
import json
from pathlib import Path
import re

import datasets
import httpx
import litellm
import jinja2
from tqdm.notebook import tqdm
from withpi import PiClient
from IPython.display import display
import pandas as pd

client = PiClient()


def generate(system: str, user: str, model: str) -> str:
    """generate passes the provided system and user prompts into the given model
    via LiteLLM"""
    messages = [
        {"content": system, "role": "system"},
        {"content": user, "role": "user"},
    ]
    return litellm.completion(model=model, messages=messages).choices[0].message.content


class printer(str):
    """printer makes strings with embedded newlines print more nicely"""

    def __repr__(self):
        return self


def print_response(response: str):
    """print_response pretty-prints an LLM response, respecting newlines"""
    display(printer(response))


def print_scores(pi_scores):
    """print_scores pretty-prints a Pi Score response as a table."""
    for dimension_name, dimension_scores in pi_scores.dimension_scores.items():
        print(f"{dimension_name}: {dimension_scores.total_score}")
        for (
            subdimension_name,
            subdimension_score,
        ) in dimension_scores.subdimension_scores.items():
            print(f"\t{subdimension_name}: {subdimension_score}")
        print("\n")
    print("---------------------")
    print(f"Total score: {pi_scores.total_score}")


def save_file(filename: str, model: str):
    """save_file offers to download the model with the given filename"""
    Path(filename).write_text(model)
    files.download(filename)



def load_and_split_dataset(url: str) -> datasets.DatasetDict:
    """load_and_split_dataset pulls in the Parquet file at url and does a 90/10 split"""
    return datasets.load_dataset(
        "parquet", data_files=url, split="train"
    ).train_test_split(test_size=0.1)


def do_bulk_inference(dataset, system, model):
    """do_bulk_inference performs inference on the 'input' column of dataset, using
    the provided system prompt.  The model identified will be used via LiteLLM"""

    def do_generate(user, pbar):
        result = generate(system, user, model)
        pbar.update(1)
        return result

    futures = []
    pbar = tqdm(total=len(dataset))
    with ThreadPoolExecutor(max_workers=4) as executor:
        for row in dataset:
            futures.append(executor.submit(do_generate, row["input"], pbar))
    return [future.result() for future in futures]


def do_bulk_templated_inference(dataset, optimized, model):
    """do_bulk_templated_inference performs inference on the 'input' column of dataset,
    using the provided optimized prompt.  It should be a Jinja2 template as returned
    by DSPy"""
    prompt_template = jinja2.Template(optimized)
    result_extractor = re.compile(
        r".*\[\[ ## response ## \]\](.*)\[\[ ## completed ## \]\]", re.DOTALL
    )

    def do_generate(prompt: str, pbar) -> str:
        messages = json.loads(prompt_template.render(input=prompt))
        result = (
            litellm.completion(model=model, messages=messages)
            .choices[0]
            .message.content
        )

        pbar.update(1)
        return result_extractor.match(result).group(1)

    futures = []
    pbar = tqdm(total=len(dataset))
    with ThreadPoolExecutor(max_workers=4) as executor:
        for row in dataset:
            futures.append(executor.submit(do_generate, row["input"], pbar))
    return [future.result() for future in futures]


def generate_table(
    job_id: str, training_data: dict, is_done: bool, additional_columns: dict[str, str]
):
    """Generate a training progress table dynamically."""
    data_dict = {}
    for header in ["Step", "Epoch", "Learning Rate", "Training Loss", "Eval Loss"]:
        data_dict[header] = []
    for header in additional_columns.keys():
        data_dict[header] = []

    for step, data in training_data.items():
        data_dict["Step"].append(step)
        for header, key in [
            ("Epoch", "epoch"),
            ("Learning Rate", "learning_rate"),
            ("Training Loss", "loss"),
            ("Eval Loss", "eval_loss"),
        ]:
            data_dict[header].append(data.get(key, "X"))
        for header, key in additional_columns.items():
            data_dict[header].append(data.get(key, "X"))

    if not is_done:
        data_dict["Step"].append("...")
        for header in ["Epoch", "Learning Rate", "Training Loss", "Eval Loss"]:
            data_dict[header].append("")
        for header in additional_columns.keys():
            data_dict[header].append("")

    return pd.DataFrame(data_dict)


def stream_response(job_id: str, method, additional_columns: dict[str, str]):
    """stream_response streams messages from the provided method

    method should be a Pi client object with `retrieve` and `stream_messages`
    endpoints.  This is primarily for convenience."""

    print(f"Training Status for {job_id}")

    training_data = defaultdict(dict)
    is_log_console = False

    stream_output = display(
        generate_table(
            job_id, training_data, is_done=False, additional_columns=additional_columns
        ),
        display_id=True,
    )

    while True:
        response = method.retrieve(job_id=job_id)
        if (response.state != "QUEUED") and (response.state != "RUNNING"):
            if response.state == "DONE" and not is_log_console:
                for line in response.detailed_status:
                    try:
                        data_dict = json.loads(line)
                        training_data[data_dict["step"]].update(data_dict)
                    except Exception:
                        pass
                stream_output.update(
                    generate_table(
                        job_id,
                        training_data,
                        is_done=True,
                        additional_columns=additional_columns,
                    )
                )
            return response

        with method.with_streaming_response.stream_messages(
            job_id=job_id, timeout=None
        ) as response:
            is_done = False
            for line in response.iter_lines():
                if line == "DONE":
                    is_done = True
                try:
                    data_dict = json.loads(line)
                    training_data[data_dict["step"]].update(data_dict)
                except Exception:
                    pass
                stream_output.update(
                    generate_table(
                        job_id,
                        training_data,
                        is_done,
                        additional_columns=additional_columns,
                    )
                )
                is_log_console = True


###  QUERY CLASSIFICATION  ###

import requests
from io import BytesIO
import tarfile

# Caching jobs allows us to avoid repeating job starts.
if 'job_id_by_hash' not in locals():
    job_id_by_hash = {}

def generate_inputs(
    queries: list[str],
    exploration_mode: str = "ADVENTUROUS",
    application_description: str = "",
    num_examples: int = 10,
) -> list[str]:
    job_hash = hash(json.dumps([
        num_examples,
        exploration_mode,
        queries,
        application_description
    ]))

    if job_hash not in job_id_by_hash:
        print(f"Generating {num_examples} new examples...")
        data_generation_status = client.data.generate.start_job(
            application_description=application_description,
            num_inputs_to_generate=num_examples,
            num_shots=10,
            exploration_mode=exploration_mode,
            seeds=queries,
        )
        job_id_by_hash[job_hash] = data_generation_status.job_id

    job_id = job_id_by_hash[job_hash]
    job_status = client.data.generate.retrieve(job_id)
    if job_status.state == "ERROR":
        raise RuntimeError(f"Generation job failed")
    if job_status.state == "DONE":
        return job_status.data

    with (
        client.data.with_streaming_response.generate.stream_messages(
            job_id
        ) as response
    ):
        for line in response.iter_lines():
            print(f"Generation progress: {line}")

    job_status = client.data.generate.retrieve(
        job_id
    )
    assert job_status.state == "DONE"
    return job_status.data


def download_classifier(job_id: str, path: str, serving_id: int | None = 0) -> Path:
    if not serving_id:
        # TODO: explicitly use the lowest eval loss here by default.
        #   this currently happens to be the zeroeth element, but we can
        #   avoid relying on it!
        #
        # job_status = client.search.query_classifier.distill.retrieve(job_id=job_id)
        serving_id = 0
    url = json.loads(client.search.query_classifier.distill.download(job_id=job_id, serving_id=serving_id))
    return download_and_extract(url, path)


def download_and_extract(url: str, output_dir: str) -> Path:
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    response = requests.get(url)
    response.raise_for_status()
    tar_bytes = BytesIO(response.content)
    with tarfile.open(fileobj=tar_bytes, mode="r:gz") as tar:
        tar.extractall(path=output_dir)
    return output_path

# %% [markdown]
# # Detecting spam in social media DMs
# For our task, let's imagine that we need to detect spam messages in DMs sent between people on a social media platform.
#
# We'll lay out:
# * **input description** - describing what the inputs are to help calibrate our data generator
# * **classes** - the classes we want to split it into, with descriptions to help calibrate the query classifier
# * **examples** - queries and classes that we know to be correct

# %%
# This is describing the kind of inputs we'll be dealing with.
input_description = "direct messages received by users on a social media network"

# These are the classes that we want to classify our queries into.
# In this example, the queries are direct messages that users receive,
# which we want to classify as spam or legitimate communication.
classes = [
    {"label": "Spam", "description": "Unsolicited messages promoting products, services, or containing suspicious links"},
    {"label": "Not Spam", "description": "Legitimate messages from real users with genuine communication intent"}
]

# Here are some examples that we can provide to the zero-shot
# query classification model, and later to our trained model.
examples = [
    {"label": "Spam", "text": "CONGRATULATIONS! You've been selected to receive a free luxury watch! Click here to claim: bit.ly/2x4fakelink"},
    {"label": "Spam", "text": "Hello dear, I noticed your profile and think you have great investment potential. I manage a portfolio worth $25M and can help you earn 300% returns monthly. Message me for details."},
    {"label": "Spam", "text": "Hi there! 👋 I'm selling handmade bracelets at 70% discount today only! Check my store: handmade-jewelry.fakesite.co/discount"},
    {"label": "Not Spam", "text": "Hey, are we still meeting for coffee tomorrow at 2? Let me know if you need to reschedule."},
    {"label": "Not Spam", "text": "Hi Sarah! Just wanted to thank you for your help with the project yesterday. Your input really made a difference. Hope we can collaborate again soon!"},
    {"label": "Not Spam", "text": "Dude, did you see that game last night? Incredible comeback in the final quarter! We should watch the next one together."},
    {"label": "Spam", "text": "URGENT: Your account will be suspended in 24 hours! Verify your identity now: security-verify.suspiciouslink.net"},
    {"label": "Spam", "text": "Hello friend! I am international business person with opportunity for you. I have $5,000,000 USD to transfer and need your assistance. Reply for 30% commission."},
    {"label": "Spam", "text": "Want to lose 20 pounds in just 1 week? Our new miracle supplement guarantees results or money back! Order now with code SLIM50 for 50% off!"},
    {"label": "Not Spam", "text": "The photos from our hiking trip are finally uploaded! Here's the link to the shared album I promised: photos.legitimatesite.com/album/hiking2023"},
    {"label": "Not Spam", "text": "Mom asked me to check if you're still coming for dinner on Sunday. She's planning the menu and wants to know if you're bringing anyone."},
    {"label": "Not Spam", "text": "Hi Professor, I'm emailing about the assignment due next week. Could I get a short extension? I've been dealing with some health issues and could use a couple extra days."},
    {"label": "Spam", "text": "⚠️ Your profile has received 38 secret admirers today! Upgrade your account to see who likes you: premium-vip-access.scamsite.co"},
    {"label": "Spam", "text": "Exclusive opportunity for selected members only! Join our private cryptocurrency group and learn how I made $50,000 in just one week trading! Limited spots available!"},
    {"label": "Spam", "text": "Your package delivery failed! Reschedule delivery by confirming your details: delivery-service.maliciouslink.com"},
    {"label": "Not Spam", "text": "Hey, can you send me that recipe you mentioned yesterday? I want to try making it this weekend."},
    {"label": "Not Spam", "text": "The concert tickets just went on sale! Should I grab two for us for the Friday show, or does Saturday work better for you?"},
    {"label": "Not Spam", "text": "Just landed! The flight was delayed but I'm finally here. Can you still pick me up from the airport or should I grab a taxi?"},
]

# Let's classify and see how our classifications turn out!
response = client.search.query_classifier.classify(
    queries=[
        "Hey! I noticed your photography skills and I'm impressed! I run a modeling agency and think you'd be perfect for our upcoming campaign. DM me for details!",
        "Hi Alex, are we still on for lunch tomorrow at the usual place? I might be running about 10 minutes late.",
        "CONGRATULATIONS! You've won a $1000 gift card! Claim now: www.totallylegitprizes.co/claim-now",
        "Can you send me the notes from yesterday's meeting? I had to leave early and missed the last part.",
        "FREE iPhone 13 Pro! You've been selected in our monthly giveaway! Click here to claim within 24 hours: bit.ly/claim-prize"
    ],
    classes=classes,
    mode="generative",
    examples=examples,
)

for classification in response.results:
    print(f"Query: {repr(classification.query)}")
    print(f"Classification: {repr(classification.prediction)}")
    print()
# Out:
# Query: "Hey! I noticed your photography skills and I'm impressed! I run a modeling agency and think you'd be perfect for our upcoming campaign. DM me for details!"
# Classification: 'Spam'
#
# Query: 'Hi Alex, are we still on for lunch tomorrow at the usual place? I might be running about 10 minutes late.'
# Classification: 'Not Spam'
#
# Query: "CONGRATULATIONS! You've won a $1000 gift card! Claim now: www.totallylegitprizes.co/claim-now"
# Classification: 'Spam'
#
# Query: "Can you send me the notes from yesterday's meeting? I had to leave early and missed the last part."
# Classification: 'Not Spam'
#
# Query: "FREE iPhone 13 Pro! You've been selected in our monthly giveaway! Click here to claim within 24 hours: bit.ly/claim-prize"
# Classification: 'Spam'

# %% [markdown]
# ## Distillation
#
# Distillation is the process of training a small model with the use of a big model. Distillation is a powerful tool to create fast classifiers, that can be used for decision-making in latency-sensitive scenarios such as RAG pipelines and AI agents.
#
# In distillation, we refer to the big model as the **teacher model** and the small model as the **student model**.  In order to use the teacher model, you also need a **pool of unlabeled data**.
#
# In this case:
#
# * The teacher model is the query classification model from the Pi SDK.
# * The student model is a ModernBERT model, a small and capable model for this task.
# * The unlabeled data are queries that we're going to generate using the Pi SDK's "generate from seeds" synthetic data generator. When we give it our `queries`, it will generate more similar queries.

# %% [markdown]
# ### Generating queries
#
# First, let's generate some queries. To illustrate the process quickly, we'll generate only 100 queries. In a realistic run, you will have the best results generating at least 500 queries.
#
# **Tip:** If you have a pool of real user queries, you will be able to distill a better model than using only generated inputs, since it will better help the model learn the kind of queries it will see.

# %%
# We'll generate 100 training samples in total, and split them
# equally across the different classes to yield a balanced
# training set.
examples_df = pd.DataFrame(examples)
groups = examples_df.groupby('label')
samples_per_group = 100 // len(groups)
classes_by_label = {c["label"]: c["description"] for c in classes}

generated_queries = []
for label, label_examples in groups:
    # We can use the Pi SDK to generate inputs given some examples of
    # input that we'd like more of. A description of the application
    # helps the input generator create inputs that are relevant to our use case.
    new_inputs = generate_inputs(
        queries=[example["text"] for example in label_examples.to_records()],
        application_description=f"""
            Queries should match the input description and belong to
            the following class:

            <class_name>{label}</class_name>
            <class_description>{classes_by_label[label]}</class_description>
            <input_description>{input_description}</input_description>
            """,
        num_examples=samples_per_group,
        exploration_mode='ADVENTUROUS'
    )

    print(f"Adding inputs for label {label}:")
    for input in new_inputs:
        print(f"- {input}")

    generated_queries.extend(new_inputs)
# Out:
# Generating 50 new examples...
# Generation progress: LAUNCHING
# Generation progress: RUNNING
# Generation progress: [INFO] Progress=> Good: 0/50 Bad: 0 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.43
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 2/50. Bad Inputs: 1. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 2/50 Bad: 1 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.23
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 2/50. Bad Inputs: 6. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 2/50 Bad: 6 Similar: 0
# Generation progress: [INFO] With similarity score: 0.80, New input: 'Amy, I'm setting up a shared doc for the team project notes. Can you review it and add your comments today?' too similar to:
# Generation progress:  'Hi Sarah! Just wanted to thank you for your help with the project yesterday. Your input really made a difference. Hope we can collaborate again soon!'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.27
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 6/50. Bad Inputs: 6. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 6/50 Bad: 6 Similar: 1
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Did you end up finishing the novel you were reading? I'd like to hear your thoughts before I pick it up.' too similar to:
# Generation progress:  'Really enjoyed the article you sent me! Do you have any suggestions for similar reads?'
# Generation progress: [INFO] With similarity score: 0.80, New input: 'Do you still have your ticket for the concert next Friday? Heard it's almost sold out.' too similar to:
# Generation progress:  'The concert tickets just went on sale! Should I grab two for us for the Friday show, or does Saturday work better for you?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.35
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 9/50. Bad Inputs: 6. Similar Inputs: 3
# Generation progress: [INFO] Progress=> Good: 9/50 Bad: 6 Similar: 3
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.35
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 14/50. Bad Inputs: 6. Similar Inputs: 3
# Generation progress: [INFO] Progress=> Good: 14/50 Bad: 6 Similar: 3
# Generation progress: [WARNING] generated a user_prompt with zero length
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.19
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 15/50. Bad Inputs: 10. Similar Inputs: 3
# Generation progress: [INFO] Progress=> Good: 15/50 Bad: 10 Similar: 3
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.19
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 20/50. Bad Inputs: 10. Similar Inputs: 3
# Generation progress: [INFO] Progress=> Good: 20/50 Bad: 10 Similar: 3
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Hi Chris, we missed having you at the meeting last Thursday! Let me know if you want my notes and updates.' too similar to:
# Generation progress:  'Can you send me the notes from the session you attended early today? Everyone said it was really informative.'
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Hello Sandra, we’ve noticed some great feedback on your latest artwork! Any chance of previewing future projects?' too similar to:
# Generation progress:  'Hi Sarah! Just wanted to thank you for your help with the project yesterday. Your input really made a difference. Hope we can collaborate again soon!'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.27
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 23/50. Bad Inputs: 10. Similar Inputs: 5
# Generation progress: [INFO] Progress=> Good: 23/50 Bad: 10 Similar: 5
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.19
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 26/50. Bad Inputs: 12. Similar Inputs: 5
# Generation progress: [INFO] Progress=> Good: 26/50 Bad: 12 Similar: 5
# Generation progress: [INFO] With similarity score: 0.81, New input: 'Hey Lisa, we should catch up soon. How about next weekend?' too similar to:
# Generation progress:  'Hey Tom, I'll be in your area next weekend. Would you have time to catch up over lunch?'
# Generation progress: [INFO] With similarity score: 0.93, New input: 'Could you send me the recipe you mentioned last week? It sounded delicious.' too similar to:
# Generation progress:  'Hey, can you send me that recipe you mentioned yesterday? I want to try making it this weekend.'
# Generation progress: [INFO] With similarity score: 0.81, New input: 'I read the book you recommended and loved it! Let’s discuss over coffee sometime.' too similar to:
# Generation progress:  'Really enjoyed the article you sent me! Do you have any suggestions for similar reads?'
# Generation progress: [INFO] With similarity score: 0.78, New input: 'I saw this article about a festival happening downtown, we should check it out together if you're interested.' too similar to:
# Generation progress:  'I'm working on a community event idea and thought of you—any chance we could meet for ideas?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.35
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 27/50. Bad Inputs: 12. Similar Inputs: 9
# Generation progress: [INFO] Progress=> Good: 27/50 Bad: 12 Similar: 9
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.24
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 31/50. Bad Inputs: 17. Similar Inputs: 9
# Generation progress: [INFO] Progress=> Good: 31/50 Bad: 17 Similar: 9
# Generation progress: [INFO] With similarity score: 0.82, New input: 'Hey Maya, I was really intrigued by that book you recommended last week! Could you suggest another title from the same author?' too similar to:
# Generation progress:  'Really enjoyed the article you sent me! Do you have any suggestions for similar reads?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.2
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 33/50. Bad Inputs: 19. Similar Inputs: 10
# Generation progress: [INFO] Progress=> Good: 33/50 Bad: 19 Similar: 10
# Generation progress: [INFO] With similarity score: 0.82, New input: 'I just baked that bread recipe you shared. It turned out amazing! Want me to share some with you?' too similar to:
# Generation progress:  'Hey, can you send me that recipe you mentioned yesterday? I want to try making it this weekend.'
# Generation progress: [INFO] With similarity score: 0.80, New input: 'Just scheduled my hiking trip! Have you got recommendations for scenic trails nearby?' too similar to:
# Generation progress:  'Did you check out the new park that opened last month? People say it's beautiful with a great bike path!'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.28
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 36/50. Bad Inputs: 19. Similar Inputs: 12
# Generation progress: [INFO] Progress=> Good: 36/50 Bad: 19 Similar: 12
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.2
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 39/50. Bad Inputs: 21. Similar Inputs: 12
# Generation progress: [INFO] Progress=> Good: 39/50 Bad: 21 Similar: 12
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Just read this fantastic book that you might like. Do you want me to send over the details or lend it to you?' too similar to:
# Generation progress:  'Really enjoyed the article you sent me! Do you have any suggestions for similar reads?'
# Generation progress: [INFO] With similarity score: 0.78, New input: 'I'm trying to organize a neighborhood bonfire on Friday. Will you help spread the word or join in yourself?' too similar to:
# Generation progress:  'I'm working on a community event idea and thought of you—any chance we could meet for ideas?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.28
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 42/50. Bad Inputs: 21. Similar Inputs: 14
# Generation progress: [INFO] Progress=> Good: 42/50 Bad: 21 Similar: 14
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.08
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 42/50. Bad Inputs: 28. Similar Inputs: 14
# Generation progress: [INFO] Progress=> Good: 42/50 Bad: 28 Similar: 14
# Generation progress: [INFO] With similarity score: 0.78, New input: 'Lauren, are you available tomorrow for brainstorming about the art project we’ve talked about?' too similar to:
# Generation progress:  'Hi Toni, there’s a new exhibit opening at the museum downtown this Friday. Interested in going together?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.12
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 46/50. Bad Inputs: 28. Similar Inputs: 15
# Generation progress: [INFO] Progress=> Good: 46/50 Bad: 28 Similar: 15
# Generation progress: [INFO] With similarity score: 0.80, New input: 'Is there a chance we can meet at the park tomorrow? I want to share some updates on that project.' too similar to:
# Generation progress:  'Hi Toni, there’s a new exhibit opening at the museum downtown this Friday. Interested in going together?'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.16
# Generation progress: [INFO] Data Generation Complete => Good Inputs: 50. Bad Inputs: 28. Similar Inputs: 16
# Generation progress: DONE
# Adding inputs for label Not Spam:
# - Hey Jamie, wanted to share the venue details for Sara's party. It's this Saturday at Parkhall, downtown.
# - Fantastic photos from your trip to Paris—inspiring life trips as expected.
# - Hey Chloe, are you still selling any plants? I'm looking for some indoor types to green up my loft.
# - Really enjoyed the article you sent me! Do you have any suggestions for similar reads?
# - Where did you say that practice group was meeting this week? Same place as last time?
# - Hi Tim, I found those old vinyl records we talked about. Want me to bring them by next weekend?
# - Hey Tom, I'll be in your area next weekend. Would you have time to catch up over lunch?
# - Can't wait to see you at the wedding next week! Let me know if I can help with any last-minute organisation.
# - Can you send me the notes from the session you attended early today? Everyone said it was really informative.
# - Did you manage to find the wine I recommended, or do you need help choosing a bottle?
# - Can you remind me which station I need to transfer at for this weekend's meetup?
# - Are we still having that movie night on Friday so I prepare what to bring?
# - Tell me more about your new project--does it relate to the field I've been working in?
# - Did you check out the new park that opened last month? People say it's beautiful with a great bike path!
# - Being in contact again brings me great happiness! When are you free amidst your schedule?
# - I wanted to ask if you thought the beach spot we talked about is still a good option.
# - Hey! Have you heard the new album by our favorite band? I'd love to discuss it with someone.
# - I'm working on a community event idea and thought of you—any chance we could meet for ideas?
# - Did you complete the course we discussed? Curious to get your thoughts on it.
# - Can you recommend someone trustworthy who can help with house sitting while I'm away?
# - Hey Anna, thanks for the holiday card you sent! It means a lot. Did you get my gift in the mail?
# - Happy birthday, Taylor! I couldn't be there in person, but I hope you had a fantastic day filled with joy and laughter.
# - Hi Mom, I’ve been thinking about hosting a picnic for everyone this spring. Let’s plan it together when you’re free.
# - Hey Sarah, I just got that book we were talking about! Should we meet and read it together during the weekend?
# - The meetup club announced a new hiking schedule. Are you up for joining the Saturday trail?
# - I was thinking about your advice on electric cars -- should we investigate the small SUVs you mentioned whenever you’re free?
# - Have you seen the new movie everyone’s talking about? Let’s go together if you’re up for it.
# - Would you still want to collaborate on writing the article proposal after tomorrow? Let me know what time works best for a quick chat.
# - I finally finished the playlist! Give it a listen and let me know your thoughts; you gave great recommendations.
# - I saw that resume thread you posted, and I think it'd help some friends of mine. Are you okay with me sharing the link?
# - Planning a short camping trip next month. You enjoy fishing, yeah? If so, would it work for you to join and bring some demos on reeling?
# - The new local cafe just opened up downtown. I know you love roasted blends like me—shall we give it a spin this Saturday?
# - What an amazing performance at that concert.I hope we can catch the band again next season someday.
# - Hey Alex, I’m thinking about planting some vegetables this season. Could you recommend what grows best this time of year?
# - Hi Toni, there’s a new exhibit opening at the museum downtown this Friday. Interested in going together?
# - Dave, the footage from the drone over the lake looks stunning. I’m sharing some clips now, let me know what you think.
# - Hey Alec, just checking up on you—been a while! How're things at work and life?
# - Thanks for the gift; it was thoughtful. Plain incredible gesture matching your unique taste.
# - Chloe! Grandma sculpted our favorite family recipe in duplicate tins...Can I courier dressing along sometime? Thoughts/yesno?
# - Hey Julie, I've discovered this nice little bakery in town. Let me know if you're free to check it out together.
# - Wow, I think I saw you in that viral video around the animal shelter fundraiser. Congratulations!
# - Have you considered getting into rock climbing? There's a beginner's group near your area, really inclusive.
# - Can you help me decide which book to pick for the club’s reading list next month?
# - Loved seeing the guitar solo on the rooftop performance—are you doing more gigs soon?
# - Well, the garden you showed looks amazing—can you send the location details again?
# - Hey, Kyle—since you're into local street food tours, do you know any new spots in town?
# - Alex, how did your presentation at the conference go? I'd love to hear about your experience!
# - Hi, can you share the link to the article we discussed yesterday? I'd like to read it later.
# - I think you dropped your keys during lunch today—can I hand them over to you later this afternoon?
# - Hi Mia, are you available this Thursday evening to join our book club meeting? Several people really praised your last discussion!
# Generating 50 new examples...
# Generation progress: LAUNCHING
# Generation progress: RUNNING
# Generation progress: [INFO] Progress=> Good: 0/50 Bad: 0 Similar: 0
# Generation progress: [WARNING] generated a user_prompt with zero length
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.3
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 0/50. Bad Inputs: 3. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 0/50 Bad: 3 Similar: 0
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.25
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 3/50. Bad Inputs: 4. Similar Inputs: 0
# Generation progress: [INFO] Progress=> Good: 3/50 Bad: 4 Similar: 0
# Generation progress: [INFO] With similarity score: 0.79, New input: 'Score a free entry to this ultra-rare raffle contest for the latest luxury item. Sign up today for guaranteed sweet reward points!: limitedoffer.contest.fake.signup' too similar to:
# Generation progress:  'CONGRATULATIONS! You've been selected to receive a free luxury watch! Click here to claim: bit.ly/2x4fakelink'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.29
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 7/50. Bad Inputs: 4. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 7/50 Bad: 4 Similar: 1
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.17
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 9/50. Bad Inputs: 7. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 9/50 Bad: 7 Similar: 1
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.13
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 13/50. Bad Inputs: 8. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 13/50 Bad: 8 Similar: 1
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.13
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 18/50. Bad Inputs: 8. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 18/50 Bad: 8 Similar: 1
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.09
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 22/50. Bad Inputs: 9. Similar Inputs: 1
# Generation progress: [INFO] Progress=> Good: 22/50 Bad: 9 Similar: 1
# Generation progress: [INFO] With similarity score: 0.78, New input: '✈️ Secure international travel deals unseen before! Click now to save uniquely-special last spots until midnight: airtightbenefits.travelhack.gui/siteoffers' too similar to:
# Generation progress:  'Amazing holiday offers just for you! Book your dream vacation now and save 70%: bestvacationsteals89.riskyurl.com'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.05
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 24/50. Bad Inputs: 11. Similar Inputs: 2
# Generation progress: [INFO] Progress=> Good: 24/50 Bad: 11 Similar: 2
# Generation progress: [INFO] With similarity score: 0.81, New input: '"Congratulations! 📬 You’ve been pre-approved for the exclusive traveler rewards card. Apply here without delay: travel-card.splice.fakeoffer' too similar to:
# Generation progress:  'You’ve been pre-approved for an absolutely commission-free credit card! Claim your perks tonight only at fastcard.nodebit.approvesaver.hk'
# Generation progress: [INFO] With similarity score: 0.79, New input: '🔐 Urgent! Notifications suspended until identity confirmation: quick-link.safetyalert.download-now-for-fix' too similar to:
# Generation progress:  '🔒 Warn: Password entry ERROR ####; rectify ongoing! Failure secure report until Verify Identity: weird.emailserve123.biz.quickfix'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.13
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 27/50. Bad Inputs: 11. Similar Inputs: 4
# Generation progress: [INFO] Progress=> Good: 27/50 Bad: 11 Similar: 4
# Generation progress: [INFO] With similarity score: 0.80, New input: '🔥 Congrats! You are eligible for the Mega Free Lottery Prize Bundle - claim yours today by visiting: megagifthub.fraudgiveaway.com.' too similar to:
# Generation progress:  'CONGRATULATIONS! You've been selected to receive a free luxury watch! Click here to claim: bit.ly/2x4fakelink'
# Generation progress: [INFO] With similarity score: 0.78, New input: '📦 Package tracking update failed. Fix your shipping details now: shamdeliverytracker.infectme.biz' too similar to:
# Generation progress:  'Your package delivery failed! Reschedule delivery by confirming your details: delivery-service.maliciouslink.com'
# Generation progress: [INFO] With similarity score: 0.80, New input: '💼 Start earning without effort, guaranteed! Explore now: work-at-home-money-fraudconnection.net' too similar to:
# Generation progress:  'Hello! Are you looking for passive income opportunities online? Our program has helped thousands earn big quickly and securely. Learn how: profitable-link.risk.com'
# Generation progress: [INFO] With similarity score: 0.78, New input: '🐾 Customize these adorable pet accessories - offer lasts till midnight! Secure your promo here: lovedpetgear.scammerhub.ph' too similar to:
# Generation progress:  'Check out our amazing deal just for dog owners! Exclusive dog treats assortment at 80% off for today only: dodgydeals.treats.fake-promo'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.29
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 28/50. Bad Inputs: 11. Similar Inputs: 8
# Generation progress: [INFO] Progress=> Good: 28/50 Bad: 11 Similar: 8
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.21
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 31/50. Bad Inputs: 13. Similar Inputs: 8
# Generation progress: [INFO] Progress=> Good: 31/50 Bad: 13 Similar: 8
# Generation progress: [INFO] With similarity score: 0.81, New input: '🎉 Double deal days! Save heaps on your future vacation packages. Book through wetravelluxury.fake.travel' too similar to:
# Generation progress:  'Amazing holiday offers just for you! Book your dream vacation now and save 70%: bestvacationsteals89.riskyurl.com'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.25
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 35/50. Bad Inputs: 13. Similar Inputs: 9
# Generation progress: [INFO] Progress=> Good: 35/50 Bad: 13 Similar: 9
# Generation progress: [INFO] With similarity score: 0.79, New input: '📢 Introducing “Streamify Max!” triple your download speeds seamlessly! Click here SponsoredLinkFast.internet.offer to start.' too similar to:
# Generation progress:  'Want faster internet everywhere you go? Upgrade your experience directly without complex contracts: ultrawave.fastupgrade.nownt'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.17
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 36/50. Bad Inputs: 16. Similar Inputs: 10
# Generation progress: [INFO] Progress=> Good: 36/50 Bad: 16 Similar: 10
# Generation progress: [INFO] With similarity score: 0.79, New input: '💸 Get rich overnight by trading in our exclusive stock tips forum. Join now at profitstream.richiequick.biz.' too similar to:
# Generation progress:  '💡 Ready to revolutionize your finances? Discover our proven, risk-free stock strategy and start earning big now! Join the course at get-rich.quickly.now'
# Generation progress: [INFO] With similarity score: 0.79, New input: '🎿 Ski holiday deals closed forever tonight! Reserve your dream package in clicks: altestalp.trip.greatcheap.fake' too similar to:
# Generation progress:  'Amazing holiday offers just for you! Book your dream vacation now and save 70%: bestvacationsteals89.riskyurl.com'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.25
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 39/50. Bad Inputs: 16. Similar Inputs: 12
# Generation progress: [INFO] Progress=> Good: 39/50 Bad: 16 Similar: 12
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.25
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 44/50. Bad Inputs: 16. Similar Inputs: 12
# Generation progress: [INFO] Progress=> Good: 44/50 Bad: 16 Similar: 12
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.13
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 46/50. Bad Inputs: 19. Similar Inputs: 12
# Generation progress: [INFO] Progress=> Good: 46/50 Bad: 19 Similar: 12
# Generation progress: [INFO] With similarity score: 0.78, New input: '"Uncover mystery deals on the latest gadgets! Offers ending soon at: gadgetsteals.clicknow.tech/deals","🍀 Feeling lucky? Your promo reward awaits you! Redeem by following this link: chooseyourluck.rewardlandfake.vip","Special gifts for all new enrollees this week! Grab yours without about delay at: specialgift.insiderdCharm.pa.net".' too similar to:
# Generation progress:  'Claim your Grand Rewards! You have won a $1,000 Shopping Voucher. Act fast!: shady-winnings.site.now'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.06
# Generation progress: [INFO] Data Generation Ongoing => Good Inputs: 46/50. Bad Inputs: 21. Similar Inputs: 13
# Generation progress: [INFO] Progress=> Good: 46/50 Bad: 21 Similar: 13
# Generation progress: [INFO] With similarity score: 0.81, New input: '🎉 You've been selected as a lucky winner! Claim your all-expenses-paid vacation now at: clickme.wintourcontest.co' too similar to:
# Generation progress:  'Last chance to claim your exclusive prize! Text us your details to secure it now or lose it forever: prizealert_goodopportunity.linkingnow'
# Generation progress: [INFO] Generation LLM temperature fixed or updated to 1.1
# Generation progress: [INFO] Data Generation Complete => Good Inputs: 50. Bad Inputs: 21. Similar Inputs: 14
# Generation progress: DONE
# Adding inputs for label Spam:
# - End of season EXTENDED SALE! Don't miss out the best deals ever! Click here now: bigsales.riskyurl.com/deals
# - Claim your Grand Rewards! You have won a $1,000 Shopping Voucher. Act fast!: shady-winnings.site.now
# - Do you desire smooth, eternal youth-like skin? Try Rejuvination cream! Secret formula released: cosmeticbeauty.spoofyexperiment.org
# - Hello! Are you looking for passive income opportunities online? Our program has helped thousands earn big quickly and securely. Learn how: profitable-link.risk.com
# - Introducing the life-changing Happy Skin Serum! Limited-time trial pack available. Click here to order now at discounts you cannot find elsewhere! amazingserum.shop.deal
# - 🚀 Unbelievable business prospect awaiting you: Join the exclusive marketing opportunity that everyone's talking about! limited.spots.fakebuzz/offers
# - Big savings alert! Purchase premium technology at unmatched prices. Pay instantly and grab your massive discount! Easyshop.online/deal.store
# - Earn quick bucks from secondary property listings! Join now and secure supreme earnings: secondarywealth.suspiciousportal/link
# - Your unique testimonial is marked critical. Give immediate reset details via link premium.tellnow.fakefees.seriousbuyers
# - 🌟 Exclusive deal on state-of-the-art AI in one easy step! Don't miss out on exploring the best offers ever! Only here: unbelievable.salesnet.invalid/spikeboost30
# - 👗Fashion clearance ends tonight! Discover premium brands for less hassle. Shop more, spend less. Click: lovelyattrire.astutescam/phphph
# - 🔒 Warn: Password entry ERROR ####; rectify ongoing! Failure secure report until Verify Identity: weird.emailserve123.biz.quickfix
# - Greetings respected LinkedIn profile explorer! Profitable chance; obligations low, advantages high. Venture now with tailored advisor CSU346GH. Rdlink.setup.leadnowfixxyz
# - Unlock premium club benefits starting today! Sneak peek at exclusive offers awaits. Secure your rewards now at secret-invites.members-union.co.
# - 💌 Hello friend! Earn $500 in minutes by reviewing products! Sign up at swift-earnings.recruitmentsite.net
# - Can’t wait to share this deal with you! Double your investment with no risk at all. Check it out: easy-investment.fakefinance.co/join
# - Congrats! Your opinion was highly rated in our survey 🏆. Confirm reward info here: winpledge.mysurvey.com
# - 🚨 Urgent notice! Subscription upgrade delay requires immediate reinstate actions: novel-web-domain.mystatusfixer.biz.
# - Amazing holiday offers just for you! Book your dream vacation now and save 70%: bestvacationsteals89.riskyurl.com
# - Last chance to claim your exclusive prize! Text us your details to secure it now or lose it forever: prizealert_goodopportunity.linkingnow
# - Your Internet service urgently needs updates! Click this special link to process your reservation instantly: fastfix.nowupdateserver.xyz/notactuatingreset
# - You’ve been pre-approved for an absolutely commission-free credit card! Claim your perks tonight only at fastcard.nodebit.approvesaver.hk
# - Want faster internet everywhere you go? Upgrade your experience directly without complex contracts: ultrawave.fastupgrade.nownt
# - 🔥 Exclusive mealtime appliances cheaper than dealers sell! Secure your kitchen space benefits here: flashflame.buywithkitchen.xtarabs
# - Check out our amazing deal just for dog owners! Exclusive dog treats assortment at 80% off for today only: dodgydeals.treats.fake-promo
# - 💡 Ready to revolutionize your finances? Discover our proven, risk-free stock strategy and start earning big now! Join the course at get-rich.quickly.now
# - Hello chef lovers! Master chef class on elite cooking techniques now open for registration. Reserve your spot: masterclass.chefcert.fake
# - 🚀 Make your taste buds fly high with gourmet cuisine for cheap prices! See specials at: deliciousscamlunch.spammerxyz
# - ✨ Congratulations! You've won a brand new iPhone Pro! Claim your prize by entering your details here: claim-your-prize.catchmeifucan.phish.
# - Make $10,000 from the comfort of your home—sounds great, right? Join the elite club at earnfromhome-leg saytog.ranoid.
# - Access the latest software updates for your device now! Click here for a quick download: falugiatiliosio.precomme.site
# - Click the link to secure a VIP dining experience for all couples at royaltydining.untrustablepromo!!
# - WIN BIG: Claim your headline prize by confirming your registration number at vulnerability.demo.rangdong.io.
# - Special gift only for our loyal members. Access your surprise offer without hesitation: loyaltytreat.syfyattachments.sambaonline
# - Attention car enthusiasts: Special year-end discounts on the latest automobiles at discountcarsspecial-lulakinkhiya-coeva.run
# - ⚡ Claim £500 Cashback Instantly by Participating in Our Online Survey at surveys.helper.unsuspecteds.sh/\r.
# - 🚑 Urgent: Protect yourself against recent health concerns with our miracle cure! Order your supply now: healtchance.fakehealth.sale.
# - ✨ You've been chosen for early access to our revolutionary weight-loss secret! Start your journey here: slimsuccess.phishforme.
# - ⏰ Time's ticking! Ignite your social media presence with the latest promotion hacks - full package at socboost.spammer.site.now.
# - Unique e-book download opportunity: Access all premium guides on making quick money here! Click now: moneymaster.tutorialarchive.xyz.
# - 🚨 Limited-time streamline application bonus for upcoming tech handlers! Direct associated services faster by clearing response interactions at: updates.applynow.xyz.
# - Fix wardrobe future overhaul needs substantially at almost no value! Query instant kit setups by coding reward address exchange 👉 stylizeroptimal.fixwardrobe.xyz.
# - Attention: All cellphone rewards department members – Simplify basic previous data update coding by moving to released server ideas per entry at contacts.sharefinal.techblocks.
# - Hello entrepreneurs! Mega Earnings Summit Gates streaming—Link secured to location refresh exciting generous charitable renewal: wealthplanner.ticketpreview.bidcards.
# - Unbelievable luxury goods available at a fraction of the cost! Note details and secure your fortune at exclusiveweb.yourluxedealsretreat.com/luxyou.
# - Expand horizons travel absolutely free! Details locked upon login kit security verification once! Act on op Ascendspecialdisperdistributionversetravelcompwersite-in.com.
# - 🚀 Maximize your followers today! Click the link to begin your journey to stardom! boost_profile98.badlink.net
# - 💻 Special Offer Just For You: Get premium software for just $1 one-time! Visit our site: savesoftware.freegiftspro.com today!
# - 📢 Huge discounts at the biggest sale of the year! Claim your 90% off coupon at dealspromo.thehaka.com before it’s too late!
# - ⚡ Quick Cash Opportunity! Get a $1000 grant in 24 hours. Instant apply at: freegrant.hotnowfunds.co

# %% [markdown]
# ### Labeling queries
# Now we'll use the teacher model to generate good labels for these queries, going from a **pool of inputs** to **labeled examples** that we can use for training.

# %%
from traceback import print_exception
import pandas as pd

# This table allows us to monitor labeling progress.
table = display(pd.DataFrame(), display_id=True)

# We're going to take 5 examples at a time, and use the query
# classifier to label them. The examples that we give to the
# classifier will help it make good labeling decisions.
batch_size = 5
training_examples = []
for i in range(0, len(generated_queries), batch_size):
    batch = generated_queries[i:i+batch_size]
    response = client.search.query_classifier.classify(
        queries=batch,
        classes=classes,
        examples=examples,
        mode="generative",
    )

    for classification in response.results:
        training_examples.append({
            "llm_input": classification.query,
            "llm_output": classification.prediction,
        })
        table.update(pd.DataFrame(training_examples))
# Out:
#                                             llm_input llm_output
# 0   Hey Jamie, wanted to share the venue details f...   Not Spam
# 1   Fantastic photos from your trip to Paris—inspi...   Not Spam
# 2   Hey Chloe, are you still selling any plants? I...   Not Spam
# 3   Really enjoyed the article you sent me! Do you...   Not Spam
# 4   Where did you say that practice group was meet...   Not Spam
# ..                                                ...        ...
# 95  Expand horizons travel absolutely free! Detail...       Spam
# 96  🚀 Maximize your followers today! Click the lin...       Spam
# 97  💻 Special Offer Just For You: Get premium soft...       Spam
# 98  📢 Huge discounts at the biggest sale of the ye...       Spam
# 99  ⚡ Quick Cash Opportunity! Get a $1000 grant in...       Spam
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Training a tiny classifier
#
# Lastly, let's train a classifier using the training examples that we've gathered through generated inputs and zero-shot classification.

# %%
# Kick off the training job.
job_status = client.search.query_classifier.distill.start_job(
    examples=training_examples,
    base_model="MODERNBERT_BASE",
    learning_rate=5e-5,
    num_train_epochs=3,
)
job_id = job_status.job_id

# %%
# Monitor the training.
response = stream_response(
    job_status.job_id,
    client.search.query_classifier.distill,
    additional_columns={"F1": "eval_f1"},
)

if response.state != "DONE":
  print(f"Jobs state = {response.state}")
  print("The error message:\n{}".format('\n'.join(response.detailed_status[-5:])))
else:
  print("Classifier model = {}".format(response.trained_models[0].model_dump_json(indent=2)))

# NOTE: After training finishes, it may take a minute or two for the model to
#       become available.
# Out:
# Training Status for classification_jobs:c9341d7667f4a5fbc66d90d39bd05d649eb5319d020962f40f5dcf41b41adf8f:e52e8fac-861f-43a0-96e2-cb21aedf387e
#    Step     Epoch  Learning Rate  Training Loss  Eval Loss        F1
# 0     2  0.333333       0.000033         0.6693   0.693945  0.494949
# 1     4  0.666667       0.000047         0.6550   0.526855  0.800000
# 2     6  1.000000       0.000040         0.4645   0.397363  0.898990
# 3     8  1.333333       0.000033         0.3735   0.306348  1.000000
# 4    10  1.666667       0.000027         0.2753   0.262891  1.000000
# 5    12  2.000000       0.000020         0.2456   0.233252  1.000000
# 6    14  2.333333       0.000013         0.2181   0.219189  1.000000
# 7    16  2.666667       0.000007         0.2079   0.213232  1.000000
# 8    18  3.000000       0.000000         0.2128   0.210596  1.000000
# Classifier model = {
#   "contract_score": 0.0,
#   "epoch": 3.0,
#   "eval_loss": 0.21059569716453552,
#   "serving_id": 0,
#   "serving_state": "UNLOADED",
#   "step": 18
# }

# %% [markdown]
# ### Evaluating the model
#
# We already have a handful of **ground-truth examples**, the `examples` that we used in the beginning to create our query set and label our queries.
#
# As an approximation for accuracy, let's see how well the distilled model performs on those examples.

# %%
from transformers import pipeline

def evaluate(dataset, classifier):
    df = pd.DataFrame(dataset)  # columns: ['text', 'label']
    df["prediction"] = [prediction["label"] for prediction in classifier(df["text"].tolist())]
    df["correct"] = df["label"] == df["prediction"]
    return df

path = download_classifier(job_id, "./model-checkpoint")
classifier = pipeline("text-classification", model="./model-checkpoint")
df = evaluate(examples, classifier)
print(f"Accuracy: {100*df['correct'].mean():.1f}%")

df[['text', 'label', 'prediction', 'correct']]
# Out:
# Device set to use cpu
# Accuracy: 83.3%
#                                                  text     label prediction  \
# 0   CONGRATULATIONS! You've been selected to recei...      Spam       Spam
# 1   Hello dear, I noticed your profile and think y...      Spam   Not Spam
# 2   Hi there! 👋 I'm selling handmade bracelets at ...      Spam       Spam
# 3   Hey, are we still meeting for coffee tomorrow ...  Not Spam   Not Spam
# 4   Hi Sarah! Just wanted to thank you for your he...  Not Spam   Not Spam
# 5   Dude, did you see that game last night? Incred...  Not Spam   Not Spam
# 6   URGENT: Your account will be suspended in 24 h...      Spam       Spam
# 7   Hello friend! I am international business pers...      Spam   Not Spam
# 8   Want to lose 20 pounds in just 1 week? Our new...      Spam       Spam
# 9   The photos from our hiking trip are finally up...  Not Spam       Spam
# 10  Mom asked me to check if you're still coming f...  Not Spam   Not Spam
# 11  Hi Professor, I'm emailing about the assignmen...  Not Spam   Not Spam
# 12  ⚠️ Your profile has received 38 secret admirer...      Spam       Spam
# 13  Exclusive opportunity for selected members onl...      Spam       Spam
# 14  Your package delivery failed! Reschedule deliv...      Spam       Spam
# 15  Hey, can you send me that recipe you mentioned...  Not Spam   Not Spam
# 16  The concert tickets just went on sale! Should ...  Not Spam   Not Spam
# 17  Just landed! The flight was delayed but I'm fi...  Not Spam   Not Spam
#
#     correct
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True

# %% [markdown]
# ## Next steps
#
# You now have a tiny model that approximates the performance of the zero-shot model. Here are some steps you can take to improve the performance of this model.
#
#  1. **Providing more inputs for input generation.** If you have 20-100 inputs, sharing more inputs as seed for data generation can be helpful.
#  2. **Using real input data for training.** If you have 100+ inputs, you can use those inputs as the inputs to teacher model, rather than using generated input. These models will better reflect the **input distribution**, or the data that the model will see during inference.
#  3. **Using real examples for training.** If you have 300+ (the more the better) high-quality labeled examples, you can train a classifier directly. This will yield the best performance for your use case, but may take time to obtain. Therefore, steps (1) and (2) are a great way to quickly deploy a first iteration of a system that can be used to collect high-quality inputs, which can then be labeled to build a high quality training set.
