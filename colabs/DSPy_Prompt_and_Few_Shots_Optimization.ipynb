# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/colabs/DSPy_Prompt_and_Few_Shots_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://withpi.ai"><img src="https://play.withpi.ai/logo/logoFullBlack.svg" width="240"></a>
#
# <a href="https://code.withpi.ai"><font size="4">Documentation</font></a>
#
# <a href="https://play.withpi.ai"><font size="4">Technique Catalog</font></a>

# %% [markdown]
# # DSPy Optimization
#
# This Colab is the companion to the DSPy Optimization Playground.  [DSPy](https://dspy.ai/) is a toolkit for optimizing an application's system prompt.  It does this by evaluating how different prompts measure up against a metric you choose.
#
# This notebook sets you up with a **Pi Scoring System** connected to DSPy, giving you an improved prompt to play with.
#
# This Colab continues with the `Aesop AI` example and a test input set, but any will do.

# %% [markdown]
# ## Install and initialize SDK
#
# Connect to a regular CPU Python 3 runtime.  You won't need GPUs for this notebook.
#
# You'll need a WITHPI_API_KEY from https://play.withpi.ai.  Add it to your notebook secrets (the key symbol) on the left.
#
# Run the cell below to install packages and load the SDK

# %%
# %%capture

# %pip install withpi withpi-utils datasets tqdm litellm

import os
from google.colab import userdata
from withpi import PiClient

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

client = PiClient()

# %% [markdown]
# # Load Scorer and Dataset
#
# Load the `Aesop AI` example and example set from Pi Labs cookbooks, or edit below to load a different one.
#
# This is using Hugging Face datasets, so any published dataset you can access should work.

# %%
# @title Load Scoring Spec
from withpi_utils.colab import load_scoring_spec_from_web, display_scoring_spec

aesop_scoring_spec = load_scoring_spec_from_web(
    "https://raw.githubusercontent.com/withpi/cookbook-withpi/refs/heads/main/scoring_specs/aesop_ai.json"
)

display_scoring_spec(aesop_scoring_spec)
# Out:
# <div style='font-family: Arial, sans-serif;'><h2 style='color: #202124; border-bottom: 2px solid #4285F4; padding-bottom: 8px; margin-bottom: 10px;'>ScoringSpec: aesop_ai</h2><p style='margin-top: 0; margin-bottom: 20px; color: #5F6368;'>Write a children's story in the style of Aesop's Fables teaching a life lesson specified by the user.  Provide just the story with no extra content.</p><h3 style='margin-bottom: 5px; color: #4285F4;'>Story Structure</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story have a clear beginning, middle, and end?</li><li><strong>PI_SCORER:</strong> Is there a conflict introduced early in the story that drives the plot?</li><li><strong>PI_SCORER:</strong> Is the resolution of the conflict clear and satisfying?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Character Development</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story include characters that are relatable for children?</li><li><strong>PI_SCORER:</strong> Do the characters demonstrate growth or change by the end of the story?</li><li><strong>PI_SCORER:</strong> Is the dialogue between characters natural and age-appropriate?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Narrative Engagement</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Is the story engaging and likely to hold a child's interest?</li><li><strong>PI_SCORER:</strong> Does the story use vivid imagery to help children visualize the scenes?</li><li><strong>PI_SCORER:</strong> Does the story incorporate repetitive elements that aid in comprehension and retention?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Language Appropriateness</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Is the language used in the story appropriate for children's understanding?</li><li><strong>PI_SCORER:</strong> Is the story an appropriate length for a children's tale (not exceeding 1000 words)?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Moral and Cultural Sensitivity</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story clearly convey a specified life lesson?</li><li><strong>PI_SCORER:</strong> Does the story reiterate the moral lesson at the end?</li><li><strong>PI_SCORER:</strong> Is the content culturally sensitive and inclusive for all children?</li></ul><h3 style='margin-bottom: 5px; color: #4285F4;'>Illustration Integration</h3><ul style='margin-top: 0; padding-left: 20px;'><li><strong>PI_SCORER:</strong> Does the story provide opportunities for illustrations that enhance the narrative?</li></ul></div>

# %%
# @title Load dataset
from datasets import load_dataset

aesop_dataset = load_dataset("withpi/aesop", split="train")

print(aesop_dataset)
# Out:
# README.md:   0%|          | 0.00/302 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/55.0k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/23 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input', 'output'],
#     num_rows: 23
# })

# %% [markdown]
# ## Optimize your prompt
#
# Kick off a prompt optimization run.  This will operate in the background and will take order of **10 minutes**

# %%
prompt_optimization_status = client.prompt.optimize.start_job(
    scoring_spec=aesop_scoring_spec,
    initial_system_instruction=aesop_scoring_spec.description,
    examples=[{"llm_input": row["input"], "llm_output": row["output"]} for row in aesop_dataset],
    model_id="gpt-4o-mini",
    tuning_algorithm="DSPY",
    dspy_optimization_type="MIPROv2",
)

# %% [markdown]
# ## Stream the messages as the inputs are generated
#
# The messages provide detail about what is being done as the prompt is getting optimized.

# %%
from withpi_utils import stream

for line in stream(client.prompt.optimize, prompt_optimization_status):
  print(line)
# Out:
# LAUNCHING
# RUNNING
# 2025/03/12 00:03:04 INFO dspy.teleprompt.mipro_optimizer_v2:
# RUNNING WITH THE FOLLOWING LIGHT AUTO RUN SETTINGS:
# num_trials: 7
# minibatch: False
# num_candidates: 5
# valset size: 18
#
#
# 2025/03/12 00:03:04 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 1: BOOTSTRAP FEWSHOT EXAMPLES <==
#
# 2025/03/12 00:03:04 INFO dspy.teleprompt.mipro_optimizer_v2: These will be used as few-shot example candidates for our program and for creating instructions.
#
#
# 2025/03/12 00:03:04 INFO dspy.teleprompt.mipro_optimizer_v2: Bootstrapping N=5 sets of demonstrations...
#
# Bootstrapping set 1/5
# Bootstrapping set 2/5
# Bootstrapping set 3/5
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2025/03/12 00:03:14 ERROR dspy.teleprompt.bootstrap: Failed to run or to evaluate example Example({'input': "Dream up a story involving a hummingbird and a stagnant pond teaching 'Every effort counts, no matter how small.'", 'response': 'The hummingbird, Pip, zipped and zoomed through the sun-drenched meadow.  His tiny wings beat a frantic tattoo against the air, carrying him from flower to flower, gathering nectar with a joyous chirrup.  He saw the other birds, the robins and the starlings, with their effortless soaring. Pip felt a pang of envy.  He wished he could be as grand, as impressive as them.\n\nFar from the bustling meadow, nestled in a hollow of the earth, was a stagnant pond.  Its water, once clear and brimming with life, was now thick and murky, choked with weeds.  A tiny, lonely frog, Croak, sat on a lily pad, his voice barely a croak.  He had tried to move, to encourage the wind to stir the water, to even sing his loudest, but the pond remained stubbornly still.  He felt small, insignificant.\n\nOne day, Pip, in a fit of frustration, spotted the stagnant pond.  He’d heard stories of the beautiful pond that had once been there, now filled with nothing but disappointment. Feeling sorry for the lonely frog, he flew down.\n\n"Why do you look so glum?" Pip chirped, landing delicately on a drooping lily pad.\n\nCroak, his eyes filled with despair, croaked, "The pond is stagnant. Nothing I do matters."\n\nPip tilted his head. "Stagnant?  But look around you.  There are weeds growing. Tiny insects are trapped, and, you see, even these tiny creatures are working to change the environment, no matter how small or how insignificant they may seem. You may not see the change, but they are still working tirelessly towards progress."\n\n"But I\'m just one tiny frog!" Croak sighed.\n\nPip, with a flash of his iridescent wings, explained, "Every little movement, every little effort you make, contributes to the bigger picture.  Your croak, though small, stirs the air.  Each tiny insect you eat, each drop of water you help push through the weeds - it\'s all a part of the process of change.  You don\'t have to be big or loud. Even the smallest efforts are important, in time they accumulate."\n\nCroak looked at the weeds, at the trapped insects, and then back at Pip. He hopped a little, a tiny movement, a ripple in the stagnant water.  "Maybe... maybe you\'re right."\n\nPip, with a tiny flutter of his wings, flew away.  He knew that even he, with his small size, could make a difference.  He continued visiting Croak, encouraging him to sing, to move, to help the little insects that still dared to stay in the water. Pip, and the little frog, worked together. Slowly, very slowly, the pond began to stir. A tiny breeze blew through, moving the water a little more, a little more with each small effort.\n\n\nDays turned into weeks.  The pond wasn\'t completely revived, but it was no longer stagnant.  The air, once still, was now filled with the little sounds of life. Croak\'s croak echoed, and Pip\'s chirps filled the air, a testament to the power of persistence, even the smallest of efforts.\n\nAnd Pip learned that it wasn\'t about being the biggest, loudest, or fastest. It was about continuing to contribute, to make a difference, no matter how small.\n'}) (input_keys={'input'}) with <function Contract.get_dspy_metric.<locals>.contract_metric at 0x7ad8d83cd120> due to unhandled errors in a TaskGroup (1 sub-exception).
#
#
#  20%|##        | 1/5 [00:09<00:36,  9.16s/it]
# 2025/03/12 00:03:25 ERROR dspy.teleprompt.bootstrap: Failed to run or to evaluate example Example({'input': "Create a story with a novice ant who refuses guidance from elders and learns that 'Listening gives you endless wisdom.'", 'response': 'Tiny, a brand-new ant, emerged from her chrysalis, her tiny legs trembling.  The sun warmed her tiny back, and a delicious scent of sweet dew filled the air.  She scurried about, her antennae twitching with curiosity.  Nearby, old Anthea, with her wise, weathered wings, and Elder Ant, with his glistening, experience-marked mandibles, were diligently collecting crumbs.\n\n"Tiny, dear," Anthea whispered, her voice like rustling leaves. "The best path to the meadow is through the whispering willows."\n\n"Whispering willows?" Tiny scoffed. "I\'m Tiny!  I\'m an amazing ant! I\'ll find the best path myself!" And with a determined flick of her head, she darted off, heading straight for the towering, prickly thistles.\n\nThe thistles pricked her, the path was rough, and the sun beat down.  She struggled, her tiny body aching.  She missed the juicy berries Elder Ant had pointed out, and the delicious nectar from the fragrant clover blossoms,  because her path led her past them.\n\nElder Ant, meanwhile, had led his group through a beautifully shaded ravine, discovering hidden treasures of honeydew and plump, juicy berries along the way.  Anthea, with her knowledge of the wind patterns and the early morning dew, had found a shorter route, leading to a wealth of food.\n\nTiny, lost and tired, finally stumbled upon a tiny stream.  A glistening pebble caught her eye.  "Look at this!" she exclaimed, picking up the pebble and staring at it.\n\nSuddenly, a voice, as soft as a summer breeze, said, "Tiny?"\n\nShe looked up.  It was Anthea. "Why did you go that way?" Anthea asked gently.\n\nTiny, her face covered in dust and frustration, mumbled, "I wanted to find my own way!"\n\nAnthea smiled patiently. "My dear Tiny, every path has its own dangers and rewards.  Listening to others, observing their experiences, and appreciating the wisdom they hold, that\'s how you find the best path, and discover the greatest rewards."\n\nAnthea pointed to the path behind them, "See how the Elder Ant made his way through the ravine?  It was shaded, there was plenty of food, and it was much faster than these prickly thistles." She also pointed to the shorter route she had taken earlier, "See the treasures I found using my knowledge of the dew?"\n\nElder Ant, with his enormous experience, came forward. "Tiny," he said, "there is no greater treasure than the wisdom of those who have walked the path before you. Listening gives you endless wisdom, that allows you to discover treasures you wouldn\'t have found otherwise."\n\n\nTiny looked at the path behind her, at the smooth path, the delicious berries, and the short distance.  She looked at Anthea\'s gentle face, and Elder Ant\'s wise eyes.\n\n"I understand," she whispered.\n\nFrom that day on, Tiny listened carefully to the elders. She learned to observe, and she learned to appreciate the wisdom of others. She never again tried to go her own way alone, and she discovered that listening to those who had come before her led her to the greatest treasures of all: knowledge, cooperation, and the joy of sharing. And so, Tiny became a wise and respected ant.\n'}) (input_keys={'input'}) with <function Contract.get_dspy_metric.<locals>.contract_metric at 0x7ad8d83cd120> due to unhandled errors in a TaskGroup (1 sub-exception).
#
#
#  40%|####      | 2/5 [00:20<00:31, 10.41s/it]
#
#  60%|######    | 3/5 [00:33<00:23, 11.60s/it]
#
#  80%|########  | 4/5 [00:39<00:09,  9.35s/it]
#
#  80%|########  | 4/5 [00:39<00:09,  9.84s/it]
# Bootstrapped 2 full traces after 4 examples for up to 1 rounds, amounting to 4 attempts.
# Bootstrapping set 4/5
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2025/03/12 00:03:54 ERROR dspy.teleprompt.bootstrap: Failed to run or to evaluate example Example({'input': "Create a story with a novice ant who refuses guidance from elders and learns that 'Listening gives you endless wisdom.'", 'response': 'Tiny, a brand-new ant, emerged from her chrysalis, her tiny legs trembling.  The sun warmed her tiny back, and a delicious scent of sweet dew filled the air.  She scurried about, her antennae twitching with curiosity.  Nearby, old Anthea, with her wise, weathered wings, and Elder Ant, with his glistening, experience-marked mandibles, were diligently collecting crumbs.\n\n"Tiny, dear," Anthea whispered, her voice like rustling leaves. "The best path to the meadow is through the whispering willows."\n\n"Whispering willows?" Tiny scoffed. "I\'m Tiny!  I\'m an amazing ant! I\'ll find the best path myself!" And with a determined flick of her head, she darted off, heading straight for the towering, prickly thistles.\n\nThe thistles pricked her, the path was rough, and the sun beat down.  She struggled, her tiny body aching.  She missed the juicy berries Elder Ant had pointed out, and the delicious nectar from the fragrant clover blossoms,  because her path led her past them.\n\nElder Ant, meanwhile, had led his group through a beautifully shaded ravine, discovering hidden treasures of honeydew and plump, juicy berries along the way.  Anthea, with her knowledge of the wind patterns and the early morning dew, had found a shorter route, leading to a wealth of food.\n\nTiny, lost and tired, finally stumbled upon a tiny stream.  A glistening pebble caught her eye.  "Look at this!" she exclaimed, picking up the pebble and staring at it.\n\nSuddenly, a voice, as soft as a summer breeze, said, "Tiny?"\n\nShe looked up.  It was Anthea. "Why did you go that way?" Anthea asked gently.\n\nTiny, her face covered in dust and frustration, mumbled, "I wanted to find my own way!"\n\nAnthea smiled patiently. "My dear Tiny, every path has its own dangers and rewards.  Listening to others, observing their experiences, and appreciating the wisdom they hold, that\'s how you find the best path, and discover the greatest rewards."\n\nAnthea pointed to the path behind them, "See how the Elder Ant made his way through the ravine?  It was shaded, there was plenty of food, and it was much faster than these prickly thistles." She also pointed to the shorter route she had taken earlier, "See the treasures I found using my knowledge of the dew?"\n\nElder Ant, with his enormous experience, came forward. "Tiny," he said, "there is no greater treasure than the wisdom of those who have walked the path before you. Listening gives you endless wisdom, that allows you to discover treasures you wouldn\'t have found otherwise."\n\n\nTiny looked at the path behind her, at the smooth path, the delicious berries, and the short distance.  She looked at Anthea\'s gentle face, and Elder Ant\'s wise eyes.\n\n"I understand," she whispered.\n\nFrom that day on, Tiny listened carefully to the elders. She learned to observe, and she learned to appreciate the wisdom of others. She never again tried to go her own way alone, and she discovered that listening to those who had come before her led her to the greatest treasures of all: knowledge, cooperation, and the joy of sharing. And so, Tiny became a wise and respected ant.\n'}) (input_keys={'input'}) with <function Contract.get_dspy_metric.<locals>.contract_metric at 0x7ad8d83cd120> due to unhandled errors in a TaskGroup (1 sub-exception).
#
#
#  20%|##        | 1/5 [00:10<00:42, 10.68s/it]
#
#  40%|####      | 2/5 [00:17<00:25,  8.42s/it]
#
#  40%|####      | 2/5 [00:17<00:26,  8.76s/it]
# Bootstrapped 1 full traces after 2 examples for up to 1 rounds, amounting to 2 attempts.
# Bootstrapping set 5/5
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|##        | 1/5 [00:07<00:30,  7.65s/it]
#
#  40%|####      | 2/5 [00:15<00:22,  7.52s/it]
#
#  40%|####      | 2/5 [00:15<00:22,  7.54s/it]
# Bootstrapped 2 full traces after 2 examples for up to 1 rounds, amounting to 2 attempts.
# 2025/03/12 00:04:16 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 2: PROPOSE INSTRUCTION CANDIDATES <==
#
# 2025/03/12 00:04:16 INFO dspy.teleprompt.mipro_optimizer_v2: We will use the few-shot examples from the previous step, a generated dataset summary, a summary of the program code, and a randomly selected prompting tip to propose instructions.
#
# 2025/03/12 00:04:23 INFO dspy.teleprompt.mipro_optimizer_v2:
# Proposing instructions...
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: Proposed Instructions for Predictor 0:
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: 0: Write a children's story in the style of Aesop's Fables teaching a life lesson specified by the user.  Provide just the story with no extra content.
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: 1: Create a children's story in the style of Aesop's Fables that conveys a specific life lesson provided by the user. Focus on crafting a vivid, engaging narrative that clearly illustrates the moral, and ensure the response contains only the story without any additional commentary or explanation.
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: 2: Compose a whimsical children's story in the style of Aesop's Fables that vividly illustrates a life lesson provided by the user. Use imaginative characters and scenarios to deliver the moral in a clear and engaging way, ensuring the story is concise and self-contained without any additional commentary or explanation.
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: 3: Compose a children's story in the style of Aesop's Fables that conveys a life lesson or moral provided by the user. Ensure the narrative is engaging, whimsical, and suitable for young readers. Incorporate anthropomorphic characters and a clear plot that exemplifies the specified lesson. The story should be self-contained, with a beginning, middle, and end, and conclude with a transformation or realization that emphasizes the moral. Do not include any additional commentary or content outside of the story itself.
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: 4: Create a children's story inspired by Aesop's Fables that conveys a life lesson provided by the user. Focus solely on the narrative and ensure the story is engaging, whimsical, and concludes with a clear moral.
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2:
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: ==> STEP 3: FINDING OPTIMAL PROMPT PARAMETERS <==
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: We will evaluate the program over a series of trials with different combinations of instructions and few-shot examples to find the optimal combination using Bayesian Optimization.
#
#
# 2025/03/12 00:04:59 INFO dspy.teleprompt.mipro_optimizer_v2: == Trial 1 / 7 - Full Evaluation of Default Program ==
#
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 0.90 / 1 (90.2%):   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 0.90 / 1 (90.2%):   6%|5         | 1/18 [00:00<00:16,  1.00it/s]
#
# Average Metric: 1.73 / 2 (86.3%):   6%|5         | 1/18 [00:01<00:16,  1.00it/s]
#
# Average Metric: 1.73 / 2 (86.3%):  11%|#1        | 2/18 [00:01<00:09,  1.70it/s]
#
# Average Metric: 2.55 / 3 (85.0%):  11%|#1        | 2/18 [00:01<00:09,  1.70it/s]
#
# Average Metric: 3.35 / 4 (83.9%):  17%|#6        | 3/18 [00:01<00:08,  1.70it/s]
#
# Average Metric: 3.35 / 4 (83.9%):  22%|##2       | 4/18 [00:01<00:04,  3.48it/s]
#
# Average Metric: 4.22 / 5 (84.5%):  22%|##2       | 4/18 [00:01<00:04,  3.48it/s]
#
# Average Metric: 5.09 / 6 (84.8%):  28%|##7       | 5/18 [00:01<00:03,  3.48it/s]
#
# Average Metric: 6.02 / 7 (86.0%):  33%|###3      | 6/18 [00:01<00:03,  3.48it/s]
#
# Average Metric: 6.91 / 8 (86.4%):  39%|###8      | 7/18 [00:02<00:03,  3.48it/s]
#
# Average Metric: 6.91 / 8 (86.4%):  44%|####4     | 8/18 [00:02<00:01,  5.48it/s]
#
# Average Metric: 7.73 / 9 (85.9%):  44%|####4     | 8/18 [00:02<00:01,  5.48it/s]
#
# Average Metric: 8.62 / 10 (86.2%):  50%|#####     | 9/18 [00:02<00:01,  5.48it/s]
#
# Average Metric: 8.62 / 10 (86.2%):  56%|#####5    | 10/18 [00:02<00:01,  6.38it/s]
#
# Average Metric: 9.48 / 11 (86.2%):  56%|#####5    | 10/18 [00:02<00:01,  6.38it/s]
#
# Average Metric: 9.48 / 11 (86.2%):  61%|######1   | 11/18 [00:02<00:01,  6.28it/s]
#
# Average Metric: 10.38 / 12 (86.5%):  61%|######1   | 11/18 [00:02<00:01,  6.28it/s]
#
# Average Metric: 10.38 / 12 (86.5%):  67%|######6   | 12/18 [00:02<00:00,  6.37it/s]
#
# Average Metric: 11.31 / 13 (87.0%):  67%|######6   | 12/18 [00:02<00:00,  6.37it/s]
#
# Average Metric: 12.21 / 14 (87.2%):  72%|#######2  | 13/18 [00:02<00:00,  6.37it/s]
#
# Average Metric: 13.09 / 15 (87.3%):  78%|#######7  | 14/18 [00:02<00:00,  6.37it/s]
#
# Average Metric: 13.09 / 15 (87.3%):  83%|########3 | 15/18 [00:02<00:00,  8.37it/s]
#
# Average Metric: 13.87 / 16 (86.7%):  83%|########3 | 15/18 [00:02<00:00,  8.37it/s]
#
# Average Metric: 14.76 / 17 (86.8%):  89%|########8 | 16/18 [00:02<00:00,  8.37it/s]
#
# Average Metric: 15.55 / 18 (86.4%):  94%|#########4| 17/18 [00:02<00:00,  8.37it/s]
#
# Average Metric: 15.55 / 18 (86.4%): 100%|##########| 18/18 [00:02<00:00, 10.10it/s]
#
# Average Metric: 15.55 / 18 (86.4%): 100%|##########| 18/18 [00:02<00:00,  6.06it/s]
# 2025/03/12 00:05:02 INFO dspy.evaluate.evaluate: Average Metric: 15.546766493055555 / 18 (86.4%)
#
# 2025/03/12 00:05:02 INFO dspy.teleprompt.mipro_optimizer_v2: Default program score: 86.37
#
#
# /app/.venv/lib/python3.11/site-packages/optuna/_experimental.py:31: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
#
# 2025/03/12 00:05:02 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 2 / 7 =====
#
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 1.00 / 1 (100.0%):   0%|          | 0/18 [00:06<?, ?it/s]
#
# Average Metric: 1.00 / 1 (100.0%):   6%|5         | 1/18 [00:06<01:56,  6.86s/it]
#
# Average Metric: 2.00 / 2 (100.0%):   6%|5         | 1/18 [00:07<01:56,  6.86s/it]
#
# Average Metric: 2.00 / 2 (100.0%):  11%|#1        | 2/18 [00:07<00:47,  2.95s/it]
#
# Average Metric: 2.93 / 3 (97.8%):  11%|#1        | 2/18 [00:08<00:47,  2.95s/it]
#
# Average Metric: 2.93 / 3 (97.8%):  17%|#6        | 3/18 [00:08<00:34,  2.32s/it]
#
# Average Metric: 3.85 / 4 (96.2%):  17%|#6        | 3/18 [00:08<00:34,  2.32s/it]
#
# Average Metric: 4.85 / 5 (97.0%):  22%|##2       | 4/18 [00:09<00:32,  2.32s/it]
#
# Average Metric: 4.85 / 5 (97.0%):  28%|##7       | 5/18 [00:09<00:16,  1.24s/it]
#
# Average Metric: 5.76 / 6 (96.1%):  28%|##7       | 5/18 [00:09<00:16,  1.24s/it]
#
# Average Metric: 5.76 / 6 (96.1%):  33%|###3      | 6/18 [00:09<00:11,  1.02it/s]
#
# Average Metric: 6.75 / 7 (96.4%):  33%|###3      | 6/18 [00:11<00:11,  1.02it/s]
#
# Average Metric: 6.75 / 7 (96.4%):  39%|###8      | 7/18 [00:11<00:12,  1.12s/it]
#
# Average Metric: 7.64 / 8 (95.5%):  39%|###8      | 7/18 [00:12<00:12,  1.12s/it]
#
# Average Metric: 7.64 / 8 (95.5%):  44%|####4     | 8/18 [00:12<00:10,  1.09s/it]
#
# Average Metric: 8.56 / 9 (95.1%):  44%|####4     | 8/18 [00:13<00:10,  1.09s/it]
#
# Average Metric: 8.56 / 9 (95.1%):  50%|#####     | 9/18 [00:13<00:09,  1.05s/it]
#
# Average Metric: 9.43 / 10 (94.3%):  50%|#####     | 9/18 [00:14<00:09,  1.05s/it]
#
# Average Metric: 9.43 / 10 (94.3%):  56%|#####5    | 10/18 [00:14<00:09,  1.25s/it]
#
# Average Metric: 10.30 / 11 (93.6%):  56%|#####5    | 10/18 [00:15<00:09,  1.25s/it]
#
# Average Metric: 10.30 / 11 (93.6%):  61%|######1   | 11/18 [00:15<00:06,  1.04it/s]
#
# Average Metric: 11.24 / 12 (93.7%):  61%|######1   | 11/18 [00:15<00:06,  1.04it/s]
#
# Average Metric: 11.24 / 12 (93.7%):  67%|######6   | 12/18 [00:15<00:04,  1.40it/s]
#
# Average Metric: 12.19 / 13 (93.7%):  67%|######6   | 12/18 [00:15<00:04,  1.40it/s]
#
# Average Metric: 12.19 / 13 (93.7%):  72%|#######2  | 13/18 [00:15<00:02,  1.78it/s]
#
# Average Metric: 13.07 / 14 (93.4%):  72%|#######2  | 13/18 [00:16<00:02,  1.78it/s]
#
# Average Metric: 13.07 / 14 (93.4%):  78%|#######7  | 14/18 [00:16<00:02,  1.41it/s]
#
# Average Metric: 14.00 / 15 (93.3%):  78%|#######7  | 14/18 [00:20<00:02,  1.41it/s]
#
# Average Metric: 14.00 / 15 (93.3%):  83%|########3 | 15/18 [00:20<00:04,  1.52s/it]
#
# Average Metric: 14.85 / 16 (92.8%):  83%|########3 | 15/18 [00:22<00:04,  1.52s/it]
#
# Average Metric: 14.85 / 16 (92.8%):  89%|########8 | 16/18 [00:22<00:03,  1.66s/it]
#
# Average Metric: 15.79 / 17 (92.9%):  89%|########8 | 16/18 [00:27<00:03,  1.66s/it]
#
# Average Metric: 15.79 / 17 (92.9%):  94%|#########4| 17/18 [00:27<00:02,  2.86s/it]
#
# Average Metric: 16.73 / 18 (93.0%):  94%|#########4| 17/18 [00:30<00:02,  2.86s/it]
#
# Average Metric: 16.73 / 18 (93.0%): 100%|##########| 18/18 [00:30<00:00,  2.84s/it]
#
# Average Metric: 16.73 / 18 (93.0%): 100%|##########| 18/18 [00:30<00:00,  1.70s/it]
# 2025/03/12 00:05:33 INFO dspy.evaluate.evaluate: Average Metric: 16.734375 / 18 (93.0%)
#
# 2025/03/12 00:05:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best full score so far! Score: 92.97
#
# 2025/03/12 00:05:33 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 92.97 with parameters ['Predictor 0: Instruction 1', 'Predictor 0: Few-Shot Set 1'].
#
# 2025/03/12 00:05:33 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [86.37, 92.97]
#
# 2025/03/12 00:05:33 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 92.97
#
# 2025/03/12 00:05:33 INFO dspy.teleprompt.mipro_optimizer_v2: =======================
#
#
#
# 2025/03/12 00:05:33 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 3 / 7 =====
#
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 0.97 / 1 (97.0%):   0%|          | 0/18 [00:06<?, ?it/s]
#
# Average Metric: 0.97 / 1 (97.0%):   6%|5         | 1/18 [00:06<01:43,  6.08s/it]
#
# Average Metric: 1.90 / 2 (95.2%):   6%|5         | 1/18 [00:06<01:43,  6.08s/it]
#
# Average Metric: 1.90 / 2 (95.2%):  11%|#1        | 2/18 [00:06<00:47,  2.99s/it]
#
# Average Metric: 2.86 / 3 (95.2%):  11%|#1        | 2/18 [00:07<00:47,  2.99s/it]
#
# Average Metric: 2.86 / 3 (95.2%):  17%|#6        | 3/18 [00:07<00:31,  2.09s/it]
#
# Average Metric: 3.81 / 4 (95.1%):  17%|#6        | 3/18 [00:08<00:31,  2.09s/it]
#
# Average Metric: 3.81 / 4 (95.1%):  22%|##2       | 4/18 [00:08<00:20,  1.47s/it]
#
# Average Metric: 4.80 / 5 (96.0%):  22%|##2       | 4/18 [00:10<00:20,  1.47s/it]
#
# Average Metric: 4.80 / 5 (96.0%):  28%|##7       | 5/18 [00:10<00:20,  1.61s/it]
#
# Average Metric: 5.71 / 6 (95.2%):  28%|##7       | 5/18 [00:10<00:20,  1.61s/it]
#
# Average Metric: 6.71 / 7 (95.9%):  33%|###3      | 6/18 [00:10<00:19,  1.61s/it]
#
# Average Metric: 6.71 / 7 (95.9%):  39%|###8      | 7/18 [00:10<00:10,  1.09it/s]
#
# Average Metric: 7.71 / 8 (96.4%):  39%|###8      | 7/18 [00:10<00:10,  1.09it/s]
#
# Average Metric: 8.62 / 9 (95.8%):  44%|####4     | 8/18 [00:11<00:09,  1.09it/s]
#
# Average Metric: 8.62 / 9 (95.8%):  50%|#####     | 9/18 [00:11<00:05,  1.56it/s]
#
# Average Metric: 9.52 / 10 (95.2%):  50%|#####     | 9/18 [00:13<00:05,  1.56it/s]
#
# Average Metric: 9.52 / 10 (95.2%):  56%|#####5    | 10/18 [00:13<00:07,  1.07it/s]
#
# Average Metric: 10.50 / 11 (95.4%):  56%|#####5    | 10/18 [00:14<00:07,  1.07it/s]
#
# Average Metric: 10.50 / 11 (95.4%):  61%|######1   | 11/18 [00:14<00:07,  1.10s/it]
#
# Average Metric: 11.50 / 12 (95.8%):  61%|######1   | 11/18 [00:14<00:07,  1.10s/it]
#
# Average Metric: 11.50 / 12 (95.8%):  67%|######6   | 12/18 [00:14<00:05,  1.19it/s]
#
# Average Metric: 12.38 / 13 (95.2%):  67%|######6   | 12/18 [00:17<00:05,  1.19it/s]
#
# Average Metric: 12.38 / 13 (95.2%):  72%|#######2  | 13/18 [00:17<00:06,  1.22s/it]
#
# Average Metric: 13.38 / 14 (95.6%):  72%|#######2  | 13/18 [00:17<00:06,  1.22s/it]
#
# Average Metric: 13.38 / 14 (95.6%):  78%|#######7  | 14/18 [00:17<00:03,  1.03it/s]
#
# Average Metric: 14.31 / 15 (95.4%):  78%|#######7  | 14/18 [00:19<00:03,  1.03it/s]
#
# Average Metric: 14.31 / 15 (95.4%):  83%|########3 | 15/18 [00:19<00:03,  1.21s/it]
#
# Average Metric: 15.28 / 16 (95.5%):  83%|########3 | 15/18 [00:19<00:03,  1.21s/it]
#
# Average Metric: 15.28 / 16 (95.5%):  89%|########8 | 16/18 [00:19<00:02,  1.01s/it]
#
# Average Metric: 16.10 / 17 (94.7%):  89%|########8 | 16/18 [00:19<00:02,  1.01s/it]
#
# Average Metric: 16.98 / 18 (94.3%):  94%|#########4| 17/18 [00:29<00:01,  1.01s/it]
#
# Average Metric: 16.98 / 18 (94.3%): 100%|##########| 18/18 [00:29<00:00,  2.70s/it]
#
# Average Metric: 16.98 / 18 (94.3%): 100%|##########| 18/18 [00:29<00:00,  1.63s/it]
# 2025/03/12 00:06:02 INFO dspy.evaluate.evaluate: Average Metric: 16.981119791666668 / 18 (94.3%)
#
# 2025/03/12 00:06:02 INFO dspy.teleprompt.mipro_optimizer_v2: Best full score so far! Score: 94.34
#
# 2025/03/12 00:06:02 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 94.34 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 1'].
#
# 2025/03/12 00:06:02 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [86.37, 92.97, 94.34]
#
# 2025/03/12 00:06:02 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 94.34
#
# 2025/03/12 00:06:02 INFO dspy.teleprompt.mipro_optimizer_v2: =======================
#
#
#
# 2025/03/12 00:06:02 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 4 / 7 =====
#
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 0.89 / 1 (88.6%):   0%|          | 0/18 [00:05<?, ?it/s]
#
# Average Metric: 0.89 / 1 (88.6%):   6%|5         | 1/18 [00:05<01:34,  5.55s/it]
#
# Average Metric: 1.89 / 2 (94.3%):   6%|5         | 1/18 [00:05<01:34,  5.55s/it]
#
# Average Metric: 1.89 / 2 (94.3%):  11%|#1        | 2/18 [00:05<00:38,  2.43s/it]
#
# Average Metric: 2.89 / 3 (96.2%):  11%|#1        | 2/18 [00:06<00:38,  2.43s/it]
#
# Average Metric: 2.89 / 3 (96.2%):  17%|#6        | 3/18 [00:06<00:27,  1.86s/it]
#
# Average Metric: 3.85 / 4 (96.1%):  17%|#6        | 3/18 [00:07<00:27,  1.86s/it]
#
# Average Metric: 3.85 / 4 (96.1%):  22%|##2       | 4/18 [00:07<00:20,  1.47s/it]
#
# Average Metric: 4.81 / 5 (96.1%):  22%|##2       | 4/18 [00:08<00:20,  1.47s/it]
#
# Average Metric: 4.81 / 5 (96.1%):  28%|##7       | 5/18 [00:08<00:13,  1.03s/it]
#
# Average Metric: 5.77 / 6 (96.1%):  28%|##7       | 5/18 [00:08<00:13,  1.03s/it]
#
# Average Metric: 5.77 / 6 (96.1%):  33%|###3      | 6/18 [00:08<00:09,  1.26it/s]
#
# Average Metric: 6.65 / 7 (95.0%):  33%|###3      | 6/18 [00:12<00:09,  1.26it/s]
#
# Average Metric: 6.65 / 7 (95.0%):  39%|###8      | 7/18 [00:12<00:19,  1.75s/it]
#
# Average Metric: 7.65 / 8 (95.6%):  39%|###8      | 7/18 [00:12<00:19,  1.75s/it]
#
# Average Metric: 7.65 / 8 (95.6%):  44%|####4     | 8/18 [00:12<00:12,  1.26s/it]
#
# Average Metric: 8.54 / 9 (94.9%):  44%|####4     | 8/18 [00:12<00:12,  1.26s/it]
#
# Average Metric: 8.54 / 9 (94.9%):  50%|#####     | 9/18 [00:12<00:08,  1.07it/s]
#
# Average Metric: 9.54 / 10 (95.4%):  50%|#####     | 9/18 [00:15<00:08,  1.07it/s]
#
# Average Metric: 9.54 / 10 (95.4%):  56%|#####5    | 10/18 [00:15<00:12,  1.57s/it]
#
# Average Metric: 10.51 / 11 (95.6%):  56%|#####5    | 10/18 [00:15<00:12,  1.57s/it]
#
# Average Metric: 10.51 / 11 (95.6%):  61%|######1   | 11/18 [00:15<00:08,  1.20s/it]
#
# Average Metric: 11.50 / 12 (95.8%):  61%|######1   | 11/18 [00:16<00:08,  1.20s/it]
#
# Average Metric: 11.50 / 12 (95.8%):  67%|######6   | 12/18 [00:16<00:05,  1.14it/s]
#
# Average Metric: 12.50 / 13 (96.1%):  67%|######6   | 12/18 [00:16<00:05,  1.14it/s]
#
# Average Metric: 12.50 / 13 (96.1%):  72%|#######2  | 13/18 [00:16<00:03,  1.37it/s]
#
# Average Metric: 13.49 / 14 (96.3%):  72%|#######2  | 13/18 [00:16<00:03,  1.37it/s]
#
# Average Metric: 13.49 / 14 (96.3%):  78%|#######7  | 14/18 [00:16<00:02,  1.83it/s]
#
# Average Metric: 14.38 / 15 (95.9%):  78%|#######7  | 14/18 [00:17<00:02,  1.83it/s]
#
# Average Metric: 14.38 / 15 (95.9%):  83%|########3 | 15/18 [00:17<00:02,  1.36it/s]
#
# Average Metric: 15.31 / 16 (95.7%):  83%|########3 | 15/18 [00:19<00:02,  1.36it/s]
#
# Average Metric: 15.31 / 16 (95.7%):  89%|########8 | 16/18 [00:19<00:01,  1.10it/s]
#
# Average Metric: 16.20 / 17 (95.3%):  89%|########8 | 16/18 [00:19<00:01,  1.10it/s]
#
# Average Metric: 16.20 / 17 (95.3%):  94%|#########4| 17/18 [00:19<00:00,  1.47it/s]
#
# Average Metric: 17.00 / 18 (94.4%):  94%|#########4| 17/18 [00:26<00:00,  1.47it/s]
#
# Average Metric: 17.00 / 18 (94.4%): 100%|##########| 18/18 [00:26<00:00,  2.60s/it]
#
# Average Metric: 17.00 / 18 (94.4%): 100%|##########| 18/18 [00:26<00:00,  1.46s/it]
# 2025/03/12 00:06:28 INFO dspy.evaluate.evaluate: Average Metric: 16.998697916666668 / 18 (94.4%)
#
# 2025/03/12 00:06:28 INFO dspy.teleprompt.mipro_optimizer_v2: Best full score so far! Score: 94.44
#
# 2025/03/12 00:06:28 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 94.44 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 1'].
#
# 2025/03/12 00:06:28 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [86.37, 92.97, 94.34, 94.44]
#
# 2025/03/12 00:06:28 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 94.44
#
# 2025/03/12 00:06:28 INFO dspy.teleprompt.mipro_optimizer_v2: =======================
#
#
#
# 2025/03/12 00:06:28 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 5 / 7 =====
#
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 0.97 / 1 (97.0%):   0%|          | 0/18 [00:01<?, ?it/s]
#
# Average Metric: 0.97 / 1 (97.0%):   6%|5         | 1/18 [00:01<00:19,  1.17s/it]
#
# Average Metric: 1.97 / 2 (98.3%):   6%|5         | 1/18 [00:01<00:19,  1.17s/it]
#
# Average Metric: 1.97 / 2 (98.3%):  11%|#1        | 2/18 [00:01<00:11,  1.39it/s]
#
# Average Metric: 2.90 / 3 (96.7%):  11%|#1        | 2/18 [00:01<00:11,  1.39it/s]
#
# Average Metric: 2.90 / 3 (96.7%):  17%|#6        | 3/18 [00:01<00:06,  2.24it/s]
#
# Average Metric: 3.90 / 4 (97.5%):  17%|#6        | 3/18 [00:01<00:06,  2.24it/s]
#
# Average Metric: 4.85 / 5 (97.0%):  22%|##2       | 4/18 [00:01<00:06,  2.24it/s]
#
# Average Metric: 4.85 / 5 (97.0%):  28%|##7       | 5/18 [00:01<00:02,  4.42it/s]
#
# Average Metric: 5.75 / 6 (95.8%):  28%|##7       | 5/18 [00:01<00:02,  4.42it/s]
#
# Average Metric: 5.75 / 6 (95.8%):  33%|###3      | 6/18 [00:01<00:02,  4.74it/s]
#
# Average Metric: 6.72 / 7 (96.1%):  33%|###3      | 6/18 [00:02<00:02,  4.74it/s]
#
# Average Metric: 6.72 / 7 (96.1%):  39%|###8      | 7/18 [00:02<00:02,  5.14it/s]
#
# Average Metric: 7.64 / 8 (95.5%):  39%|###8      | 7/18 [00:02<00:02,  5.14it/s]
#
# Average Metric: 7.64 / 8 (95.5%):  44%|####4     | 8/18 [00:02<00:02,  4.62it/s]
#
# Average Metric: 8.64 / 9 (96.0%):  44%|####4     | 8/18 [00:02<00:02,  4.62it/s]
#
# Average Metric: 8.64 / 9 (96.0%):  50%|#####     | 9/18 [00:02<00:01,  4.99it/s]
#
# Average Metric: 9.56 / 10 (95.6%):  50%|#####     | 9/18 [00:02<00:01,  4.99it/s]
#
# Average Metric: 9.56 / 10 (95.6%):  56%|#####5    | 10/18 [00:02<00:01,  5.30it/s]
#
# Average Metric: 10.56 / 11 (96.0%):  56%|#####5    | 10/18 [00:02<00:01,  5.30it/s]
#
# Average Metric: 10.56 / 11 (96.0%):  61%|######1   | 11/18 [00:02<00:01,  5.75it/s]
#
# Average Metric: 11.51 / 12 (96.0%):  61%|######1   | 11/18 [00:03<00:01,  5.75it/s]
#
# Average Metric: 11.51 / 12 (96.0%):  67%|######6   | 12/18 [00:03<00:01,  5.74it/s]
#
# Average Metric: 12.40 / 13 (95.4%):  67%|######6   | 12/18 [00:03<00:01,  5.74it/s]
#
# Average Metric: 13.31 / 14 (95.1%):  72%|#######2  | 13/18 [00:03<00:00,  5.74it/s]
#
# Average Metric: 14.31 / 15 (95.4%):  78%|#######7  | 14/18 [00:03<00:00,  5.74it/s]
#
# Average Metric: 14.31 / 15 (95.4%):  83%|########3 | 15/18 [00:03<00:00,  9.70it/s]
#
# Average Metric: 15.29 / 16 (95.5%):  83%|########3 | 15/18 [00:03<00:00,  9.70it/s]
#
# Average Metric: 16.17 / 17 (95.1%):  89%|########8 | 16/18 [00:03<00:00,  9.70it/s]
#
# Average Metric: 16.17 / 17 (95.1%):  94%|#########4| 17/18 [00:03<00:00,  6.20it/s]
#
# Average Metric: 16.99 / 18 (94.4%):  94%|#########4| 17/18 [00:03<00:00,  6.20it/s]
#
# Average Metric: 16.99 / 18 (94.4%): 100%|##########| 18/18 [00:03<00:00,  4.81it/s]
# 2025/03/12 00:06:32 INFO dspy.evaluate.evaluate: Average Metric: 16.98611111111111 / 18 (94.4%)
#
# 2025/03/12 00:06:32 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 94.37 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 1'].
#
# 2025/03/12 00:06:32 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [86.37, 92.97, 94.34, 94.44, 94.37]
#
# 2025/03/12 00:06:32 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 94.44
#
# 2025/03/12 00:06:32 INFO dspy.teleprompt.mipro_optimizer_v2: =======================
#
#
#
# 2025/03/12 00:06:32 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 6 / 7 =====
#
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 1.00 / 1 (100.0%):   0%|          | 0/18 [00:07<?, ?it/s]
#
# Average Metric: 1.00 / 1 (100.0%):   6%|5         | 1/18 [00:07<02:05,  7.38s/it]
#
# Average Metric: 2.00 / 2 (100.0%):   6%|5         | 1/18 [00:07<02:05,  7.38s/it]
#
# Average Metric: 2.00 / 2 (100.0%):  11%|#1        | 2/18 [00:07<00:51,  3.19s/it]
#
# Average Metric: 3.00 / 3 (100.0%):  11%|#1        | 2/18 [00:08<00:51,  3.19s/it]
#
# Average Metric: 3.00 / 3 (100.0%):  17%|#6        | 3/18 [00:08<00:28,  1.90s/it]
#
# Average Metric: 3.90 / 4 (97.5%):  17%|#6        | 3/18 [00:08<00:28,  1.90s/it]
#
# Average Metric: 3.90 / 4 (97.5%):  22%|##2       | 4/18 [00:08<00:16,  1.21s/it]
#
# Average Metric: 4.80 / 5 (96.1%):  22%|##2       | 4/18 [00:08<00:16,  1.21s/it]
#
# Average Metric: 5.71 / 6 (95.2%):  28%|##7       | 5/18 [00:08<00:15,  1.21s/it]
#
# Average Metric: 5.71 / 6 (95.2%):  33%|###3      | 6/18 [00:08<00:08,  1.41it/s]
#
# Average Metric: 6.67 / 7 (95.3%):  33%|###3      | 6/18 [00:08<00:08,  1.41it/s]
#
# Average Metric: 6.67 / 7 (95.3%):  39%|###8      | 7/18 [00:08<00:06,  1.72it/s]
#
# Average Metric: 7.53 / 8 (94.2%):  39%|###8      | 7/18 [00:12<00:06,  1.72it/s]
#
# Average Metric: 7.53 / 8 (94.2%):  44%|####4     | 8/18 [00:12<00:13,  1.36s/it]
#
# Average Metric: 8.42 / 9 (93.6%):  44%|####4     | 8/18 [00:14<00:13,  1.36s/it]
#
# Average Metric: 8.42 / 9 (93.6%):  50%|#####     | 9/18 [00:14<00:13,  1.49s/it]
#
# Average Metric: 9.37 / 10 (93.7%):  50%|#####     | 9/18 [00:15<00:13,  1.49s/it]
#
# Average Metric: 9.37 / 10 (93.7%):  56%|#####5    | 10/18 [00:15<00:10,  1.36s/it]
#
# Average Metric: 10.24 / 11 (93.1%):  56%|#####5    | 10/18 [00:15<00:10,  1.36s/it]
#
# Average Metric: 10.24 / 11 (93.1%):  61%|######1   | 11/18 [00:15<00:07,  1.06s/it]
#
# Average Metric: 11.24 / 12 (93.6%):  61%|######1   | 11/18 [00:16<00:07,  1.06s/it]
#
# Average Metric: 11.24 / 12 (93.6%):  67%|######6   | 12/18 [00:16<00:06,  1.13s/it]
#
# Average Metric: 12.17 / 13 (93.6%):  67%|######6   | 12/18 [00:16<00:06,  1.13s/it]
#
# Average Metric: 12.17 / 13 (93.6%):  72%|#######2  | 13/18 [00:16<00:04,  1.20it/s]
#
# Average Metric: 13.17 / 14 (94.0%):  72%|#######2  | 13/18 [00:19<00:04,  1.20it/s]
#
# Average Metric: 13.17 / 14 (94.0%):  78%|#######7  | 14/18 [00:19<00:05,  1.49s/it]
#
# Average Metric: 14.10 / 15 (94.0%):  78%|#######7  | 14/18 [00:21<00:05,  1.49s/it]
#
# Average Metric: 14.10 / 15 (94.0%):  83%|########3 | 15/18 [00:21<00:04,  1.66s/it]
#
# Average Metric: 15.10 / 16 (94.3%):  83%|########3 | 15/18 [00:22<00:04,  1.66s/it]
#
# Average Metric: 15.10 / 16 (94.3%):  89%|########8 | 16/18 [00:22<00:02,  1.37s/it]
#
# Average Metric: 15.92 / 17 (93.7%):  89%|########8 | 16/18 [00:23<00:02,  1.37s/it]
#
# Average Metric: 15.92 / 17 (93.7%):  94%|#########4| 17/18 [00:23<00:01,  1.08s/it]
#
# Average Metric: 16.85 / 18 (93.6%):  94%|#########4| 17/18 [00:29<00:01,  1.08s/it]
#
# Average Metric: 16.85 / 18 (93.6%): 100%|##########| 18/18 [00:29<00:00,  2.81s/it]
#
# Average Metric: 16.85 / 18 (93.6%): 100%|##########| 18/18 [00:29<00:00,  1.66s/it]
# 2025/03/12 00:07:02 INFO dspy.evaluate.evaluate: Average Metric: 16.848524305555557 / 18 (93.6%)
#
# 2025/03/12 00:07:02 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 93.6 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 3'].
#
# 2025/03/12 00:07:02 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [86.37, 92.97, 94.34, 94.44, 94.37, 93.6]
#
# 2025/03/12 00:07:02 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 94.44
#
# 2025/03/12 00:07:02 INFO dspy.teleprompt.mipro_optimizer_v2: =======================
#
#
#
# 2025/03/12 00:07:02 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 7 / 7 =====
#
#
#   0%|          | 0/18 [00:00<?, ?it/s]
#
# Average Metric: 1.00 / 1 (100.0%):   0%|          | 0/18 [00:06<?, ?it/s]
#
# Average Metric: 1.00 / 1 (100.0%):   6%|5         | 1/18 [00:06<01:57,  6.93s/it]
#
# Average Metric: 2.00 / 2 (100.0%):   6%|5         | 1/18 [00:07<01:57,  6.93s/it]
#
# Average Metric: 2.00 / 2 (100.0%):  11%|#1        | 2/18 [00:07<00:50,  3.16s/it]
#
# Average Metric: 3.00 / 3 (100.0%):  11%|#1        | 2/18 [00:07<00:50,  3.16s/it]
#
# Average Metric: 3.00 / 3 (100.0%):  17%|#6        | 3/18 [00:07<00:26,  1.79s/it]
#
# Average Metric: 3.98 / 4 (99.6%):  17%|#6        | 3/18 [00:08<00:26,  1.79s/it]
#
# Average Metric: 3.98 / 4 (99.6%):  22%|##2       | 4/18 [00:08<00:19,  1.37s/it]
#
# Average Metric: 4.98 / 5 (99.7%):  22%|##2       | 4/18 [00:08<00:19,  1.37s/it]
#
# Average Metric: 4.98 / 5 (99.7%):  28%|##7       | 5/18 [00:08<00:12,  1.01it/s]
#
# Average Metric: 5.96 / 6 (99.4%):  28%|##7       | 5/18 [00:09<00:12,  1.01it/s]
#
# Average Metric: 5.96 / 6 (99.4%):  33%|###3      | 6/18 [00:09<00:09,  1.25it/s]
#
# Average Metric: 6.90 / 7 (98.6%):  33%|###3      | 6/18 [00:09<00:09,  1.25it/s]
#
# Average Metric: 6.90 / 7 (98.6%):  39%|###8      | 7/18 [00:09<00:06,  1.67it/s]
#
# Average Metric: 7.89 / 8 (98.6%):  39%|###8      | 7/18 [00:11<00:06,  1.67it/s]
#
# Average Metric: 7.89 / 8 (98.6%):  44%|####4     | 8/18 [00:11<00:11,  1.15s/it]
#
# Average Metric: 8.78 / 9 (97.5%):  44%|####4     | 8/18 [00:12<00:11,  1.15s/it]
#
# Average Metric: 8.78 / 9 (97.5%):  50%|#####     | 9/18 [00:12<00:08,  1.01it/s]
#
# Average Metric: 9.73 / 10 (97.3%):  50%|#####     | 9/18 [00:12<00:08,  1.01it/s]
#
# Average Metric: 9.73 / 10 (97.3%):  56%|#####5    | 10/18 [00:12<00:06,  1.21it/s]
#
# Average Metric: 10.66 / 11 (96.9%):  56%|#####5    | 10/18 [00:12<00:06,  1.21it/s]
#
# Average Metric: 11.63 / 12 (96.9%):  61%|######1   | 11/18 [00:15<00:05,  1.21it/s]
#
# Average Metric: 11.63 / 12 (96.9%):  67%|######6   | 12/18 [00:15<00:05,  1.02it/s]
#
# Average Metric: 12.56 / 13 (96.6%):  67%|######6   | 12/18 [00:16<00:05,  1.02it/s]
#
# Average Metric: 12.56 / 13 (96.6%):  72%|#######2  | 13/18 [00:16<00:05,  1.17s/it]
#
# Average Metric: 13.48 / 14 (96.3%):  72%|#######2  | 13/18 [00:17<00:05,  1.17s/it]
#
# Average Metric: 13.48 / 14 (96.3%):  78%|#######7  | 14/18 [00:17<00:04,  1.19s/it]
#
# Average Metric: 14.47 / 15 (96.5%):  78%|#######7  | 14/18 [00:20<00:04,  1.19s/it]
#
# Average Metric: 14.47 / 15 (96.5%):  83%|########3 | 15/18 [00:20<00:04,  1.50s/it]
#
# Average Metric: 15.22 / 16 (95.1%):  83%|########3 | 15/18 [00:20<00:04,  1.50s/it]
#
# Average Metric: 16.20 / 17 (95.3%):  89%|########8 | 16/18 [00:22<00:03,  1.50s/it]
#
# Average Metric: 16.20 / 17 (95.3%):  94%|#########4| 17/18 [00:22<00:01,  1.27s/it]
#
# Average Metric: 17.19 / 18 (95.5%):  94%|#########4| 17/18 [00:28<00:01,  1.27s/it]
#
# Average Metric: 17.19 / 18 (95.5%): 100%|##########| 18/18 [00:28<00:00,  2.39s/it]
#
# Average Metric: 17.19 / 18 (95.5%): 100%|##########| 18/18 [00:28<00:00,  1.57s/it]
# 2025/03/12 00:07:30 INFO dspy.evaluate.evaluate: Average Metric: 17.193467881944446 / 18 (95.5%)
#
# 2025/03/12 00:07:30 INFO dspy.teleprompt.mipro_optimizer_v2: Best full score so far! Score: 95.52
#
# 2025/03/12 00:07:30 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 95.52 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 1'].
#
# 2025/03/12 00:07:30 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [86.37, 92.97, 94.34, 94.44, 94.37, 93.6, 95.52]
#
# 2025/03/12 00:07:30 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 95.52
#
# 2025/03/12 00:07:30 INFO dspy.teleprompt.mipro_optimizer_v2: =======================
#
#
#
# 2025/03/12 00:07:30 INFO dspy.teleprompt.mipro_optimizer_v2: Returning best identified program with score 95.52!
#
# DONE

# %% [markdown]
# ## Check out the optimized prompt

# %%
import json

prompt_optimization_status = client.prompt.optimize.retrieve(prompt_optimization_status.job_id)
optimized_prompt = json.dumps(prompt_optimization_status.optimized_prompt_messages, indent=2)
print(optimized_prompt)
# Out:
# [
#   {
#     "content": "Your input fields are:\n1. `input` (str): The input to the AI application\n\nYour output fields are:\n1. `response` (str): The response from the AI application\n\nAll interactions will be structured in the following way, with the appropriate values filled in.\n\n[[ ## input ## ]]\n{input}\n\n[[ ## response ## ]]\n{response}\n\n[[ ## completed ## ]]\n\nIn adhering to this structure, your objective is: \n        Write a children's story in the style of Aesop's Fables teaching a life lesson specified by the user.  Provide just the story with no extra content.",
#     "role": "system"
#   },
#   {
#     "content": "[[ ## input ## ]]\nDream up a story involving a hummingbird and a stagnant pond teaching 'Every effort counts, no matter how small.'\n\nRespond with the corresponding output fields, starting with the field `[[ ## response ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.",
#     "role": "user"
#   },
#   {
#     "content": "[[ ## response ## ]]\nPip the hummingbird, a flash of emerald and ruby, zipped through the air, a tiny speck against the vast blue sky.  He was famous, or at least, famous among the other hummingbirds.  Pip could fly further, faster, and with more daring loops than any other in the valley.  He boasted of his prowess, flitting from flower to flower, a tiny, arrogant king.\n\nDown in the valley, nestled beside a tall, ancient oak, was a stagnant pond.  It was a pool of murky green, its surface still and lifeless, reflecting the grey sky like a broken mirror.  No fish darted, no frogs hopped, and not a single dragonfly dared to approach.  The other birds mocked the pond, whispering about its uselessness.\n\n\"What good is a pond like that?\" one mocking robin chirped. \"It's nothing but stagnant water, a waste of space.\"\n\nPip, perched on a nearby rose, scoffed.  \"Waste of space?  I could fly across the entire meadow in the time it takes that pond to evaporate!\"\n\nOne day, a tiny raindrop, barely bigger than Pip's head, fell into the pond.  It splashed softly, creating a tiny ripple that quickly faded.\n\n\"See?\" Pip taunted. \"Even a drop like that can't make a difference.\"\n\nBut the raindrop, though small, didn't give up.  It joined with other drops, tiny streams, and trickles.  Slowly, painstakingly, the pond began to fill.  The water, once murky, slowly cleared. Tiny plants sprouted from the muddy banks, attracting the first beetles.  Tadpoles appeared, wriggling happily.\n\nA little frog hopped out, its eyes wide with wonder. \"What a beautiful pond!\" he croaked, grateful to the slow, relentless work of the small drops of rain.\n\nPip, watching from the rose, felt a pang of shame.  He had been so focused on his own impressive feats that he hadn't noticed the slow, steady work of these seemingly insignificant drops.\n\nAs the pond blossomed, attracting new life, Pip saw a new perspective.  The little frog was right; the pond was beautiful, thriving, precisely because every drop, every effort, added to the final result.\n\nFrom that day on, Pip still flew with incredible speed and skill, but he also appreciated the tiny efforts.  He learned that even the smallest drop can fill a pond, and that every act of kindness, every small effort, counts toward something greater.  He realised that the greatest achievements are not always the flashiest or the biggest, but the ones built upon the many small acts that make up the whole. And he learned that the quiet pond, even with its humble drops, was beautiful in its own right.\n\n\n[[ ## completed ## ]]",
#     "role": "assistant"
#   },
#   {
#     "content": "[[ ## input ## ]]\nThink up a scenario involving a butterfly embarrassed by its wings to highlight 'Embrace your uniqueness.'\n\nRespond with the corresponding output fields, starting with the field `[[ ## response ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.",
#     "role": "user"
#   },
#   {
#     "content": "[[ ## response ## ]]\nPip the butterfly was a worrier.  He watched the other butterflies, their wings a dazzling tapestry of blues and oranges, shimmering and swirling in the air.  Pip's wings, however, were a muted, greyish-brown.  They weren't speckled, they weren't patterned, they were simply... plain.\n\nPip felt terribly self-conscious.  He'd try to hide amongst the leaves, hoping no one would notice him.  He'd flap his wings as little as possible, preferring to spend his days tucked away in his cozy chrysalis, dreaming of wings like the vibrant, eye-catching butterflies who flitted freely about.\n\nOne day, a gust of wind blew a particularly striking orange butterfly right in front of Pip.  The orange butterfly, boasting a cascade of orange scales and black spots,  danced around in a dizzying display of aerial acrobatics.  Pip, hiding beneath a dandelion, felt his cheeks flush.  He wished he could disappear.  \"Oh, how beautiful you are,\" he whispered to himself, feeling his own plain wings deflate.\n\nSuddenly, a wise old caterpillar, munching on a leaf, spotted Pip.  He had seen butterflies come and go, their beauty and their flaws.  \"Why are you hiding, little one?\" he asked.\n\nPip, shrinking back, mumbled, \"My wings... they're so dull, so boring.  The other butterflies laugh at them.\"\n\nThe caterpillar smiled, a slow, thoughtful curve of his mouth. \"Tell me, Pip,\" he said, \"have you ever seen a flower with only one color?  A song with only one note?  The world is full of beautiful things, but not all of them are the same.\"\n\nPip looked up at the caterpillar, his usually drooping antennae suddenly perkier.  \"But if my wings aren't special, then what's the point?\" he questioned, feeling lost.\n\nThe wise caterpillar chuckled. \"The point is not in being the same as everyone else, Pip. The point is in being you.  Look closely at your wings.  Notice how the gentle sunbeams catch the subtle shimmer in the grey.  Notice how the dappled shade creates a pattern you wouldn't have seen otherwise.\"\n\nHe pointed to a small pool of water near them, reflecting the sky.  \"See how the light reflects differently on each drop?  Each one is unique.\"  \n\nPip, slowly, carefully unfurled his wings. He watched the light play across the grey.  He saw the subtle variations in shade, the tiny flecks of light that danced within the muted tones.  He was no longer just plain; he was a unique blend of subtle colours, a whisper of light, distinct and beautiful in his own way.  From that day on, Pip proudly flapped his wings, appreciating the beauty in their simple elegance. He still watched the other butterflies, but he found their vibrant colours weren't the only things that were beautiful. He knew, now, that his own muted colours, too, held a unique and captivating charm, a beautiful testament to his own being.  He was, after all, Pip, the butterfly with the greyish-brown wings, and that was enough.\n\n\n[[ ## completed ## ]]",
#     "role": "assistant"
#   },
#   {
#     "content": "[[ ## input ## ]]\n{{ input }}\n\nRespond with the corresponding output fields, starting with the field `[[ ## response ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.",
#     "role": "user"
#   }
# ]

# %% [markdown]
# ## Save the new system prompt template
#
# It's convenient to stash this template for use later.

# %%
from google.colab import files
from pathlib import Path

filename = 'aesop_ai_dspy_prompt.json.jinja'
Path(filename).write_text(optimized_prompt)
files.download(filename)

# %% [markdown]
# ## (if resuming) Load system prompt
#
# If you don't want to wait, load the pre-optimized one.

# %%
import httpx

optimized_prompt = httpx.get("https://raw.githubusercontent.com/withpi/cookbook-withpi/refs/heads/main/prompts/aesop_ai_dspy_prompt.json.jinja").text

# %% [markdown]
# #Run inference with the test split
#
# DSPy emits a Jinja2-style template, so inference requires some template substitution.  Let's compare results before and after on a few examples.

# %%
import os
import re
import litellm
import jinja2
from withpi_utils.colab import pretty_print_responses

os.environ["GEMINI_API_KEY"] = userdata.get('GOOGLE_API_KEY')

def generate(system: str, user: str, model: str) -> str:
    """generate passes the provided system and user prompts into the given model
    via LiteLLM"""
    messages = [
        {"content": system, "role": "system"},
        {"content": user, "role": "user"},
    ]
    return litellm.completion(model=model, messages=messages).choices[0].message.content

prompt_template = jinja2.Template(optimized_prompt)
result_extractor = re.compile(
    r".*\[\[ ## response ## \]\](.*)\[\[ ## completed ## \]\]", re.DOTALL
)

for i in range(5):
  row = aesop_dataset[i]

  original_output = generate(system=aesop_scoring_spec.description,
                             user=row['input'],
                             model="gemini/gemini-2.0-flash")
  raw_dspy_output = litellm.completion(
      model="gemini/gemini-2.0-flash",
      messages=json.loads(prompt_template.render(input=row['input']))).choices[0].message.content
  dspy_output = result_extractor.match(raw_dspy_output).group(1)

  original_score = client.scoring_system.score(
      llm_input=row["input"],
      llm_output=original_output,
      scoring_spec=aesop_scoring_spec,
  )
  dspy_score = client.scoring_system.score(
      llm_input=row["input"],
      llm_output=dspy_output,
      scoring_spec=aesop_scoring_spec,
  )

  pretty_print_responses(
      header="#### Input:\n" + row["input"],
      response1="#### Output:\n" + original_output,
      response2="#### Output:\n" + dspy_output,
      left_label="Original",
      right_label="DSPy",
      scores_left=original_score,
      scores_right=dspy_score,
  )
  print("\n\n")
# Out:
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a children's story in the style of Aesop's Fables that teaches the lesson 'Slow and steady wins the race.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Original</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>DSPy</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the Badger was known throughout the Whispering Woods for his boundless energy. He dashed, he leaped, he zipped this way and that, never still for a moment. Across the meadow lived Tilly the Tortoise, who moved with a deliberate, unhurried pace.</p>
# <p>One sunny morning, the animals decided to hold a berry-picking contest. Whoever collected the most plump, juicy blueberries by sunset would be crowned Berry King or Queen!</p>
# <p>Barnaby, with a flash of his striped snout, zoomed off. He bounced from bush to bush, grabbing handfuls of berries, stuffing them haphazardly into his basket. Berries tumbled out as he ran, but he didn't notice, too focused on speed.</p>
# <p>Tilly the Tortoise started slowly. She examined each blueberry bush carefully, picking only the ripest, juiciest berries and placing them gently in her basket. She didn't rush, taking small, measured steps.</p>
# <p>Barnaby, after an hour, declared himself far ahead. He sat down beneath a shady oak tree, his basket half-full, panting. "Plenty of time," he thought, closing his eyes for a quick nap.</p>
# <p>Tilly continued her steady work. She didn't boast, didn't pause. Slowly, steadily, her basket began to fill.</p>
# <p>Barnaby woke with a start! The sun was beginning to dip behind the trees. He sprang up, his basket still only half-full. He rushed to gather more berries, but he was tired now, his paws clumsy. He tripped over a root, sending berries scattering.</p>
# <p>As the sun set, the animals gathered to see who had won. Barnaby, sweating and frustrated, presented his basket, barely three-quarters full. Then Tilly arrived, her basket overflowing with perfectly ripe blueberries.</p>
# <p>The animals cheered for Tilly. Barnaby, embarrassed, understood. Speed alone was not enough.</p>
# <p>And so, Barnaby learned that day, it is not the swiftness of your stride, but the consistency of your effort that carries you to victory. Slow and steady truly wins the race.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the Hare was known throughout Sunny Meadow for his speed. He could zip across the field faster than the wind, leaving a trail of dust in his wake. One sunny morning, as Barnaby was boasting about his swiftness, Tilly the Tortoise overheard him.</p>
# <p>"Oh, Barnaby," Tilly said slowly, "you may be fast, but I bet I could beat you in a race."</p>
# <p>Barnaby burst into laughter. "You? Beat me? That's the funniest thing I've ever heard!" He agreed to the race, sure of an easy win.</p>
# <p>The race began the next day. Barnaby shot off like an arrow, quickly disappearing from Tilly's sight. He was so far ahead that he decided to take a nap under a shady apple tree. "Plenty of time to win," he thought, closing his eyes.</p>
# <p>Meanwhile, Tilly plodded along, one slow step after another. She never stopped, never hurried, just kept moving steadily forward.</p>
# <p>Barnaby woke up with a yawn, stretched, and looked around. He saw Tilly nearing the finish line. "Oh no!" he cried, and darted off towards the goal, but it was too late! Tilly crossed the finish line just as Barnaby was about to overtake her.</p>
# <p>The animals of Sunny Meadow cheered for Tilly, the slow and steady tortoise, who had won the race.</p>
# <p>Moral: Slow and steady wins the race.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2abe69'>0.857</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2cc56d'>0.805</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dc96f'>0.766</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2bbf6a'>0.848</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #27ae60'>0.992</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dc96f'>0.77</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #2dc76e'>0.781</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2cc66e'>0.792</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2abe69'>0.863</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>0.988</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27b061'>0.977</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #29b765'>0.919</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dcb70'>0.75</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dcb70'>0.75</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2abe69'><b>0.859</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Tell a fable about a crow and a fox that illustrates the importance of being cautious with flattery.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Original</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>DSPy</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Corvus the crow was no ordinary crow. He possessed a voice of pure, ringing melody, a voice that could charm the birds right out of the trees. One sun-drenched morning, Corvus perched upon the highest branch of an oak, a plump, juicy plum clutched in his claw.</p>
# <p>Reynard the fox, sleek and cunning, strolled beneath the oak. He caught sight of Corvus and the plum and, with a sly gleam in his eye, began to speak.</p>
# <p>"Oh, Corvus!" Reynard called up, his voice dripping with honey. "Is that you? I haven't seen you in ages! You are looking magnificent today! Your feathers, such a deep and glossy black, they shine like polished jet. And your posture! So regal and proud! I hear you have the most enchanting voice in the whole forest."</p>
# <p>Corvus, usually quite sensible, puffed out his chest. He knew his singing voice was good, but he'd never heard it described with such flattering words. Reynard continued, "Indeed, I've heard it said that the king himself would envy the sound of your singing! If only I could hear you sing just one note, one tiny trill, I would die a happy fox!"</p>
# <p>Corvus, overwhelmed by the praise, thought to himself, "Surely, one little note won't hurt. Besides," he preened, "Reynard deserves to hear such a beautiful sound."</p>
# <p>He opened his beak to let loose a soaring melody. But as he did, the plum tumbled from his claw and landed with a soft thud at Reynard's feet.</p>
# <p>Reynard snatched up the plum in a flash. He grinned up at Corvus, his eyes sparkling with amusement. "Thank you, Corvus," he chuckled. "Your singing is indeed lovely, but it seems your head is even emptier!" And with that, Reynard trotted off into the woods, leaving Corvus to perch, red-faced and plum-less, on the branch.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>[[ ## reasoning ## ]]
# Once upon a time, in a lush green meadow, lived a clever Fox named Finley. One sunny morning, Corvus the Crow perched proudly on a tall oak tree, a delicious piece of cheese clutched tightly in his beak.</p>
# <p>Finley, strolling by, caught a whiff of the cheese and his mouth watered. "Oh, Corvus," he called out, his voice dripping with sweetness, "I had no idea such a magnificent bird lived in these woods! Your feathers shimmer like polished obsidian, and your eyes sparkle like the morning dew."</p>
# <p>Corvus, puffed up with pride, shifted on his branch. He'd never received such compliments before. Finley continued, "But surely, a bird as handsome as you must possess a voice of equal splendor! If only I could hear you sing, I would be the happiest creature in the world."</p>
# <p>Corvus, eager to show off his supposed talent, opened his beak wide and let out a loud, "Caw!" As he did, the cheese slipped from his grasp and fell straight into Finley's waiting jaws.</p>
# <p>Finley, with a twinkle in his eye and the cheese firmly in his mouth, chuckled. "Thank you, Corvus," he said, "for the song, and for the cheese! Remember, friend, be wary of those who offer excessive praise; they often have their own desires at heart." And with that, he scampered away, leaving Corvus to rue his foolish vanity.</p>
# <p>Moral: Beware of flattery; it is often a disguise for deceit.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #5fc958'>0.686</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #e8901c'>0.316</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #31cb6f'>0.742</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2ecb70'>0.749</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dcb70'>0.75</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #31cb6f'>0.742</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #2dcb70'>0.754</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2dca70'>0.759</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dcb70'>0.754</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2dc96f'>0.766</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #29ba66'>0.895</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #2cc46c'>0.81</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #4aca62'>0.711</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27b262'>0.961</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dca70'>0.762</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2dc86f'><b>0.777</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns te
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Create a story featuring a lion and a mouse that conveys the message 'Even the smallest friends can be the most helpful.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Original</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>DSPy</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Leo the lion was King of the Jungle, and he knew it. He roared with power, strutted with pride, and generally made sure everyone understood his importance. One scorching afternoon, while napping under a baobab tree, Leo felt a tickle on his nose.</p>
# <p>He swatted with a paw, but the tickle persisted. Annoyed, Leo opened one eye and saw a tiny mouse, no bigger than his claw, scampering across his face.</p>
# <p>"Get off me, you insignificant creature!" Leo boomed, sending the mouse tumbling to the ground.</p>
# <p>The little mouse, named Millie, trembled. "Please, great Leo, forgive my intrusion! I meant no harm."</p>
# <p>Leo chuckled, a deep rumble that shook the leaves. "Harm? You couldn't harm a fly! What good could a tiny thing like you ever be?"</p>
# <p>Millie squeaked, "Perhaps… perhaps someday, I could be of help."</p>
# <p>Leo roared with laughter. "Help a king? You? Preposterous!" He then, feeling magnanimous, released her with a flick of his paw. "Now, be gone, before I change my mind."</p>
# <p>Millie scurried away, humbled but undeterred.</p>
# <p>Days later, Leo was stalking through the jungle when he stepped into a cleverly hidden hunter's trap. A strong net sprung up, ensnaring him completely. He roared and thrashed, but the net held firm. He was trapped.</p>
# <p>Panic set in. He roared again, a desperate call for help, but no one came. Fear gnawed at him. He, the mighty Leo, was helpless.</p>
# <p>Suddenly, he heard a tiny voice. "Leo? Are you alright?"</p>
# <p>He looked down and saw Millie, her whiskers twitching with concern.</p>
# <p>"Millie?" he said, his voice hoarse. "Can you… can you help me?"</p>
# <p>Millie didn't hesitate. With incredible speed and determination, she began gnawing at the thick ropes of the net. Her tiny teeth worked tirelessly, strand by strand. It took a long time, but finally, with a last, frantic nip, she severed the final rope.</p>
# <p>Leo was free! He stepped out of the net, amazed. He looked at Millie, panting and exhausted but beaming with pride.</p>
# <p>"Millie," he said, his voice full of gratitude. "You… you saved me. You, the smallest creature in the jungle, saved the King of the Jungle."</p>
# <p>Millie blushed. "It was nothing, Leo. I was happy to help."</p>
# <p>From that day on, Leo never underestimated anyone, no matter how small. He learned that strength wasn't the only thing that mattered, and that even the most powerful lion could need the help of the smallest mouse.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in the heart of the African savanna, lived a mighty lion named Leo. He was the king of the jungle, feared by all. One sunny afternoon, while chasing a gazelle, Leo stumbled into a hunter's cleverly disguised net. He roared and struggled, but the ropes held firm.</p>
# <p>A tiny mouse, Pip, scurried by, minding his own business. He heard Leo's desperate roars and, though frightened, crept closer. Pip recognized Leo, the king, trapped and helpless. Remembering tales of the lion's kindness, Pip decided to help.</p>
# <p>"Don't worry, Your Majesty," squeaked Pip. "I may be small, but I can help!"</p>
# <p>Leo, initially doubtful, watched as Pip began gnawing at the thick ropes with his sharp teeth. Slowly but surely, Pip nibbled through the tough fibers. Finally, with a snap, the last rope broke, and Leo was free!</p>
# <p>Leo was amazed. He nuzzled Pip gently. "Thank you, little one," he said. "You saved my life. I will never forget your kindness."</p>
# <p>And so, Leo and Pip became the best of friends, proving that even the smallest friends can be the most helpful.</p>
# <p>Moral: Even the smallest friends can be the most helpful.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #28b664'>0.928</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2cc76e'>0.785</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #29b665'>0.923</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dc96f'>0.77</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2abe69'>0.865</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2bc16b'>0.832</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #28b664'>0.93</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dca70'>0.762</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #29b966'><b>0.901</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Write a fable involving a tortoise and a hare that emphasizes the value of perseverance and determination.</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Original</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>DSPy</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the Hare was known throughout Sunny Meadow for his speed. He zoomed past dandelions like shooting stars and outraced the butterflies on a whim. Penelope the Tortoise, on the other hand, was known for her slow and steady pace. Her shell gleamed with patient wisdom, but she was, undeniably, the slowest creature in Sunny Meadow.</p>
# <p>One day, Barnaby, bursting with energy, hopped up to Penelope who was carefully munching on a clover. "Penelope, Penelope!" he cried, his nose twitching. "You're so… deliberate! Why don't we have a race? Just for fun, of course. I'll even give you a head start!"</p>
# <p>Penelope, never one to back down from a challenge, especially one disguised as playful mockery, agreed. "Very well, Barnaby. Let the race begin tomorrow, at the old oak tree, and end at the babbling brook."</p>
# <p>The next day, a crowd gathered. Barnaby, bouncing on his toes, winked at Penelope. Penelope, her eyes focused on the brook, began her slow, steady march.</p>
# <p>Barnaby zoomed ahead, a blur of brown fur. He glanced back and chuckled, seeing Penelope barely past the dandelion patch. "Plenty of time for a nap," he thought, settling down beneath a shady apple tree. He closed his eyes, enjoying the gentle breeze.</p>
# <p>He dreamt of carrots and winning medals. Time drifted by.</p>
# <p>Meanwhile, Penelope continued her slow, steady pace. One foot in front of the other. She didn’t look to the left, she didn’t look to the right. She didn’t hurry, she didn’t stop. She just kept going.</p>
# <p>The sun began to dip low in the sky when Barnaby awoke with a jolt. He stretched, yawned, and remembered the race. He sprang up, expecting to see Penelope still far behind. But to his astonishment, he saw her, just a few feet from the babbling brook!</p>
# <p>Barnaby bolted towards the finish line, but it was too late. Penelope, with one final, determined step, crossed the line.</p>
# <p>The crowd erupted in cheers. Barnaby, panting and bewildered, could only stare.</p>
# <p>Penelope, breathing steadily, smiled. "It's not about how fast you start, Barnaby," she said. "It's about how consistently you move towards your goal."</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a sunny meadow filled with wildflowers, lived a speedy hare named Zoom and a thoughtful tortoise named Slowpoke. Zoom was known throughout the meadow for his incredible speed, and he never missed an opportunity to boast about it.</p>
# <p>One day, as Slowpoke munched on a dandelion, Zoom zipped by, leaving a cloud of dust. "Why so slow, Slowpoke?" Zoom chuckled. "At this rate, you'll never get anywhere!"</p>
# <p>Slowpoke, tired of Zoom's teasing, calmly replied, "Perhaps not as fast as you, Zoom, but I am determined. I may even be determined enough to beat you in a race."</p>
# <p>Zoom burst into laughter. "You? Beat me? That's the funniest thing I've ever heard!" But intrigued by the challenge, he agreed.</p>
# <p>The news of the race spread quickly, and soon all the animals in the meadow gathered to watch. A finish line was marked near the old oak tree at the edge of the woods.</p>
# <p>As the starting signal was given, Zoom shot off like an arrow, quickly disappearing from sight. Slowpoke, on the other hand, began his steady, deliberate pace.</p>
# <p>Zoom, confident in his lead, decided to take a nap under a shady tree. "Slowpoke will take ages to catch up," he thought. "I have plenty of time to rest."</p>
# <p>Meanwhile, Slowpoke continued his journey, one step at a time, never stopping, never resting. He focused on his goal, ignoring the taunts of the watching animals and the distance he still had to cover.</p>
# <p>When Zoom finally woke up, he stretched and yawned, glancing towards the finish line. To his horror, he saw Slowpoke nearing the old oak tree. Zoom darted off, putting all his energy into one final sprint, but it was too late.</p>
# <p>Slowpoke crossed the finish line, the winner of the race! The animals cheered, amazed by the tortoise's unwavering determination.</p>
# <p>Zoom, humbled and out of breath, approached Slowpoke. "I...I don't understand. How did you do it?"</p>
# <p>Slowpoke smiled. "By never giving up, Zoom. Perseverance and determination can take you further than speed alone."</p>
# <p>Moral: Perseverance and determination are more valuable than natural talent without focus.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc06a'>0.842</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #2dc96f'>0.766</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #2bc06a'>0.844</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dc96f'>0.766</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #2dc86f'>0.773</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #27ae60'>0.992</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2dca70'>0.764</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2cc66e'>0.789</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2dca70'>0.758</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2ecb70'>0.746</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #29b765'>0.914</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #2bc26b'>0.828</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #2bc06a'>0.844</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #2dc86f'
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Tell a story about a greedy dog who loses his bone to teach the lesson 'Don't be greedy; appreciate what you have.'</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>Original</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>DSPy</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the Beagle was a dog of simple needs: sunshine, naps, and bones. One sunny afternoon, he unearthed a particularly magnificent bone – a juicy beef bone with a knobble on the end, perfect for gnawing. Barnaby trotted home, tail wagging, already imagining the hours of blissful chewing ahead.</p>
# <p>As he crossed the rickety wooden bridge over the babbling creek, Barnaby glanced down. In the clear water, he saw another dog staring back at him, also with a magnificent bone in its mouth! Barnaby’s eyes widened. This bone looked even bigger, even juicier than his own!</p>
# <p>“Why should I have just <em>one</em> bone,” Barnaby thought, drool dripping from his jowls, “when I could have <em>two</em>?”</p>
# <p>Consumed by greed, Barnaby snarled at the reflection, hoping to scare the other dog into dropping its prize. He barked a loud, sharp <em>woof!</em></p>
# <p>Instantly, his own bone tumbled from his mouth and splashed into the creek. The reflection, along with its bone, vanished.</p>
# <p>Barnaby scrambled down the bank, frantic. He searched high and low, but the creek was too deep, the current too strong. His bone was gone.</p>
# <p>He sat on the bank, whimpering, empty-mouthed. The sun still shone, the naps still beckoned, but all Barnaby could think about was the lost bone. He had been so focused on getting more that he lost everything he already possessed. Now, he had no bone at all.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a sunny meadow, lived a dog named Barnaby. Barnaby loved bones more than anything in the world. One day, he found a particularly juicy bone. Delighted, he trotted home, his tail wagging furiously.</p>
# <p>As he crossed a small wooden bridge over a clear stream, Barnaby glanced down. He saw his reflection in the water, and it appeared to him as another dog, also with a bone. But this bone looked bigger and juicier than his own!</p>
# <p>Greedy Barnaby, forgetting all about the delicious bone in his mouth, snapped at the reflection, hoping to snatch the other dog's prize. But as he opened his mouth, his own bone tumbled into the water and sank to the bottom.</p>
# <p>Barnaby searched and searched, but his bone was gone forever. Sadly, he walked home, his stomach rumbling and his tail drooping. He had lost his own good fortune by trying to grab something that wasn't even real.</p>
# <p>Moral: Don't be greedy; appreciate what you have.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #2bc16b'>0.835</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #27ae60'>1.0</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #2cc36c'>0.816</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #5cca59'>0.688</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #53ca5e'>0.7</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Presence</td><td style='color: #2dc96f'>0.77</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Character Development</td><td style='color: #f0c010'>0.486</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Dialogue Quality</td><td style='color: #2bc06a'>0.844</td></tr>
#
#
# <tr><td><b>Narrative Engagement</b></td><td></td><td style='color: #2cc76e'>0.785</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Engaging Narrative</td><td style='color: #2bc36c'>0.82</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Imagery Use</td><td style='color: #2cc76e'>0.785</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Repetitive Elements</td><td style='color: #2dcb70'>0.75</td></tr>
#
#
# <tr><td><b>Language Appropriateness</b></td><td></td><td style='color: #29ba66'>0.896</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Language Simplicity</td><td style='color: #2cc66d'>0.793</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Length Appropriateness</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Moral and Cultural Sensitivity</b></td><td></td><td style='color: #2abc68'>0.879</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Moral Clarity</td><td style='color: #2abe69'>0.863</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Life Lesson Reiteration</td><td style='color: #2dc86f'>0.773</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Cultural Sensitivity</td><td style='color: #27ae60'>1.0</td></tr>
#
#
# <tr><td><b>Illustration Integration</b></td><td></td><td style='color: #2dca70'>0.762</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Illustration Suggestions</td><td style='color: #2dca70'>0.762</td></tr>
#
#
# <tr></tr>
# <tr><td>Total score</td><td></td><td style='color: #2cc46c'><b>0.809</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Story Structure</b></td><td></td><td style='color: #b2c62e'>0.581</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Plot Structure</td><td style='color: #2dc86e'>0.777</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Conflict Introduction</td><td style='color: #f0bd10'>0.477</td></tr>
# <tr><td></td><td style='font-weight: normal;'>Resolution Clarity</td><td style='color: #f0c10f'>0.488</td></tr>
#
#
# <tr><td><b>Character Development</b></td><td></td><td style='color: #e3c415'>0.517</td></tr>
# <tr><td></td><td style='font-weight: norma

# %% [markdown]
# # Optimizing Few Shots
#
# Details of the few shots optimization are similar. We use DSPy's `BOOTSTRAP_FEW_SHOT` algorithm here.
#
# We kick off a job first, then read the messages as the few shots are getting optimized and finally print the prompt with optimized few shots in it.

# %%
shot_optimization_status = client.prompt.optimize.start_job(
    scoring_spec=aesop_scoring_spec,
    initial_system_instruction=aesop_scoring_spec.description,
    examples=[{"llm_input": row["input"], "llm_output": row["output"]} for row in aesop_dataset],
    model_id="gpt-4o-mini",
    tuning_algorithm="DSPY",
    dspy_optimization_type="BOOTSTRAP_FEW_SHOT",
    use_chain_of_thought=True,
)

# %%
from withpi_utils import stream

for line in stream(client.prompt.optimize, shot_optimization_status):
  print(line)
# Out:
# LAUNCHING
# RUNNING
#
#   0%|          | 0/23 [00:00<?, ?it/s]
#
#   4%|4         | 1/23 [00:05<01:53,  5.16s/it]
#
#   9%|8         | 2/23 [00:12<02:14,  6.39s/it]
#
#   9%|8         | 2/23 [00:12<02:10,  6.20s/it]
# Bootstrapped 2 full traces after 2 examples for up to 10 rounds, amounting to 2 attempts.
# DONE

# %%
shot_optimization_status = client.prompt.optimize.retrieve(shot_optimization_status.job_id)
optimized_shots = json.dumps(shot_optimization_status.optimized_prompt_messages, indent=2)
print(optimized_shots)
# Out:
# [
#   {
#     "content": "Your input fields are:\n1. `input` (str): The input to the AI application\n\nYour output fields are:\n1. `reasoning` (str)\n2. `response` (str): The response from the AI application\n\nAll interactions will be structured in the following way, with the appropriate values filled in.\n\nInputs will have the following structure:\n\n[[ ## input ## ]]\n{input}\n\nOutputs will be a JSON object with the following fields.\n\n{\n  \"reasoning\": \"{reasoning}\",\n  \"response\": \"{response}\"\n}\n\nIn adhering to this structure, your objective is: \n        Write a children's story in the style of Aesop's Fables teaching a life lesson specified by the user.  Provide just the story with no extra content.",
#     "role": "system"
#   },
#   {
#     "content": "[[ ## input ## ]]\nWrite a fable involving a tortoise and a hare that emphasizes the value of perseverance and determination.\n\nRespond with a JSON object in the following order of fields: `reasoning`, then `response`.",
#     "role": "user"
#   },
#   {
#     "content": "{\n  \"reasoning\": \"In this fable, the classic story of the tortoise and the hare is reimagined to emphasize perseverance and determination as the keys to success. The characters' contrasting traits and their journey will illustrate the lesson effectively.\",\n  \"response\": \"Once upon a time, in a sunny meadow, there lived a hare named Hoppy and a tortoise named Tilly. Hoppy was known far and wide for his incredible speed. He would dash around the meadow, boasting about how no one could ever beat him in a race. Tilly, on the other hand, was slow and steady. She often spent her days plodding along, picking daisies and chatting with other animals.\\n\\nOne sunny day, Hoppy decided to challenge Tilly to a race. He laughed loudly, \\\"A race, Tilly? You? You'll never win! I'm the fastest creature in the whole meadow!\\\"\\n\\nTilly, undeterred by Hoppy's taunts, smiled serenely and replied, \\\"I may be slow, but I would love to race you, Hoppy.\\\"\\n\\nAll the animals gathered to watch, excited to see how this unusual race would unfold. They lined up at the starting point, and with a loud shout, the race began!\\n\\nHoppy sprinted forward, his long legs quickly carrying him far ahead, while Tilly started off slowly, one determined step at a time. As Hoppy raced ahead, he grew overconfident. \\\"I can take a nice break. Tilly is so far behind; I have plenty of time!\\\" He plopped down under a shady tree and fell asleep.\\n\\nMeanwhile, Tilly continued her steady pace, never stopping, never rushing. She passed the sleeping hare, who didn\\u2019t stir from his nap, and kept moving forward, one determined foot in front of the other.\\n\\nWhen Hoppy finally woke up, he was shocked to see Tilly nearing the finish line! \\\"Oh no!\\\" he cried, springing up. He dashed as fast as he could, but it was too late. Just as Tilly crossed the finish line, Hoppy arrived, panting and exhausted.\\n\\nAll the meadow animals cheered for Tilly, who smiled and humbly thanked them. Hoppy, on the other hand, learned a valuable lesson that day. \\\"I thought speed alone would win, but I see now that perseverance and determination are what truly matter.\\\"\\n\\nFrom that day on, Hoppy worked harder, practicing along with Tilly, understanding that while he was fast, it was Tilly's steady spirit that taught him the true meaning of determination. As for Tilly, she continued to remind everyone that slow and steady wins the race, not just with legs, but with heart.\\n\\nAnd so, the tortoise and the hare became the best of friends, proving that every creature has its strengths, and with perseverance, anything is possible.\"\n}",
#     "role": "assistant"
#   },
#   {
#     "content": "[[ ## input ## ]]\nSpin a tale with a squirrel and an owl teaching that clever thinking often trumps physical strength.\n\nRespond with a JSON object in the following order of fields: `reasoning`, then `response`.",
#     "role": "user"
#   },
#   {
#     "content": "{\n  \"reasoning\": \"The story illustrates the life lesson that clever thinking can be more effective than relying solely on physical strength. It showcases a squirrel outsmarting a stronger owl, demonstrating that intelligence and resourcefulness can prevail in challenging situations.\",\n  \"response\": \"In the heart of a lush, green forest, there lived a clever little squirrel named Sammy. Sammy was known far and wide for his quick thinking and nimble feet.  He loved to gather acorns and play games with his fellow woodland creatures.  However, in the same forest, nestled high in an ancient oak tree, lived an imposing owl named Olivia. With her magnificent wings and sharp talons, Olivia was deemed the strongest creature in the wood, and she wasn't shy about it.\\n\\nOne sunny afternoon, as Sammy scurried about collecting acorns, he overheard Olivia boasting to a group of admirers. \\u201cI am the mightiest creature in this forest! No one can outrun me or escape my grasp!\\u201d The animals nodded in agreement, a bit frightened of Olivia\\u2019s prowess.\\n\\nSammy, with a twinkle in his eye, felt a challenge brewing within him. \\u201cI bet I can outsmart you, Olivia!\\u201d he called out in a playful tone.\\n\\nOlivia, with her piercing gaze, fixed her eyes on Sammy. \\u201cYou think you can outsmart me, little squirrel? I\\u2019m not just strong; I\\u2019m wise too!\\\" She hooted with laughter. Intrigued, she accepted the challenge. \\u201cVery well, let\\u2019s see what you can do!\\u201d\\n\\nSammy had a plan. \\u201cLet\\u2019s have a race! We\\u2019ll start at this very tree, and whoever reaches the big rock across the creek first wins. The loser will have to give up the best acorn they can find!\\u201d Olivia nodded, thinking the race was a simple way to prove her superiority.\\n\\nThe woodland creatures gathered to watch the spectacle. Sammy, quick and agile, dashed up and down the branches, while Olivia took flight and soared high above. Underneath the trees, a tricky path lay ahead\\u2014a winding route filled with obstacles like fallen branches and thick underbrush.\\n\\nAs they neared the creek, Sammy suddenly halted and hid behind a bush. Olivia soared over, looking down for her little competitor. \\u201cWhere are you, Sammy?\\u201d she hooted, glancing around in confusion. \\n\\nSammy, waiting patiently, spotted a clever opportunity. He noticed that the creek had a narrow, moss-covered log stretching across it. With a spring in his step, he scampered along the log while Olivia was still searching the bushes. Just as Olivia realized what had happened, she turned to fly toward the rocky shore, but it was too late! Sammy had already reached the big rock.\\n\\nThe crowd erupted in cheers for the clever squirrel. Olivia puffed up her feathers, surprised but impressed. \\u201cYou may have won this time, Sammy,\\u201d she said, regaining her composure, \\u201cbut remember, strength has its own value. You\\u2019re lucky to be quick of mind.\\u201d\\n\\nSammy smiled, his eyes sparkling mischievously. \\u201cAnd you remind us all that while strength is important, clever thinking can turn the tide! Together, we make a balanced forest.\\u201d With that, Olivia conceded, and the two learned to respect their unique abilities. From that day on, they united their strengths and wits, leading the woodland creatures in games and encouraging everyone to embrace their own talents.\\n\\nAnd so, in the heart of the lush green forest, it was clear that clever thinking often trumps raw strength, and together they could accomplish wonderful things.\"\n}",
#     "role": "assistant"
#   },
#   {
#     "content": "[[ ## input ## ]]\n{{ input }}\n\nRespond with a JSON object in the following order of fields: `reasoning`, then `response`.",
#     "role": "user"
#   }
# ]

# %% [markdown]
# ## Next Steps
#
# Now you have an improved prompt on a small sample set.  You could deploy this now, but improving the training set or the scorer will give you better performance.  Check out the rest of the playgrounds to proceed from here.
