# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/colabs/Model_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://withpi.ai"><img src="https://play.withpi.ai/logo/logoFullBlack.svg" width="240"></a>
#
# <a href="https://code.withpi.ai"><font size="4">Documentation</font></a>
#
# <a href="https://build.withpi.ai"><font size="4">Copilot</font></a>

# %% [markdown]
# # Model Comparison
#
# Pi lets you objectively compare two models based on how they perform against questions you care about.  This notebook walks through using a Scoring System to do this evaluation.

# %% [markdown]
# ## Install and initialize SDK
#
# You'll need a `WITHPI_API_KEY` from https://build.withpi.ai/account/keys.  Add it to your notebook secrets (the key symbol) on the left.
#
# Run the cell below to install packages and load the SDK

# %%
# %%capture

# %pip install withpi withpi-utils litellm

import os
from google.colab import userdata
from withpi import PiClient

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

pi = PiClient()

# %% [markdown]
# ## Setup scoring system
#
# Let's say we're building an AI to generate stories in the style of Aesop's Fables.  In good test-driven development, we need to decide what we're looking for out of our system.  Initialize a Scoring System and score function:

# %%
scoring_spec = [{'question': q} for q in [
    "Does the response contain a clear beginning, middle, and end?",
    "Does the story follow a logical progression of events?",
    "Does the story resolve the conflict in a satisfying manner?",
    "Is the life lesson clearly conveyed in the story?",
    "Is the life lesson relevant to the input provided by the user?"
]]

def score(input, output):
  return pi.scoring_system.score(
    scoring_spec=scoring_spec,
    llm_input=input,
    llm_output=output,
)

# %% [markdown]
# ## Evaluate the scoring spec on different models.
#
# Let's try generating responses from a "big" model and a "small" one to compare scores.
#
# The cell below uses a simple prompt and a list of questions to evaluate.  It uses Gemini because you can get a free key on the left pane (select Gemini API keys).  You can use a different model (see https://docs.litellm.ai/docs/), or your own questions as you see fit.

# %%
from withpi_utils.colab import pretty_print_responses
import litellm

os.environ["GEMINI_API_KEY"] = userdata.get("GOOGLE_API_KEY")

system_prompt = """
Write a children's story in the style of Aesop's Fables teaching a life lesson
specified by the user. Provide just the story with no extra content.
"""

aesop_prompts = [
    "Slow and steady wins the race",
    "Be cautious with flattery",
    "Even the smallest friends can be the most helpful",
]

def generate(user: str, model: str) -> str:
    """generate passes the provided system and user prompts into the given model
    via LiteLLM"""
    messages = [
        {"content": system_prompt, "role": "system"},
        {"content": user, "role": "user"},
    ]
    return litellm.completion(model=model, messages=messages).choices[0].message.content


for prompt in aesop_prompts:
    small_model_output = generate(
        user=prompt,
        model="gemini/gemini-2.0-flash-lite",
    )
    big_model_output = generate(
        user=prompt,
        model="gemini/gemini-2.0-flash",
    )

    small_score = score(prompt, small_model_output)
    big_score = score(prompt, big_model_output)

    pretty_print_responses(
        header="#### Input:\n" + prompt,
        response1="#### Output:\n" + small_model_output,
        response2="#### Output:\n" + big_model_output,
        left_label="gemini/gemini-2.0-flash-lite",
        right_label="gemini/gemini-2.0-flash",
        scores_left=small_score,
        scores_right=big_score,
    )
    print("\n\n")
# Out:
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Slow and steady wins the race</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash-lite</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>The sun beat down upon the dusty track, and the race was about to begin! The Hare, swift and boasting, twitched his nose at the starting line. Beside him stood the Tortoise, calm and determined.</p>
# <p>"Well, this will be a short race, slowpoke," the Hare scoffed, twitching his nose again. "I'll be at the finish line before you’ve even taken your first step!"</p>
# <p>The Tortoise simply smiled and said, "We shall see."</p>
# <p>The starting gun fired! The Hare was off like a streak of lightning. He zoomed ahead, leaving a cloud of dust in his wake. The Tortoise, true to his nature, took a slow and steady step forward. Step by step, he began his journey.</p>
# <p>The Hare, confident in his speed, looked back and, seeing the Tortoise far behind, decided to take a nap under a shady tree. "Plenty of time to win this," he thought, and promptly fell asleep.</p>
# <p>Meanwhile, the Tortoise continued his slow but steady pace. He kept his head down, ignoring the tempting berries and the butterflies fluttering by. He focused on one step at a time, determined to reach the finish line.</p>
# <p>When the Hare finally awoke, he stretched and yawned. "Time to win this race!" he declared. He looked towards the finish line and was shocked! There, just a few paces away, was the Tortoise!</p>
# <p>With a desperate burst of speed, the Hare raced toward the finish line, but it was too late. The Tortoise, with a final, determined push, crossed the line first!</p>
# <p>The crowd cheered. The Hare hung his head in shame.</p>
# <p>The Tortoise, panting, smiled and said, "Slow and steady wins the race."</p>
# <p>And so, the Hare learned that day that it is better to be persistent and patient than to be boastful and lazy. </p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the Hare was known throughout the Whispering Woods for his speed. He could zip past a field of daisies before a bumblebee could even find the best blossom. He bragged about it constantly. "Look at me!" he'd shout, blurring by Mrs. Badger, "I'm faster than the wind!"</p>
# <p>One sunny morning, Penelope the Tortoise was sunning herself near the old oak tree. Barnaby hopped over, his nose twitching with amusement. "Well, well, well," he chuckled, "if it isn't Penelope the Pokey! Still inching along at your usual snail's pace?"</p>
# <p>Penelope sighed. She was used to Barnaby's teasing. "Good morning, Barnaby," she said calmly.</p>
# <p>"Morning?" Barnaby scoffed. "By the time you finish saying 'morning', I could run to the Singing River and back!"</p>
# <p>He paused, a mischievous glint in his eye. "Tell you what, Penelope. Let's have a race. From this oak tree to the top of Willow Hill. Whoever gets there first wins a basket of juicy berries."</p>
# <p>Penelope considered. She knew she couldn't possibly outrun Barnaby. But she was determined. "Alright, Barnaby," she said. "I accept your challenge."</p>
# <p>Barnaby burst into laughter. "You? Win? This will be easier than eating clover!"</p>
# <p>The next day, a crowd gathered. Squirrels chattered, birds tweeted, and even a grumpy old toad hopped over to watch. Barnaby and Penelope lined up at the base of the oak tree.</p>
# <p>"On your mark...get set...GO!" cried Rosie Robin.</p>
# <p>Barnaby shot off like a furry rocket. He was a blur of brown fur, disappearing in a cloud of dust. Penelope, on the other hand, started slowly but steadily, her little legs carrying her forward, one step at a time.</p>
# <p>Barnaby reached the halfway point in a flash. He looked back and saw Penelope was barely a speck in the distance. "Ha!" he thought. "Plenty of time for a nap."</p>
# <p>He found a shady spot under a berry bush and promptly fell asleep. The sun warmed his fur, and the gentle breeze lulled him into a deep slumber.</p>
# <p>Meanwhile, Penelope continued her journey, one slow, determined step after another. She didn't stop to rest, she didn't look back, she just kept going.</p>
# <p>Hours passed. Barnaby finally woke up with a start. "The race!" he cried, realizing how long he'd slept. He jumped up and raced toward Willow Hill, certain he could still win.</p>
# <p>But as he rounded the final bend, he saw something that made his ears droop. There, at the top of Willow Hill, munching on a basket of juicy berries, was Penelope the Tortoise.</p>
# <p>Barnaby stood there, panting and speechless. Penelope looked up and smiled. "Hello, Barnaby," she said gently. "It seems I won."</p>
# <p>Barnaby, humbled and defeated, could only nod. He had been so confident in his speed that he hadn't taken the race seriously. He'd been too busy boasting and napping to remember the importance of perseverance. Penelope, though slow, had kept her focus and won the day.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #29b966'>0.902</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27af61'><b>0.98</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Be cautious with flattery</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash-lite</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a sunny meadow, lived a clever Fox named Finley. Finley was known for his sharp wit and his love of a good meal. One day, he spotted a Crow perched high in a tree, holding a delicious piece of cheese in her beak. </p>
# <p>“Oh, what a beautiful bird!” Finley called up to the Crow, his voice dripping with honey. "Such magnificent feathers! They shimmer in the sunlight like a thousand tiny jewels."</p>
# <p>The Crow, who had rarely heard a kind word from anyone, puffed out her chest with pride.</p>
# <p>"And your voice!" Finley continued, "I've heard tell of the most beautiful singing, even more lovely than the nightingale. Surely, such a glorious bird as yourself must have a voice to match!"</p>
# <p>The Crow, completely taken in by Finley's flattery, forgot all about the cheese. She opened her beak wide to sing, "Caw!"</p>
# <p>Down tumbled the cheese, right into the waiting paws of the sly Fox. Finley gobbled it up in a flash.</p>
# <p>“My dear Crow,” Finley said, smirking as he wiped his mouth, “you are indeed a beautiful bird, but remember this: those who flatter only want something in return. Be careful not to trust sweet words more than your own good sense.”</p>
# <p>And with a final flick of his tail, Finley disappeared back into the woods.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby Badger loved berries. He loved squishy blueberries, tart raspberries, and plump blackberries most of all. One day, Barnaby was sniffing under a particularly large blackberry bush when he heard a voice.</p>
# <p>"Good morning, most handsome Barnaby!"</p>
# <p>Barnaby startled and looked up. Perched on a branch was Cecil Crow. Cecil was known for his booming caw and even boomier ego.</p>
# <p>"Er, good morning, Cecil," Barnaby mumbled, continuing his search for the juiciest berries.</p>
# <p>"Surely a badger as refined as you isn't content with just <em>any</em> blackberry," Cecil crooned. "No, no. A creature with such a gleaming nose and such impeccably trimmed claws deserves the best! And I, dear Barnaby, know where the <em>biggest</em>, <em>sweetest</em>, <em>most perfectly ripe</em> blackberries grow."</p>
# <p>Barnaby's ears perked up. "You do?"</p>
# <p>Cecil puffed out his chest. "Indeed! A secret patch, hidden away. But I only reveal it to those who truly appreciate the finer things in life, like… a badger with such a magnificent coat of fur."</p>
# <p>Barnaby blushed. He had always thought his fur was a little… ordinary.</p>
# <p>"Follow me, my discerning friend," Cecil said, taking flight. Barnaby eagerly followed, pushing through bushes and stumbling over roots, all the while Cecil showered him with compliments. "Such graceful movements for a badger! Such keen eyesight to navigate these tricky paths!"</p>
# <p>Finally, they arrived at a clearing. Barnaby's eyes widened. There, nestled in a hollow, were the biggest, shiniest blackberries he had ever seen.</p>
# <p>"Behold!" Cecil announced.</p>
# <p>Barnaby rushed forward, mouth watering. He grabbed a huge berry and popped it into his mouth. He chewed… and frowned. It tasted… awful. Bitter and hard.</p>
# <p>"What do you think?" Cecil asked, preening.</p>
# <p>Barnaby tried another berry. Still awful. "These… these aren't very good," he said, disappointed.</p>
# <p>Cecil chuckled. "Oh, they're perfectly adequate. But I needed to get you away from those <em>other</em> berries, the ones you were so diligently searching for." He hopped down to the base of a nearby tree and began pecking at a pile of discarded berry skins. "You see, <em>I</em> wanted those delicious berries all to myself. And your… well, your vanity made it so easy."</p>
# <p>Barnaby, realizing he’d been fooled, felt a pang of shame. He glared at Cecil, who was now cawing with laughter. Barnaby turned and trudged back to his original blackberry bush, a wiser badger. He found the berries there, while not the biggest, were sweet and satisfying.</p>
# <p><strong>Moral: Heed not the flattering tongue, for it often hides a selfish heart.</strong></p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #28b664'>0.93</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #e67526'>0.208</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #2bc26b'><b>0.828</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #2bc26b'>0.824</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #eca417'>0.387</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <t
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Even the smallest friends can be the most helpful</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash-lite</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a lush green meadow, lived a mighty Lion. He was King of the Beasts, strong and brave, and everyone trembled at his roar. One sweltering afternoon, as he lumbered through the tall grass, a sharp thorn pricked his paw. </p>
# <p>“Ouch!” roared the Lion, louder than thunder. He tried to pull it out, but the thorn was stubborn. He paced and roared, but the pain wouldn’t go away. He was trapped, unable to hunt or even walk properly.</p>
# <p>Nearby, a tiny Field Mouse peeked out from her burrow. She saw the great Lion's distress. “Is something wrong, your Majesty?” squeaked the Mouse, her voice barely audible.</p>
# <p>The Lion, annoyed at such a small creature, looked down. "Can't you see? I have a thorn stuck in my paw! And I, the King, am helpless!"</p>
# <p>The Field Mouse, without a moment’s hesitation, scurried towards the Lion's paw. With tiny teeth, she gnawed around the thorn, carefully pulling it free.</p>
# <p>The Lion, surprised by her bravery, felt the pain vanish. He looked at the tiny Mouse with respect. "You...you saved me," he mumbled, still a bit embarrassed.</p>
# <p>"Even the smallest friend can be the most helpful, your Majesty," squeaked the Mouse, before scurrying back to her burrow.</p>
# <p>From that day on, the Lion and the Field Mouse became the best of friends. And the Lion, remembering his humbling experience, learned that size isn't everything and that even the smallest among us can offer the greatest of assistance.</p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby Badger was boasting again. Perched on the highest rock in the meadow, he puffed out his chest. “I, Barnaby Badger, am the strongest in all the land! I can dig the deepest burrows, carry the heaviest stones, and scare away the fiercest foxes!”</p>
# <p>Below him, Millie Mouse trembled. Barnaby's booming voice always frightened her. She scurried behind a dandelion, trying to disappear.</p>
# <p>Suddenly, a loud SNAP echoed through the meadow. Barnaby yelped and tumbled off the rock, clutching his paw. A large branch had fallen from the old oak tree, trapping his foot beneath it.</p>
# <p>He roared in pain, struggling to free himself. “Help! Someone, help me! I am too strong to be defeated by a mere branch, but I need assistance!”</p>
# <p>Squirrels chattered nervously from the trees. Rabbits thumped their feet in alarm. But no one dared approach the furious, trapped badger.</p>
# <p>Millie Mouse, peeking from behind the dandelion, saw Barnaby’s distress. Though frightened, she knew she had to help. Taking a deep breath, she scurried towards the branch.</p>
# <p>Barnaby, noticing her approach, scoffed. “You? A tiny mouse? What can you possibly do? I need someone strong, like... well, like me!”</p>
# <p>Millie ignored his words. She examined the branch carefully. She noticed that a small root was wedged beneath it, preventing it from being lifted. Millie, being small and nimble, could easily reach it.</p>
# <p>Squeaking with effort, she gnawed at the root with her sharp little teeth. Slowly, patiently, she worked until finally, with a final snap, the root broke free.</p>
# <p>The branch shifted just enough for Barnaby to pull his paw out. He stared at Millie in astonishment.</p>
# <p>“You… you freed me?” he stammered, rubbing his sore paw.</p>
# <p>Millie nodded shyly. “The root was stuck,” she squeaked.</p>
# <p>Barnaby, for once, was speechless. He had always underestimated Millie, seeing only her small size. Now, he realized that her tininess had been her greatest strength.</p>
# <p>Barnaby gently nudged Millie with his nose. “Thank you, Millie. You were more helpful than anyone else could have been.”</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #2cc66e'>0.789</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #28b262'><b>0.958</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27ae60'><b>1.0</b></td></tr>
# </table>
#                 </div>
#             </div>

# %% [markdown]
# ## Next Steps
#
# Try using different models (Gemini Flash and Lite are quite similar for such an easy creative task).  Pick a different task.  Use different questions.
