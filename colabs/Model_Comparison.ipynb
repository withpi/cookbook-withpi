# %% [markdown]
# <a href="https://colab.research.google.com/github/withpi/cookbook-withpi/blob/main/colabs/Model_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://withpi.ai"><img src="https://play.withpi.ai/logo/logoFullBlack.svg" width="240"></a>
#
# <a href="https://code.withpi.ai"><font size="4">Documentation</font></a>
#
# <a href="https://build.withpi.ai"><font size="4">Copilot</font></a>

# %% [markdown]
# # Model Comparison
#
# Pi lets you objectively compare two models based on how they perform against questions you care about.  This notebook walks through using a Scoring System to do this evaluation.

# %% [markdown]
# ## Install and initialize SDK
#
# You'll need a `WITHPI_API_KEY` from https://build.withpi.ai/account/keys.  Add it to your notebook secrets (the key symbol) on the left.
#
# Run the cell below to install packages and load the SDK

# %%
# %%capture

# %pip install withpi withpi-utils litellm

import os
from google.colab import userdata
from withpi import PiClient

# Load the notebook secret into the environment so the Pi Client can access it.
os.environ["WITHPI_API_KEY"] = userdata.get('WITHPI_API_KEY')

pi = PiClient()

scoring_spec = [{'question': q} for q in [
    "Does the response contain a clear beginning, middle, and end?",
    "Does the story follow a logical progression of events?",
    "Does the story resolve the conflict in a satisfying manner?",
    "Is the life lesson clearly conveyed in the story?",
    "Is the life lesson relevant to the input provided by the user?"
]]

def score(example):
    return pi.scoring_system.score(
        llm_input=example["input"],
        llm_output=example["output"],
        scoring_spec=scoring_spec,
    )

# %% [markdown]
# ## Evaluate the scoring spec on different models.
#
# Let's try generating responses from a "big" model and a "small" one to compare scores.
#
# The cell below uses a simple prompt and a list of questions to evaluate.  It uses Gemini because you can get a free key on the left pane (select Gemini API keys).  You can use a different model (see https://docs.litellm.ai/docs/), or your own questions as you see fit.

# %%
from withpi_utils.colab import pretty_print_responses
import litellm

os.environ["GEMINI_API_KEY"] = userdata.get("GOOGLE_API_KEY")

system_prompt = """
Write a children's story in the style of Aesop's Fables teaching a life lesson
specified by the user. Provide just the story with no extra content.
"""

aesop_prompts = [
    "Slow and steady wins the race",
    "Be cautious with flattery",
    "Even the smallest friends can be the most helpful",
]

def generate(user: str, model: str) -> str:
    """generate passes the provided system and user prompts into the given model
    via LiteLLM"""
    messages = [
        {"content": system_prompt, "role": "system"},
        {"content": user, "role": "user"},
    ]
    return litellm.completion(model=model, messages=messages).choices[0].message.content


for prompt in aesop_prompts:
    small_model_output = generate(
        user=prompt,
        model="gemini/gemini-2.0-flash-lite",
    )
    big_model_output = generate(
        user=prompt,
        model="gemini/gemini-2.0-flash",
    )

    small_score = score({"input": prompt, "output": small_model_output})
    big_score = score({"input": prompt, "output": big_model_output})

    pretty_print_responses(
        header="#### Input:\n" + prompt,
        response1="#### Output:\n" + small_model_output,
        response2="#### Output:\n" + big_model_output,
        left_label="gemini/gemini-2.0-flash-lite",
        right_label="gemini/gemini-2.0-flash",
        scores_left=small_score,
        scores_right=big_score,
    )
    print("\n\n")
# Out:
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 80%; padding: 30px; border: 1px solid #ddd; background-color: #fff9f5;">
#                 <h4><h4>Input:</h4>
# <p>Slow and steady wins the race</p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash-lite</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a lush green meadow, lived a boastful Hare and a patient Tortoise. The Hare, with his long legs and lightning speed, was always bragging about how fast he was. "I can run faster than the wind!" he'd declare. "No creature can ever beat me in a race!"</p>
# <p>The Tortoise, on the other hand, was slow and steady. He never boasted, but simply went about his business at his own pace.</p>
# <p>One sunny afternoon, the Hare, tired of the Tortoise's quiet demeanor, challenged him to a race. The other animals gathered, eager to see such an odd pairing.</p>
# <p>The race began, and the Hare, with a burst of energy, zoomed ahead, leaving the Tortoise far behind. He was so far ahead that he decided to take a nap under a shady tree. "What's the point of rushing when the finish line is so far away?" he yawned, and promptly fell asleep.</p>
p></h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash-lite</h4>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f0f0f0; text-align:center;">
#                 <h4>gemini/gemini-2.0-flash</h4>
#             </div>
#         </div>
#         <div style="display: flex; gap: 20px;">
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Once upon a time, in a lush green meadow, lived a mighty Lion, the King of the Beasts. The Lion was strong and roared with a voice that shook the very ground. He ruled over all the animals, from the tallest Giraffe to the smallest Field Mouse.</p>
# <p>One sweltering afternoon, the Lion, while hunting, stumbled upon a cunning trap. A hunter had cleverly laid it, and the Lion, in his haste, was ensnared. He roared in fury and struggled with all his might, but the ropes held him fast.</p>
# <p>His roars echoed through the meadow, bringing terror to all who heard. The Giraffe, seeing his King's plight, stretched his long neck to the sky, but could not reach the ropes. The Elephant, with his enormous strength, pushed and pulled, but the trap was too cleverly made. One by one, the other animals tried to help, but their efforts proved futile.</p>
# <p>Finally, a tiny Field Mouse scurried onto the scene. Seeing the Lion trapped and in distress, she squeaked, "Don't worry, King! I shall help you!"</p>
# <p>The Lion scoffed. "You, a little mouse? What can you possibly do?"</p>
# <p>Ignoring the King's doubt, the Field Mouse began to gnaw at the ropes. Her tiny teeth worked tirelessly, and bit by bit, the strong bonds began to fray. Finally, after much effort, the last rope snapped. The Lion, free, roared his gratitude.</p>
# <p>"You, little Mouse," he said, humbled, "saved me when all the others failed."</p>
# <p>From that day on, the Lion never underestimated the power of even the smallest creature. And the Field Mouse was always treated with respect, showing that even the smallest friends can be the most helpful.</p>
# <p><strong>The Moral of the Story: Do not underestimate the power of anyone, for even the smallest among us can offer the greatest help.</strong></p>
#             </div>
#             <div style="width: 40%; padding: 10px; border: 1px solid #ddd;">
#                 <h4>Output:</h4>
# <p>Barnaby the Bear was preparing for the annual Berry Banquet. He was famed throughout the forest for his delicious berry pies, and this year he wanted to make the biggest, juiciest pie the forest had ever seen! He gathered baskets and baskets of plump blueberries, sweet raspberries, and tart cranberries.</p>
# <p>But as he hummed a happy tune, pushing his laden wheelbarrow up the hill, disaster struck! The wheel caught on a root, and with a crash, all the berries tumbled down the slope, scattering amongst the leaves and bushes. Barnaby sighed. He was too big and clumsy to pick them all up. "Oh dear, what am I going to do?" he groaned, feeling defeated.</p>
# <p>A tiny ant, Antoinette, watched from a nearby anthill. She had seen Barnaby's struggles. Though small, she knew she had to help. "Psst! Mr. Bear! Mr. Bear!" she called, waving her antennae.</p>
# <p>Barnaby looked down, surprised. "Hello there, little one. What can I do for you?"</p>
# <p>"We can help you!" Antoinette declared, and just then, hundreds of ants emerged from the anthill, ready and eager.</p>
# <p>Barnaby chuckled. "How can you possibly help? You're so tiny!"</p>
# <p>Antoinette puffed out her chest. "We may be small, but we are many! Each ant can carry a berry. We can gather them much faster than you can!"</p>
# <p>Barnaby, though doubtful, decided to give them a chance. He watched in amazement as the ants scurried among the fallen berries, each carrying one with determined effort. They formed a long, organized line, marching back up the hill to Barnaby's waiting baskets.</p>
# <p>Soon, all the berries were safely back in the wheelbarrow. Barnaby was astonished. "Wow! You little ants are amazing!" he exclaimed. "Thank you so much! You saved the Berry Banquet!"</p>
# <p>Antoinette smiled. "You see, Mr. Bear? Even the smallest friends can be the most helpful." And with that, the ants marched back to their anthill, leaving Barnaby with a full wheelbarrow and a grateful heart. He learned that day that size doesn't matter when it comes to friendship and helpfulness.</p>
#             </div>
#         </div>
#
#             <div style="display: flex; gap: 20px;">
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #27b061'>0.977</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27ae60'><b>0.995</b></td></tr>
# </table>
#                 </div>
#                 <div style="width: 40%; padding: 10px; border: 1px solid #ddd; background-color: #f2f1fe;">
#
#   <style>
#   table {
#     border-collapse: collapse; /* Ensures borders don't double up */
#     width: 100%; /* Optional: makes the table full width */
#   }
#
#   tr {
#     border-bottom: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-top: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#
#   th, td {
#     font-weight: bold;
#     padding: 4px; /* Adds some spacing */
#     text-align: left; /* Aligns text to the left */
#     border-right: 1px solid #ccc; /* Sets a bottom border for each row */
#     border-left: 1px solid #ccc; /* Sets a bottom border for each row */
#   }
#   img {
#     width: 30%;
#   }
#   </style>
#   <table><tr><td><b>Does the response contain a clear beginning, middle, and end?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story follow a logical progression of events?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Does the story resolve the conflict in a satisfying manner?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson clearly conveyed in the story?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td><b>Is the life lesson relevant to the input provided by the user?</b></td><td style='color: #27ae60'>1.0</td><td></td></tr>
# <tr><td>Total score</td><td></td><td style='color: #27ae60'><b>1.0</b></td></tr>
# </table>
#                 </div>

# %% [markdown]
# ## Next Steps
#
# Try using different models (Gemini Flash and Lite are quite similar for such an easy task).  Pick a different task.  Use different questions.
